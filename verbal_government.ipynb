# %% [markdown]
# #  Глагольное управление для прямого дополнения

# %%
import pickle
import matplotlib.pyplot as plt
from collections import Counter, defaultdict
import numpy as np
import pandas as pd
from copy import deepcopy
from tqdm import tqdm

# %%
def read_correct(filename: str):
    verb_correct = {}
    with open(filename, "rt") as in_file:
        for line in in_file:
            if len(line) <= 1 or line[0] == '#':
                continue
            verb = line[:21].strip()
            verb_correct[verb] = {}
            cases = line[21:].split(',')
            for pair in cases[:-1]:
                pair = pair.strip()
                cas = pair[:3]
                freq = pair[4:].strip()
#                 print(f"'{cas}'", f"'{freq}'")
                verb_correct[verb][cas] = not (freq == '0.0' or freq[0] == '-')
    return verb_correct

# %%
verb_correct = read_correct("verbal_government_200_300.csv")

# %%
verb_correct
# Out:
# {'одобрить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'действовать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'запретить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'заключить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'учитывать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': False,
#   'Loc': False},
#  'пытаться': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': False,
#   'Loc': False},
#  'лежать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'отправить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'заметить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'попросить': {'Nom': True,
#   'Gen': True,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'любить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'убить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'окончить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'определять': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'привлечь': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'предполагать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'вестись': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'вернуть': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'ставить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'бросить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'захватить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'выиграть': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'потребовать': {'Nom': True,
#   'Gen': True,
#   'Dat': False,
#   'Acc': True,
#   'Ins': False,
#   'Loc': False},
#  'помогать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'следовать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'расти': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'услышать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'образовать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'произвести': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'отменить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'возглавлять': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': False,
#   'Loc': False},
#  'выделить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'призывать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'вынести': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': False,
#   'Loc': False},
#  'заключаться': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': False,
#   'Ins': True,
#   'Loc': False},
#  'готовить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'удаться': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': False,
#   'Loc': False},
#  'испытывать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'обсудить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'закончиться': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': False,
#   'Ins': True,
#   'Loc': False},
#  'исполнять': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'избрать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'казаться': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'ответить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'оценивать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'продать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'высказать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'рассматриваться': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': False,
#   'Ins': True,
#   'Loc': False},
#  'понимать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'изучать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'заняться': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': False,
#   'Ins': True,
#   'Loc': False},
#  'упасть': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': False,
#   'Ins': True,
#   'Loc': False},
#  'превышать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': False,
#   'Loc': False},
#  'подтверждать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'отражать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'остановить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'уделять': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': False,
#   'Loc': False},
#  'прийтись': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'встретить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'повысить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'предъявить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'уничтожить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'заменить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'заставить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'понять': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'чувствовать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'рассказывать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'указать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'отвечать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'закончить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'рекомендовать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'увеличиться': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': False,
#   'Ins': True,
#   'Loc': False},
#  'открывать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'попасть': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'свидетельствовать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': False,
#   'Loc': False},
#  'начинаться': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': False,
#   'Ins': True,
#   'Loc': False},
#  'читать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'возглавить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': False,
#   'Loc': False},
#  'совершать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'завершиться': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': False,
#   'Ins': True,
#   'Loc': False},
#  'решать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'продемонстрировать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'объяснять': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'содержаться': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': False,
#   'Ins': False,
#   'Loc': False},
#  'планировать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': False,
#   'Loc': False},
#  'собирать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'наградить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'управлять': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': False,
#   'Ins': True,
#   'Loc': False},
#  'подчёркивать': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'перевести': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'поступить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'обусловить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'производить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'сократить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'предусмотреть': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'посетить': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'ограничить': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'выдать': {'Nom': True,
#   'Gen': False,
#   'Dat': True,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False},
#  'зависеть': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': False,
#   'Ins': False,
#   'Loc': False},
#  'появляться': {'Nom': True,
#   'Gen': False,
#   'Dat': False,
#   'Acc': True,
#   'Ins': True,
#   'Loc': False}}

# %%
with open("comb_verb_noun.pickle", "rb") as in_file:
    verb_comb = pickle.load(in_file)

# %%
exceptional = []
too_short = []

for verb, comb1 in verb_comb.items():
    for prep, comb2 in comb1.items():
        for cas, comb3 in comb2.items():
            if len(comb3) < 3:
                too_short.append((verb, prep, cas))
                continue
            s_combs = sorted(comb3.items(), key=lambda x:x[1], reverse=True)
            if s_combs[0][1] > 4 * s_combs[1][1] and s_combs[0][1] > 50:
                exceptional.append((verb, prep, cas, s_combs[0][0]))
            
for short in too_short:
    del verb_comb[short[0]][short[1]][short[2]]
    
for ex in exceptional:
    del verb_comb[ex[0]][ex[1]][ex[2]][ex[3]]

# %%
exceptional
# Out:
# [('случиться', '_', 'Gen', 'год'),
#  ('просиять', 'В', 'Loc', 'земля'),
#  ('просиять', '_', 'Nom', 'лицо'),
#  ('просиять', '_', 'Ins', 'улыбка'),
#  ('приступить', 'НА', 'Acc', 'день'),
#  ('приступить', 'ВО', 'Acc', 'вторник'),
#  ('приступить', 'КО', 'Dat', 'этап'),
#  ('приступить', 'ПОД', 'Ins', 'руководство'),
#  ('рассказать', 'СО', 'Ins', 'ссылка'),
#  ('рассказать', 'ДЛЯ', 'Gen', 'начало'),
#  ('рассказать', 'С', 'Gen', 'начало'),
#  ('рассказать', 'ПРИ', 'Loc', 'встреча'),
#  ('рассказать', 'В КАЧЕСТВЕ', 'Gen', 'пример'),
#  ('рассказать', 'ВО', 'Acc', 'вторник'),
#  ('рассказать', 'БЕЗ', 'Gen', 'утайка'),
#  ('рассказать', 'ДО', 'Gen', 'конец'),
#  ('стоять', '_', 'Acc', 'время'),
#  ('стоять', '_', 'Loc', 'посередине'),
#  ('стоять', 'ВО', 'Loc', 'двор'),
#  ('стоять', 'С', 'Gen', 'сторона'),
#  ('стоять', 'С', 'Acc', 'минута'),
#  ('стоять', 'О', 'Acc', 'бок'),
#  ('стоять', 'РАДИ', 'Gen', 'справедливость'),
#  ('стоять', 'ПОСРЕДИ', 'Gen', 'комната'),
#  ('стоять', 'ВОКРУГ', 'Gen', 'стол'),
#  ('получать', '_', 'Ins', 'образ'),
#  ('получать', '_', 'Loc', 'год'),
#  ('получать', 'СО', 'Gen', 'спутник'),
#  ('получать', 'В ХОДЕ', 'Gen', 'гонка'),
#  ('получать', 'ВНЕ', 'Gen', 'зависимость'),
#  ('получать', 'ПЕРЕД', 'Ins', 'выбор'),
#  ('быть', '_', 'Loc', '.'),
#  ('быть', 'НА', 'Acc', 'момент'),
#  ('быть', 'ПО', 'Acc', 'сторона'),
#  ('быть', 'ВО', 'Acc', 'время'),
#  ('быть', 'С', 'Ins', 'учёт'),
#  ('быть', 'БЕЗ', 'Gen', 'сомнение'),
#  ('быть', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('быть', 'ОТ', 'Gen', 'брак'),
#  ('быть', 'СО', 'Ins', 'время'),
#  ('быть', 'КО', 'Dat', 'время'),
#  ('родиться', '_', 'Loc', '.'),
#  ('родиться', 'НА', 'Acc', 'свет'),
#  ('родиться', 'ОТ', 'Gen', 'брак'),
#  ('родиться', 'ВО', 'Acc', 'время'),
#  ('родиться', 'ВНЕ', 'Gen', 'брак'),
#  ('родиться', 'ЧЕРЕЗ', 'Acc', 'год'),
#  ('переехать', '_', 'Nom', 'семья'),
#  ('переехать', '_', 'Loc', '.'),
#  ('переехать', 'ПО', 'Loc', 'окончание'),
#  ('переехать', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('получить', '_', 'Loc', '.'),
#  ('получить', 'В', 'Loc', 'результат'),
#  ('получить', 'СО', 'Ins', 'время'),
#  ('получить', 'ДО', 'Gen', 'конец'),
#  ('получить', 'ПО МЕРЕ', 'Gen', 'освобождение'),
#  ('учиться', 'ПО', 'Loc', 'окончание'),
#  ('учиться', '_', 'Loc', '.'),
#  ('учиться', 'ЗА', 'Acc', 'граница'),
#  ('учиться', 'ЗА', 'Ins', 'граница'),
#  ('учиться', 'ПОД', 'Ins', 'руководство'),
#  ('учиться', 'ВО', 'Acc', 'смена'),
#  ('учиться', 'ПОСЛЕ', 'Gen', 'окончание'),
#  ('рукоположить', 'ПО', 'Loc', 'окончание'),
#  ('рукоположить', 'ДЛЯ', 'Gen', 'служение'),
#  ('продолжать', 'ПО', 'Acc', 'день'),
#  ('продолжать', 'К', 'Dat', 'сожаление'),
#  ('продолжать', 'В ТЕЧЕНИЕ', 'Gen', 'период'),
#  ('продолжать', 'ВНЕ', 'Gen', 'зависимость'),
#  ('приглашать', 'ДЛЯ', 'Gen', 'участие'),
#  ('жить', '_', 'Ins', 'жизнь'),
#  ('жить', 'ВО', 'Acc', 'время'),
#  ('жить', 'ЗА', 'Acc', 'счёт'),
#  ('жить', 'О', 'Acc', 'бок'),
#  ('жить', 'СРЕДИ', 'Gen', 'человек'),
#  ('жить', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('жить', 'ПЕРЕД', 'Ins', 'война'),
#  ('жить', 'ДЛЯ', 'Gen', 'человек'),
#  ('провести', '_', 'Loc', '.'),
#  ('провести', 'С', 'Ins', 'цель'),
#  ('провести', 'ВО', 'Acc', 'вторник'),
#  ('провести', 'У', 'Gen', 'здание'),
#  ('провести', 'О', 'Acc', 'бок'),
#  ('провести', 'ОТ', 'Gen', 'имя'),
#  ('приходить', 'К', 'Dat', 'вывод'),
#  ('приходить', 'С', 'Gen', 'работа'),
#  ('приходить', 'ВО', 'Loc', 'сон'),
#  ('приходить', 'ВО ВРЕМЯ', 'Gen', 'еда'),
#  ('приходить', 'СО СТОРОНЫ', 'Gen', 'залив'),
#  ('принять', '_', 'Nom', 'решение'),
#  ('принять', '_', 'Gen', 'человек'),
#  ('принять', 'НА', 'Acc', 'вооружение'),
#  ('принять', 'К', 'Dat', 'сведение'),
#  ('принять', 'ВНЕ', 'Gen', 'зависимость'),
#  ('принять', 'БЕЗ', 'Gen', 'голосование'),
#  ('принять', 'ВО', 'Loc', 'чтение'),
#  ('принять', 'ВО', 'Acc', 'внимание'),
#  ('принять', 'ИЗ', 'Gen', 'рука'),
#  ('принять', 'ДО', 'Gen', 'конец'),
#  ('принять', 'ОКОЛО', 'Gen', 'человек'),
#  ('состояться', 'НА', 'Acc', 'день'),
#  ('состояться', 'С', 'Gen', 'космодром'),
#  ('состояться', 'ВО', 'Acc', 'вторник'),
#  ('состояться', 'ДО', 'Gen', 'конец'),
#  ('состояться', 'В СВЯЗИ С', 'Ins', 'рассмотрение'),
#  ('идти', '_', 'Nom', 'речь'),
#  ('идти', 'О', 'Acc', 'бок'),
#  ('идти', 'ДО', 'Gen', 'конец'),
#  ('идти', 'КО', 'Dat', 'дно'),
#  ('идти', 'МИМО', 'Gen', 'дом'),
#  ('идти', 'ПОД', 'Ins', 'флаг'),
#  ('идти', 'ИЗО', 'Gen', 'рот'),
#  ('идти', 'С ПОМОЩЬЮ', 'Gen', 'наклейка'),
#  ('понравиться', 'В', 'Loc', 'целое'),
#  ('понравиться', 'С', 'Gen', 'взгляд'),
#  ('понравиться', 'ПО', 'Dat', 'слово'),
#  ('строить', 'С', 'Gen', 'нуль'),
#  ('строить', 'ВО', 'Acc', 'время'),
#  ('строить', 'ПРИ', 'Loc', 'поддержка'),
#  ('организовать', 'С', 'Ins', 'цель'),
#  ('организовать', '_', 'Loc', '.'),
#  ('организовать', 'ПО', 'Acc', 'сторона'),
#  ('организовать', 'В ХОДЕ', 'Gen', 'сессия'),
#  ('организовать', 'ОТ', 'Gen', 'имя'),
#  ('организовать', 'У', 'Gen', 'здание'),
#  ('публиковать', 'СО', 'Ins', 'ссылка'),
#  ('уменьшиться', '_', 'Ins', 'образ'),
#  ('уменьшиться', 'СО', 'Ins', 'время'),
#  ('уменьшиться', 'С', 'Gen', 'начало'),
#  ('уменьшиться', 'В СООТВЕТСТВИИ С', 'Ins', 'условие'),
#  ('стать', '_', 'Loc', '.'),
#  ('стать', 'СО', 'Ins', 'время'),
#  ('стать', 'ИЗО', 'Gen', 'сила'),
#  ('иметь', 'ПО', 'Acc', 'день'),
#  ('иметь', 'СО', 'Ins', 'ссылка'),
#  ('иметь', 'В СВЯЗИ С', 'Ins', 'рассмотрение'),
#  ('иметь', 'СРЕДИ', 'Gen', 'награда'),
#  ('иметь', 'ВО', 'Acc', 'время'),
#  ('укрываться', '_', 'Nom', 'боевик'),
#  ('укрываться', '_', 'Acc', 'время'),
#  ('укрываться', 'ПО', 'Dat', 'данные'),
#  ('укрываться', 'НА', 'Loc', 'территория'),
#  ('проводить', 'С', 'Ins', 'цель'),
#  ('проводить', 'В ХОДЕ', 'Gen', 'сессия'),
#  ('проводить', 'ОТ', 'Gen', 'имя'),
#  ('проводить', 'ПО МЕРЕ', 'Gen', 'необходимость'),
#  ('объясняться', 'ВО', 'Loc', 'многое'),
#  ('объясняться', 'НА', 'Acc', 'взгляд'),
#  ('напоминать', 'ВО', 'Loc', 'многое'),
#  ('напоминать', 'ДО', 'Gen', 'боль'),
#  ('напоминать', 'ПОД', 'Acc', 'поп'),
#  ('определить', 'ВО', 'Loc', 'многое'),
#  ('определить', 'ПО', 'Loc', 'окончание'),
#  ('определить', 'ИЗ', 'Gen', 'расчёт'),
#  ('определить', 'ДО', 'Gen', 'конец'),
#  ('выбирать', 'С', 'Ins', 'учёт'),
#  ('обсуждаться', '_', 'Nom', 'вопрос'),
#  ('обсуждаться', 'ВО', 'Acc', 'вторник'),
#  ('обсуждаться', 'ПО', 'Dat', 'слово'),
#  ('обсуждаться', 'БЕЗ', 'Gen', 'участие'),
#  ('вызывать', 'ПО', 'Acc', 'день'),
#  ('вызывать', 'С', 'Ins', 'учёт'),
#  ('вызывать', 'В КАЧЕСТВЕ', 'Gen', 'свидетель'),
#  ('попросить', '_', 'Nom', 'президент'),
#  ('попросить', '_', 'Gen', 'помощь'),
#  ('попросить', 'ОТ', 'Gen', 'имя'),
#  ('попросить', 'К', 'Dat', 'телефон'),
#  ('отметить', 'С', 'Ins', 'удовлетворение'),
#  ('отметить', 'В СВЯЗИ С', 'Ins', 'вопрос'),
#  ('отметить', 'СО', 'Gen', 'сторона'),
#  ('отметить', 'СО', 'Ins', 'ссылка'),
#  ('отметить', 'ВО', 'Acc', 'вторник'),
#  ('отметить', 'РАДИ', 'Gen', 'справедливость'),
#  ('измениться', '_', 'Ins', 'образ'),
#  ('измениться', 'С', 'Gen', 'момент'),
#  ('измениться', 'СО', 'Gen', 'время'),
#  ('измениться', 'СО', 'Ins', 'время'),
#  ('измениться', 'ДО', 'Gen', 'неузнаваемость'),
#  ('находиться', 'НА', 'Acc', 'момент'),
#  ('находиться', '_', 'Ins', 'образ'),
#  ('находиться', '_', 'Acc', 'время'),
#  ('находиться', 'У', 'Gen', 'власть'),
#  ('находиться', 'С', 'Ins', 'визит'),
#  ('находиться', 'СО', 'Gen', 'время'),
#  ('находиться', 'ЧЕРЕЗ', 'Acc', 'дорога'),
#  ('находиться', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('находиться', 'В ХОДЕ', 'Gen', 'война'),
#  ('находиться', 'ИЗ', 'Gen', 'число'),
#  ('находиться', 'ВОПРЕКИ', 'Dat', 'договорённость'),
#  ('находиться', 'КО', 'Dat', 'время'),
#  ('оставаться', '_', 'Gen', 'время'),
#  ('оставаться', '_', 'Acc', 'время'),
#  ('оставаться', 'ПО', 'Acc', 'день'),
#  ('оставаться', 'У', 'Gen', 'власть'),
#  ('оставаться', 'СО', 'Gen', 'время'),
#  ('оставаться', 'СРЕДИ', 'Gen', 'стать'),
#  ('оставаться', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('отмечать', 'С', 'Ins', 'удовлетворение'),
#  ('отмечать', 'С', 'Gen', 'сторона'),
#  ('отмечать', 'СО', 'Gen', 'сторона'),
#  ('отмечать', 'СО', 'Ins', 'ссылка'),
#  ('посвящать', '_', 'Nom', 'газета'),
#  ('обстоять', '_', 'Nom', 'дело'),
#  ('обстоять', '_', 'Gen', 'дело'),
#  ('обстоять', '_', 'Ins', 'образ'),
#  ('обстоять', 'НА', 'Loc', 'дело'),
#  ('обстоять', 'ПРИ', 'Loc', 'замер'),
#  ('обстоять', 'ИЗ', 'Gen', 'страна'),
#  ('обстоять', 'К', 'Dat', 'сожаление'),
#  ('касаться', 'ПО', 'Dat', 'слово'),
#  ('касаться', 'НА', 'Acc', 'раз'),
#  ('касаться', 'ВНЕ', 'Gen', 'зависимость'),
#  ('касаться', 'ВО ВРЕМЯ', 'Gen', 'удар'),
#  ('ждать', 'С', 'Ins', 'нетерпение'),
#  ('ждать', 'ПО', 'Acc', 'сторона'),
#  ('ждать', 'ВО', 'Acc', 'вторник'),
#  ('ждать', 'СО', 'Gen', 'день'),
#  ('ждать', 'СО', 'Ins', 'страх'),
#  ('протекать', '_', 'Nom', 'река'),
#  ('протекать', 'МИМО', 'Gen', 'деревня'),
#  ('бороться', 'ДО', 'Gen', 'конец'),
#  ('бороться', 'ИЗ', 'Gen', 'сила'),
#  ('бороться', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('бороться', 'ПРИ', 'Loc', 'поддержка'),
#  ('приходиться', 'НА', 'Acc', 'доля'),
#  ('приходиться', 'ВО', 'Acc', 'время'),
#  ('приходиться', 'ЗА', 'Ins', 'неимение'),
#  ('видеть', '_', 'Ins', 'глаз'),
#  ('видеть', 'ВОЗЛЕ', 'Gen', 'дом'),
#  ('видеть', 'ИЗ', 'Gen', 'окно'),
#  ('видеть', 'ВО', 'Loc', 'сон'),
#  ('видеть', 'НАД', 'Ins', 'голова'),
#  ('произойти', 'ВО', 'Acc', 'вторник'),
#  ('произойти', 'СО', 'Gen', 'время'),
#  ('вывести', 'С', 'Gen', 'территория'),
#  ('вывести', 'ДО', 'Gen', 'конец'),
#  ('вывести', 'ПОД', 'Acc', 'рука'),
#  ('вывести', 'ВО', 'Acc', 'двор'),
#  ('комментировать', '_', 'Ins', 'образ'),
#  ('комментировать', 'ПО', 'Dat', 'просьба'),
#  ('брать', 'В', 'Acc', 'рука'),
#  ('брать', 'ВО', 'Acc', 'внимание'),
#  ('брать', 'ПОД', 'Ins', 'председательство'),
#  ('брать', 'ОТ', 'Gen', 'жизнь'),
#  ('остаться', 'ПО', 'Loc', 'окончание'),
#  ('остаться', 'ПРИ', 'Loc', 'мнение'),
#  ('остаться', 'СО', 'Gen', 'время'),
#  ('расследовать', '_', 'Ins', 'образ'),
#  ('расследовать', 'ДО', 'Gen', 'конец'),
#  ('совершить', '_', 'Loc', '.'),
#  ('совершить', '_', 'Dat', 'хиротония'),
#  ('совершить', 'ИЗ', 'Gen', 'побуждение'),
#  ('совершить', 'НА', 'Loc', 'территория'),
#  ('совершить', 'НА', 'Acc', 'день'),
#  ('совершить', 'ОТ', 'Gen', 'имя'),
#  ('совершить', 'СО', 'Gen', 'время'),
#  ('совершить', 'ВОЗЛЕ', 'Gen', 'дом'),
#  ('совершить', 'ВСЛЕДСТВИЕ', 'Gen', 'исполнение'),
#  ('переходить', 'СО', 'Ins', 'время'),
#  ('переходить', 'ИЗ', 'Gen', 'рука'),
#  ('переходить', 'ПОСЛЕ', 'Gen', 'смерть'),
#  ('переходить', 'ВО', 'Acc', 'владение'),
#  ('переходить', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('связать', 'ВО', 'Loc', 'многое'),
#  ('связать', 'ЗА', 'Ins', 'спина'),
#  ('связать', 'В ТЕЧЕНИЕ', 'Gen', 'период'),
#  ('уходить', '_', 'Ins', 'корень'),
#  ('уходить', '_', 'Gen', 'время'),
#  ('уходить', 'С', 'Ins', 'голова'),
#  ('уходить', 'ВО ВРЕМЯ', 'Gen', 'наводнение'),
#  ('справляться', 'О', 'Loc', 'здоровье'),
#  ('слышать', 'ИЗ', 'Gen', 'уста'),
#  ('слышать', 'ЗА', 'Ins', 'спина'),
#  ('слышать', 'ВО', 'Loc', 'сон'),
#  ('слышать', 'СКВОЗЬ', 'Acc', 'сон'),
#  ('слышать', 'СО', 'Gen', 'сторона'),
#  ('доверять', 'В', 'Acc', 'время'),
#  ('доверять', 'ДО', 'Gen', 'конец'),
#  ('решить', 'ЗА', 'Acc', 'время'),
#  ('решить', 'ДО', 'Gen', 'конец'),
#  ('решить', 'СО', 'Ins', 'время'),
#  ('обладать', 'С', 'Ins', 'учёт'),
#  ('пользоваться', '_', 'Gen', 'человек'),
#  ('пользоваться', 'ВО', 'Loc', 'мир'),
#  ('пользоваться', 'ВО', 'Acc', 'время'),
#  ('пользоваться', 'СО', 'Gen', 'время'),
#  ('отправиться', '_', 'Acc', 'раз'),
#  ('отправиться', '_', 'Loc', '.'),
#  ('отправиться', 'ДО', 'Gen', 'конец'),
#  ('отправиться', 'СО', 'Gen', 'станция'),
#  ('отправиться', 'ВО', 'Loc', 'половина'),
#  ('отправиться', 'КО', 'Dat', 'двор'),
#  ('встречаться', 'ДЛЯ', 'Gen', 'обсуждение'),
#  ('встречаться', 'ПОД', 'Ins', 'название'),
#  ('встречаться', 'ОКОЛО', 'Gen', 'год'),
#  ('заехать', 'ВО', 'Acc', 'двор'),
#  ('узнать', 'НА', 'Acc', 'день'),
#  ('узнать', 'БЕЗ', 'Gen', 'труд'),
#  ('узнать', 'СО', 'Ins', 'время'),
#  ('узнать', 'ДО', 'Gen', 'конец'),
#  ('предложить', '_', 'Loc', '.'),
#  ('предложить', 'ПОД', 'Acc', 'конец'),
#  ('предложить', 'ВО', 'Acc', 'вторник'),
#  ('предложить', 'СО', 'Gen', 'сторона'),
#  ('предложить', 'У', 'Gen', 'скала'),
#  ('предложить', 'КО', 'Dat', 'чтение'),
#  ('предложить', 'ОТ', 'Gen', 'имя'),
#  ('ехать', '_', 'Gen', 'фургон'),
#  ('ехать', 'БЕЗ', 'Gen', 'остановка'),
#  ('ехать', 'СО', 'Ins', 'скорость'),
#  ('ехать', 'В КАЧЕСТВЕ', 'Gen', 'пассажир'),
#  ('продолжить', 'НА', 'Loc', 'сессия'),
#  ('продолжить', 'НА', 'Acc', 'день'),
#  ('продолжить', 'ПОД', 'Ins', 'руководство'),
#  ('продолжить', 'ВО', 'Acc', 'вторник'),
#  ('продолжить', 'В ХОДЕ', 'Gen', 'сессия'),
#  ('продолжить', 'ВНЕ', 'Gen', 'зависимость'),
#  ('продолжить', 'СО', 'Gen', 'сторона'),
#  ('писать', '_', 'Loc', '.'),
#  ('писать', 'О', 'Loc', 'влияние'),
#  ('писать', 'ВО', 'Acc', 'вторник'),
#  ('писать', 'СО', 'Gen', 'слово'),
#  ('писать', 'СО', 'Ins', 'ссылка'),
#  ('писать', 'ПОД', 'Ins', 'псевдоним'),
#  ('писать', 'ПОД', 'Acc', 'диктовка'),
#  ('писать', 'К', 'Dat', 'пример'),
#  ('задавать', '_', 'Acc', 'вопрос'),
#  ('задавать', '_', 'Gen', 'вопрос'),
#  ('составлять', '_', 'Ins', 'образ'),
#  ('составлять', '_', 'Loc', '.'),
#  ('составлять', 'ДЛЯ', 'Gen', 'сравнение'),
#  ('составлять', 'С', 'Ins', 'учёт'),
#  ('составлять', 'БЕЗ', 'Gen', 'учёт'),
#  ('составлять', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('составлять', 'В ХОДЕ', 'Gen', 'торг'),
#  ('составлять', 'ВНЕ', 'Gen', 'зависимость'),
#  ('назвать', '_', 'Loc', '.'),
#  ('назвать', 'В', 'Acc', 'честь'),
#  ('назвать', 'ПО', 'Dat', 'имя'),
#  ('назвать', 'ПО', 'Loc', 'окончание'),
#  ('назвать', 'СО', 'Gen', 'сторона'),
#  ('назвать', 'ВО', 'Acc', 'вторник'),
#  ('назвать', 'ДО', 'Gen', 'конец'),
#  ('делиться', 'БЕЗ', 'Gen', 'остаток'),
#  ('делиться', 'С', 'Gen', 'точка'),
#  ('делиться', 'В', 'Acc', 'очередь'),
#  ('крыться', '_', 'Nom', 'причина'),
#  ('крыться', 'ЗА', 'Ins', 'слово'),
#  ('крыться', 'НА', 'Acc', 'взгляд'),
#  ('крыться', 'НА', 'Loc', 'дело'),
#  ('использовать', '_', 'Ins', 'образ'),
#  ('использовать', 'ПО', 'Acc', 'день'),
#  ('использовать', 'С', 'Ins', 'цель'),
#  ('использовать', 'ВНЕ', 'Gen', 'зависимость'),
#  ('использовать', 'В СВЯЗИ С', 'Ins', 'лечение'),
#  ('использовать', 'ВОПРЕКИ', 'Dat', 'интерес'),
#  ('покупать', 'К', 'Dat', 'пример'),
#  ('покупать', 'НА', 'Acc', 'деньга'),
#  ('покупать', 'НА', 'Loc', 'рынок'),
#  ('покупать', 'ЗА', 'Ins', 'граница'),
#  ('покупать', 'ПО', 'Dat', 'цена'),
#  ('покупать', 'СО', 'Ins', 'скидка'),
#  ('покупать', 'ВО', 'Loc', 'сон'),
#  ('покупать', 'ВО', 'Acc', 'время'),
#  ('покупать', 'В КАЧЕСТВЕ', 'Gen', 'подарок'),
#  ('иметься', '_', 'Ins', 'образ'),
#  ('иметься', 'С', 'Gen', 'сторона'),
#  ('иметься', 'ПОЗАДИ', 'Gen', 'глаз'),
#  ('считать', 'ПО', 'Acc', 'день'),
#  ('считать', 'ЗА', 'Acc', 'честь'),
#  ('считать', 'С', 'Ins', 'учёт'),
#  ('считать', 'ПОД', 'Acc', 'сила'),
#  ('считать', 'ВО', 'Loc', 'случай'),
#  ('считать', 'СО', 'Gen', 'сторона'),
#  ('считать', 'ВНЕ', 'Gen', 'зависимость'),
#  ('наблюдаться', 'НА', 'Loc', 'рынок'),
#  ('наблюдаться', 'СОГЛАСНО', 'Dat', 'данные'),
#  ('поступать', 'ПО', 'Loc', 'окончание'),
#  ('поступать', 'СОГЛАСНО', 'Dat', 'соглашение'),
#  ('поступать', 'СО СТОРОНЫ', 'Gen', 'сепаратист'),
#  ('давать', '_', 'Gen', 'деньга'),
#  ('давать', 'О', 'Loc', 'дело'),
#  ('стараться', 'ИЗО', 'Gen', 'сила'),
#  ('стараться', 'ВО', 'Loc', 'случай'),
#  ('стараться', 'ИЗ', 'Gen', 'сила'),
#  ('стараться', 'СО', 'Gen', 'сторона'),
#  ('стараться', 'С ПОМОЩЬЮ', 'Gen', 'мера'),
#  ('приниматься', 'ВО', 'Acc', 'внимание'),
#  ('приниматься', 'В ВИДЕ', 'Gen', 'копия'),
#  ('повысить', '_', 'Ins', 'образ'),
#  ('повысить', '_', 'Loc', '.'),
#  ('повысить', 'ДО', 'Gen', 'уровень'),
#  ('направить', '_', 'Gen', 'рубль'),
#  ('направить', '_', 'Loc', '.'),
#  ('направить', 'НА', 'Loc', 'фон'),
#  ('направить', 'ПО', 'Loc', 'окончание'),
#  ('направить', 'ПОСЛЕ', 'Gen', 'окончание'),
#  ('направить', 'ЗА СЧЕТ', 'Gen', 'штраф'),
#  ('направить', 'ВО', 'Acc', 'вторник'),
#  ('направить', 'ЗА', 'Ins', 'подпись'),
#  ('направить', 'ОТ', 'Gen', 'имя'),
#  ('направить', 'ВМЕСТО', 'Gen', 'уничтожение'),
#  ('доставлять', '_', 'Acc', 'удовольствие'),
#  ('доставлять', 'В', 'Loc', 'страна'),
#  ('вести', '_', 'Ins', 'образ'),
#  ('вести', 'НА', 'Acc', 'этаж'),
#  ('вести', 'ЗА', 'Acc', 'рука'),
#  ('вести', 'С', 'Acc', 'переговоры'),
#  ('вести', 'С ПОМОЩЬЮ', 'Gen', 'камера'),
#  ('вести', 'ПРИ ПОМОЩИ', 'Gen', 'плакат'),
#  ('вести', 'КО', 'Dat', 'вход'),
#  ('вести', 'БЛАГОДАРЯ', 'Dat', 'гол'),
#  ('устранять', '_', 'Ins', 'образ'),
#  ('хватить', 'В', 'Loc', 'случай'),
#  ('хватить', 'ДО', 'Gen', 'конец'),
#  ('хватить', 'ЗА', 'Acc', 'глаз'),
#  ('хватить', 'ЧЕРЕЗ', 'Acc', 'край'),
#  ('составить', '_', 'Ins', 'образ'),
#  ('составить', '_', 'Loc', '.'),
#  ('составить', 'С', 'Gen', 'начало'),
#  ('составить', 'С', 'Ins', 'учёт'),
#  ('составить', 'БЕЗ', 'Gen', 'учёт'),
#  ('составить', 'ВО', 'Loc', 'квартал'),
#  ('составить', 'ВО', 'Acc', 'вторник'),
#  ('составить', 'ЧЕРЕЗ', 'Acc', 'год'),
#  ('составить', 'СО', 'Gen', 'слово'),
#  ('составить', 'ПОД', 'Ins', 'руководство'),
#  ('посеять', 'НА', 'Loc', 'турнир'),
#  ('посеять', 'ПОД', 'Ins', 'номер'),
#  ('посеять', 'ПЕРЕД', 'Ins', 'начало'),
#  ('проводиться', 'В', 'Loc', 'рамка'),
#  ('проводиться', 'ПЕРЕД', 'Ins', 'начало'),
#  ('проводиться', 'ПО МЕРЕ', 'Gen', 'необходимость'),
#  ('проводиться', 'ЗА', 'Ins', 'предел'),
#  ('внести', 'НА', 'Acc', 'рассмотрение'),
#  ('внести', 'КО', 'Dat', 'чтение'),
#  ('внести', 'ДО', 'Gen', 'конец'),
#  ('внести', 'СОГЛАСНО', 'Dat', 'постановление'),
#  ('внести', 'ОТ', 'Gen', 'имя'),
#  ('получиться', '_', 'Ins', 'образ'),
#  ('получиться', 'В', 'Acc', 'раз'),
#  ('получиться', 'СО', 'Ins', 'время'),
#  ('собрать', 'С', 'Acc', 'удовольствие'),
#  ('собрать', '_', 'Loc', '.'),
#  ('собрать', 'В ХОДЕ', 'Gen', 'перепись'),
#  ('собрать', 'ПРИ', 'Loc', 'бюджет'),
#  ('собрать', 'ПОД', 'Acc', 'знамя'),
#  ('собрать', 'ДО', 'Gen', 'конец'),
#  ('собрать', 'ОТ', 'Gen', 'продажа'),
#  ('собрать', 'В СВЯЗИ С', 'Ins', 'инцидент'),
#  ('затянуться', '_', 'Dat', 'флот'),
#  ('затянуться', 'ЗА', 'Acc', 'полночь'),
#  ('использоваться', '_', 'Ins', 'образ'),
#  ('использоваться', 'С', 'Ins', 'цель'),
#  ('использоваться', 'ПО', 'Acc', 'день'),
#  ('использоваться', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('использоваться', 'ВО', 'Acc', 'время'),
#  ('использоваться', 'СО', 'Gen', 'время'),
#  ('использоваться', 'В СООТВЕТСТВИИ С', 'Ins', 'процедура'),
#  ('использоваться', 'ЗА', 'Ins', 'предел'),
#  ('устраняться', '_', 'Ins', 'образ'),
#  ('занять', '_', 'Acc', 'место'),
#  ('занять', 'ДЛЯ', 'Gen', 'подготовка'),
#  ('занять', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('занять', 'ПОД', 'Ins', 'руководство'),
#  ('занять', 'ПРИ', 'Loc', 'поддержка'),
#  ('занять', 'ПЕРЕД', 'Ins', 'театр'),
#  ('занять', 'СО', 'Ins', 'время'),
#  ('занять', 'В ТЕЧЕНИЕ', 'Gen', 'день'),
#  ('занять', 'СПУСТЯ', 'Acc', 'год'),
#  ('занять', 'В СООТВЕТСТВИИ С', 'Ins', 'протокол'),
#  ('наградить', '_', 'Loc', '.'),
#  ('наградить', 'ОТ', 'Gen', 'имя'),
#  ('наградить', 'С', 'Ins', 'формулировка'),
#  ('наградить', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('заложить', '_', 'Dat', 'банк'),
#  ('заложить', '_', 'Loc', '.'),
#  ('заложить', 'ВО', 'Acc', 'время'),
#  ('выдать', '_', 'Loc', '.'),
#  ('выдать', 'С', 'Ins', 'голова'),
#  ('выдать', 'В ВИДЕ', 'Gen', 'кредит'),
#  ('выдать', 'В КАЧЕСТВЕ', 'Gen', 'кредит'),
#  ('выдать', 'ПРОТИВ', 'Gen', 'воля'),
#  ('оставить', '_', 'Nom', 'суд'),
#  ('оставить', 'ВО', 'Loc', 'двор'),
#  ('оставить', 'ВО', 'Acc', 'вторник'),
#  ('оставить', 'ПО', 'Loc', 'окончание'),
#  ('оставить', 'ПРО', 'Acc', 'запас'),
#  ('оставить', 'ОТ', 'Gen', 'брак'),
#  ('выдаваться', 'ПО', 'Loc', 'окончание'),
#  ('выдаваться', 'ИЗ', 'Gen', 'околоцветник'),
#  ('приобрести', '_', 'Loc', '.'),
#  ('приобрести', 'ЗА СЧЕТ', 'Gen', 'средство'),
#  ('приобрести', 'ВО ВРЕМЯ', 'Gen', 'служба'),
#  ('приобрести', 'ДО', 'Gen', 'конец'),
#  ('приобрести', 'У', 'Gen', 'компания'),
#  ('приобрести', 'ВО', 'Acc', 'время'),
#  ('приобрести', 'ИЗ', 'Gen', 'госбюджет'),
#  ('погасить', 'ДО', 'Gen', 'конец'),
#  ('погасить', 'ЗА СЧЕТ', 'Gen', 'средство'),
#  ('перечислять', 'НА', 'Acc', 'счёт'),
#  ('сказать', 'К', 'Dat', 'слово'),
#  ('сказать', 'ВО', 'Acc', 'вторник'),
#  ('сказать', 'ПРИ', 'Loc', 'встреча'),
#  ('сказать', 'ДО', 'Gen', 'свидание'),
#  ('сказать', 'МЕЖДУ', 'Ins', 'дело'),
#  ('начать', '_', 'Loc', '.'),
#  ('начать', 'С', 'Ins', 'цель'),
#  ('начать', 'НА', 'Acc', 'день'),
#  ('начать', 'СО', 'Ins', 'время'),
#  ('начать', 'ПРИ', 'Loc', 'поддержка'),
#  ('начать', 'ДО', 'Gen', 'конец'),
#  ('начать', 'ВО', 'Loc', 'половина'),
#  ('довести', '_', 'Ins', 'образ'),
#  ('довести', 'К', 'Dat', 'конец'),
#  ('довести', 'ПОД', 'Acc', 'конец'),
#  ('довести', 'ПЕРЕД', 'Ins', 'неизбежность'),
#  ('потребоваться', '_', 'Ins', 'образ'),
#  ('потребоваться', 'В', 'Loc', 'случай'),
#  ('потребоваться', 'С', 'Ins', 'учёт'),
#  ('потребоваться', 'СОГЛАСНО', 'Dat', 'оценка'),
#  ('потребоваться', 'В ТЕЧЕНИЕ', 'Gen', 'период'),
#  ('потребоваться', 'ИЗ', 'Gen', 'бюджет'),
#  ('поднять', 'В', 'Acc', 'воздух'),
#  ('поднять', 'ИЗ', 'Gen', 'вода'),
#  ('поднять', 'ПО', 'Dat', 'тревога'),
#  ('поднять', 'ДО', 'Gen', 'уровень'),
#  ('поднять', 'НАД', 'Ins', 'голова'),
#  ('поднять', 'СО', 'Gen', 'дно'),
#  ('поднять', 'СРЕДИ', 'Gen', 'ночь'),
#  ('прекратить', 'НА', 'Acc', 'время'),
#  ('прекратить', 'С', 'Acc', 'сотрудничество'),
#  ('прекратить', 'ВВИДУ', 'Gen', 'отсутствие'),
#  ('прекратить', 'ЗА', 'Ins', 'отсутствие'),
#  ('прекратить', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('прекратить', 'ВО', 'Acc', 'вторник'),
#  ('прекратить', 'ИЗ', 'Gen', 'соображение'),
#  ('прекратить', 'В ХОДЕ', 'Gen', 'реформа'),
#  ('нет', 'С', 'Ins', 'учёт'),
#  ('нет', 'К', 'Dat', 'сожаление'),
#  ('нет', 'ПО', 'Acc', 'день'),
#  ('нет', 'ПРОТИВ', 'Gen', 'лом'),
#  ('приезжать', 'В ХОДЕ', 'Gen', 'волна'),
#  ('закрепить', 'С', 'Gen', 'сторона'),
#  ('закрепить', 'ВО', 'Loc', 'декларация'),
#  ('работать', '_', 'Gen', 'житель'),
#  ('работать', 'ПО', 'Loc', 'окончание'),
#  ('работать', 'ПО', 'Acc', 'день'),
#  ('работать', 'ПОСЛЕ', 'Gen', 'окончание'),
#  ('работать', 'СПУСТЯ', 'Acc', 'рукав'),
#  ('работать', 'О', 'Acc', 'бок'),
#  ('работать', 'ВМЕСТО', 'Gen', 'телеканал'),
#  ('садиться', 'К', 'Dat', 'стол'),
#  ('оборудовать', 'ПО', 'Dat', 'слово'),
#  ('оборудовать', 'ДО', 'Gen', 'конец'),
#  ('приводить', '_', 'Acc', 'слово'),
#  ('приводить', 'В КАЧЕСТВЕ', 'Gen', 'пример'),
#  ('приводить', 'СО', 'Ins', 'ссылка'),
#  ('приводить', 'ВО', 'Acc', 'вращение'),
#  ('заниматься', 'ВО', 'Acc', 'время'),
#  ('заниматься', 'У', 'Gen', 'тренер'),
#  ('заниматься', 'ПОД', 'Ins', 'руководство'),
#  ('заниматься', 'ОКОЛО', 'Gen', 'год'),
#  ('перекрыть', 'НА', 'Acc', 'время'),
#  ('перекрыть', 'ДЛЯ', 'Gen', 'движение'),
#  ('перекрыть', 'В СВЯЗИ С', 'Ins', 'проведение'),
#  ('перекрыть', 'ВО', 'Acc', 'вторник'),
#  ('перекрыть', 'ИЗ', 'Gen', 'соображение'),
#  ('хранить', 'НА', 'Acc', 'случай'),
#  ('хранить', 'ПРИ', 'Loc', 'температура'),
#  ('хранить', 'ПО', 'Acc', 'день'),
#  ('хранить', 'С', 'Ins', 'цель'),
#  ('хранить', 'В ВИДЕ', 'Gen', 'газ'),
#  ('заказать', 'ЧЕРЕЗ', 'Acc', 'интернет'),
#  ('заказать', 'ЗА', 'Ins', 'граница'),
#  ('уйти', '_', 'Loc', '.'),
#  ('уйти', 'В', 'Acc', 'отставка'),
#  ('уйти', 'С', 'Ins', 'голова'),
#  ('уйти', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('уменьшаться', 'СО', 'Ins', 'время'),
#  ('употреблять', 'В', 'Acc', 'пища'),
#  ('употреблять', 'ДЛЯ', 'Gen', 'обозначение'),
#  ('употреблять', 'В СООТВЕТСТВИИ С', 'Ins', 'правило'),
#  ('употреблять', 'ПУТЕМ', 'Gen', 'инъекция'),
#  ('привести', '_', 'Gen', 'пример'),
#  ('привести', 'НА', 'Acc', 'слушание'),
#  ('привести', 'В КАЧЕСТВЕ', 'Gen', 'пример'),
#  ('привести', 'КО', 'Dat', 'спад'),
#  ('взяться', '_', 'Ins', 'рука'),
#  ('взяться', '_', 'Acc', 'невесть'),
#  ('вонзить', 'В', 'Loc', 'сердце'),
#  ('лежать', '_', 'Acc', 'время'),
#  ('лежать', 'В', 'Loc', 'основа'),
#  ('лежать', 'ПО', 'Acc', 'сторона'),
#  ('лежать', 'С', 'Ins', 'глаз'),
#  ('лежать', 'О', 'Acc', 'бок'),
#  ('лежать', 'ПРИ', 'Loc', 'смерть'),
#  ('прийтись', '_', 'Ins', 'образ'),
#  ('прийтись', 'ЗА', 'Ins', 'неимение'),
#  ('прийтись', 'СО', 'Ins', 'время'),
#  ('прийтись', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('прийтись', 'БЕЗ', 'Gen', 'помощь'),
#  ('прийтись', 'ПОД', 'Ins', 'давление'),
#  ('прийтись', 'КО', 'Dat', 'двор'),
#  ('наступить', '_', 'Acc', 'раз'),
#  ('наступить', '_', 'Dat', 'песня'),
#  ('наступить', 'В', 'Loc', 'результат'),
#  ('читать', 'ПЕРЕД', 'Ins', 'сон'),
#  ('читать', 'НА', 'Acc', 'ночь'),
#  ('читать', 'СО', 'Gen', 'сцена'),
#  ('читать', 'ПРИ', 'Loc', 'свет'),
#  ('читать', 'ВМЕСТО', 'Gen', 'слово'),
#  ('читать', 'МЕЖДУ', 'Gen', 'строка'),
#  ('изъять', 'В ХОДЕ', 'Gen', 'обыск'),
#  ('изъять', 'ВО ВРЕМЯ', 'Gen', 'обыск'),
#  ('изъять', 'С', 'Gen', 'место'),
#  ('изъять', 'В КАЧЕСТВЕ', 'Gen', 'доказательство'),
#  ('мочь', '_', 'Ins', 'образ'),
#  ('мочь', 'В', 'Loc', 'случай'),
#  ('мочь', 'СО', 'Ins', 'время'),
#  ('мочь', 'У', 'Gen', 'человек'),
#  ('мочь', 'ДО', 'Gen', 'конец'),
#  ('мочь', 'ВСЛЕДСТВИЕ', 'Gen', 'стечение'),
#  ('мочь', 'ОБ', 'Loc', 'учёба'),
#  ('мочь', 'В ВИДЕ', 'Gen', 'исключение'),
#  ('перевозить', 'ЧЕРЕЗ', 'Acc', 'граница'),
#  ('перевозить', 'ПРИ', 'Loc', 'температура'),
#  ('перевозить', 'СО', 'Ins', 'скорость'),
#  ('перевозить', 'В СООТВЕТСТВИИ С', 'Ins', 'положение'),
#  ('загрузить', '_', 'Gen', 'раз'),
#  ('загрузить', 'ПОД', 'Acc', 'завязка'),
#  ('остановиться', '_', 'Acc', 'раз'),
#  ('остановиться', '_', 'Gen', 'комната'),
#  ('остановиться', 'ЗА', 'Ins', 'спина'),
#  ('остановиться', 'ПРИ', 'Loc', 'вид'),
#  ('отключиться', 'В', 'Acc', 'момент'),
#  ('отключиться', 'НА', 'Acc', 'время'),
#  ('пойти', '_', 'Acc', 'раз'),
#  ('пойти', 'НА', 'Loc', 'повод'),
#  ('пойти', 'В КАЧЕСТВЕ', 'Gen', 'самовыдвиженец'),
#  ('пойти', 'КО', 'Dat', 'дно'),
#  ('пойти', 'ПРОТИВ', 'Gen', 'воля'),
#  ('пойти', 'ДО', 'Gen', 'конец'),
#  ('пойти', 'ИЗО', 'Gen', 'рот'),
#  ('проверить', '_', 'Ins', 'время'),
#  ('проверить', 'ДЛЯ', 'Gen', 'начало'),
#  ('виднеться', 'ПО', 'Acc', 'сторона'),
#  ('виднеться', 'С', 'Gen', 'сторона'),
#  ('виднеться', 'ИЗ', 'Gen', 'окно'),
#  ('попытаться', '_', 'Acc', 'раз'),
#  ('попытаться', 'ЗА', 'Acc', 'время'),
#  ('попытаться', 'ДЛЯ', 'Gen', 'начало'),
#  ('ликвидировать', 'В', 'Loc', 'результат'),
#  ('ликвидировать', 'С', 'Gen', 'начало'),
#  ('распространяться', 'СО', 'Ins', 'скорость'),
#  ('распространяться', 'ПРИ', 'Loc', 'условие'),
#  ('распространяться', 'ЗА', 'Acc', 'предел'),
#  ('распространяться', 'ЗА', 'Ins', 'предел'),
#  ('распространяться', 'ДЛЯ', 'Gen', 'обсуждение'),
#  ('распространяться', 'ВО', 'Acc', 'сторона'),
#  ('распространяться', 'В КАЧЕСТВЕ', 'Gen', 'документ'),
#  ('распространяться', 'ВНЕ', 'Gen', 'зависимость'),
#  ('выгореть', 'В', 'Loc', 'результат'),
#  ('выгореть', 'НА', 'Loc', 'солнце'),
#  ('выгореть', 'ОТ', 'Gen', 'солнце'),
#  ('повредить', '_', 'Gen', 'дом'),
#  ('повредить', 'В', 'Loc', 'результат'),
#  ('повредить', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('поступить', '_', 'Gen', 'рубль'),
#  ('поступить', '_', 'Loc', '.'),
#  ('поступить', '_', 'Ins', 'образ'),
#  ('поступить', 'ОТ', 'Gen', 'предприниматель'),
#  ('поступить', 'ЗА', 'Ins', 'подпись'),
#  ('поступить', 'ПОСЛЕ', 'Gen', 'окончание'),
#  ('поступить', 'ПО', 'Loc', 'окончание'),
#  ('поступить', 'ДО', 'Gen', 'конец'),
#  ('поступить', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('поступить', 'КО', 'Dat', 'чтение'),
#  ('приехать', '_', 'Acc', 'раз'),
#  ('приехать', 'ПО', 'Loc', 'окончание'),
#  ('приехать', 'ДЛЯ', 'Gen', 'участие'),
#  ('приехать', 'ВО', 'Loc', 'половина'),
#  ('выехать', 'К', 'Dat', 'место'),
#  ('выехать', 'ЗА', 'Ins', 'руль'),
#  ('выехать', 'ПЕРЕД', 'Ins', 'поезд'),
#  ('закрыть', 'ДО', 'Gen', 'конец'),
#  ('закрыть', 'СО', 'Gen', 'сторона'),
#  ('закрыть', 'ЗА', 'Ins', 'отсутствие'),
#  ('закрыть', 'В КАЧЕСТВЕ', 'Gen', 'мера'),
#  ('закрыть', 'ИЗ', 'Gen', 'соображение'),
#  ('закрыть', 'ПЕРЕД', 'Ins', 'нос'),
#  ('разбить', 'ДЛЯ', 'Gen', 'удобство'),
#  ('разбить', 'ДО', 'Gen', 'кровь'),
#  ('разбить', 'СРЕДИ', 'Gen', 'развалина'),
#  ('стучаться', 'В', 'Acc', 'дверь'),
#  ('стучаться', 'ВО', 'Acc', 'дверь'),
#  ('сообщить', 'В', 'Loc', 'пресс-служба'),
#  ('сообщить', 'СО', 'Ins', 'ссылка'),
#  ('сообщить', 'СО', 'Gen', 'сторона'),
#  ('сообщить', 'ВО', 'Acc', 'вторник'),
#  ('сообщить', 'ОТ', 'Gen', 'имя'),
#  ('сообщить', 'СОГЛАСНО', 'Dat', 'информация'),
#  ('пытаться', 'ЧЕРЕЗ', 'Acc', 'суд'),
#  ('пытаться', 'ИЗО', 'Gen', 'сила'),
#  ('пытаться', 'С ПОМОЩЬЮ', 'Gen', 'бинокль'),
#  ('пытаться', 'БЕЗ', 'Gen', 'успех'),
#  ('пытаться', 'ИЗ', 'Gen', 'сила'),
#  ('потушить', '_', 'Nom', 'пожар'),
#  ('потушить', '_', 'Ins', 'сила'),
#  ('соединяться', 'ПРИ ПОМОЩИ', 'Gen', 'ушко'),
#  ('показывать', 'С', 'Gen', 'сторона'),
#  ('показывать', 'СО', 'Ins', 'очевидность'),
#  ('тонуть', 'ПРИ', 'Loc', 'попытка'),
#  ('говорить', 'ПРО', 'Acc', 'человек'),
#  ('говорить', 'НА', 'Loc', 'язык'),
#  ('говорить', 'НА', 'Acc', 'тема'),
#  ('говорить', 'ПРИ', 'Loc', 'встреча'),
#  ('утонуть', 'С', 'Gen', 'начало'),
#  ('отдыхать', 'ЗА', 'Ins', 'граница'),
#  ('отдыхать', 'БЕЗ', 'Gen', 'пиво'),
#  ('всплыть', 'В', 'Loc', 'память'),
#  ('всплыть', 'НА', 'Acc', 'поверхность'),
#  ('всплыть', 'ПЕРЕД', 'Ins', 'глаз'),
#  ('увидеть', '_', 'Ins', 'глаз'),
#  ('увидеть', 'ПРИ', 'Loc', 'свет'),
#  ('увидеть', 'ВО', 'Loc', 'сон'),
#  ('увидеть', 'ПО', 'Acc', 'сторона'),
#  ('увидеть', 'СО', 'Ins', 'время'),
#  ('увидеть', 'СО', 'Gen', 'сторона'),
#  ('увидеть', 'ИЗ', 'Gen', 'окно'),
#  ('увидеть', 'НАД', 'Ins', 'голова'),
#  ('выйти', '_', 'Acc', 'раз'),
#  ('выйти', '_', 'Loc', '.'),
#  ('выйти', 'ПО', 'Loc', 'окончание'),
#  ('выйти', 'ДО', 'Gen', 'конец'),
#  ('выйти', 'В КАЧЕСТВЕ', 'Gen', 'сингл'),
#  ('выйти', 'РАДИ', 'Gen', 'деньга'),
#  ('обнаружить', '_', 'Gen', 'рубль'),
#  ('обнаружить', '_', 'Loc', '.'),
#  ('обнаружить', 'ВО', 'Loc', 'двор'),
#  ('обнаружить', 'ВО', 'Acc', 'вторник'),
#  ('обнаружить', 'С', 'Ins', 'удивление'),
#  ('обнаружить', 'ПРИ ПОМОЩИ', 'Gen', 'телескоп'),
#  ('обнаружить', 'БЕЗ', 'Gen', 'сознание'),
#  ('вестись', 'ПО', 'Acc', 'день'),
#  ('вестись', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('вестись', 'ЗА СЧЕТ', 'Gen', 'средство'),
#  ('вестись', 'В СВЯЗИ С', 'Ins', 'покупка'),
#  ('устанавливаться', 'ПОД', 'Ins', 'угол'),
#  ('оказать', '_', 'Nom', 'помощь'),
#  ('оказать', 'НА', 'Loc', 'место'),
#  ('оказать', 'С', 'Ins', 'цель'),
#  ('оказать', 'ПУТЕМ', 'Gen', 'предоставление'),
#  ('пострадать', 'В', 'Loc', 'результат'),
#  ('пострадать', '_', 'Gen', 'человек'),
#  ('пострадать', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('пострадать', 'ПО', 'Dat', 'данные'),
#  ('пострадать', 'ПОД', 'Ins', 'колесо'),
#  ('упасть', '_', 'Dat', 'яблоко'),
#  ('упасть', 'В ХОДЕ', 'Gen', 'торг'),
#  ('упасть', 'ВО', 'Acc', 'вторник'),
#  ('упасть', 'ДЛЯ', 'Gen', 'сравнение'),
#  ('избить', 'ВОЗЛЕ', 'Gen', 'дом'),
#  ('избить', 'ВО', 'Loc', 'двор'),
#  ('поставить', '_', 'Loc', '.'),
#  ('поставить', 'ПО', 'Acc', 'сторона'),
#  ('поставить', 'ДО', 'Gen', 'конец'),
#  ('поставить', 'С', 'Acc', 'штамп'),
#  ('поставить', 'ВО', 'Acc', 'глава'),
#  ('поставить', 'СО', 'Ins', 'стук'),
#  ('поставить', 'ВНЕ', 'Gen', 'закон'),
#  ('поставить', 'ОТ', 'Gen', 'имя'),
#  ('поставить', 'НАПРОТИВ', 'Gen', 'фамилия'),
#  ('выпить', '_', 'Ins', 'залп'),
#  ('выпить', '_', 'Par', 'чай'),
#  ('выпить', 'ДО', 'Gen', 'дно'),
#  ('выпить', 'С', 'Ins', 'удовольствие'),
#  ('рассмотреть', 'НА', 'Acc', 'предмет'),
#  ('рассмотреть', 'ВО', 'Loc', 'чтение'),
#  ('рассмотреть', 'ВО', 'Acc', 'вторник'),
#  ('рассмотреть', 'С', 'Gen', 'точка'),
#  ('рассмотреть', 'ДО', 'Gen', 'конец'),
#  ('рассмотреть', 'СО', 'Gen', 'сторона'),
#  ('рассмотреть', 'В СВЯЗИ С', 'Ins', 'вопрос'),
#  ('рассмотреть', 'С ПОМОЩЬЮ', 'Gen', 'эксперт'),
#  ('признать', '_', 'Nom', 'суд'),
#  ('признать', '_', 'Loc', '.'),
#  ('признать', 'ПО', 'Loc', 'окончание'),
#  ('признать', 'ПОД', 'Ins', 'давление'),
#  ('признать', 'ВО', 'Loc', 'мир'),
#  ('признать', 'ВО', 'Acc', 'вторник'),
#  ('потерпеть', 'ПО', 'Dat', 'дело'),
#  ('потерпеть', 'НА', 'Loc', 'выбор'),
#  ('потерпеть', 'ВО', 'Acc', 'вторник'),
#  ('выпивать', '_', 'Ins', 'залп'),
#  ('выпивать', 'ДО', 'Gen', 'дно'),
#  ('тушить', 'ПО', 'Dat', 'номер'),
#  ('тушить', '_', 'Nom', 'пожарный'),
#  ('тушить', 'ПОСЛЕ', 'Gen', 'завершение'),
#  ('постелить', 'В', 'Loc', 'комната'),
#  ('накрыть', 'НА', 'Acc', 'стол'),
#  ('накрыть', 'С', 'Ins', 'голова'),
#  ('накрыть', 'ВО', 'Loc', 'двор'),
#  ('засыпать', 'НА', 'Loc', 'ход'),
#  ('засыпать', 'ОТ', 'Gen', 'усталость'),
#  ('проснуться', '_', 'Ins', 'утро'),
#  ('проснуться', 'НА', 'Loc', 'рассвет'),
#  ('проснуться', 'СРЕДИ', 'Gen', 'ночь'),
#  ('проснуться', 'ПОСРЕДИ', 'Gen', 'ночь'),
#  ('проснуться', 'ПЕРЕД', 'Ins', 'рассвет'),
#  ('кричать', '_', 'Gen', 'ура'),
#  ('кричать', 'ВО', 'Loc', 'сон'),
#  ('кричать', 'ПОД', 'Ins', 'окно'),
#  ('кричать', 'ИЗО', 'Gen', 'сила'),
#  ('разбудить', 'НА', 'Loc', 'рассвет'),
#  ('разбудить', 'СРЕДИ', 'Gen', 'ночь'),
#  ('разбудить', 'ПОСРЕДИ', 'Gen', 'ночь'),
#  ('разбудить', 'ПОД', 'Acc', 'утро'),
#  ('открыть', '_', 'Loc', '.'),
#  ('открыть', 'ДО', 'Gen', 'конец'),
#  ('открыть', 'ВО', 'Acc', 'вторник'),
#  ('крикнуть', '_', 'Ins', 'голос'),
#  ('крикнуть', 'С', 'Gen', 'порог'),
#  ('выбираться', 'НА', 'Loc', 'основа'),
#  ('выбираться', 'ДЛЯ', 'Gen', 'открытие'),
#  ('найти', '_', 'Loc', '.'),
#  ('найти', 'С', 'Acc', 'десяток'),
#  ('найти', 'ПОСРЕДИ', 'Gen', 'дорога'),
#  ('выбраться', 'С', 'Ins', 'труд'),
#  ('выбраться', 'ВО', 'Acc', 'двор'),
#  ('послужить', 'ВО', 'Loc', 'многое'),
#  ('послужить', 'В КАЧЕСТВЕ', 'Gen', 'основа'),
#  ('установить', '_', 'Ins', 'закон'),
#  ('установить', 'С ПОМОЩЬЮ', 'Gen', 'система'),
#  ('установить', 'ВО', 'Loc', 'двор'),
#  ('установить', 'ДО', 'Gen', 'конец'),
#  ('установить', 'МЕЖДУ', 'Ins', 'город'),
#  ('установить', 'ПРИ ПОМОЩИ', 'Gen', 'система'),
#  ('установить', 'ОБ', 'Loc', 'установление'),
#  ('привлечь', 'К', 'Dat', 'ответственность'),
#  ('привлечь', '_', 'Acc', 'внимание'),
#  ('привлечь', 'НА', 'Acc', 'сторона'),
#  ('прибыть', 'НА', 'Acc', 'место'),
#  ('прибыть', 'К', 'Dat', 'место'),
#  ('прибыть', '_', 'Loc', '.'),
#  ('прибыть', '_', 'Dat', 'полок'),
#  ('прибыть', 'ВО', 'Loc', 'половина'),
#  ('прибыть', 'С', 'Ins', 'визит'),
#  ('прибыть', 'ДЛЯ', 'Gen', 'участие'),
#  ('прибыть', 'ДО', 'Gen', 'конец'),
#  ('прибыть', 'ОКОЛО', 'Gen', 'беженец'),
#  ('прибыть', 'КО', 'Dat', 'двор'),
#  ('посмотреть', '_', 'Dat', 'правда'),
#  ('посмотреть', 'ПОД', 'Ins', 'угол'),
#  ('посмотреть', 'ПОД', 'Acc', 'нога'),
#  ('посмотреть', 'СО', 'Gen', 'сторона'),
#  ('посмотреть', 'ДЛЯ', 'Gen', 'начало'),
#  ('посмотреть', 'ЧЕРЕЗ', 'Acc', 'плечо'),
#  ('посмотреть', 'ВО', 'Acc', 'двор'),
#  ('посмотреть', 'ВО ВРЕМЯ', 'Gen', 'показ'),
#  ('опросить', '_', 'Gen', 'человек'),
#  ('опросить', 'В ХОДЕ', 'Gen', 'исследование'),
#  ('обратить', '_', 'Acc', 'внимание'),
#  ('обратить', '_', 'Gen', 'внимание'),
#  ('доставить', 'В', 'Acc', 'больница'),
#  ('доставить', 'В', 'Loc', 'состояние'),
#  ('доставить', 'ПЕРЕД', 'Ins', 'начало'),
#  ('дать', '_', 'Par', 'мах'),
#  ('дать', '_', 'Loc', '.'),
#  ('дать', 'ВО', 'Acc', 'вторник'),
#  ('возбудить', 'ПО', 'Dat', 'факт'),
#  ('возбудить', '_', 'Nom', 'дело'),
#  ('возбудить', '_', 'Acc', 'дело'),
#  ('возбудить', '_', 'Gen', 'дело'),
#  ('возбудить', 'НА', 'Loc', 'основание'),
#  ('возбудить', 'С', 'Ins', 'цель'),
#  ('возбудить', 'ВО', 'Acc', 'вторник'),
#  ('похитить', '_', 'Gen', 'рубль'),
#  ('похитить', 'С', 'Ins', 'цель'),
#  ('похитить', 'ОКОЛО', 'Gen', 'рубль'),
#  ('похитить', 'ДО', 'Gen', 'выход'),
#  ('похитить', 'ВО', 'Acc', 'вторник'),
#  ('похитить', 'РАДИ', 'Gen', 'выкуп'),
#  ('взломать', '_', 'Nom', 'хакер'),
#  ('взломать', '_', 'Ins', 'хакер'),
#  ('призывать', '_', 'Ins', 'образ'),
#  ('призывать', '_', 'Dat', 'власть'),
#  ('призывать', 'В', 'Loc', 'связь'),
#  ('призывать', 'ЧЕРЕЗ', 'Acc', 'громкоговоритель'),
#  ('призывать', 'ВО', 'Acc', 'имя'),
#  ('призывать', 'ОТ', 'Gen', 'имя'),
#  ('позаботиться', '_', 'Ins', 'образ'),
#  ('позаботиться', 'В', 'Loc', 'случай'),
#  ('предпринять', '_', 'Loc', '.'),
#  ('предпринять', 'ПРИ', 'Loc', 'поддержка'),
#  ('предпринять', 'К', 'Dat', 'время'),
#  ('предпринять', 'С', 'Ins', 'цель'),
#  ('предпринять', 'ДО', 'Gen', 'время'),
#  ('сходить', 'С', 'Gen', 'ум'),
#  ('сходить', 'К', 'Dat', 'врач'),
#  ('купить', '_', 'Loc', '.'),
#  ('купить', 'НА', 'Acc', 'деньга'),
#  ('купить', 'ЗА', 'Ins', 'граница'),
#  ('купить', 'СО', 'Ins', 'скидка'),
#  ('купить', 'В КАЧЕСТВЕ', 'Gen', 'подарок'),
#  ('уснуть', '_', 'Ins', 'сон'),
#  ('уснуть', 'ЗА', 'Ins', 'руль'),
#  ('уснуть', 'С', 'Ins', 'мысль'),
#  ('уснуть', 'ПОД', 'Acc', 'утро'),
#  ('уснуть', 'ОТ', 'Gen', 'усталость'),
#  ('взять', '_', 'Loc', '.'),
#  ('взять', 'К', 'Dat', 'пример'),
#  ('взять', 'ИЗ', 'Gen', 'рука'),
#  ('взять', 'СО', 'Gen', 'стол'),
#  ('обналичить', '_', 'Gen', 'рубль'),
#  ('потратить', '_', 'Loc', '.'),
#  ('потратить', 'В', 'Loc', 'год'),
#  ('задержать', 'ВО ВРЕМЯ', 'Gen', 'акция'),
#  ('задержать', 'С', 'Gen', 'начало'),
#  ('задержать', 'С', 'Ins', 'поличное'),
#  ('задержать', 'ВО', 'Acc', 'вторник'),
#  ('задержать', 'В КАЧЕСТВЕ', 'Gen', 'подозреваемый'),
#  ('задержать', 'ИЗ', 'Gen', 'число'),
#  ('предусмотреть', '_', 'Gen', 'рубль'),
#  ('предусмотреть', '_', 'Dat', 'владелец'),
#  ('сдать', '_', 'Acc', 'экзамен'),
#  ('сдать', '_', 'Gen', 'метр'),
#  ('сдать', '_', 'Ins', 'экстерн'),
#  ('сдать', '_', 'Loc', '.'),
#  ('сдать', 'НА', 'Acc', 'хранение'),
#  ('сдать', 'ДО', 'Gen', 'конец'),
#  ('сдать', 'БЕЗ', 'Gen', 'бой'),
#  ('сдать', 'ВО ВРЕМЯ', 'Gen', 'праздник'),
#  ('помнить', 'ПО', 'Acc', 'день'),
#  ('помнить', 'С', 'Gen', 'детство'),
#  ('вернуться', '_', 'Dat', 'мигрант'),
#  ('вернуться', '_', 'Loc', '.'),
#  ('вернуться', 'ДЛЯ', 'Gen', 'участие'),
#  ('вернуться', 'ЗА', 'Acc', 'стол'),
#  ('вернуться', 'ПО', 'Loc', 'окончание'),
#  ('вернуться', 'ВО ВРЕМЯ', 'Gen', 'война'),
#  ('согласиться', 'ПОД', 'Ins', 'давление'),
#  ('согласиться', 'СО', 'Gen', 'сторона'),
#  ('согласиться', 'ПРИ', 'Loc', 'условие'),
#  ('облегчить', '_', 'Ins', 'образ'),
#  ('облегчить', 'ВО', 'Loc', 'многое'),
#  ('написать', '_', 'Loc', '.'),
#  ('написать', 'СО', 'Ins', 'ссылка'),
#  ('предоставить', 'В', 'Acc', 'распоряжение'),
#  ('рассматривать', 'С', 'Gen', 'точка'),
#  ('рассматривать', 'С', 'Acc', 'минута'),
#  ('рассматривать', 'СО', 'Gen', 'сторона'),
#  ('рассматривать', 'ЧЕРЕЗ', 'Acc', 'призма'),
#  ('рассматривать', 'ОТ', 'Gen', 'лицо'),
#  ('рассматривать', 'СКВОЗЬ', 'Acc', 'призма'),
#  ('рассматривать', 'ПО МЕРЕ', 'Gen', 'необходимость'),
#  ('изменить', '_', 'Ins', 'образ'),
#  ('изменить', 'ВО', 'Loc', 'многое'),
#  ('изменить', 'СО', 'Ins', 'время'),
#  ('изменить', 'ДО', 'Gen', 'неузнаваемость'),
#  ('выявить', 'В ХОДЕ', 'Gen', 'проверка'),
#  ('выявить', 'С', 'Gen', 'начало'),
#  ('выявить', 'ЗА', 'Acc', 'сутки'),
#  ('выявить', 'ЗА', 'Ins', 'предел'),
#  ('выявить', 'СОГЛАСНО', 'Dat', 'данные'),
#  ('выявить', 'БЕЗ', 'Gen', 'проявление'),
#  ('выявить', 'ВНЕ', 'Gen', 'сомнение'),
#  ('уволиться', 'ПО', 'Dat', 'желание'),
#  ('уволиться', 'В', 'Acc', 'запас'),
#  ('уволиться', 'СО', 'Gen', 'служба'),
#  ('двигаться', '_', 'Acc', 'время'),
#  ('двигаться', 'В', 'Acc', 'сторона'),
#  ('двигаться', 'В', 'Loc', 'направление'),
#  ('двигаться', 'С', 'Ins', 'скорость'),
#  ('двигаться', 'СО', 'Ins', 'скорость'),
#  ('двигаться', 'ОТ', 'Gen', 'метро'),
#  ('двигаться', 'ПОД', 'Acc', 'музыка'),
#  ('заметить', 'СРЕДИ', 'Gen', 'гость'),
#  ('заметить', 'ЧЕРЕЗ', 'Acc', 'время'),
#  ('заметить', 'ИЗ', 'Gen', 'окно'),
#  ('заметить', 'СПУСТЯ', 'Acc', 'время'),
#  ('заметить', 'РАДИ', 'Gen', 'справедливость'),
#  ('увеличить', '_', 'Ins', 'образ'),
#  ('увеличить', '_', 'Dat', 'исследователь'),
#  ('увеличить', '_', 'Loc', '.'),
#  ('увеличить', 'СО', 'Ins', 'время'),
#  ('подтвердить', 'ЗА', 'Acc', 'сутки'),
#  ('подтвердить', 'ВО', 'Acc', 'вторник'),
#  ('подтвердить', 'СО', 'Gen', 'сторона'),
#  ('подтвердить', 'СО', 'Ins', 'ссылка'),
#  ('подтвердить', 'ПОД', 'Ins', 'присяга'),
#  ('подтвердить', 'ОТ', 'Gen', 'имя'),
#  ('сбежать', 'ЗА', 'Acc', 'граница'),
#  ('разыскать', 'С', 'Ins', 'труд'),
#  ('начинаться', 'ВО', 'Loc', 'половина'),
#  ('начинаться', 'СО', 'Gen', 'слово'),
#  ('начинаться', 'ПОД', 'Ins', 'знак'),
#  ('встретиться', '_', 'Acc', 'раз'),
#  ('встретиться', 'ДЛЯ', 'Gen', 'обсуждение'),
#  ('договориться', 'С', 'Gen', 'начало'),
#  ...]

# %%
from collections import Counter

ex2 = [x[1:] for x in exceptional]
ex2 = Counter(ex2)
len(ex2), sorted(ex2.items(), key=lambda x: x[1], reverse=True)
# Out:
# (3566,
#  [(('_', 'Ins', 'образ'), 393),
#   (('В', 'Acc', 'сторона'), 170),
#   (('_', 'Acc', 'раз'), 153),
#   (('ДО', 'Gen', 'конец'), 147),
#   (('_', 'Loc', '.'), 123),
#   (('ВО', 'Acc', 'вторник'), 122),
#   (('С', 'Ins', 'труд'), 107),
#   (('СО', 'Ins', 'время'), 100),
#   (('СО', 'Gen', 'сторона'), 95),
#   (('ОТ', 'Gen', 'имя'), 89),
#   (('ПО', 'Dat', 'слово'), 80),
#   (('ВО ВРЕМЯ', 'Gen', 'война'), 75),
#   (('_', 'Acc', 'время'), 69),
#   (('С', 'Ins', 'цель'), 68),
#   (('В', 'Acc', 'время'), 68),
#   (('С', 'Ins', 'учёт'), 65),
#   (('ВО', 'Loc', 'сон'), 64),
#   (('В', 'Loc', 'результат'), 56),
#   (('В', 'Loc', 'случай'), 49),
#   (('С', 'Gen', 'начало'), 48),
#   (('ЗА', 'Ins', 'спина'), 48),
#   (('ПОД', 'Ins', 'руководство'), 47),
#   (('ВО', 'Acc', 'время'), 47),
#   (('ВО', 'Loc', 'многое'), 46),
#   (('ПО', 'Loc', 'окончание'), 44),
#   (('С', 'Ins', 'сила'), 43),
#   (('_', 'Nom', 'друг'), 40),
#   (('_', 'Ins', 'рука'), 38),
#   (('СО', 'Ins', 'ссылка'), 37),
#   (('СО', 'Gen', 'время'), 37),
#   (('НА', 'Loc', 'место'), 37),
#   (('_', 'Acc', 'глаз'), 36),
#   (('_', 'Nom', 'глаз'), 36),
#   (('ПО', 'Acc', 'день'), 35),
#   (('ПРИ', 'Loc', 'поддержка'), 34),
#   (('НАД', 'Ins', 'голова'), 33),
#   (('_', 'Nom', 'человек'), 33),
#   (('В', 'Acc', 'ответ'), 32),
#   (('С', 'Gen', 'сторона'), 31),
#   (('НА', 'Loc', 'основа'), 31),
#   (('С', 'Gen', 'точка'), 30),
#   (('НА', 'Loc', 'фон'), 30),
#   (('_', 'Acc', 'рука'), 30),
#   (('НА', 'Acc', 'день'), 29),
#   (('ВО', 'Acc', 'двор'), 29),
#   (('СО', 'Ins', 'скорость'), 29),
#   (('С', 'Gen', 'место'), 29),
#   (('В', 'Acc', 'момент'), 29),
#   (('НА', 'Acc', 'время'), 28),
#   (('ПЕРЕД', 'Ins', 'глаз'), 28),
#   (('_', 'Acc', 'голова'), 28),
#   (('_', 'Ins', 'голова'), 28),
#   (('ВО', 'Loc', 'двор'), 27),
#   (('ПОСЛЕ', 'Gen', 'смерть'), 27),
#   (('НА', 'Acc', 'тема'), 27),
#   (('_', 'Ins', 'нога'), 27),
#   (('В', 'Loc', 'глаз'), 26),
#   (('ВНЕ', 'Gen', 'зависимость'), 25),
#   (('_', 'Gen', 'человек'), 25),
#   (('ПО', 'Dat', 'данные'), 25),
#   (('В', 'Acc', 'раз'), 25),
#   (('_', 'Nom', 'сердце'), 25),
#   (('В', 'Loc', 'поиск'), 24),
#   (('_', 'Acc', 'волос'), 24),
#   (('ИЗ', 'Gen', 'сторона'), 24),
#   (('_', 'Nom', 'лицо'), 23),
#   (('НА', 'Acc', 'раз'), 23),
#   (('_', 'Nom', 'волос'), 23),
#   (('К', 'Dat', 'сожаление'), 21),
#   (('С', 'Ins', 'голова'), 21),
#   (('_', 'Ins', 'голос'), 21),
#   (('ЧЕРЕЗ', 'Acc', 'плечо'), 21),
#   (('В', 'Loc', 'направление'), 21),
#   (('НА', 'Acc', 'шутка'), 21),
#   (('НА', 'Acc', 'момент'), 20),
#   (('ИЗО', 'Gen', 'сила'), 20),
#   (('_', 'Gen', 'рубль'), 20),
#   (('ЗА', 'Ins', 'окно'), 20),
#   (('ИЗ', 'Gen', 'страна'), 19),
#   (('В ХОДЕ', 'Gen', 'торг'), 19),
#   (('ПОД', 'Ins', 'угол'), 19),
#   (('НА', 'Loc', 'ход'), 19),
#   (('В', 'Acc', 'польза'), 19),
#   (('НА', 'Loc', 'глаз'), 19),
#   (('В', 'Loc', 'воздух'), 19),
#   (('ПО', 'Dat', 'сторона'), 19),
#   (('ДЛЯ', 'Gen', 'участие'), 18),
#   (('ИЗ', 'Gen', 'окно'), 18),
#   (('НА', 'Loc', 'минута'), 18),
#   (('ПОД', 'Ins', 'нога'), 18),
#   (('ИЗО', 'Gen', 'рот'), 17),
#   (('ВО', 'Loc', 'половина'), 17),
#   (('К', 'Dat', 'пример'), 17),
#   (('НА', 'Loc', 'рынок'), 17),
#   (('НА', 'Loc', 'выбор'), 17),
#   (('ПОД', 'Acc', 'нос'), 17),
#   (('ЗА', 'Ins', 'граница'), 16),
#   (('НА', 'Loc', 'дело'), 16),
#   (('_', 'Acc', 'слово'), 16),
#   (('НА', 'Loc', 'язык'), 16),
#   (('С', 'Gen', 'детство'), 16),
#   (('_', 'Nom', 'ветер'), 16),
#   (('НА', 'Loc', 'сайт'), 16),
#   (('ОТ', 'Gen', 'душа'), 16),
#   (('НА', 'Loc', 'уровень'), 16),
#   (('В', 'Loc', 'голова'), 16),
#   (('ДЛЯ', 'Gen', 'начало'), 15),
#   (('ПОСЛЕ', 'Gen', 'окончание'), 15),
#   (('ИЗ', 'Gen', 'рука'), 15),
#   (('НА', 'Loc', 'территория'), 15),
#   (('ЗА', 'Acc', 'время'), 15),
#   (('ВО', 'Loc', 'случай'), 15),
#   (('К', 'Dat', 'конец'), 15),
#   (('НА', 'Acc', 'предмет'), 15),
#   (('ПОД', 'Acc', 'нога'), 15),
#   (('НА', 'Acc', 'территория'), 15),
#   (('_', 'Ins', 'вода'), 15),
#   (('НА', 'Loc', 'протяжение'), 15),
#   (('ОТ', 'Gen', 'боль'), 15),
#   (('_', 'Ins', 'глаз'), 14),
#   (('ДЛЯ', 'Gen', 'сравнение'), 14),
#   (('ВО', 'Acc', 'сторона'), 14),
#   (('НА', 'Acc', 'место'), 14),
#   (('В', 'Loc', 'год'), 14),
#   (('С', 'Gen', 'нога'), 14),
#   (('С', 'Gen', 'утро'), 14),
#   (('ПО', 'Dat', 'итог'), 14),
#   (('_', 'Ins', 'взгляд'), 14),
#   (('С', 'Gen', 'лицо'), 14),
#   (('НА', 'Acc', 'свет'), 13),
#   (('ЧЕРЕЗ', 'Acc', 'год'), 13),
#   (('ВО', 'Loc', 'мир'), 13),
#   (('ЗА', 'Acc', 'рука'), 13),
#   (('ЗА', 'Ins', 'предел'), 13),
#   (('_', 'Acc', 'внимание'), 13),
#   (('НА', 'Loc', 'основание'), 13),
#   (('_', 'Acc', 'жизнь'), 13),
#   (('ОТ', 'Gen', 'удар'), 13),
#   (('_', 'Acc', 'дверь'), 13),
#   (('В', 'Loc', 'рука'), 13),
#   (('СО', 'Gen', 'счёт'), 13),
#   (('_', 'Ins', 'зуб'), 13),
#   (('_', 'Nom', 'дверь'), 13),
#   (('СКВОЗЬ', 'Acc', 'зуб'), 13),
#   (('В', 'Acc', 'цвет'), 13),
#   (('_', 'Nom', 'голова'), 13),
#   (('С', 'Acc', 'минута'), 12),
#   (('_', 'Nom', 'дело'), 12),
#   (('ПОД', 'Ins', 'название'), 12),
#   (('БЕЗ', 'Gen', 'труд'), 12),
#   (('ПО', 'Dat', 'цена'), 12),
#   (('НА', 'Acc', 'счёт'), 12),
#   (('ЧЕРЕЗ', 'Acc', 'суд'), 12),
#   (('НА', 'Loc', 'улица'), 12),
#   (('ПОД', 'Ins', 'предлог'), 12),
#   (('В', 'Loc', 'кресло'), 12),
#   (('ДО', 'Gen', 'предел'), 12),
#   (('В', 'Loc', 'зависимость'), 12),
#   (('_', 'Ins', 'язык'), 12),
#   (('ДО', 'Gen', 'блеск'), 12),
#   (('ПО', 'Acc', 'сторона'), 11),
#   (('СПУСТЯ', 'Acc', 'год'), 11),
#   (('_', 'Nom', 'суд'), 11),
#   (('НА', 'Acc', 'случай'), 11),
#   (('НА', 'Loc', 'солнце'), 11),
#   (('_', 'Nom', 'волна'), 11),
#   (('В', 'Loc', 'улыбка'), 11),
#   (('НА', 'Acc', 'прощание'), 11),
#   (('ВО', 'Loc', 'время'), 11),
#   (('СО', 'Gen', 'лоб'), 11),
#   (('В ТЕЧЕНИЕ', 'Gen', 'период'), 10),
#   (('СОГЛАСНО', 'Dat', 'данные'), 10),
#   (('_', 'Gen', 'деньга'), 10),
#   (('ПОД', 'Ins', 'давление'), 10),
#   (('ПРИ', 'Loc', 'условие'), 10),
#   (('К', 'Dat', 'место'), 10),
#   (('В', 'Acc', 'дверь'), 10),
#   (('В', 'Loc', 'память'), 10),
#   (('ВО', 'Acc', 'имя'), 10),
#   (('ДО', 'Gen', 'смерть'), 10),
#   (('НА', 'Acc', 'улица'), 10),
#   (('ЗА', 'Acc', 'борт'), 10),
#   (('ДО', 'Gen', 'пора'), 10),
#   (('_', 'Acc', 'деньга'), 10),
#   (('ЗА', 'Ins', 'стол'), 10),
#   (('ДО', 'Gen', 'температура'), 10),
#   (('В', 'Acc', 'день'), 10),
#   (('В', 'Loc', 'суд'), 10),
#   (('НА', 'Acc', 'нога'), 10),
#   (('_', 'Ins', 'нос'), 10),
#   (('НА', 'Acc', 'расстояние'), 10),
#   (('_', 'Ins', 'тело'), 10),
#   (('О', 'Acc', 'бок'), 9),
#   (('НА', 'Acc', 'взгляд'), 9),
#   (('_', 'Nom', 'вопрос'), 9),
#   (('ДО', 'Gen', 'неузнаваемость'), 9),
#   (('ИЗ', 'Gen', 'число'), 9),
#   (('ИЗ', 'Gen', 'сила'), 9),
#   (('ВОЗЛЕ', 'Gen', 'дом'), 9),
#   (('БЕЗ', 'Gen', 'учёт'), 9),
#   (('В', 'Acc', 'очередь'), 9),
#   (('ДО', 'Gen', 'уровень'), 9),
#   (('ПЕРЕД', 'Ins', 'начало'), 9),
#   (('ЗА СЧЕТ', 'Gen', 'средство'), 9),
#   (('ИЗ', 'Gen', 'бюджет'), 9),
#   (('ИЗ', 'Gen', 'соображение'), 9),
#   (('ПРИ', 'Loc', 'вид'), 9),
#   (('ЗА', 'Acc', 'предел'), 9),
#   (('_', 'Ins', 'сила'), 9),
#   (('ПОД', 'Ins', 'имя'), 9),
#   (('К', 'Dat', 'жизнь'), 9),
#   (('_', 'Acc', 'сигарета'), 9),
#   (('В', 'Acc', 'окно'), 9),
#   (('_', 'Acc', 'губа'), 9),
#   (('_', 'Nom', 'мысль'), 9),
#   (('К', 'Dat', 'нога'), 9),
#   (('СО', 'Gen', 'нога'), 9),
#   (('НА', 'Loc', 'путь'), 9),
#   (('_', 'Ins', 'слово'), 9),
#   (('С', 'Ins', 'точность'), 9),
#   (('ПЕРЕД', 'Ins', 'зеркало'), 9),
#   (('_', 'Ins', 'кровь'), 9),
#   (('НА', 'Acc', 'плечо'), 9),
#   (('_', 'Ins', 'палец'), 9),
#   (('НА', 'Acc', 'ухо'), 9),
#   (('В', 'Acc', 'земля'), 9),
#   (('_', 'Nom', 'кровь'), 9),
#   (('_', 'Acc', 'вода'), 9),
#   (('_', 'Ins', 'губа'), 9),
#   (('ПРИ', 'Loc', 'встреча'), 8),
#   (('ЗА', 'Acc', 'граница'), 8),
#   (('_', 'Ins', 'жизнь'), 8),
#   (('ИЗ', 'Gen', 'расчёт'), 8),
#   (('С', 'Gen', 'момент'), 8),
#   (('У', 'Gen', 'власть'), 8),
#   (('ПОД', 'Acc', 'рука'), 8),
#   (('ЧЕРЕЗ', 'Acc', 'край'), 8),
#   (('ПРИ', 'Loc', 'температура'), 8),
#   (('ПРИ', 'Loc', 'свет'), 8),
#   (('В СООТВЕТСТВИИ С', 'Ins', 'положение'), 8),
#   (('С', 'Ins', 'удовольствие'), 8),
#   (('ПО', 'Dat', 'дело'), 8),
#   (('НА', 'Acc', 'сторона'), 8),
#   (('ДО', 'Gen', 'время'), 8),
#   (('СО', 'Gen', 'стол'), 8),
#   (('ЗА', 'Acc', 'сутки'), 8),
#   (('С', 'Ins', 'скорость'), 8),
#   (('В', 'Acc', 'голова'), 8),
#   (('ИЗ', 'Gen', 'дом'), 8),
#   (('ПОД', 'Ins', 'взгляд'), 8),
#   (('ВО', 'Acc', 'глаз'), 8),
#   (('ПО', 'Dat', 'телефон'), 8),
#   (('_', 'Ins', 'лицо'), 8),
#   (('НА', 'Acc', 'жизнь'), 8),
#   (('ПО', 'Dat', 'мнение'), 8),
#   (('ЗА', 'Acc', 'спина'), 8),
#   (('НА', 'Loc', 'ветер'), 8),
#   (('В', 'Acc', 'страна'), 8),
#   (('НА', 'Acc', 'голова'), 8),
#   (('_', 'Nom', 'рука'), 8),
#   (('_', 'Nom', 'стена'), 8),
#   (('ПО', 'Acc', 'ухо'), 8),
#   (('_', 'Nom', 'нога'), 8),
#   (('_', 'Gen', 'год'), 7),
#   (('В КАЧЕСТВЕ', 'Gen', 'пример'), 7),
#   (('С', 'Gen', 'работа'), 7),
#   (('В ХОДЕ', 'Gen', 'сессия'), 7),
#   (('В', 'Acc', 'рука'), 7),
#   (('КО', 'Dat', 'двор'), 7),
#   (('В', 'Loc', 'рамка'), 7),
#   (('ПРОТИВ', 'Gen', 'воля'), 7),
#   (('СРЕДИ', 'Gen', 'ночь'), 7),
#   (('В', 'Loc', 'сердце'), 7),
#   (('У', 'Gen', 'человек'), 7),
#   (('В КАЧЕСТВЕ', 'Gen', 'мера'), 7),
#   (('_', 'Par', 'чай'), 7),
#   (('В', 'Loc', 'связь'), 7),
#   (('ПОД', 'Ins', 'влияние'), 7),
#   (('В', 'Acc', 'вода'), 7),
#   (('В', 'Loc', 'вода'), 7),
#   (('_', 'Nom', 'компания'), 7),
#   (('ПО', 'Dat', 'проект'), 7),
#   (('В', 'Loc', 'мера'), 7),
#   (('НА', 'Acc', 'работа'), 7),
#   (('ПОД', 'Ins', 'контроль'), 7),
#   (('ДЛЯ', 'Gen', 'цель'), 7),
#   (('ПО', 'Dat', 'закон'), 7),
#   (('НА', 'Loc', 'полуслово'), 7),
#   (('НА', 'Loc', 'лицо'), 7),
#   (('ЗА', 'Acc', 'нарушение'), 7),
#   (('НА', 'Loc', 'кладбище'), 7),
#   (('ВО', 'Loc', 'мнение'), 7),
#   (('ВО', 'Loc', 'взгляд'), 7),
#   (('В', 'Acc', 'жизнь'), 7),
#   (('ДО', 'Gen', 'глубина'), 7),
#   (('_', 'Acc', 'лицо'), 7),
#   (('ОТ', 'Gen', 'неожиданность'), 7),
#   (('ИЗ', 'Gen', 'глаз'), 7),
#   (('_', 'Ins', 'ветер'), 7),
#   (('НА', 'Loc', 'скорость'), 7),
#   (('_', 'Ins', 'солнце'), 7),
#   (('К', 'Dat', 'стена'), 7),
#   (('_', 'Acc', 'нога'), 7),
#   (('_', 'Ins', 'волна'), 7),
#   (('_', 'Nom', 'голос'), 7),
#   (('К', 'Dat', 'небо'), 7),
#   (('КО', 'Dat', 'время'), 6),
#   (('С', 'Gen', 'нуль'), 6),
#   (('ПО МЕРЕ', 'Gen', 'необходимость'), 6),
#   (('ДО', 'Gen', 'боль'), 6),
#   (('_', 'Nom', 'президент'), 6),
#   (('С', 'Ins', 'визит'), 6),
#   (('С', 'Gen', 'территория'), 6),
#   (('КО', 'Dat', 'чтение'), 6),
#   (('В', 'Acc', 'честь'), 6),
#   (('В', 'Loc', 'страна'), 6),
#   (('СО', 'Gen', 'дно'), 6),
#   (('В ХОДЕ', 'Gen', 'реформа'), 6),
#   (('СО', 'Gen', 'сцена'), 6),
#   (('ЧЕРЕЗ', 'Acc', 'граница'), 6),
#   (('ПОД', 'Acc', 'завязка'), 6),
#   (('ЗА', 'Ins', 'руль'), 6),
#   (('ПЕРЕД', 'Ins', 'нос'), 6),
#   (('ОТ', 'Gen', 'усталость'), 6),
#   (('_', 'Dat', 'человек'), 6),
#   (('НА', 'Acc', 'рука'), 6),
#   (('ВО', 'Loc', 'тур'), 6),
#   (('ЗА', 'Acc', 'решётка'), 6),
#   (('ЧЕРЕЗ', 'Acc', 'голова'), 6),
#   (('_', 'Ins', 'место'), 6),
#   (('_', 'Nom', 'собака'), 6),
#   (('В', 'Acc', 'год'), 6),
#   (('_', 'Gen', 'тонна'), 6),
#   (('С', 'Ins', 'улыбка'), 6),
#   (('ВО', 'Acc', 'карман'), 6),
#   (('_', 'Nom', 'ситуация'), 6),
#   (('ЗА', 'Acc', 'дверь'), 6),
#   (('_', 'Acc', 'год'), 6),
#   (('БЕЗ', 'Gen', 'изменение'), 6),
#   (('_', 'Ins', 'лето'), 6),
#   (('НА', 'Acc', 'срок'), 6),
#   (('НА', 'Loc', 'кухня'), 6),
#   (('ЗА', 'Acc', 'угол'), 6),
#   (('ВО', 'Acc', 'рост'), 6),
#   (('ИЗ', 'Gen', 'год'), 6),
#   (('ЗА', 'Acc', 'год'), 6),
#   (('ПО', 'Dat', 'комната'), 6),
#   (('ОТ', 'Gen', 'мир'), 6),
#   (('СКВОЗЬ', 'Acc', 'толпа'), 6),
#   (('ПО', 'Dat', 'повод'), 6),
#   (('НА', 'Loc', 'грудь'), 6),
#   (('В', 'Loc', 'среднее'), 6),
#   (('ВОКРУГ', 'Gen', 'ось'), 6),
#   (('ПО', 'Dat', 'вопрос'), 6),
#   (('С', 'Ins', 'бой'), 6),
#   (('У', 'Gen', 'нога'), 6),
#   (('ПРИ', 'Loc', 'империя'), 6),
#   (('ОТ', 'Gen', 'время'), 6),
#   (('_', 'Ins', 'ночь'), 6),
#   (('_', 'Ins', 'краска'), 6),
#   (('В', 'Acc', 'клок'), 6),
#   (('ПО', 'Dat', 'дорога'), 6),
#   (('В', 'Loc', 'грудь'), 6),
#   (('В', 'Acc', 'лицо'), 6),
#   (('_', 'Ins', 'нож'), 6),
#   (('К', 'Dat', 'берег'), 6),
#   (('_', 'Acc', 'срок'), 6),
#   (('К', 'Dat', 'земля'), 6),
#   (('В', 'Acc', 'такт'), 6),
#   (('В', 'Acc', 'голос'), 6),
#   (('ЗА', 'Acc', 'счёт'), 5),
#   (('ОКОЛО', 'Gen', 'человек'), 5),
#   (('В СВЯЗИ С', 'Ins', 'рассмотрение'), 5),
#   (('В КАЧЕСТВЕ', 'Gen', 'свидетель'), 5),
#   (('В ХОДЕ', 'Gen', 'война'), 5),
#   (('СО', 'Gen', 'день'), 5),
#   (('НА', 'Loc', 'сессия'), 5),
#   (('СО', 'Gen', 'слово'), 5),
#   (('ПО', 'Dat', 'имя'), 5),
#   (('НА', 'Acc', 'рассмотрение'), 5),
#   (('В ТЕЧЕНИЕ', 'Gen', 'день'), 5),
#   (('К', 'Dat', 'стол'), 5),
#   (('ПЕРЕД', 'Ins', 'сон'), 5),
#   (('_', 'Gen', 'раз'), 5),
#   (('НА', 'Acc', 'поверхность'), 5),
#   (('ВНЕ', 'Gen', 'закон'), 5),
#   (('ПОД', 'Acc', 'утро'), 5),
#   (('_', 'Gen', 'внимание'), 5),
#   (('К', 'Dat', 'время'), 5),
#   (('_', 'Gen', 'метр'), 5),
#   (('ОТ', 'Gen', 'лицо'), 5),
#   (('ЧЕРЕЗ', 'Acc', 'время'), 5),
#   (('СПУСТЯ', 'Acc', 'время'), 5),
#   (('_', 'Nom', 'комитет'), 5),
#   (('_', 'Ins', 'суд'), 5),
#   (('ИЗ', 'Gen', 'карман'), 5),
#   (('С', 'Ins', 'парашют'), 5),
#   (('С', 'Ins', 'треск'), 5),
#   (('ДЛЯ', 'Gen', 'обеспечение'), 5),
#   (('_', 'Acc', 'дорога'), 5),
#   (('В', 'Loc', 'степень'), 5),
#   (('ЧЕРЕЗ', 'Acc', 'окно'), 5),
#   (('_', 'Nom', 'самолёт'), 5),
#   (('НА', 'Acc', 'сумма'), 5),
#   (('С', 'Ins', 'ответ'), 5),
#   (('_', 'Nom', 'право'), 5),
#   (('_', 'Ins', 'огонь'), 5),
#   (('В ХОДЕ', 'Gen', 'кампания'), 5),
#   (('В', 'Loc', 'цель'), 5),
#   (('ПРИ', 'Loc', 'необходимость'), 5),
#   (('БЕЗ', 'Gen', 'основание'), 5),
#   (('У', 'Gen', 'дверь'), 5),
#   (('ОТ', 'Gen', 'рука'), 5),
#   (('_', 'Acc', 'взгляд'), 5),
#   (('ВО', 'Acc', 'раз'), 5),
#   (('_', 'Ins', 'вечер'), 5),
#   (('С', 'Gen', 'время'), 5),
#   (('_', 'Nom', 'карикатурист'), 5),
#   (('В', 'Acc', 'поддержка'), 5),
#   (('С', 'Ins', 'почесть'), 5),
#   (('_', 'Acc', 'память'), 5),
#   (('_', 'Gen', 'слово'), 5),
#   (('С', 'Gen', 'дорога'), 5),
#   (('В', 'Loc', 'порядок'), 5),
#   (('ДО', 'Gen', 'голова'), 5),
#   (('ПО', 'Dat', 'ночь'), 5),
#   (('НА', 'Loc', 'карта'), 5),
#   (('ПО', 'Dat', 'ставка'), 5),
#   (('ДО', 'Gen', 'край'), 5),
#   (('ПОД', 'Ins', 'глаз'), 5),
#   (('_', 'Acc', 'сердце'), 5),
#   (('_', 'Acc', 'палец'), 5),
#   (('НА', 'Acc', 'берег'), 5),
#   (('ПО', 'Dat', 'очередь'), 5),
#   (('В', 'Loc', 'поцелуй'), 5),
#   (('ЗА', 'Acc', 'плечо'), 5),
#   (('_', 'Acc', 'человек'), 5),
#   (('ПО', 'Dat', 'река'), 5),
#   (('_', 'Nom', 'солнце'), 5),
#   (('НА', 'Loc', 'стол'), 5),
#   (('НА', 'Loc', 'высота'), 5),
#   (('В', 'Loc', 'горло'), 5),
#   (('ОТ', 'Gen', 'волнение'), 5),
#   (('ИЗ', 'Gen', 'память'), 5),
#   (('НА', 'Acc', 'глаз'), 5),
#   (('НА', 'Acc', 'план'), 5),
#   (('_', 'Acc', 'ребёнок'), 5),
#   (('_', 'Ins', 'полотенце'), 5),
#   (('_', 'Acc', 'вина'), 5),
#   (('В', 'Acc', 'угол'), 5),
#   (('_', 'Nom', 'сон'), 5),
#   (('_', 'Nom', 'слеза'), 5),
#   (('_', 'Acc', 'тело'), 5),
#   (('_', 'Ins', 'смех'), 5),
#   (('НА', 'Loc', 'душа'), 5),
#   (('_', 'Acc', 'мяч'), 5),
#   (('_', 'Acc', 'рана'), 5),
#   (('_', 'Acc', 'слеза'), 5),
#   (('РАДИ', 'Gen', 'справедливость'), 4),
#   (('БЕЗ', 'Gen', 'сомнение'), 4),
#   (('ПЕРЕД', 'Ins', 'война'), 4),
#   (('У', 'Gen', 'здание'), 4),
#   (('ВО', 'Acc', 'внимание'), 4),
#   (('КО', 'Dat', 'дно'), 4),
#   (('ПОД', 'Ins', 'флаг'), 4),
#   (('С', 'Gen', 'взгляд'), 4),
#   (('В СВЯЗИ С', 'Ins', 'вопрос'), 4),
#   (('_', 'Gen', 'дело'), 4),
#   (('С', 'Ins', 'нетерпение'), 4),
#   (('ИЗ', 'Gen', 'уста'), 4),
#   (('ДЛЯ', 'Gen', 'обсуждение'), 4),
#   (('ПОД', 'Acc', 'конец'), 4),
#   (('БЕЗ', 'Gen', 'остаток'), 4),
#   (('СО', 'Ins', 'скидка'), 4),
#   (('В КАЧЕСТВЕ', 'Gen', 'подарок'), 4),
#   (('КО', 'Dat', 'вход'), 4),
#   (('В СООТВЕТСТВИИ С', 'Ins', 'правило'), 4),
#   (('В КАЧЕСТВЕ', 'Gen', 'доказательство'), 4),
#   (('ДО', 'Gen', 'кровь'), 4),
#   (('ПРИ', 'Loc', 'попытка'), 4),
#   (('_', 'Ins', 'залп'), 4),
#   (('ДО', 'Gen', 'дно'), 4),
#   (('НА', 'Acc', 'стол'), 4),
#   (('_', 'Ins', 'утро'), 4),
#   (('С', 'Gen', 'порог'), 4),
#   (('В', 'Acc', 'больница'), 4),
#   (('С', 'Gen', 'ум'), 4),
#   (('_', 'Ins', 'сон'), 4),
#   (('_', 'Acc', 'ремень'), 4),
#   (('ЗА', 'Acc', 'ухо'), 4),
#   (('У', 'Gen', 'берег'), 4),
#   (('_', 'Nom', 'окно'), 4),
#   (('ПО', 'Dat', 'лестница'), 4),
#   (('К', 'Dat', 'счастие'), 4),
#   (('_', 'Ins', 'сторона'), 4),
#   (('БЕЗ', 'Gen', 'след'), 4),
#   (('ПОД', 'Acc', 'вода'), 4),
#   (('ПОД', 'Acc', 'арест'), 4),
#   (('БЕЗ', 'Gen', 'объяснение'), 4),
#   (('_', 'Acc', 'машина'), 4),
#   (('_', 'Gen', '.'), 4),
#   (('ОТ', 'Gen', 'должность'), 4),
#   (('В ХОДЕ', 'Gen', 'операция'), 4),
#   (('ЗА', 'Acc', 'период'), 4),
#   (('_', 'Acc', 'история'), 4),
#   (('ПОД', 'Acc', 'стража'), 4),
#   (('ИЗ', 'Gen', 'больница'), 4),
#   (('_', 'Nom', 'время'), 4),
#   (('ЗА', 'Ins', 'ненадобность'), 4),
#   (('В', 'Loc', 'голос'), 4),
#   (('_', 'Nom', 'внимание'), 4),
#   (('ПРИ', 'Loc', 'жизнь'), 4),
#   (('_', 'Ins', 'зима'), 4),
#   (('_', 'Gen', 'дрова'), 4),
#   (('_', 'Ins', 'жест'), 4),
#   (('ДО', 'Gen', 'начало'), 4),
#   (('ПО', 'Dat', 'периметр'), 4),
#   (('ПОД', 'Ins', 'дождь'), 4),
#   (('ПРИ', 'Loc', 'участие'), 4),
#   (('С', 'Gen', 'рынок'), 4),
#   (('СО', 'Ins', 'вкус'), 4),
#   (('_', 'Acc', 'пара'), 4),
#   (('_', 'Acc', 'гость'), 4),
#   (('СКВОЗЬ', 'Acc', 'палец'), 4),
#   (('НА', 'Loc', 'счёт'), 4),
#   (('НА', 'Loc', 'работа'), 4),
#   (('НА', 'Acc', 'роль'), 4),
#   (('НА', 'Loc', 'рука'), 4),
#   (('НА', 'Loc', 'колено'), 4),
#   (('В', 'Acc', 'кресло'), 4),
#   (('_', 'Nom', 'улыбка'), 4),
#   (('ПО', 'Dat', 'дом'), 4),
#   (('ДО', 'Gen', 'основание'), 4),
#   (('НА', 'Acc', 'слава'), 4),
#   (('_', 'Nom', 'рана'), 4),
#   (('_', 'Ins', 'война'), 4),
#   (('В', 'Acc', 'ворота'), 4),
#   (('НА', 'Acc', 'мысль'), 4),
#   (('_', 'Nom', 'машина'), 4),
#   (('ПОСЛЕ', 'Gen', 'война'), 4),
#   (('В', 'Loc', 'пространство'), 4),
#   (('_', 'Ins', 'плечо'), 4),
#   (('ВО', 'Acc', 'рот'), 4),
#   (('_', 'Acc', 'зуб'), 4),
#   (('В', 'Loc', 'стиль'), 4),
#   (('С', 'Ins', 'корень'), 4),
#   (('НА', 'Loc', 'цыпочка'), 4),
#   (('_', 'Ins', 'день'), 4),
#   (('НА', 'Loc', 'машина'), 4),
#   (('_', 'Nom', 'срок'), 4),
#   (('В', 'Acc', 'ряд'), 4),
#   (('_', 'Nom', 'власть'), 4),
#   (('_', 'Ins', 'галоп'), 4),
#   (('НА', 'Loc', 'условие'), 4),
#   (('_', 'Acc', 'рот'), 4),
#   (('_', 'Nom', 'воздух'), 4),
#   (('В', 'Loc', 'право'), 4),
#   (('ДО', 'Gen', 'кость'), 4),
#   (('В', 'Loc', 'ум'), 4),
#   (('НА', 'Acc', 'бок'), 4),
#   (('В', 'Acc', 'небо'), 4),
#   (('В', 'Loc', 'ожидание'), 4),
#   (('С', 'Gen', 'небо'), 4),
#   (('_', 'Nom', 'телефон'), 4),
#   (('_', 'Nom', 'небо'), 4),
#   (('_', 'Acc', 'бровь'), 4),
#   (('В', 'Loc', 'количество'), 4),
#   (('_', 'Ins', 'поток'), 4),
#   (('_', 'Acc', 'ночь'), 4),
#   (('СО', 'Ins', 'свист'), 4),
#   (('_', 'Ins', 'мысль'), 4),
#   (('ЗА', 'Ins', 'ухо'), 4),
#   (('В', 'Acc', 'кулак'), 4),
#   (('ПО', 'Dat', 'тело'), 4),
#   (('ОТ', 'Gen', 'удовольствие'), 4),
#   (('_', 'Dat', 'шутка'), 4),
#   (('НА', 'Acc', 'часть'), 4),
#   (('ДО', 'Gen', 'нитка'), 4),
#   (('_', 'Ins', 'хвост'), 4),
#   (('_', 'Nom', 'тело'), 4),
#   (('_', 'Nom', 'чёрт'), 4),
#   (('_', 'Acc', 'окно'), 4),
#   (('В', 'Acc', 'ладоши'), 4),
#   (('В', 'Loc', 'затылок'), 4),
#   (('_', 'Acc', 'мозг'), 4),
#   (('НА', 'Acc', 'кухня'), 4),
#   (('_', 'Ins', 'спина'), 4),
#   (('ПО', 'Dat', 'карман'), 4),
#   (('_', 'Nom', 'корова'), 4),
#   (('_', 'Acc', 'грех'), 4),
#   (('_', 'Ins', 'улыбка'), 3),
#   (('ОТ', 'Gen', 'брак'), 3),
#   (('_', 'Nom', 'семья'), 3),
#   (('ВО', 'Loc', 'чтение'), 3),
#   (('С', 'Gen', 'космодром'), 3),
#   (('С', 'Ins', 'удовлетворение'), 3),
#   (('СО', 'Ins', 'страх'), 3),
#   (('_', 'Nom', 'река'), 3),
#   (('НА', 'Acc', 'доля'), 3),
#   (('ПО', 'Dat', 'просьба'), 3),
#   (('_', 'Dat', 'хиротония'), 3),
#   (('ВО', 'Acc', 'владение'), 3),
#   (('_', 'Ins', 'корень'), 3),
#   (('БЕЗ', 'Gen', 'остановка'), 3),
#   (('ПОД', 'Ins', 'псевдоним'), 3),
#   (('_', 'Acc', 'вопрос'), 3),
#   (('НА', 'Acc', 'деньга'), 3),
#   (('БЛАГОДАРЯ', 'Dat', 'гол'), 3),
#   (('ЗА', 'Acc', 'глаз'), 3),
#   (('ВО', 'Loc', 'квартал'), 3),
#   (('ОТ', 'Gen', 'продажа'), 3),
#   (('_', 'Acc', 'место'), 3),
#   (('С', 'Ins', 'формулировка'), 3),
#   (('У', 'Gen', 'компания'), 3),
#   (('МЕЖДУ', 'Ins', 'дело'), 3),
#   (('ЗА', 'Ins', 'отсутствие'), 3),
#   (('ВО', 'Loc', 'декларация'), 3),
#   (('В СВЯЗИ С', 'Ins', 'проведение'), 3),
#   (('В', 'Acc', 'пища'), 3),
#   (('ВМЕСТО', 'Gen', 'слово'), 3),
#   (('_', 'Ins', 'время'), 3),
#   (('В КАЧЕСТВЕ', 'Gen', 'документ'), 3),
#   (('СО', 'Ins', 'очевидность'), 3),
#   (('БЕЗ', 'Gen', 'сознание'), 3),
#   (('ВО', 'Acc', 'глава'), 3),
#   (('ПОСРЕДИ', 'Gen', 'ночь'), 3),
#   (('ПО', 'Dat', 'факт'), 3),
#   (('_', 'Acc', 'дело'), 3),
#   (('ОКОЛО', 'Gen', 'рубль'), 3),
#   (('_', 'Dat', 'власть'), 3),
#   (('С', 'Ins', 'мысль'), 3),
#   (('С', 'Ins', 'поличное'), 3),
#   (('_', 'Acc', 'экзамен'), 3),
#   (('БЕЗ', 'Gen', 'бой'), 3),
#   (('ЗА', 'Acc', 'стол'), 3),
#   (('В', 'Acc', 'распоряжение'), 3),
#   (('ЧЕРЕЗ', 'Acc', 'призма'), 3),
#   (('В', 'Acc', 'запас'), 3),
#   (('СРЕДИ', 'Gen', 'гость'), 3),
#   (('ПОД', 'Ins', 'угроза'), 3),
#   (('ПОСЛЕ', 'Gen', 'удар'), 3),
#   (('ДЛЯ', 'Gen', 'удар'), 3),
#   (('НА', 'Acc', 'помощь'), 3),
#   (('_', 'Ins', 'тираж'), 3),
#   (('ПОД', 'Ins', 'вид'), 3),
#   (('ВО', 'Loc', 'война'), 3),
#   (('СО', 'Gen', 'спина'), 3),
#   (('_', 'Ins', 'самоубийство'), 3),
#   (('БЕЗ', 'Gen', 'весть'), 3),
#   (('В', 'Loc', 'место'), 3),
#   (('СО', 'Ins', 'слово'), 3),
#   (('В', 'Loc', 'церковь'), 3),
#   (('В', 'Acc', 'жертва'), 3),
#   (('ПЕРЕД', 'Ins', 'слово'), 3),
#   (('ПОД', 'Ins', 'вода'), 3),
#   (('ОТ', 'Gen', 'дверь'), 3),
#   (('СО', 'Gen', 'сила'), 3),
#   (('ПОД', 'Ins', 'огонь'), 3),
#   (('В СООТВЕТСТВИИ С', 'Ins', 'понимание'), 3),
#   (('ВДОЛЬ', 'Gen', 'стена'), 3),
#   (('С', 'Ins', 'мир'), 3),
#   (('_', 'Acc', 'секретарь'), 3),
#   (('ПОСЛЕ', 'Gen', 'консультация'), 3),
#   (('ПРИ', 'Loc', 'обстоятельство'), 3),
#   (('В', 'Loc', 'борьба'), 3),
#   (('ПОД', 'Ins', 'стол'), 3),
#   (('_', 'Nom', 'деревня'), 3),
#   (('В', 'Loc', 'состав'), 3),
#   (('ИЗ', 'Gen', 'вид'), 3),
#   (('_', 'Acc', 'право'), 3),
#   (('НА', 'Acc', 'вопрос'), 3),
#   (('К', 'Dat', 'удивление'), 3),
#   (('ПОД', 'Acc', 'земля'), 3),
#   (('_', 'Ins', 'чудо'), 3),
#   (('_', 'Acc', 'дерево'), 3),
#   (('_', 'Gen', 'вода'), 3),
#   (('ВО ВРЕМЯ', 'Gen', 'кампания'), 3),
#   (('КО', 'Dat', 'сон'), 3),
#   (('СОГЛАСНО', 'Dat', 'прогноз'), 3),
#   (('ЗА', 'Acc', 'деньга'), 3),
#   (('ЗА', 'Ins', 'дверь'), 3),
#   (('С', 'Gen', 'язык'), 3),
#   (('В', 'Loc', 'карман'), 3),
#   (('ВМЕСТО', 'Gen', 'ответ'), 3),
#   (('ВО', 'Loc', 'взаимодействие'), 3),
#   (('ПОД', 'Acc', 'одеяло'), 3),
#   (('В', 'Loc', 'интервью'), 3),
#   (('ЧЕРЕЗ', 'Acc', 'стол'), 3),
#   (('В', 'Acc', 'состав'), 3),
#   (('ПОСЛЕ', 'Gen', 'реформа'), 3),
#   (('В', 'Acc', 'карман'), 3),
#   (('_', 'Ins', 'грудь'), 3),
#   (('НА', 'Loc', 'площадь'), 3),
#   (('_', 'Dat', 'народ'), 3),
#   (('В', 'Loc', 'пепельница'), 3),
#   (('НА', 'Loc', 'пот'), 3),
#   (('_', 'Dat', 'журналист'), 3),
#   (('_', 'Ins', 'снег'), 3),
#   (('БЕЗ', 'Gen', 'разрешение'), 3),
#   (('БЛАГОДАРЯ', 'Dat', 'победа'), 3),
#   (('_', 'Ins', 'путь'), 3),
#   (('_', 'Acc', 'порог'), 3),
#   (('В', 'Acc', 'плен'), 3),
#   (('ПО', 'Loc', 'истечение'), 3),
#   (('В', 'Acc', 'глаз'), 3),
#   (('С', 'Acc', 'контракт'), 3),
#   (('В ХОДЕ', 'Gen', 'визит'), 3),
#   (('_', 'Acc', 'стол'), 3),
#   (('ПУТЕМ', 'Gen', 'голосование'), 3),
#   (('В КАЧЕСТВЕ', 'Gen', 'причина'), 3),
#   (('ПО', 'Dat', 'рука'), 3),
#   (('В', 'Loc', 'условие'), 3),
#   (('СО', 'Ins', 'слеза'), 3),
#   (('БЕЗ', 'Gen', 'память'), 3),
#   (('НА', 'Acc', 'период'), 3),
#   (('ПЕРЕД', 'Ins', 'лицо'), 3),
#   (('_', 'Gen', 'усилие'), 3),
#   (('_', 'Acc', 'век'), 3),
#   (('К', 'Dat', 'участие'), 3),
#   (('В', 'Acc', 'сумма'), 3),
#   (('_', 'Nom', 'ребёнок'), 3),
#   (('ОТ', 'Gen', 'глаз'), 3),
#   (('_', 'Ins', 'компания'), 3),
#   (('ДО', 'Gen', 'размер'), 3),
#   (('НА', 'Loc', 'корень'), 3),
#   (('_', 'Nom', 'жизнь'), 3),
#   (('_', 'Nom', 'необходимость'), 3),
#   (('КО', 'Dat', 'чёрт'), 3),
#   (('ДО', 'Gen', 'дыра'), 3),
#   (('СО', 'Gen', 'место'), 3),
#   (('НА', 'Acc', 'лад'), 3),
#   (('СО', 'Gen', 'стена'), 3),
#   (('У', 'Gen', 'висок'), 3),
#   (('НА', 'Loc', 'палец'), 3),
#   (('_', 'Acc', 'имя'), 3),
#   (('_', 'Acc', 'победа'), 3),
#   (('ЗА', 'Acc', 'день'), 3),
#   (('В', 'Acc', 'путь'), 3),
#   (('В', 'Loc', 'аэропорт'), 3),
#   (('В', 'Acc', 'адрес'), 3),
#   (('В ТЕЧЕНИЕ', 'Gen', 'год'), 3),
#   (('_', 'Acc', 'интерес'), 3),
#   (('НА', 'Loc', 'воздух'), 3),
#   (('_', 'Gen', 'сила'), 3),
#   (('В ХОДЕ', 'Gen', 'учение'), 3),
#   (('КО', 'Dat', 'лоб'), 3),
#   (('ОКОЛО', 'Gen', 'отметка'), 3),
#   (('В', 'Loc', 'бой'), 3),
#   (('_', 'Nom', 'дождь'), 3),
#   (('ОБ', 'Loc', 'опасность'), 3),
#   (('НА', 'Acc', 'земля'), 3),
#   (('В', 'Loc', 'начало'), 3),
#   (('О', 'Loc', 'необходимость'), 3),
#   (('НА', 'Loc', 'прощание'), 3),
#   (('В ХОДЕ', 'Gen', 'бой'), 3),
#   (('ОТ', 'Gen', 'коронавирус'), 3),
#   (('С', 'Gen', 'январь'), 3),
#   (('ЧЕРЕЗ', 'Acc', 'сила'), 3),
#   (('СКВОЗЬ', 'Acc', 'слеза'), 3),
#   (('_', 'Acc', 'песня'), 3),
#   (('НА', 'Acc', 'рынок'), 3),
#   (('_', 'Nom', 'бог'), 3),
#   (('_', 'Nom', 'губа'), 3),
#   (('НА', 'Loc', 'станция'), 3),
#   (('ВО', 'Acc', 'власть'), 3),
#   (('_', 'Acc', 'бог'), 3),
#   (('В', 'Acc', 'зеркало'), 3),
#   (('РАДИ', 'Gen', 'бог'), 3),
#   (('С', 'Ins', 'земля'), 3),
#   (('ПОД', 'Acc', 'удар'), 3),
#   (('ОТ', 'Gen', 'снег'), 3),
#   (('В', 'Loc', 'жизнь'), 3),
#   (('В', 'Loc', 'душа'), 3),
#   (('ПОД', 'Ins', 'тяжесть'), 3),
#   (('_', 'Nom', 'след'), 3),
#   (('_', 'Ins', 'человек'), 3),
#   (('ИЗ', 'Gen', 'засада'), 3),
#   (('_', 'Ins', 'камень'), 3),
#   (('В', 'Acc', 'ухо'), 3),
#   (('ПЕРЕД', 'Ins', 'смерть'), 3),
#   (('_', 'Nom', 'бюджет'), 3),
#   (('ПО', 'Dat', 'щека'), 3),
#   (('_', 'Acc', 'желание'), 3),
#   (('ОТ', 'Gen', 'партия'), 3),
#   (('НА', 'Loc', 'лодка'), 3),
#   (('ПО', 'Dat', 'почта'), 3),
#   (('ПОД', 'Ins', 'ложечка'), 3),
#   (('ДО', 'Gen', 'небо'), 3),
#   (('_', 'Ins', 'шаг'), 3),
#   (('_', 'Acc', 'ситуация'), 3),
#   (('К', 'Dat', 'грудь'), 3),
#   (('ПО', 'Dat', 'причина'), 3),
#   (('_', 'Acc', 'мысль'), 3),
#   (('_', 'Acc', 'тесто'), 3),
#   (('С', 'Gen', 'высота'), 3),
#   (('_', 'Nom', 'марка'), 3),
#   (('НА', 'Acc', 'час'), 3),
#   (('В', 'Loc', 'конец'), 3),
#   (('НА', 'Acc', 'царство'), 3),
#   (('_', 'Acc', 'рукав'), 3),
#   (('_', 'Acc', 'язык'), 3),
#   (('ОТ', 'Gen', 'слеза'), 3),
#   (('НА', 'Acc', 'дно'), 3),
#   (('_', 'Dat', 'страх'), 3),
#   (('В', 'Acc', 'куча'), 3),
#   (('В', 'Loc', 'район'), 3),
#   (('ДО', 'Gen', 'скорость'), 3),
#   (('_', 'Ins', 'поцелуй'), 3),
#   (('БЕЗ', 'Gen', 'суд'), 3),
#   (('В', 'Loc', 'ресторан'), 3),
#   (('_', 'Ins', 'гвоздь'), 3),
#   (('БЕЗ', 'Gen', 'дело'), 3),
#   (('В', 'Acc', 'режим'), 3),
#   (('_', 'Nom', 'пользователь'), 3),
#   (('_', 'Nom', 'взгляд'), 3),
#   (('НА', 'Acc', 'спинка'), 3),
#   (('НА', 'Acc', 'аэродром'), 3),
#   (('В', 'Acc', 'знак'), 3),
#   (('ОТ', 'Gen', 'холод'), 3),
#   (('_', 'Nom', 'девушка'), 3),
#   (('_', 'Acc', 'душа'), 3),
#   (('_', 'Acc', 'стена'), 3),
#   (('_', 'Ins', 'голод'), 3),
#   (('_', 'Acc', 'нерв'), 3),
#   (('_', 'Ins', 'оружие'), 3),
#   (('_', 'Acc', 'бутылка'), 3),
#   (('_', 'Ins', 'красота'), 3),
#   (('НА', 'Acc', 'мир'), 3),
#   (('_', 'Ins', 'кулак'), 3),
#   (('НА', 'Acc', 'пол'), 3),
#   (('НА', 'Acc', 'сидение'), 3),
#   (('_', 'Acc', 'дурак'), 3),
#   (('ОТ', 'Gen', 'смех'), 3),
#   (('ПРИ', 'Loc', 'мысль'), 3),
#   (('С', 'Ins', 'вид'), 3),
#   (('_', 'Ins', 'дух'), 3),
#   (('К', 'Dat', 'горло'), 3),
#   (('В', 'Loc', 'живот'), 3),
#   (('_', 'Acc', 'вид'), 3),
#   (('ПО', 'Dat', 'стол'), 3),
#   (('В', 'Loc', 'земля'), 2),
#   (('_', 'Loc', 'посередине'), 2),
#   (('ВОКРУГ', 'Gen', 'стол'), 2),
#   (('ПЕРЕД', 'Ins', 'выбор'), 2),
#   (('ВНЕ', 'Gen', 'брак'), 2),
#   (('ДЛЯ', 'Gen', 'человек'), 2),
#   (('К', 'Dat', 'вывод'), 2),
#   (('_', 'Nom', 'решение'), 2),
#   (('НА', 'Acc', 'вооружение'), 2),
#   (('К', 'Dat', 'сведение'), 2),
#   (('_', 'Nom', 'речь'), 2),
#   (('МИМО', 'Gen', 'дом'), 2),
#   (('В', 'Loc', 'целое'), 2),
#   (('БЕЗ', 'Gen', 'участие'), 2),
#   (('_', 'Gen', 'время'), 2),
#   (('ЗА', 'Ins', 'неимение'), 2),
#   (('ПОД', 'Ins', 'председательство'), 2),
#   (('СО', 'Gen', 'станция'), 2),
#   (('ОКОЛО', 'Gen', 'год'), 2),
#   (('ПОД', 'Acc', 'диктовка'), 2),
#   (('_', 'Gen', 'вопрос'), 2),
#   (('ПОД', 'Acc', 'сила'), 2),
#   (('ЗА', 'Ins', 'подпись'), 2),
#   (('ВМЕСТО', 'Gen', 'уничтожение'), 2),
#   (('ПОД', 'Ins', 'номер'), 2),
#   (('ПРИ', 'Loc', 'бюджет'), 2),
#   (('ПОД', 'Acc', 'знамя'), 2),
#   (('ЗА', 'Acc', 'полночь'), 2),
#   (('В СООТВЕТСТВИИ С', 'Ins', 'процедура'), 2),
#   (('В СООТВЕТСТВИИ С', 'Ins', 'протокол'), 2),
#   (('ПРО', 'Acc', 'запас'), 2),
#   (('К', 'Dat', 'слово'), 2),
#   (('ДО', 'Gen', 'свидание'), 2),
#   (('В', 'Acc', 'воздух'), 2),
#   (('ПО', 'Dat', 'тревога'), 2),
#   (('СПУСТЯ', 'Acc', 'рукав'), 2),
#   (('ВО', 'Acc', 'вращение'), 2),
#   (('ЧЕРЕЗ', 'Acc', 'интернет'), 2),
#   (('В', 'Acc', 'отставка'), 2),
#   (('ДЛЯ', 'Gen', 'обозначение'), 2),
#   (('НА', 'Acc', 'ночь'), 2),
#   (('В ВИДЕ', 'Gen', 'исключение'), 2),
#   (('_', 'Gen', 'дом'), 2),
#   (('ДЛЯ', 'Gen', 'удобство'), 2),
#   (('ВО', 'Acc', 'дверь'), 2),
#   (('СОГЛАСНО', 'Dat', 'информация'), 2),
#   (('БЕЗ', 'Gen', 'успех'), 2),
#   (('_', 'Nom', 'пожар'), 2),
#   (('В КАЧЕСТВЕ', 'Gen', 'сингл'), 2),
#   (('ПОСЛЕ', 'Gen', 'завершение'), 2),
#   (('НА', 'Loc', 'рассвет'), 2),
#   (('В КАЧЕСТВЕ', 'Gen', 'основа'), 2),
#   (('_', 'Ins', 'закон'), 2),
#   (('МЕЖДУ', 'Ins', 'город'), 2),
#   (('К', 'Dat', 'ответственность'), 2),
#   (('_', 'Dat', 'правда'), 2),
#   (('_', 'Nom', 'хакер'), 2),
#   (('СКВОЗЬ', 'Acc', 'призма'), 2),
#   (('ПО', 'Dat', 'желание'), 2),
#   (('СО', 'Gen', 'служба'), 2),
#   (('ПОД', 'Ins', 'знак'), 2),
#   (('ЗА', 'Acc', 'жизнь'), 2),
#   (('ПОД', 'Acc', 'контроль'), 2),
#   (('ПОД', 'Ins', 'небо'), 2),
#   (('С', 'Gen', 'поле'), 2),
#   (('ПРИ', 'Loc', 'рассмотрение'), 2),
#   (('МЕЖДУ', 'Gen', 'нога'), 2),
#   (('ПО', 'Acc', 'душа'), 2),
#   (('В ХОДЕ', 'Gen', 'выбор'), 2),
#   (('_', 'Ins', 'пара'), 2),
#   (('_', 'Gen', 'работа'), 2),
#   (('_', 'Acc', 'обвинение'), 2),
#   (('ПО', 'Dat', 'неосторожность'), 2),
#   (('У', 'Gen', 'граница'), 2),
#   (('С', 'Ins', 'человек'), 2),
#   (('_', 'Acc', 'роль'), 2),
#   (('ВО ВРЕМЯ', 'Gen', 'пандемия'), 2),
#   (('В КАЧЕСТВЕ', 'Gen', 'кандидат'), 2),
#   (('БЕЗ', 'Gen', 'конец'), 2),
#   (('В', 'Acc', 'кювет'), 2),
#   (('СО', 'Ins', 'скандал'), 2),
#   (('СРЕДИ', 'Gen', 'дерево'), 2),
#   (('СО', 'Ins', 'смерть'), 2),
#   (('_', 'Nom', 'опасность'), 2),
#   (('ПО', 'Loc', 'возвращение'), 2),
#   (('ПОСЛЕ', 'Gen', 'драка'), 2),
#   (('НА', 'Loc', 'родина'), 2),
#   (('ПОСЛЕ', 'Gen', 'публикация'), 2),
#   (('БЕЗ', 'Gen', 'сопровождение'), 2),
#   (('НА', 'Loc', 'практика'), 2),
#   (('СРЕДИ', 'Gen', 'население'), 2),
#   (('В ХОДЕ', 'Gen', 'встреча'), 2),
#   (('О', 'Loc', 'помощь'), 2),
#   (('ПОД', 'Acc', 'кат'), 2),
#   (('СО', 'Gen', 'след'), 2),
#   (('ПОСЛЕ', 'Gen', 'болезнь'), 2),
#   (('В КАЧЕСТВЕ', 'Gen', 'государство'), 2),
#   (('СОГЛАСНО', 'Dat', 'список'), 2),
#   (('_', 'Acc', 'война'), 2),
#   (('_', 'Ins', 'бог'), 2),
#   (('ПО', 'Dat', 'оценка'), 2),
#   (('ПОД', 'Ins', 'завал'), 2),
#   (('_', 'Gen', 'жизнь'), 2),
#   (('ПОД', 'Acc', 'залог'), 2),
#   (('_', 'Nom', 'вид'), 2),
#   (('ДЛЯ', 'Gen', 'рассмотрение'), 2),
#   (('СО', 'Ins', 'степень'), 2),
#   (('В СВЯЗИ С', 'Ins', 'утрата'), 2),
#   (('ПОСЛЕ', 'Gen', 'перерыв'), 2),
#   (('_', 'Acc', 'впечатление'), 2),
#   (('С', 'Gen', 'горе'), 2),
#   (('ВО', 'Loc', 'краса'), 2),
#   (('НА', 'Loc', 'пост'), 2),
#   (('В ВИДЕ', 'Gen', 'взнос'), 2),
#   (('ПОД', 'Acc', 'суд'), 2),
#   (('БЕЗ', 'Gen', 'слово'), 2),
#   (('_', 'Ins', 'узел'), 2),
#   (('_', 'Acc', 'усилие'), 2),
#   (('ПЕРЕД', 'Ins', 'суд'), 2),
#   (('ВО ВРЕМЯ', 'Gen', 'шествие'), 2),
#   (('_', 'Acc', 'итог'), 2),
#   (('_', 'Nom', 'итог'), 2),
#   (('В КАЧЕСТВЕ', 'Gen', 'прилов'), 2),
#   (('ИЗ', 'Gen', 'зал'), 2),
#   (('ПОСРЕДСТВОМ', 'Gen', 'карточка'), 2),
#   (('ВО', 'Acc', 'исполнение'), 2),
#   (('БЕЗ', 'Gen', 'виза'), 2),
#   (('_', 'Dat', 'лицо'), 2),
#   (('В', 'Acc', 'постель'), 2),
#   (('_', 'Acc', 'цель'), 2),
#   (('_', 'Ins', 'лоб'), 2),
#   (('ПОД', 'Ins', 'стража'), 2),
#   (('ОТ', 'Gen', 'слово'), 2),
#   (('ОТ', 'Gen', 'удивление'), 2),
#   (('_', 'Ins', 'темп'), 2),
#   (('БЕЗ', 'Gen', 'право'), 2),
#   (('ЧЕРЕЗ', 'Acc', 'повешение'), 2),
#   (('С ПОМОЩЬЮ', 'Gen', 'карта'), 2),
#   (('ДЛЯ', 'Gen', 'проверка'), 2),
#   (('НА', 'Loc', 'ладонь'), 2),
#   (('_', 'Ins', 'смерть'), 2),
#   (('ЧЕРЕЗ', 'Acc', 'дверь'), 2),
#   (('С', 'Ins', 'облегчение'), 2),
#   (('_', 'Gen', 'километр'), 2),
#   (('_', 'Nom', 'выбор'), 2),
#   (('НА', 'Loc', 'поле'), 2),
#   (('ВО ВРЕМЯ', 'Gen', 'полёт'), 2),
#   (('ОТ', 'Gen', 'станция'), 2),
#   (('_', 'Ins', 'пуля'), 2),
#   (('СО', 'Gen', 'пост'), 2),
#   (('_', 'Ins', 'слеза'), 2),
#   (('ВО ВРЕМЯ', 'Gen', 'выступление'), 2),
#   (('В СВЯЗИ С', 'Ins', 'пандемия'), 2),
#   (('МЕЖДУ', 'Ins', 'бровь'), 2),
#   (('СО', 'Gen', 'скала'), 2),
#   (('ДО', 'Gen', 'потолок'), 2),
#   (('ПО', 'Dat', 'берег'), 2),
#   (('ПРИ', 'Loc', 'длина'), 2),
#   (('В', 'Loc', 'центр'), 2),
#   (('_', 'Nom', 'удар'), 2),
#   ...])

# %%
# !!! Можно освободить память, убрав всё, что не относится к прямым дополнениям.

# %%
all_nouns_freq = defaultdict(int)

for verb, comb1 in tqdm(verb_comb.items()):
    for prep, comb2 in comb1.items():
        for cas, comb3 in comb2.items():
            for noun, freq in comb3.items():
                all_nouns_freq[noun] += freq
# Out:
#   0%|          | 0/35223 [00:00<?, ?it/s]

# %%
list(verb_comb.keys())[:10]
# Out:
# ['случиться',
#  'просиять',
#  'приступить',
#  'рассказать',
#  'стоять',
#  'получать',
#  'быть',
#  'родиться',
#  'переехать',
#  'получить']

# %%
sum(verb_comb['вызывать']['_']['Nom'].values())
# Out:
# 103678

# %%
verb_freq = []
for verb in verb_comb.keys():
    cnt = 0
    if '_' not in verb_comb[verb].keys():
        continue
#     print(verb)
    for words in verb_comb[verb]['_'].values():
        cnt += sum(words.values())
    verb_freq.append((verb, cnt))

# %%
verb_freq = sorted(verb_freq, key=lambda x: x[1], reverse=True)

# %%
verb_freq[:10]
# Out:
# [('стать', 3199537),
#  ('являться', 2641444),
#  ('иметь', 2049862),
#  ('мочь', 1989789),
#  ('получить', 1896987),
#  ('быть', 1528541),
#  ('принять', 1501017),
#  ('сделать', 933251),
#  ('провести', 928981),
#  ('составлять', 892744)]

# %% [markdown]
# ## А актанты и сирконстанты - это скорее обязательность или процент присутствия при глаголе.

# %%
sorted(verb_comb['ждать']['_']['Dat'].items(), key=lambda x: x[1], reverse=True)
# Out:
# [('белорус', 99),
#  ('россиянин', 54),
#  ('человек', 26),
#  ('тюменец', 24),
#  ('сосед', 12),
#  ('поклонник', 12),
#  ('житель', 11),
#  ('горожанин', 10),
#  ('зритель', 10),
#  ('народ', 9),
#  ('реализация', 8),
#  ('партнёр', 8),
#  ('москвич', 7),
#  ('бизнес', 7),
#  ('экономика', 7),
#  ('страна', 7),
#  ('пассажир', 7),
#  ('ребёнок', 7),
#  ('гражданин', 6),
#  ('украинец', 6),
#  ('такси', 6),
#  ('победа', 6),
#  ('парень', 6),
#  ('пенсионер', 5),
#  ('рынок', 5),
#  ('автомобилист', 5),
#  ('помощь', 4),
#  ('мир', 4),
#  ('человечество', 4),
#  ('публика', 4),
#  ('болельщик', 4),
#  ('инвестор', 4),
#  ('рубль', 4),
#  ('девушка', 4),
#  ('армеец', 4),
#  ('премьер', 4),
#  ('водитель', 4),
#  ('потребитель', 3),
#  ('очередь', 3),
#  ('женщина', 3),
#  ('застройщик', 3),
#  ('покупатель', 3),
#  ('дольщик', 3),
#  ('сектор', 3),
#  ('радость', 3),
#  ('час', 3),
#  ('любовь', 3),
#  ('версия', 3),
#  ('избиратель', 3),
#  ('творчество', 3),
#  ('уход', 3),
#  ('момент', 3),
#  ('участник', 2),
#  ('команда', 2),
#  ('студент', 2),
#  ('сотрудник', 2),
#  ('негритянка', 2),
#  ('убийца', 2),
#  ('стажер', 2),
#  ('справедливость', 2),
#  ('презентация', 2),
#  ('заказчик', 2),
#  ('власть', 2),
#  ('мак', 2),
#  ('модник', 2),
#  ('банк', 2),
#  ('новость', 2),
#  ('корабль', 2),
#  ('терраса', 2),
#  ('судья', 2),
#  ('матерь', 2),
#  ('реакция', 2),
#  ('гардения', 2),
#  ('пациент', 2),
#  ('мужчина', 2),
#  ('родитель', 2),
#  ('юг', 2),
#  ('семья', 2),
#  ('подсудимый', 2),
#  ('запись', 2),
#  ('приказ', 2),
#  ('турист', 2),
#  ('карета', 2),
#  ('резервист', 2),
#  ('следствие', 2),
#  ('землянин', 2),
#  ('дядька', 2),
#  ('поход', 2),
#  ('обыватель', 2),
#  ('библиотека', 1),
#  ('ребята', 1),
#  ('тонкий', 1),
#  ('посетитель', 1),
#  ('абонент', 1),
#  ('оператор', 1),
#  ('язык', 1),
#  ('разработчик', 1),
#  ('конкурент', 1),
#  ('инженер', 1),
#  ('зависимость', 1),
#  ('рекламодатель', 1),
#  ('индустрия', 1),
#  ('пользователь', 1),
#  ('брат', 1),
#  ('глупость', 1),
#  ('честь', 1),
#  ('коротышка', 1),
#  ('циклоп', 1),
#  ('король', 1),
#  ('приятель', 1),
#  ('население', 1),
#  ('фанат', 1),
#  ('армия', 1),
#  ('модификация', 1),
#  ('флот', 1),
#  ('беженец', 1),
#  ('голос', 1),
#  ('лётчик', 1),
#  ('корреспондент', 1),
#  ('планировщик', 1),
#  ('туриндустрия', 1),
#  ('экспортёр', 1),
#  ('критик', 1),
#  ('президент', 1),
#  ('мигрант', 1),
#  ('группа', 1),
#  ('поддержка', 1),
#  ('учащийся', 1),
#  ('литовец', 1),
#  ('инвестиция', 1),
#  ('лагерь', 1),
#  ('инвалид', 1),
#  ('журналист', 1),
#  ('иммигрант', 1),
#  ('читатель', 1),
#  ('родина', 1),
#  ('победить', 1),
#  ('ярл', 1),
#  ('село', 1),
#  ('киборг', 1),
#  ('командир', 1),
#  ('дедуля', 1),
#  ('партия', 1),
#  ('капитан', 1),
#  ('опасность', 1),
#  ('машина', 1),
#  ('эмир', 1),
#  ('подполковник', 1),
#  ('спецназ', 1),
#  ('офицер', 1),
#  ('банда', 1),
#  ('лейтенант', 1),
#  ('сторона', 1),
#  ('царь', 1),
#  ('дело', 1),
#  ('дон', 1),
#  ('дача', 1),
#  ('бельгиец', 1),
#  ('собственник', 1),
#  ('компания', 1),
#  ('слава', 1),
#  ('вкладчик', 1),
#  ('заёмщик', 1),
#  ('клиент', 1),
#  ('котировка', 1),
#  ('американец', 1),
#  ('авиакомпания', 1),
#  ('евро', 1),
#  ('валюта', 1),
#  ('индекс', 1),
#  ('.', 1),
#  ('ясность', 1),
#  ('столица', 1),
#  ('волна', 1),
#  ('трейдер', 1),
#  ('лента', 1),
#  ('вакцинация', 1),
#  ('мучитель', 1),
#  ('традиция', 1),
#  ('мысль', 1),
#  ('сеньор', 1),
#  ('приём', 1),
#  ('прибыль', 1),
#  ('вожделеть', 1),
#  ('страсть', 1),
#  ('учительница', 1),
#  ('время', 1),
#  ('овечка', 1),
#  ('фильм', 1),
#  ('роль', 1),
#  ('владелец', 1),
#  ('редакция', 1),
#  ('европеец', 1),
#  ('доченька', 1),
#  ('папуля', 1),
#  ('самореализация', 1),
#  ('муж', 1),
#  ('знак', 1),
#  ('звезда', 1),
#  ('актриса', 1),
#  ('производитель', 1),
#  ('лошадка', 1),
#  ('иностранец', 1),
#  ('шоу-бизнес', 1),
#  ('револьвер', 1),
#  ('отрасль', 1),
#  ('акционер', 1),
#  ('отчётность', 1),
#  ('судно', 1),
#  ('автоваз', 1),
#  ('веста', 1),
#  ('конференция', 1),
#  ('матрасник', 1),
#  ('трагедия', 1),
#  ('ветеран', 1),
#  ('бизнесмен', 1),
#  ('регион', 1),
#  ('любитель', 1),
#  ('жилец', 1),
#  ('пешеход', 1),
#  ('соискатель', 1),
#  ('работник', 1),
#  ('продукт', 1),
#  ('способность', 1),
#  ('паства', 1),
#  ('работа', 1),
#  ('православный', 1),
#  ('рекламщик', 1),
#  ('грант', 1),
#  ('верующий', 1),
#  ('организация', 1),
#  ('экс-президент', 1),
#  ('станция', 1),
#  ('водочка', 1),
#  ('предприниматель', 1),
#  ('фронтовик', 1),
#  ('претендент', 1),
#  ('отец', 1),
#  ('приход', 1),
#  ('стёпа', 1),
#  ('правило', 1),
#  ('отправка', 1),
#  ('подмога', 1),
#  ('мужик', 1),
#  ('сирота', 1),
#  ('властолюбец', 1),
#  ('почта', 1),
#  ('набор', 1),
#  ('ответ', 1),
#  ('мама', 1),
#  ('социум', 1),
#  ('бар', 1),
#  ('вечер', 1),
#  ('семейство', 1),
#  ('подлость', 1),
#  ('иногородний', 1),
#  ('времяисчисление', 1),
#  ('внучка', 1),
#  ('старуха', 1),
#  ('деревня', 1),
#  ('предложение', 1),
#  ('многогранник', 1),
#  ('весточка', 1),
#  ('рука', 1),
#  ('грек', 1),
#  ('обещание', 1),
#  ('рыбак', 1),
#  ('оказия', 1),
#  ('мистер', 1),
#  ('новосибирец', 1),
#  ('милость', 1),
#  ('класс', 1),
#  ('кот', 1),
#  ('лицо', 1),
#  ('грешник', 1),
#  ('душа', 1),
#  ('невеста', 1),
#  ('крестьянин', 1),
#  ('проходить', 1),
#  ('самолёт', 1),
#  ('особист', 1),
#  ('мальчик', 1),
#  ('известие', 1),
#  ('солдат', 1),
#  ('удовлетворённость', 1),
#  ('внук', 1),
#  ('сепаратист', 1),
#  ('обитатель', 1),
#  ('сборная', 1),
#  ('потомок', 1),
#  ('бай', 1),
#  ('пароход', 1),
#  ('пенсионерка', 1),
#  ('игрок', 1),
#  ('подопечный', 1),
#  ('конец', 1),
#  ('кандидат', 1),
#  ('император', 1),
#  ('ханство', 1),
#  ('бин', 1),
#  ('публикация', 1),
#  ('реабилитация', 1),
#  ('кинофильм', 1),
#  ('зима', 1),
#  ('лошадь', 1),
#  ('героиня', 1),
#  ('баба', 1),
#  ('родоначальник', 1)]

# %%
exceptions = defaultdict(int)

for verb, _ in verb_freq:
    combs1 = verb_comb[verb]
    for cas, comb2 in combs1['_'].items():
        if cas == 'Loc' or cas == 'Par' or cas == 'Nom':
            continue
        comb3 = sorted(comb2.items(), key=lambda x: x[1], reverse=True)
        if len(comb3) > 5 and comb3[0][1] > 3 * comb3[1][1]:
            if comb3[0][1] / sum([c[1] for c in comb3]) > 0.2:
                print(verb, cas, comb3[0], comb3[1], f'{comb3[0][1] / sum([c[1] for c in comb3]):6.3}')
                exceptions[f'{cas} {comb3[0][0]}'] += 1
# Out:
# мочь Ins ('образ', 21857) ('причина', 3579)  0.246
# принять Gen ('человек', 1786) ('.', 373)   0.24
# составлять Ins ('образ', 2925) ('год', 606)  0.394
# нет Ins ('образ', 948) ('слово', 293)  0.321
# дать Gen ('деньга', 3217) ('здоровье', 902)  0.251
# составить Ins ('образ', 5710) ('год', 885)  0.299
# находиться Ins ('образ', 1688) ('лето', 273)  0.213
# находиться Acc ('время', 8856) ('год', 1173)  0.473
# представлять Ins ('образ', 2142) ('секретарь', 398)  0.201
# взять Ins ('штурм', 5554) ('рука', 1588)    0.2
# вести Ins ('образ', 3231) ('путь', 295)  0.293
# работать Gen ('житель', 5622) ('человек', 883)   0.52
# занять Acc ('место', 147821) ('позиция', 24324)   0.55
# получать Ins ('образ', 2811) ('способ', 392)  0.249
# установить Ins ('закон', 8511) ('законодательство', 2077)  0.205
# проходить Dat ('обвинять', 320) ('улица', 24)  0.403
# оставаться Acc ('время', 5258) ('год', 1083)  0.271
# стоять Acc ('время', 3666) ('день', 681)  0.325
# включать Ins ('образ', 712) ('вечер', 42)  0.458
# видеть Ins ('глаз', 5023) ('ночь', 975)  0.237
# направить Gen ('рубль', 2352) ('доллар', 356)   0.49
# увидеть Ins ('глаз', 4869) ('край', 1030)  0.398
# совершить Dat ('хиротония', 523) ('военнослужащий', 33)   0.55
# посвятить Ins ('образ', 748) ('королева', 53)  0.388
# способствовать Ins ('образ', 2318) ('действие', 257)  0.557
# принадлежать Acc ('время', 400) ('право', 119)  0.286
# играть Acc ('роль', 122210) ('музыка', 1822)   0.79
# прийти Acc ('раз', 1063) ('год', 178)  0.291
# прийти Gen ('человек', 368) ('год', 92)  0.225
# выйти Acc ('раз', 1568) ('год', 374)  0.283
# ввести Gen ('метр', 896) ('.', 105)  0.424
# носить Acc ('характер', 68236) ('название', 20239)  0.363
# существовать Ins ('образ', 1127) ('слово', 131)   0.43
# выполнять Ins ('образ', 1727) ('сотрудник', 208)  0.293
# рассмотреть Acc ('вопрос', 50637) ('возможность', 15898)  0.269
# использоваться Acc ('время', 840) ('раз', 272)  0.389
# закрыть Ins ('рука', 5838) ('ладонь', 1529)  0.244
# пользоваться Gen ('человек', 298) ('житель', 40)  0.267
# рассматривать Ins ('образ', 942) ('суд', 313)   0.22
# считаться Acc ('время', 2687) ('повреждение', 579)  0.577
# предусматривать Ins ('образ', 445) ('закон', 122)  0.232
# позволить Ins ('образ', 857) ('слово', 46)  0.376
# построить Gen ('метр', 1250) ('квартира', 101)  0.391
# вырасти Ins ('образ', 1753) ('человек', 408)  0.344
# покинуть Gen ('человек', 177) ('год', 52)  0.255
# потерять Ins ('образ', 912) ('пленный', 116)  0.303
# содержимый Ins ('образ', 431) ('слово', 28)   0.43
# нести Acc ('ответственность', 48694) ('служба', 10321)  0.297
# позволять Ins ('образ', 1184) ('слово', 108)  0.479
# состоять Acc ('время', 462) ('год', 95)  0.365
# происходить Ins ('образ', 2479) ('ночь', 524)  0.299
# подать Ins ('рука', 2614) ('компания', 341)  0.233
# соответствовать Ins ('образ', 774) ('слово', 49)  0.503
# просить Acc ('секретарь', 39438) ('прощение', 7303)  0.348
# жить Ins ('жизнь', 12129) ('семья', 614)   0.37
# смочь Ins ('образ', 4688) ('усилие', 303)  0.549
# изменить Ins ('образ', 7510) ('решение', 153)  0.728
# выступить Acc ('раз', 403) ('год', 107)  0.257
# передавать Ins ('путь', 2397) ('образ', 331)  0.435
# держать Ins ('рука', 1073) ('хватка', 286)  0.219
# приводить Acc ('слово', 32532) ('данные', 4770)  0.345
# иметься Ins ('образ', 613) ('слово', 80)  0.484
# хотеть Ins ('образ', 3469) ('слово', 335)  0.241
# призвать Dat ('власть', 162) ('вызов', 38)  0.213
# означать Ins ('образ', 476) ('слово', 129)   0.29
# обратить Acc ('внимание', 120059) ('взор', 1784)  0.916
# обратить Gen ('внимание', 410) ('сми', 38)  0.577
# увеличить Ins ('образ', 941) ('лето', 56)  0.413
# увеличить Gen ('рубль', 471) ('доллар', 134)  0.278
# называться Acc ('время', 269) ('раз', 43)   0.43
# выглядеть Ins ('образ', 9104) ('фаворит', 651)  0.301
# выглядеть Gen ('республиканец', 226) ('год', 45)  0.234
# возбудить Acc ('дело', 48304) ('иск', 506)  0.899
# возбудить Gen ('дело', 187) ('.', 45)  0.499
# относиться Ins ('образ', 1223) ('часть', 68)  0.491
# относиться Gen ('стан', 358) ('род', 41)  0.312
# начинать Gen ('.', 1014) ('дело', 43)  0.509
# сыграть Acc ('роль', 75031) ('матч', 4421)  0.701
# добавить Dat ('инвестор', 1182) ('образ', 96)  0.204
# действовать Ins ('образ', 3741) ('метод', 1143)   0.36
# запретить Ins ('закон', 2767) ('законодательство', 677)  0.228
# учитывать Ins ('образ', 2273) ('метод', 20)  0.799
# лежать Acc ('время', 1326) ('день', 280)   0.37
# попросить Gen ('помощь', 21187) ('убежище', 2353)   0.69
# привлечь Acc ('внимание', 52430) ('инвестиция', 1512)  0.539
# ставить Ins ('цель', 5351) ('задача', 949)  0.582
# бросить Acc ('взгляд', 34529) ('вызов', 5477)  0.309
# выиграть Dat ('команда', 55) ('игрок', 9)  0.251
# расти Ins ('темп', 5141) ('ребёнок', 603)  0.536
# произвести Acc ('впечатление', 21482) ('фурор', 2307)  0.314
# произвести Gen ('тонна', 1050) ('.', 231)  0.281
# призывать Ins ('образ', 573) ('время', 115)  0.335
# призывать Dat ('власть', 247) ('делегация', 37)  0.568
# вынести Ins ('суд', 3341) ('судья', 283)  0.372
# заключаться Ins ('образ', 959) ('срок', 80)  0.558
# удаться Ins ('образ', 3990) ('усилие', 867)  0.438
# обсудить Acc ('вопрос', 20869) ('ситуация', 6944)  0.208
# обсудить Ins ('вечер', 940) ('образ', 117)  0.521
# исполнять Acc ('обязанность', 52585) ('роль', 11366)   0.46
# высказать Acc ('мнение', 28620) ('предположение', 5107)  0.385
# заняться Acc ('раз', 96) ('время', 26)  0.249
# упасть Dat ('яблоко', 167) ('девушка', 16)  0.295
# уделять Acc ('внимание', 50405) ('время', 1282)  0.942
# уделять Gen ('внимание', 1247) ('время', 218)  0.741
# прийтись Ins ('образ', 1057) ('утро', 243)  0.266
# встретить Dat ('буржуа', 32) ('большинство', 6)  0.254
# повысить Ins ('образ', 711) ('способ', 49)  0.432
# предъявить Acc ('обвинение', 21778) ('претензия', 3445)   0.49
# заменить Gen ('слово', 425) ('производство', 21)  0.337
# рассказывать Acc ('история', 11479) ('сказка', 2172)   0.44
# рекомендовать Ins ('комитет', 3629) ('группа', 336)  0.452
# увеличиться Ins ('образ', 1759) ('время', 102)  0.732
# попасть Ins ('образ', 2126) ('путь', 568)  0.224
# попасть Acc ('раз', 817) ('год', 150)  0.312
# свидетельствовать Ins ('образ', 377) ('слово', 35)  0.375
# свидетельствовать Acc ('уважение', 2359) ('раз', 500)  0.605
# свидетельствовать Dat ('секретарь', 620) ('секретариат', 83)  0.581
# начинаться Ins ('слово', 1012) ('образ', 292)  0.216
# возглавить Dat ('хиротония', 121) ('экс-глава', 6)  0.548
# совершать Dat ('хиротония', 116) ('пользователь', 7)    0.4
# завершиться Gen ('.', 95) ('год', 26)  0.403
# содержаться Ins ('образ', 257) ('власть', 48)  0.254
# содержаться Acc ('время', 334) ('год', 45)  0.485
# наградить Ins ('орден', 46068) ('медаль', 11576)  0.525
# управлять Acc ('время', 224) ('год', 67)   0.23
# подчёркивать Ins ('образ', 331) ('неприязнь', 55)  0.207
# поступить Gen ('рубль', 808) ('доллар', 157)  0.319
# поступить Ins ('образ', 3652) ('осень', 870)  0.318
# сократить Ins ('образ', 684) ('усилие', 49)  0.439
# предусмотреть Gen ('рубль', 452) ('доллар', 29)  0.423
# предусмотреть Dat ('владелец', 103) ('регион', 13)  0.265
# посетить Gen ('человек', 981) ('турист', 302)  0.471
# зависеть Ins ('образ', 1415) ('слово', 102)  0.739
# разместить Acc ('материал', 12521) ('фотография', 1416)  0.218
# владеть Acc ('время', 257) ('часть', 61)  0.318
# подвергаться Gen ('год', 130) ('род', 33)  0.265
# подвергаться Acc ('раз', 992) ('время', 213)  0.503
# обвинить Dat ('власть', 44) ('муж', 5)  0.319
# содействовать Ins ('образ', 1230) ('сила', 60)   0.58
# снизить Ins ('образ', 400) ('весна', 51)   0.34
# снизить Gen ('рубль', 106) ('доллар', 31)  0.207
# сидеть Dat ('клетка', 72) ('голова', 17)   0.21
# воспользоваться Acc ('раз', 183) ('пара', 16)  0.489
# придавать Acc ('значение', 16756) ('вид', 3672)   0.36
# возникать Ins ('образ', 941) ('пора', 88)  0.511
# превысить Ins ('образ', 876) ('время', 57)  0.613
# вернуться Acc ('раз', 861) ('страна', 223)  0.318
# вернуться Dat ('мигрант', 316) ('час', 37)  0.271
# перейти Ins ('лето', 4690) ('образ', 666)  0.509
# участвовать Gen ('человек', 510) ('.', 58)  0.335
# комментировать Ins ('образ', 188) ('слово', 44)  0.304
# сохранять Ins ('образ', 399) ('цена', 68)  0.344
# грозить Ins ('последствие', 7534) ('импичмент', 1589)  0.283
# грозить Acc ('раз', 139) ('время', 36)  0.258
# снизиться Ins ('образ', 610) ('время', 93)  0.482
# присвоить Gen ('рубль', 155) ('звание', 51)  0.248
# обратиться Acc ('раз', 515) ('время', 103)  0.371
# обратиться Gen ('человек', 121) ('.', 27)  0.213
# посмотреть Dat ('правда', 799) ('человек', 120)  0.225
# зафиксировать Gen ('случай', 472) ('нарушение', 106)  0.311
# располагаться Acc ('время', 203) ('год', 28)  0.575
# располагаться Ins ('образ', 457) ('ряд', 77)  0.253
# коснуться Acc ('раз', 182) ('пара', 13)   0.51
# оказываться Acc ('раз', 1539) ('время', 242)  0.606
# нарушить Ins ('образ', 1174) ('действие', 356)  0.272
# прибыть Dat ('полок', 85) ('состав', 17)  0.284
# проверить Ins ('время', 1484) ('образ', 321)  0.247
# перенести Dat ('солдат', 200) ('человек', 12)  0.583
# прокомментировать Ins ('образ', 1908) ('слово', 299)  0.681
# завоевать Gen ('медаль', 443) ('награда', 75)   0.63
# заявлять Acc ('раз', 3290) ('протест', 429)  0.487
# протянуть Acc ('рука', 40011) ('ладонь', 1064)  0.566
# изучить Ins ('образ', 587) ('специалист', 100)  0.242
# поручить Gen ('.', 39) ('дело', 9)  0.219
# звучать Ins ('образ', 957) ('эхо', 195)   0.26
# одержать Acc ('победа', 56575) ('верх', 2980)  0.928
# одержать Gen ('победа', 77) ('год', 8)  0.558
# одержать Dat ('команда', 10) ('обед', 3)  0.204
# защитить Acc ('диссертация', 22081) ('титул', 2604)  0.353
# расширить Ins ('образ', 592) ('пристройка', 35)  0.271
# расширить Dat ('кзади', 43) ('потребность', 8)  0.225
# отсутствовать Ins ('образ', 287) ('слово', 40)  0.415
# терять Ins ('образ', 261) ('время', 62)  0.374
# выдвинуть Ins ('кандидат', 3258) ('партия', 1050)  0.237
# требоваться Ins ('образ', 398) ('слово', 79)  0.304
# сократиться Ins ('образ', 890) ('время', 90)  0.683
# применяться Ins ('образ', 1253) ('суд', 221)  0.206
# привлекать Acc ('внимание', 17205) ('средство', 1717)  0.309
# придерживаться Dat ('версия', 205) ('стратегия', 38)  0.388
# исполнить Acc ('роль', 18256) ('песня', 5380)  0.338
# произнести Gen ('слово', 509) ('человек', 47)  0.527
# подвергнуть Dat ('критика', 13765) ('пытка', 3169)  0.309
# подвергнуть Ins ('образ', 603) ('сотрудник', 56)  0.397
# подлежать Ins ('образ', 170) ('срок', 46)  0.208
# удовлетворить Dat ('требование', 197) ('критерий', 35)   0.46
# забить Acc ('гол', 31290) ('мяч', 5860)  0.693
# забить Gen ('голова', 85) ('шайба', 28)  0.236
# нарушать Ins ('образ', 679) ('действие', 163)   0.24
# измениться Acc ('раз', 88) ('год', 29)   0.23
# измениться Ins ('образ', 1942) ('лето', 66)  0.755
# посещать Gen ('человек', 234) ('турист', 74)  0.332
# приобретать Ins ('образ', 440) ('путь', 42)  0.315
# набрать Dat ('воздух', 227) ('мама', 14)  0.476
# вынудить Gen ('человек', 121) ('житель', 22)  0.279
# вынудить Dat ('власть', 43) ('компания', 5)  0.377
# проявлять Acc ('интерес', 12236) ('активность', 3208)  0.212
# разделить Gen ('акция', 102) ('рубль', 13)   0.22
# покупать Dat ('ребёнок', 233) ('жена', 68)  0.216
# присутствовать Ins ('образ', 240) ('вечер', 58)  0.231
# забрать Dat ('человек', 25) ('банк', 4)   0.26
# пригласить Ins ('жест', 2053) ('вечер', 401)  0.281
# последовать Dat ('пример', 13007) ('совет', 2525)   0.74
# последовать Acc ('пример', 305) ('рекомендация', 75)  0.465
# умереть Ins ('смерть', 2179) ('ночь', 382)  0.363
# умереть Acc ('год', 389) ('усилие', 109)  0.268
# выдавать Gen ('паспорт', 244) ('пропуск', 54)  0.295
# обращать Acc ('внимание', 49356) ('взор', 498)  0.933
# обращать Gen ('внимание', 1025) ('развитие', 6)  0.891
# подойти Acc ('раз', 251) ('пара', 26)  0.319
# явиться Acc ('раз', 94) ('чёрт', 15)   0.25
# вносить Acc ('вклад', 20132) ('изменение', 6105)  0.356
# вносить Dat ('президент', 67) ('глава', 16)  0.272
# задать Acc ('вопрос', 35590) ('тон', 918)  0.769
# задать Gen ('вопрос', 135) ('корм', 27)   0.29
# пожать Ins ('плечо', 46744) ('плечико', 151)  0.991
# пожать Acc ('рука', 13117) ('ладонь', 318)  0.891
# пожать Gen ('рука', 49) ('нарцисс', 4)  0.527
# выпускать Dat ('составитель', 54) ('форвард', 12)  0.378
# подняться Acc ('раз', 237) ('боль', 15)  0.298
# бывать Acc ('раз', 2876) ('день', 429)  0.621
# бывать Dat ('человек', 131) ('посетитель', 30)  0.239
# разрабатывать Ins ('компания', 641) ('образ', 197)  0.223
# уделяться Gen ('внимание', 569) ('время', 19)  0.757
# уделяться Ins ('образ', 147) ('командование', 21)  0.325
# лишиться Ins ('образ', 561) ('лето', 69)   0.54
# думать Acc ('время', 3043) ('день', 969)   0.32
# уступить Acc ('место', 10572) ('дорога', 1448)  0.465
# уделить Acc ('внимание', 19181) ('время', 814)  0.912
# уделить Gen ('внимание', 200) ('время', 31)  0.575
# цитировать Acc ('слово', 12188) ('заявление', 3199)  0.297
# раскрыть Dat ('россиянин', 552) ('мир', 94)  0.312
# приговорить Ins ('суд', 4173) ('срок', 464)   0.55
# заложить Acc ('основа', 8063) ('рука', 2146)  0.307
# заложить Gen ('рубль', 397) ('год', 118)  0.408
# вспоминать Ins ('слово', 391) ('вечер', 108)  0.224
# противоречить Ins ('образ', 295) ('пора', 10)  0.583
# преодолеть Ins ('образ', 378) ('усилие', 121)  0.208
# преодолеть Gen ('километр', 297) ('миля', 57)  0.499
# возрасти Ins ('образ', 755) ('время', 44)  0.705
# сдать Acc ('экзамен', 9146) ('анализ', 2171)  0.218
# сдать Gen ('метр', 166) ('паспорт', 37)  0.226
# сдать Ins ('экстерн', 617) ('лето', 137)  0.291
# победить Gen ('боевик', 213) ('чемпион', 69)  0.236
# соблюдать Ins ('образ', 171) ('сторона', 49)  0.374
# повышать Ins ('образ', 374) ('темп', 59)  0.488
# исчезнуть Ins ('образ', 739) ('миг', 118)  0.451
# приехать Acc ('раз', 770) ('неделя', 89)  0.397
# улучшить Ins ('образ', 492) ('способ', 32)  0.476
# наступить Ins ('нога', 315) ('каблук', 94)  0.252
# наступить Acc ('раз', 74) ('пара', 18)  0.289
# покачать Ins ('голова', 55097) ('крыло', 93)  0.989
# закрывать Ins ('рука', 1140) ('ладонь', 294)  0.227
# закрывать Dat ('противник', 205) ('ребёнок', 26)  0.312
# командовать Acc ('время', 200) ('год', 49)  0.346
# осудить Ins ('суд', 1763) ('трибунал', 477)  0.334
# убрать Gen ('малёк', 96) ('га', 21)  0.216
# предстоять Gen ('работа', 121) ('дело', 16)  0.381
# задавать Acc ('вопрос', 32834) ('тон', 2449)  0.716
# задавать Gen ('вопрос', 225) ('раз', 50)  0.543
# страдать Gen ('человек', 134) ('ребёнок', 21)   0.26
# обвинять Dat ('власть', 60) ('предприниматель', 9)   0.33
# запланировать Gen ('рубль', 280) ('.', 42)  0.464
# преследовать Acc ('цель', 15606) ('интерес', 1618)  0.438
# зарегистрировать Ins ('кандидат', 1162) ('образ', 359)  0.226
# приводиться Acc ('раз', 42) ('время', 10)  0.328
# встретиться Acc ('раз', 1478) ('пара', 123)   0.74
# уходить Ins ('корень', 3022) ('утро', 350)  0.423
# уходить Gen ('время', 161) ('рубль', 39)  0.229
# препятствовать Ins ('образ', 435) ('сила', 96)   0.46
# пересмотреть Ins ('образ', 854) ('группа', 79)  0.519
# сохраняться Acc ('время', 693) ('усилие', 182)  0.221
# сохраняться Ins ('образ', 335) ('год', 37)  0.351
# развернуть Ins ('лицо', 1297) ('спина', 266)   0.28
# обрести Ins ('образ', 272) ('цена', 33)  0.319
# завести Acc ('дело', 9239) ('разговор', 2978)  0.229
# прозвучать Acc ('раз', 167) ('неделя', 27)  0.386
# прозвучать Ins ('лето', 575) ('музыка', 124)  0.245
# повторить Gen ('раз', 118) ('слово', 5)  0.492
# поступать Ins ('образ', 1596) ('транзит', 496)   0.45
# проживать Gen ('человек', 2933) ('житель', 320)  0.513
# затронуть Gen ('человек', 146) ('житель', 17)  0.325
# схватить Ins ('рука', 1546) ('зуб', 298)  0.271
# запрещать Ins ('образ', 110) ('закон', 21)  0.231
# прикрыть Gen ('глаз', 28) ('дверь', 4)  0.201
# превратиться Ins ('образ', 741) ('старание', 102)  0.433
# попытаться Acc ('раз', 1167) ('год', 44)  0.633
# опасаться Acc ('время', 141) ('раз', 37)  0.244
# предоставляться Acc ('раз', 75) ('год', 16)  0.301
# подходить Ins ('образ', 653) ('время', 167)  0.346
# увеличивать Ins ('образ', 338) ('темп', 74)  0.454
# заканчиваться Acc ('раз', 273) ('время', 16)  0.688
# потребоваться Ins ('образ', 292) ('слово', 29)  0.517
# понести Acc ('потеря', 14671) ('наказание', 4690)  0.442
# анализировать Ins ('образ', 115) ('метод', 32)  0.359
# вытащить Dat ('чек', 14) ('банк', 3)  0.255
# получиться Ins ('образ', 558) ('слово', 76)  0.293
# сложиться Ins ('образ', 1171) ('век', 93)   0.57
# остановиться Acc ('раз', 192) ('мгновение', 33)   0.34
# собраться Acc ('раз', 257) ('дождь', 67)   0.24
# собраться Gen ('человек', 491) ('зритель', 37)   0.41
# собраться Dat ('народ', 213) ('член', 10)  0.455
# пострадать Gen ('человек', 265) ('страна', 21)  0.381
# повлечь Acc ('смерть', 10535) ('последствие', 3510)  0.257
# повлечь Ins ('образ', 54) ('срок', 6)  0.386
# утратить Ins ('образ', 223) ('россиянин', 66)  0.259
# утратить Dat ('врач', 4) ('коллектив', 1)  0.286
# скончаться Gen ('пациент', 1322) ('человек', 411)  0.537
# формировать Ins ('образ', 368) ('средство', 22)  0.247
# отразить Ins ('образ', 1211) ('огонь', 183)  0.348
# отразить Dat ('комиссия', 10) ('тип', 2)  0.213
# случиться Gen ('год', 110) ('.', 19)  0.244
# проанализировать Ins ('образ', 258) ('эксперт', 43)  0.282
# объединять Ins ('образ', 181) ('понятие', 46)  0.229
# сосредоточить Ins ('образ', 729) ('часть', 27)   0.75
# затрагивать Dat ('страна', 15) ('потомок', 1)  0.517
# повернуть Acc ('голова', 17393) ('ключ', 2236)  0.501
# повернуть Ins ('лицо', 1699) ('спина', 314)   0.43
# сжать Gen ('виски', 134) ('сила', 19)  0.486
# приложить Gen ('усилие', 138) ('сила', 25)  0.405
# снижать Ins ('образ', 286) ('темп', 28)  0.565
# оформить Ins ('образ', 1097) ('число', 118)   0.24
# повторять Gen ('раз', 93) ('ошибка', 30)   0.27
# убедить Dat ('власть', 37) ('человек', 4)  0.474
# двигаться Acc ('время', 425) ('день', 66)  0.316
# потратить Ins ('образ', 278) ('лето', 89)  0.223
# наладить Ins ('образ', 195) ('компания', 38)  0.275
# предупредить Dat ('власть', 7) ('письмо', 2)  0.233
# покрывать Ins ('поцелуй', 2820) ('слой', 462)  0.369
# висеть Acc ('время', 334) ('год', 67)  0.335
# висеть Dat ('стена', 71) ('царь', 3)  0.651
# подразумевать Ins ('образ', 125) ('слово', 25)  0.332
# подчиняться Ins ('образ', 56) ('командующий', 17)  0.223
# подчиняться Gen ('человек', 74) ('язык', 6)  0.448
# интересовать Ins ('образ', 137) ('дело', 16)  0.398
# успеть Acc ('многий', 347) ('раз', 83)  0.216
# провозгласить Gen ('год', 197) ('.', 19)  0.668
# хватать Ins ('рот', 1696) ('рука', 392)  0.534
# надеяться Ins ('образ', 1249) ('способ', 125)   0.43
# улыбнуться Ins ('улыбка', 3806) ('уголок', 548)  0.615
# улыбнуться Acc ('раз', 646) ('пара', 51)  0.604
# возвращаться Ins ('вечер', 1406) ('ночь', 456)  0.235
# доставлять Acc ('удовольствие', 6593) ('груз', 1243)  0.234
# послышаться Ins ('время', 49) ('утро', 16)   0.31
# учесть Ins ('образ', 1126) ('суд', 95)  0.544
# подвести Acc ('итог', 15986) ('черта', 1581)  0.643
# символизировать Ins ('образ', 91) ('язык', 8)  0.294
# уменьшить Ins ('образ', 291) ('способ', 20)  0.429
# забыть Ins ('бог', 997) ('миг', 101)  0.347
# увеличиваться Acc ('год', 492) ('день', 153)   0.38
# повредить Gen ('дом', 52) ('метр', 11)  0.257
# противостоять Acc ('время', 82) ('год', 24)   0.27
# обращаться Acc ('раз', 1021) ('время', 257)  0.531
# обращаться Dat ('г-жа', 135) ('наблюдатель', 12)  0.249
# обращаться Ins ('образ', 631) ('слово', 75)  0.308
# попадать Ins ('образ', 595) ('путь', 164)  0.286
# высказывать Acc ('мнение', 6846) ('предположение', 2032)  0.239
# похитить Gen ('рубль', 1724) ('доллар', 134)  0.712
# укреплять Ins ('образ', 239) ('мешок', 52)  0.221
# укреплять Gen ('тонна', 42) ('страна', 8)  0.288
# укреплять Dat ('сотрудник', 35) ('страна', 7)  0.432
# стартовать Gen ('.', 32) ('число', 7)  0.372
# выпить Ins ('залп', 2171) ('вечер', 185)   0.71
# активизировать Acc ('усилие', 13523) ('деятельность', 3206)  0.382
# активизировать Ins ('образ', 116) ('время', 20)  0.356
# активизировать Gen ('устранение', 22) ('страна', 3)  0.259
# столкнуться Acc ('раз', 284) ('лоб', 80)  0.341
# столкнуться Ins ('лицо', 1068) ('утро', 283)  0.306
# признаваться Acc ('раз', 727) ('год', 56)  0.678
# пропустить Ins ('образ', 260) ('команда', 38)  0.318
# изъять Gen ('рубль', 302) ('доллар', 93)  0.245
# предшествовать Ins ('образ', 31) ('заместитель', 10)  0.214
# планироваться Gen ('рубль', 278) ('.', 58)  0.383
# ускорить Ins ('образ', 142) ('способ', 20)  0.265
# лишать Ins ('образ', 198) ('срок', 27)  0.408
# держаться Acc ('время', 897) ('год', 178)  0.331
# позвонить Acc ('раз', 1022) ('пара', 96)  0.593
# выделяться Gen ('рубль', 266) ('средство', 59)  0.259
# выделяться Acc ('год', 78) ('раз', 25)  0.246
# подорвать Ins ('граната', 558) ('образ', 174)  0.216
# передаваться Ins ('путь', 1722) ('образ', 273)  0.392
# облегчить Ins ('образ', 168) ('способ', 22)  0.258
# свести Ins ('судорога', 737) ('образ', 221)  0.334
# понадобиться Gen ('время', 366) ('доллар', 96)  0.323
# расширять Ins ('образ', 249) ('темп', 31)  0.354
# рассчитывать Gen ('рубль', 36) ('.', 8)  0.203
# рассчитывать Ins ('образ', 993) ('институт', 117)  0.464
# упоминаться Acc ('раз', 526) ('время', 44)  0.774
# родить Dat ('муж', 199) ('король', 42)  0.231
# перехватить Acc ('дыхание', 9314) ('инициатива', 2734)  0.332
# бежать Dat ('автобус', 251) ('человек', 12)  0.458
# бежать Gen ('сириец', 711) ('сила', 70)   0.56
# переименовать Ins ('указ', 1417) ('постановление', 327)  0.468
# сформулировать Ins ('образ', 2188) ('государство', 258)  0.422
# тратить Ins ('образ', 85) ('моль', 28)  0.224
# поражать Acc ('цель', 6176) ('воображение', 1761)   0.32
# поражать Dat ('цель', 14) ('гротескность', 4)  0.304
# стимулировать Ins ('образ', 320) ('способ', 42)  0.246
# махнуть Ins ('рука', 27871) ('голова', 359)  0.897
# критиковать Dat ('власть', 7) ('человек', 2)   0.28
# складываться Ins ('образ', 1305) ('век', 171)  0.599
# суметь Ins ('образ', 864) ('чудо', 180)  0.354
# обернуться Acc ('раз', 236) ('пара', 25)  0.605
# опуститься Ins ('ночь', 646) ('образ', 181)  0.347
# опуститься Gen ('отметка', 365) ('уровень', 120)  0.483
# опуститься Acc ('раз', 51) ('год', 15)  0.208
# развить Ins ('образ', 436) ('последователь', 18)  0.408
# расследовать Acc ('дело', 6115) ('обстоятельство', 2025)  0.211
# расследовать Ins ('образ', 285) ('орган', 53)  0.347
# найтись Ins ('образ', 72) ('слово', 22)  0.206
# распространять Gen ('род', 67) ('страна', 7)  0.406
# уступать Acc ('место', 3952) ('дорога', 1061)  0.538
# отказать Ins ('образ', 302) ('лето', 92)  0.293
# помешать Ins ('образ', 164) ('ложка', 50)    0.2
# пересечь Acc ('граница', 9358) ('комната', 1745)  0.349
# получаться Ins ('образ', 1302) ('слово', 85)  0.462
# рассчитать Ins ('образ', 547) ('метод', 78)  0.437
# дойти Gen ('финал', 166) ('чемпионат', 27)  0.306
# стараться Ins ('сила', 1212) ('образ', 328)  0.305
# устранить Ins ('образ', 378) ('способ', 94)  0.279
# кивнуть Ins ('голова', 9154) ('головка', 58)  0.951
# кивнуть Acc ('раз', 225) ('пара', 35)  0.416
# возвести Dat ('империя', 21) ('проект', 5)  0.212
# возвести Gen ('метр', 312) ('год', 43)  0.525
# подумать Acc ('раз', 1183) ('секунда', 335)  0.357
# подвергать Ins ('образ', 78) ('лишение', 13)  0.237
# информировать Ins ('образ', 529) ('письмо', 40)  0.581
# оправдать Ins ('суд', 930) ('присяжный', 229)  0.229
# оправдать Gen ('ожидание', 41) ('надежда', 10)   0.25
# влиять Ins ('образ', 1986) ('путь', 77)   0.75
# даваться Acc ('дива', 864) ('раз', 155)  0.712
# эвакуировать Gen ('человек', 704) ('житель', 105)  0.637
# выводить Dat ('пользователь', 18) ('график', 3)  0.254
# формироваться Ins ('образ', 749) ('год', 74)  0.229
# снижаться Dat ('женщина', 16) ('рост', 3)  0.308
# . Ins ('цвет', 52) ('волос', 6)  0.612
# унести Acc ('жизнь', 12270) ('нога', 1111)  0.592
# унести Ins ('ветер', 1227) ('течение', 378)  0.438
# унести Gen ('жизнь', 268) ('рубль', 38)  0.492
# подобрать Ins ('образ', 382) ('вертолёт', 41)  0.234
# подобрать Gen ('слово', 63) ('заяц', 8)  0.211
# усиливать Dat ('воздействие', 15) ('лицо', 3)  0.306
# задействовать Ins ('образ', 243) ('осень', 27)  0.341
# ехать Gen ('фургон', 132) ('час', 24)  0.231
# признаться Acc ('раз', 95) ('пара', 27)  0.275
# признаться Gen ('женщина', 25) ('усилие', 3)  0.236
# поменять Ins ('место', 1118) ('образ', 174)  0.699
# пропасть Ins ('пропадом', 734) ('образ', 131)  0.443
# пропасть Dat ('слух', 10) ('поодиночке', 3)  0.233
# характеризовать Ins ('образ', 424) ('слово', 135)  0.242
# обстрелять Ins ('ракета', 823) ('ночь', 267)  0.205
# обжаловать Dat ('прокурор', 26) ('начальник', 6)  0.268
# заверить Dat ('делегация', 29) ('риа', 7)  0.345
# наметить Dat ('заказчик', 39) ('флот', 8)  0.379
# спасать Dat ('человек', 87) ('ребёнок', 14)  0.213
# выполняться Acc ('раз', 106) ('время', 32)  0.384
# отвергать Acc ('обвинение', 6684) ('предложение', 836)  0.276
# отвергать Gen ('обвинение', 59) ('род', 7)  0.536
# отвергать Ins ('образ', 126) ('большинство', 16)  0.314
# уменьшиться Ins ('образ', 471) ('время', 20)  0.758
# окружать Gen ('человек', 122) ('мир', 16)  0.214
# лететь Ins ('рейс', 1129) ('самолёт', 364)  0.252
# отказываться Ins ('образ', 122) ('время', 37)  0.207
# следить Acc ('время', 772) ('день', 185)  0.408
# ослабить Acc ('позиция', 5066) ('хватка', 1349)  0.227
# исключать Dat ('влияние', 15) ('поставщик', 3)  0.341
# исключать Ins ('образ', 129) ('закон', 8)  0.449
# спрашивать Gen ('совет', 572) ('разрешение', 180)  0.411
# подорожать Ins ('образ', 229) ('вечер', 67)  0.467
# подорожать Dat ('население', 26) ('итог', 4)  0.565
# пересекать Acc ('граница', 4999) ('улица', 1569)  0.217
# окинуть Ins ('взгляд', 16376) ('взор', 919)  0.929
# окинуть Dat ('зал', 5) ('взгляд', 1)    0.5
# направляться Gen ('рубль', 43) ('суд', 7)  0.226
# зарабатывать Acc ('деньга', 7074) ('время', 2181)  0.521
# обхватить Ins ('рука', 9566) ('ладонь', 1623)  0.708
# обхватить Dat ('рука', 7) ('наёмник', 2)   0.35
# упразднить Ins ('указ', 800) ('решение', 202)  0.475
# упразднить Dat ('постановление', 20) ('банк', 2)  0.645
# упразднить Gen ('с', 82) ('.', 20)  0.512
# игнорировать Gen ('трактовка', 28) ('страна', 7)  0.206
# игнорировать Ins ('образ', 88) ('год', 27)  0.274
# уважать Ins ('образ', 44) ('человек', 11)  0.208
# заключать Gen ('договор', 198) ('род', 10)  0.588
# нуждаться Ins ('образ', 120) ('слово', 31)  0.289
# присоединиться Gen ('человек', 54) ('государство', 11)  0.248
# повлиять Ins ('образ', 1756) ('способ', 46)   0.78
# отреагировать Ins ('образ', 2565) ('рост', 330)  0.371
# преподавать Gen ('.', 61) ('смерть', 13)  0.265
# повыситься Gen ('.', 101) ('рубль', 25)  0.288
# повыситься Acc ('раз', 66) ('снижение', 8)  0.344
# удовлетворять Dat ('требование', 5088) ('критерий', 1546)   0.45
# удовлетворять Acc ('потребность', 5625) ('спрос', 607)   0.49
# удовлетворять Ins ('образ', 306) ('способ', 25)  0.546
# предвещать Dat ('женщина', 331) ('человек', 108)  0.332
# отслеживать Ins ('образ', 123) ('зрение', 10)  0.361
# оккупировать Ins ('войско', 7306) ('немец', 977)  0.582
# оккупировать Gen ('держава', 43) ('год', 9)  0.434
# повернуться Acc ('раз', 90) ('пара', 12)  0.398
# украсть Gen ('рубль', 294) ('доллар', 90)  0.358
# прилагать Acc ('усилие', 18994) ('максимум', 488)  0.871
# прилагать Gen ('усилие', 193) ('сила', 5)  0.737
# размещаться Ins ('образ', 151) ('лицо', 21)  0.304
# размещаться Acc ('время', 144) ('раз', 17)  0.621
# координировать Ins ('образ', 145) ('секретариат', 23)  0.276
# застрелить Dat ('полицейский', 96) ('военнослужащий', 11)  0.828
# подозревать Dat ('обвинять', 51) ('подсудимый', 13)  0.349
# оплачивать Dat ('человек', 353) ('сотрудник', 56)  0.352
# высказаться Acc ('раз', 101) ('пара', 20)  0.281
# обновить Ins ('образ', 327) ('лето', 57)  0.334
# возвратить Gen ('рубль', 67) ('доллар', 13)  0.319
# приглашать Ins ('жест', 474) ('вечер', 137)  0.369
# делить Ins ('образ', 91) ('ночь', 22)  0.243
# исправить Ins ('образ', 402) ('сила', 43)  0.294
# осуждать Ins ('образ', 663) ('общество', 25)  0.695
# изменять Ins ('образ', 412) ('способ', 37)  0.468
# продлиться Ins ('образ', 85) ('немногий', 12)  0.497
# зайти Acc ('раз', 364) ('пара', 24)  0.444
# превращаться Ins ('образ', 549) ('ночь', 87)  0.366
# учитываться Ins ('образ', 1059) ('метод', 151)  0.474
# учитываться Acc ('раз', 18) ('время', 4)  0.261
# сокращать Ins ('образ', 196) ('темп', 40)  0.462
# править Acc ('бал', 669) ('время', 190)  0.276
# править Gen ('смерть', 275) ('год', 64)  0.444
# потрясти Ins ('голова', 1983) ('известие', 182)  0.202
# избираться Acc ('раз', 167) ('число', 42)  0.506
# распахнуть Acc ('дверь', 9656) ('дверца', 2411)  0.511
# распахнуть Ins ('рывок', 453) ('пинок', 137)  0.307
# кричать Ins ('голос', 650) ('крик', 215)   0.35
# кричать Gen ('ура', 218) ('моча', 14)  0.528
# царить Acc ('время', 242) ('год', 56)  0.319
# царить Dat ('бедлам', 5) ('музыка', 1)  0.333
# подрывать Ins ('образ', 232) ('действие', 58)  0.356
# подрывать Gen ('граница', 12) ('представитель', 3)  0.293
# звонить Gen ('раз', 39) ('полчаса', 12)  0.242
# сунуть Acc ('рука', 5469) ('нога', 1030)  0.249
# опровергать Ins ('образ', 73) ('время', 22)  0.232
# сказаться Ins ('образ', 2147) ('больной', 147)  0.872
# сказаться Dat ('больной', 12) ('работа', 2)  0.286
# прожить Acc ('жизнь', 9359) ('год', 1735)  0.544
# прожить Gen ('год', 256) ('смерть', 69)  0.357
# прожить Dat ('созидатель', 51) ('человек', 11)  0.381
# навести Acc ('порядок', 10175) ('справка', 2377)  0.508
# волновать Gen ('власть', 103) ('россиянин', 6)  0.452
# раскрывать Dat ('общественность', 211) ('человек', 37)   0.26
# обменяться Acc ('раз', 71) ('пара', 5)  0.826
# совпадать Ins ('образ', 350) ('слово', 17)  0.614
# повесить Acc ('трубка', 7033) ('табличка', 560)   0.34
# освоить Gen ('рубль', 147) ('доллар', 15)  0.484
# научить Dat ('многое', 1496) ('искусство', 213)  0.216
# научить Ins ('опыт', 984) ('образ', 28)  0.609
# задаваться Ins ('вопрос', 11891) ('цель', 140)  0.846
# заполнять Dat ('банк', 18) ('гражданин', 3)  0.391
# настроить Ins ('образ', 618) ('время', 37)  0.585
# обходить Ins ('сторона', 3294) ('молчание', 268)  0.734
# обнаруживать Gen ('паспорт', 129) ('развитие', 6)  0.343
# разглядеть Ins ('глаз', 113) ('ночь', 27)  0.328
# развести Ins ('рука', 9117) ('вода', 140)  0.919
# развести Gen ('костерок', 99) ('лох', 13)  0.379
# сесть Acc ('раз', 160) ('козёл', 15)  0.234
# затруднять Ins ('образ', 113) ('действие', 10)  0.433
# пробежать Ins ('глаз', 2339) ('палец', 490)  0.543
# употреблять Ins ('китаец', 152) ('образ', 41)  0.221
# подешеветь Acc ('раз', 59) ('новость', 12)  0.242
# обвести Ins ('взгляд', 6644) ('глаз', 1457)  0.553
# гласить Dat ('воин', 40) ('память', 6)  0.351
# избить Dat ('полицейский', 9) ('шайка', 1)  0.529
# препроводить Ins ('настоящее', 1008) ('секретарь', 48)  0.729
# препроводить Gen ('шеф', 42) ('сессия', 10)  0.433
# доложить Dat ('президент', 1921) ('командир', 497)  0.207
# организовывать Ins ('образ', 160) ('лето', 35)   0.38
# поддерживаться Acc ('время', 94) ('год', 30)  0.407
# протекать Acc ('деревня', 445) ('село', 112)  0.522
# приподнять Dat ('пол', 21) ('девушка', 6)  0.304
# подтверждаться Acc ('раз', 118) ('день', 14)  0.634
# случаться Acc ('раз', 1477) ('время', 443)  0.531
# праздновать Gen ('трус', 20) ('май', 5)   0.23
# истекать Ins ('кровь', 3387) ('лето', 281)  0.699
# истекать Dat ('некого', 4) ('страна', 1)  0.308
# выпасть Acc ('раз', 72) ('время', 15)  0.336
# выстроить Ins ('образ', 400) ('архитектор', 50)  0.239
# выигрывать Dat ('ход', 35) ('сборная', 3)  0.614
# побывать Acc ('раз', 744) ('пара', 72)  0.685
# радовать Acc ('глаз', 2368) ('поклонник', 567)  0.266
# радовать Gen ('глаз', 185) ('окружающий', 4)  0.634
# описываться Acc ('раз', 18) ('год', 5)  0.281
# ломать Acc ('голова', 5018) ('комедия', 532)  0.276
# ломать Dat ('человек', 79) ('ребёнок', 11)  0.206
# основываться Ins ('образ', 441) ('часть', 15)  0.736
# осматривать Gen ('турист', 33) ('искоса', 4)  0.287
# слышаться Acc ('время', 239) ('раз', 30)  0.558
# свернуть Gen ('гора', 56) ('работа', 5)  0.392
# подводить Acc ('итог', 12589) ('черта', 474)  0.767
# дрожать Ins ('тело', 1149) ('дрожь', 210)  0.642
# пригрозить Acc ('раз', 27) ('журналист', 7)  0.284
# вступать Ins ('образ', 187) ('доброволец', 39)  0.259
# вступать Acc ('раз', 161) ('время', 44)  0.333
# облегчать Ins ('образ', 95) ('способ', 12)  0.385
# обстоять Gen ('дело', 301) ('учитель', 2)  0.918
# обстоять Ins ('образ', 1319) ('слово', 10)  0.934
# заморозить Dat ('сотрудник', 17) ('фигурист', 5)  0.288
# налить Dat ('чай', 372) ('коньяк', 103)  0.291
# налить Ins ('кровь', 1007) ('свинец', 216)  0.448
# созвать Gen ('год', 28) ('.', 7)  0.264
# превращать Ins ('образ', 181) ('сила', 15)  0.348
# разобрать Gen ('слово', 161) ('лицо', 7)  0.526
# наполниться Ins ('слеза', 2634) ('запах', 306)  0.235
# превзойти Acc ('ожидание', 4276) ('прогноз', 759)  0.336
# превзойти Ins ('образ', 121) ('численность', 14)  0.209
# ворваться Acc ('форточка', 238) ('раз', 27)  0.476
# броситься Ins ('опрометью', 572) ('дело', 144)  0.302
# функционировать Ins ('образ', 784) ('лето', 33)  0.799
# удостоиться Acc ('раз', 28) ('год', 9)  0.226
# обходиться Acc ('время', 161) ('год', 46)  0.315
# уехать Gen ('человек', 37) ('.', 9)  0.201
# уехать Dat ('слух', 18) ('муж', 3)  0.247
# улыбаться Ins ('улыбка', 1644) ('глаз', 269)  0.483
# отразиться Ins ('образ', 974) ('эхо', 274)   0.58
# оправдывать Gen ('ожидание', 28) ('средство', 5)  0.329
# направиться Ins ('шаг', 2908) ('походка', 967)  0.523
# возлагать Gen ('надежда', 33) ('род', 8)  0.418
# именоваться Acc ('время', 85) ('год', 8)  0.654
# запечатлеть Gen ('народ', 30) ('самолёт', 4)  0.288
# оторвать Ins ('взрыв', 277) ('сила', 61)  0.226
# обнять Ins ('рука', 1578) ('ладонь', 172)  0.611
# проложить Gen ('километр', 35) ('стена', 7)  0.219
# сводиться Ins ('образ', 437) ('слово', 29)  0.558
# разойтись Ins ('тираж', 2667) ('мир', 345)  0.694
# молчать Acc ('время', 3167) ('дорога', 902)  0.584
# биться Ins ('голова', 978) ('лоб', 126)  0.413
# заинтересовать Gen ('регион', 38) ('человек', 7)  0.264
# подписывать Gen ('договор', 28) ('бумага', 7)  0.311
# скользнуть Ins ('взгляд', 2700) ('рука', 676)  0.506
# скользнуть Acc ('раз', 68) ('взгляд', 10)   0.54
# сводить Ins ('судорога', 281) ('образ', 90)  0.294
# улучшиться Ins ('образ', 92) ('день', 24)  0.442
# виднеться Acc ('время', 18) ('пара', 5)  0.321
# сказываться Ins ('образ', 1497) ('больной', 12)  0.912
# вдохновить Acc ('президент', 1038) ('создатель', 281)  0.201
# выключить Acc ('свет', 3706) ('телевизор', 996)  0.226
# контролироваться Acc ('время', 30) ('заявление', 7)  0.337
# подбирать Acc ('слово', 4314) ('человек', 370)  0.255
# подбирать Ins ('образ', 97) ('время', 22)   0.25
# прорвать Acc ('оборона', 3762) ('блокада', 924)  0.271
# сниться Ins ('ночь', 631) ('зима', 10)  0.809
# сниться Acc ('ночь', 604) ('время', 104)  0.627
# выдаваться Acc ('раз', 58) ('день', 19)  0.341
# унижать Acc ('достоинство', 16582) ('человек', 253)  0.897
# высказываться Acc ('раз', 480) ('время', 47)  0.762
# творить Acc ('чудо', 3388) ('добро', 804)  0.268
# творить Dat ('человек', 30) ('новгородец', 4)    0.3
# удаваться Ins ('образ', 712) ('чудо', 93)  0.461
# скрываться Acc ('время', 639) ('год', 117)  0.616
# набить Gen ('шишка', 74) ('синяк', 10)  0.315
# побить Acc ('рекорд', 7913) ('достижение', 245)  0.718
# побить Dat ('народ', 10) ('англичанин', 2)  0.263
# покончить Acc ('жизнь', 5995) ('раз', 890)  0.839
# покончить Ins ('самоубийство', 5428) ('образ', 164)  0.863
# упростить Ins ('образ', 122) ('указ', 13)  0.454
# доходить Acc ('раз', 96) ('время', 31)  0.352
# равняться Acc ('год', 105) ('неделя', 7)  0.695
# представиться Acc ('раз', 73) ('сотрудник', 4)  0.598
# публиковаться Ins ('издательство', 282) ('компания', 39)   0.26
# сотрудничать Ins ('образ', 534) ('член', 48)  0.426
# госпитализировать Ins ('лето', 283) ('вечер', 79)  0.419
# распределить Ins ('образ', 1209) ('слой', 13)   0.76
# распределить Gen ('рубль', 153) ('доллар', 21)  0.407
# базироваться Ins ('образ', 118) ('часть', 12)  0.498
# базироваться Acc ('время', 58) ('год', 7)  0.423
# проснуться Ins ('утро', 4619) ('ночь', 980)   0.73
# проснуться Acc ('раз', 113) ('час', 32)  0.353
# пасть Gen ('четверть', 133) ('трава', 19)  0.439
# пасть Acc ('ниц', 137) ('раз', 18)  0.457
# поцеловать Ins ('поцелуй', 543) ('губа', 117)  0.552
# взяться Ins ('рука', 641) ('палец', 70)   0.45
# взяться Acc ('невесть', 143) ('раз', 35)  0.348
# завершаться Acc ('раз', 19) ('год', 6)  0.432
# внушать Gen ('доверие', 33) ('опасение', 10)  0.379
# глядеть Ins ('глаз', 4413) ('взгляд', 986)  0.674
# вставать Ins ('утро', 573) ('ночь', 178)  0.324
# вставать Dat ('футболист', 129) ('человек', 5)  0.668
# добыть Ins ('путь', 845) ('способ', 202)  0.248
# добыть Gen ('тонна', 1216) ('метр', 342)  0.419
# доноситься Acc ('время', 207) ('раз', 29)  0.549
# реагировать Ins ('образ', 1412) ('снижение', 44)  0.477
# реагировать Acc ('раз', 96) ('время', 22)  0.262
# двинуться Ins ('шаг', 737) ('походка', 213)  0.227
# фигурировать Ins ('образ', 55) ('лето', 7)  0.253
# разослать Acc ('письмо', 1521) ('приглашение', 426)  0.234
# присоединить Dat ('с', 1013) ('о', 26)  0.941
# вздохнуть Ins ('грудь', 671) ('украдкой', 93)  0.652
# вздохнуть Acc ('раз', 741) ('воздух', 84)  0.688
# вздохнуть Gen ('воздух', 38) ('корка', 4)   0.38
# умирать Gen ('человек', 212) ('ребёнок', 42)  0.492
# умирать Ins ('смерть', 431) ('образ', 58)  0.387
# вытирать Gen ('слеза', 10) ('глаз', 3)  0.278
# оспорить Acc ('решение', 3870) ('результат', 699)  0.272
# совершенствовать Ins ('образ', 44) ('день', 13)  0.277
# завладеть Gen ('рубль', 21) ('доллар', 5)    0.3
# протягивать Acc ('рука', 6619) ('ладонь', 241)   0.45
# послушать Gen ('совет', 264) ('речь', 12)  0.576
# улучшать Ins ('образ', 137) ('способ', 18)  0.468
# уменьшать Ins ('образ', 200) ('зима', 9)  0.619
# спустить Gen ('.', 187) ('год', 23)   0.53
# побрать Gen ('тип', 9) ('субъект', 2)  0.257
# затянуть Gen ('пояс', 28) ('цвет', 4)  0.295
# исчерпать Ins ('образ', 110) ('слово', 8)  0.381
# взглянуть Dat ('правда', 345) ('факт', 81)   0.32
# взглянуть Acc ('раз', 2800) ('разок', 128)   0.86
# целовать Gen ('раз', 21) ('сапог', 3)  0.256
# откладывать Acc ('яйцо', 2805) ('деньга', 798)   0.22
# мечтать Acc ('жизнь', 1564) ('год', 386)  0.466
# поехать Acc ('раз', 302) ('чёрт', 16)  0.371
# санкционировать Acc ('арест', 2190) ('проведение', 461)  0.242
# отодвинуть Dat ('пол', 10) ('кулиса', 2)   0.37
# нажать Acc ('кнопка', 9336) ('клавиша', 732)  0.708
# нажать Ins ('палец', 375) ('рука', 109)  0.339
# нажать Dat ('тангента', 26) ('номер', 1)  0.491
# откинуть Dat ('пол', 124) ('бразилец', 8)  0.838
# задерживать Gen ('суд', 37) ('человек', 10)  0.274
# опередить Ins ('образ', 174) ('вопрос', 21)  0.414
# рисковать Ins ('жизнь', 5695) ('здоровье', 510)  0.605
# рисковать Gen ('человек', 18) ('житель', 4)  0.247
# рисковать Dat ('человек', 23) ('финн', 3)  0.348
# вскрыть Dat ('банк', 24) ('потомок', 6)  0.222
# разбирать Ins ('рука', 243) ('образ', 21)  0.516
# распространиться Ins ('образ', 77) ('лето', 24)  0.236
# забросить Acc ('шайба', 3793) ('дело', 323)   0.36
# забросить Gen ('шайба', 28) ('деньга', 4)  0.241
# претерпеть Acc ('изменение', 6298) ('ряд', 444)  0.657
# претерпеть Gen ('изменение', 42) ('унижение', 6)  0.347
# отнять Dat ('девочка', 7) ('девушка', 2)   0.25
# выявлять Ins ('образ', 163) ('метод', 16)  0.464
# заручиться Ins ('поддержка', 11318) ('согласие', 994)  0.721
# заручиться Gen ('пересмотр', 12) ('об', 2)  0.308
# финансироваться Acc ('заверение', 102) ('реляция', 19)  0.534
# расположить Ins ('образ', 438) ('полукруг', 78)  0.329
# полететь Acc ('раз', 43) ('пара', 8)  0.247
# окутать Acc ('столица', 1519) ('тело', 185)  0.342
# выписать Gen ('штраф', 104) ('постановление', 20)  0.314
# обретать Ins ('образ', 78) ('время', 12)  0.366
# поинтересоваться Acc ('раз', 61) ('пара', 9)  0.496
# поинтересоваться Gen ('дело', 26) ('рост', 6)  0.255
# предполагаться Gen ('рубль', 59) ('.', 11)  0.245
# склонить Acc ('голова', 11278) ('чаша', 407)  0.768
# застыть Dat ('крем', 9) ('металл', 2)  0.429
# крутить Gen ('педаль', 24) ('ворота', 4)  0.226
# тронуть Acc ('губа', 1727) ('сердце', 446)  0.248
# увлечься Acc ('время', 28) ('пара', 8)  0.354
# провожать Ins ('взгляд', 3994) ('глаз', 703)  0.657
# исчезать Ins ('образ', 243) ('утро', 32)  0.384
# прекращать Ins ('образ', 49) ('лето', 9)  0.226
# прекращать Dat ('гражданин', 9) ('больной', 2)  0.333
# обязывать Ins ('образ', 26) ('член', 3)  0.241
# отвлечь Acc ('внимание', 5905) ('сила', 334)  0.569
# запереть Acc ('дверь', 5683) ('ворота', 257)  0.554
# загрузить Gen ('раз', 64) ('тонна', 9)  0.274
# упустить Ins ('образ', 106) ('ночь', 11)  0.307
# запомниться Dat ('зритель', 894) ('болельщик', 153)  0.288
# запомниться Acc ('год', 53) ('день', 8)  0.402
# ткнуть Ins ('палец', 7290) ('кулак', 411)  0.594
# ткнуть Gen ('палец', 31) ('сила', 4)  0.307
# уменьшаться Acc ('год', 109) ('время', 31)  0.376
# уменьшаться Ins ('образ', 151) ('темп', 48)  0.415
# потереть Gen ('виски', 87) ('глаз', 15)  0.588
# повышаться Ins ('образ', 172) ('темп', 52)  0.376
# толкнуть Acc ('дверь', 3775) ('калитка', 157)  0.402
# толкнуть Gen ('сила', 31) ('муж', 4)  0.256
# опережать Ins ('образ', 83) ('слово', 12)  0.381
# арендовать Gen ('метр', 115) ('квадрат', 17)  0.608
# предназначаться Ins ('образ', 142) ('слово', 6)  0.441
# сделаться Gen ('цвет', 20) ('род', 6)  0.241
# обитать Gen ('год', 60) ('вид', 10)  0.238
# резать Ins ('нож', 592) ('ножницы', 76)  0.329
# поделить Ins ('образ', 155) ('перегородка', 17)  0.266
# разъяснить Ins ('образ', 90) ('вечер', 25)  0.276
# расставить Acc ('нога', 2010) ('рука', 617)  0.216
# препровождать Ins ('настоящее', 298) ('комиссия', 22)  0.703
# заразиться Ins ('коронавирус', 7464) ('вирус', 1101)   0.59
# заразиться Gen ('человек', 798) ('житель', 113)  0.809
# махать Ins ('рука', 6833) ('крыло', 592)  0.553
# приблизиться Acc ('раз', 40) ('пара', 10)  0.305
# вручать Gen ('оскар', 14) ('паспорт', 3)   0.25
# трудиться Gen ('человек', 162) ('год', 19)  0.317
# оштрафовать Gen ('рубль', 261) ('доллар', 25)  0.643
# оштрафовать Dat ('заключение', 8) ('сотрудник', 2)  0.381
# научиться Dat ('многое', 2210) ('искусство', 207)  0.384
# сформироваться Gen ('год', 91) ('школьник', 3)  0.469
# сформироваться Ins ('образ', 293) ('осень', 18)  0.573
# ориентировать Ins ('образ', 632) ('часть', 29)  0.642
# выслать Gen ('деньга', 67) ('.', 8)   0.33
# обостриться Gen ('.', 12) ('водить', 2)   0.25
# приняться Gen ('сила', 21) ('месть', 4)  0.231
# прижаться Acc ('раз', 25) ('тепло', 2)  0.472
# дышать Ins ('воздух', 2214) ('грудь', 586)  0.258
# подставить Ins ('образ', 87) ('рука', 11)  0.238
# зажать Acc ('рот', 1858) ('ухо', 547)  0.232
# измерять Dat ('водитель', 558) ('строитель', 85)  0.656
# вырваться Acc ('раз', 29) ('пара', 7)  0.221
# захлопнуть Acc ('дверь', 7493) ('дверца', 2402)  0.553
# захлопнуть Ins ('нога', 255) ('движение', 49)  0.469
# захлопнуть Dat ('организация', 8) ('орёл', 1)  0.533
# удивиться Acc ('раз', 132) ('малость', 3)  0.667
# пускать Gen ('слюни', 329) ('человек', 5)   0.72
# сгореть Gen ('дом', 103) ('лес', 13)  0.377
# переполнить Acc ('чаша', 1210) ('сердце', 91)   0.66
# отводить Ins ('рука', 61) ('образ', 19)  0.208
# ссылаться Ins ('образ', 73) ('слово', 9)  0.372
# сдвинуть Acc ('бровь', 2381) ('срок', 540)  0.221
# питать Gen ('иллюзия', 65) ('юноша', 18)  0.417
# портить Dat ('человек', 181) ('радиолюбитель', 49)  0.266
# портить Gen ('отношение', 15) ('чёрт', 3)  0.224
# поведать Acc ('история', 1937) ('тайна', 221)   0.47
# потянуться Acc ('раз', 72) ('день', 8)  0.529
# пожаловаться Acc ('раз', 37) ('пара', 12)  0.378
# размахивать Ins ('рука', 4338) ('флаг', 1240)  0.325
# размахивать Acc ('время', 19) ('раз', 6)  0.237
# помахать Ins ('рука', 7728) ('ручка', 566)  0.683
# помахать Acc ('раз', 60) ('пара', 10)  0.351
# затопить Ins ('вода', 817) ('лава', 165)  0.332
# потянуть Ins ('нос', 659) ('запах', 114)  0.289
# накопить Acc ('опыт', 1704) ('потенция', 457)  0.285
# накопить Gen ('деньга', 452) ('доллар', 143)  0.351
# пролететь Gen ('километр', 152) ('миля', 25)   0.45
# управляться Acc ('время', 20) ('часть', 5)  0.278
# регламентировать Gen ('мера', 13) ('норматив', 4)  0.236
# понизиться Gen ('.', 48) ('конкурент', 14)  0.338
# понизиться Acc ('раз', 81) ('месяц', 5)  0.643
# поверить Gen ('представительство', 87) ('присяжный', 17)  0.327
# скорректировать Ins ('образ', 690) ('время', 16)  0.711
# сверкнуть Ins ('глаз', 3024) ('улыбка', 444)  0.495
# разводить Ins ('рука', 2556) ('вода', 100)  0.854
# затянуться Ins ('сигарета', 656) ('дым', 165)  0.384
# затянуться Dat ('флот', 185) ('рана', 8)  0.907
# расторгнуть Gen ('договор', 19) ('контракт', 6)  0.514
# подчёркиваться Acc ('раз', 97) ('время', 10)  0.651
# полагаться Ins ('образ', 102) ('утро', 13)  0.211
# щёлкнуть Ins ('палец', 2695) ('выключатель', 848)  0.311
# взломать Ins ('хакер', 237) ('образ', 45)  0.297
# распахнуться Ins ('рывок', 44) ('утро', 14)  0.263
# распахнуться Gen ('глаз', 4) ('цимбала', 1)  0.267
# почтить Acc ('память', 7477) ('мероприятие', 33)  0.878
# почтить Gen ('жертва', 14) ('житель', 3)  0.438
# торговаться Ins ('утро', 129) ('образ', 23)  0.417
# изменяться Ins ('образ', 368) ('работа', 30)  0.399
# изменяться Dat ('характер', 18) ('изменение', 4)   0.24
# ложиться Ins ('бремя', 884) ('груз', 129)  0.314
# намереваться Ins ('образ', 435) ('вечер', 25)  0.542
# намереваться Dat ('въезд', 40) ('власть', 6)  0.494
# стиснуть Acc ('зуб', 6127) ('рука', 1057)  0.547
# судить Ins ('суд', 401) ('трибунал', 74)  0.414
# стянуть Gen ('сапог', 16) ('полицейский', 4)  0.232
# перерезать Ins ('нож', 255) ('движение', 57)  0.214
# расшириться Ins ('образ', 93) ('лето', 6)  0.388
# инвестировать Acc ('средство', 2827) ('деньга', 670)  0.463
# проявиться Ins ('образ', 160) ('лето', 28)  0.321
# проявиться Acc ('раз', 42) ('год', 12)  0.382
# возбуждать Acc ('дело', 4415) ('преследование', 387)  0.453
# вдохнуть Ins ('грудь', 1112) ('нос', 37)  0.837
# вдохнуть Gen ('воздух', 539) ('сила', 14)  0.769
# вдохнуть Dat ('воздух', 10) ('табак', 2)  0.303
# совмещать Ins ('образ', 112) ('способ', 5)  0.514
# совмещать Dat ('женщина', 4) ('человек', 1)  0.286
# возместить Acc ('ущерб', 3852) ('убыток', 1015)  0.404
# возместить Gen ('рубль', 146) ('доллар', 33)  0.577
# кинуть Acc ('взгляд', 3137) ('граната', 292)  0.298
# качать Ins ('голова', 6697) ('нога', 87)  0.908
# идентифицировать Ins ('образ', 187) ('полиция', 16)  0.294
# потушить Ins ('сила', 232) ('пожарный', 45)  0.291
# опросить Gen ('человек', 315) ('респондент', 78)  0.416
# истечь Ins ('кровь', 503) ('лето', 70)  0.621
# покорить Gen ('полмира', 15) ('вершина', 4)  0.268
# замедлить Ins ('образ', 44) ('время', 9)  0.239
# сжаться Gen ('живот', 14) ('сердце', 4)  0.311
# сжаться Acc ('сердце', 41) ('раз', 10)  0.432
# расстегнуть Gen ('ворота', 24) ('ворот', 4)  0.316
# красоваться Dat ('девушка', 7) ('поддержка', 1)   0.35
# извлекать Dat ('спасатель', 15) ('медик', 3)  0.417
# обвить Acc ('шея', 3377) ('талия', 667)  0.582
# обвить Ins ('рука', 4087) ('нога', 475)  0.676
# обвить Dat ('рука', 5) ('караульный', 1)    0.5
# нащупать Dat ('хоккеист', 4) ('следствие', 1)  0.333
# попасться Acc ('раз', 183) ('пара', 36)  0.587
# велеть Ins ('жест', 453) ('кивок', 69)   0.43
# просмотреть Gen ('раз', 143) ('человек', 28)  0.443
# завязать Ins ('узел', 660) ('платок', 92)   0.37
# дебютировать Gen ('.', 12) ('год', 3)  0.286
# дебютировать Dat ('выступление', 9) ('лига', 2)   0.45
# нацелить Ins ('образ', 289) ('слово', 12)   0.73
# блеснуть Acc ('раз', 41) ('пара', 11)  0.506
# запрещаться Ins ('закон', 256) ('образ', 75)  0.223
# воскликнуть Ins ('голос', 595) ('хор', 168)  0.516
# обвиняться Acc ('раз', 49) ('год', 7)  0.645
# обвиняться Gen ('житель', 6) ('область', 1)  0.375
# проглотить Gen ('кусочек', 29) ('кусок', 7)  0.238
# проглотить Ins ('залп', 140) ('миг', 35)  0.289
# отступить Gen ('год', 17) ('метр', 5)  0.293
# жечь Ins ('огонь', 416) ('железо', 99)  0.372
# побудить Ins ('образ', 31) ('пример', 8)  0.225
# побудить Dat ('власть', 9) ('делегация', 2)  0.375
# сочетаться Ins ('брак', 1962) ('образ', 488)  0.687
# сочетаться Acc ('раз', 12) ('количество', 3)   0.24
# отметиться Acc ('раз', 38) ('пара', 6)  0.427
# совпасть Ins ('образ', 347) ('лето', 6)  0.785
# совпасть Acc ('раз', 10) ('разница', 3)  0.238
# освятить Gen ('год', 56) ('.', 16)  0.544
# переместить Gen ('страна', 5316) ('человек', 18)  0.971
# поменяться Ins ('место', 2419) ('роль', 661)  0.557
# поменяться Acc ('раз', 16) ('год', 4)  0.308
# варьироваться Ins ('образ', 67) ('зима', 13)  0.429
# проехать Gen ('километр', 162) ('миля', 41)  0.343
# ознаменовать Acc ('начало', 1464) ('конец', 467)  0.227
# обнимать Ins ('рука', 539) ('лапа', 48)  0.449
# общаться Dat ('человек', 34) ('пользователь', 6)  0.245
# обозначаться Acc ('время', 25) ('раз', 4)  0.556
# засунуть Acc ('рука', 4055) ('палец', 568)  0.374
# казнить Dat ('народ', 5) ('семья', 1)   0.25
# проверяться Acc ('раз', 90) ('год', 13)   0.52
# сопротивляться Acc ('время', 141) ('мгновение', 21)  0.425
# сопротивляться Ins ('сила', 90) ('образ', 27)  0.265
# исказить Acc ('лицо', 1355) ('черта', 228)  0.275
# исказить Gen ('гримаса', 23) ('род', 6)  0.371
# исказить Dat ('процесс', 4) ('данные', 1)  0.333
# возводить Gen ('метр', 49) ('дом', 7)   0.45
# прижимать Ins ('рука', 350) ('плечо', 67)  0.307
# ...
# доучиваться Acc ('год', 7) ('класс', 2)  0.538
# сжижать Acc ('газ', 48) ('водород', 4)  0.762
# приукрашать Acc ('действительность', 13) ('заслуга', 3)  0.295
# проинтегрировать Acc ('уравнение', 15) ('функция', 4)  0.278
# прокрасить Acc ('ресница', 12) ('ресничка', 3)  0.444
# разрумянить Ins ('мороз', 6) ('гнев', 1)  0.545
# облокотить Acc ('голова', 27) ('рука', 8)  0.443
# оградиться Ins ('стена', 10) ('забор', 3)  0.204
# пробарабанить Ins ('палец', 19) ('град', 3)  0.576
# любезничать Acc ('время', 4) ('час', 1)  0.444
# проращивать Acc ('семя', 21) ('зерно', 4)  0.382
# подсобрать Gen ('деньга', 11) ('материал', 3)  0.524
# закупориваться Ins ('пробка', 8) ('способ', 2)   0.32
# начесать Acc ('волос', 25) ('холка', 3)  0.556
# поперчить Ins ('перец', 21) ('патриотизм', 2)   0.75
# оглуплять Acc ('человек', 15) ('народ', 4)  0.357
# сплетня Gen ('анекдот', 32) ('версия', 2)  0.542
# снискивать Acc ('пропитание', 18) ('расположение', 4)  0.486
# попалить Ins ('огонь', 6) ('луч', 1)    0.5
# сообразовать Acc ('действие', 11) ('поведение', 2)  0.244
# пошаркать Ins ('нога', 23) ('ножка', 7)  0.451
# вдыхаться Ins ('человек', 8) ('лёгкое', 2)  0.444
# пригубливать Acc ('вино', 17) ('жидкость', 5)  0.304
# шпиговать Acc ('мясо', 9) ('средство', 1)  0.429
# меряющий Ins ('шаг', 22) ('поступь', 1)  0.759
# дрожь Gen ('земля', 24) ('вампир', 4)  0.558
# облупить Ins ('место', 8) ('возраст', 1)  0.615
# перехвалить Acc ('лайнер', 8) ('власть', 2)  0.222
# прорицать Acc ('будущее', 12) ('картина', 2)  0.353
# проконопатить Ins ('мох', 14) ('земля', 1)    0.7
# передумывать Acc ('раз', 7) ('дума', 2)  0.269
# замусолить Ins ('дух', 10) ('компания', 1)  0.417
# лучить Acc ('рыба', 9) ('приз', 2)   0.29
# настричь Gen ('шерсть', 12) ('лох', 2)  0.462
# приплатить Gen ('деньга', 4) ('дом', 1)  0.444
# гранить Acc ('камень', 16) ('алмаз', 4)    0.5
# давеча Ins ('утро', 4) ('течение', 1)    0.4
# умеряться Ins ('здравомыслие', 7) ('дальновидность', 2)  0.241
# пырять Ins ('нож', 19) ('метать', 2)  0.543
# ушатый Gen ('вода', 38) ('помои', 2)  0.826
# доукомплектовываться Ins ('состав', 8) ('средство', 2)  0.276
# вкрутую Acc ('яйцо', 28) ('сок', 2)  0.667
# неделя Gen ('безопасность', 30) ('четыре', 2)  0.811
# грунтовать Acc ('холст', 18) ('стена', 4)    0.5
# нарумянить Acc ('щека', 21) ('соска', 1)  0.778
# спрягать Acc ('глагол', 23) ('технология', 4)    0.5
# развращаться Ins ('душа', 10) ('свобода', 2)  0.455
# подслащивать Acc ('пилюля', 19) ('кофе', 4)  0.487
# прокомпостировать Acc ('билет', 31) ('талон', 8)  0.646
# воссылать Acc ('молитва', 17) ('слава', 5)  0.405
# притворять Acc ('дверь', 26) ('план', 3)  0.542
# цапать Acc ('сотовый', 12) ('дяденька', 1)  0.414
# допустимый Ins ('закон', 36) ('законодательство', 3)  0.643
# поседлать Ins ('седло', 11) ('вечер', 1)  0.688
# притаптывать Ins ('нога', 13) ('лапа', 4)   0.52
# послюнить Acc ('палец', 36) ('карандаш', 6)   0.72
# меченый Ins ('изотоп', 16) ('метка', 4)  0.302
# порыскать Ins ('глаз', 19) ('взгляд', 6)  0.594
# бравый Acc ('раз', 7) ('брависсимо', 2)  0.438
# поплескать Ins ('вода', 33) ('пригоршня', 2)  0.767
# ороситься Ins ('кровь', 17) ('брызги', 5)  0.548
# перестраховывать Acc ('риск', 30) ('ответственность', 2)  0.714
# заворотить Acc ('подол', 12) ('сарафан', 3)  0.308
# франкировать Ins ('марка', 37) ('лорд', 1)  0.841
# издырявить Ins ('пуля', 8) ('сотня', 2)  0.381
# позёвывать Ins ('украдкой', 6) ('время', 1)    0.5
# начёркать Acc ('записка', 7) ('пара', 2)   0.25
# занятый Ins ('дело', 10) ('подготовка', 3)  0.345
# подтормаживать Acc ('колесо', 16) ('затвор', 2)  0.533
# перемести Acc ('дорога', 12) ('центр', 2)  0.545
# скриншот Acc ('страница', 9) ('фото', 2)    0.5
# протыкаться Ins ('вилка', 13) ('ряд', 2)  0.448
# обсаживать Ins ('дерево', 10) ('куст', 3)   0.37
# заплёвывать Ins ('косточка', 11) ('кровь', 2)  0.524
# истребуемый Ins ('заявитель', 27) ('орган', 7)   0.54
# прорастить Acc ('семя', 15) ('косточка', 3)  0.349
# откромсать Acc ('кусок', 11) ('башка', 3)  0.314
# взлохмачивать Acc ('волос', 24) ('шевелюра', 4)  0.585
# перепаковать Acc ('фотка', 16) ('багаж', 2)  0.457
# цыкать Ins ('зуб', 16) ('язык', 4)   0.64
# дохаживать Acc ('день', 13) ('месяц', 3)  0.406
# пломбировать Acc ('зуб', 15) ('канал', 3)  0.395
# закомпостировать Acc ('билет', 32) ('мозг', 8)  0.711
# вытапливать Acc ('жир', 24) ('сало', 3)  0.522
# подкуривать Acc ('сигарета', 28) ('сигара', 2)  0.683
# запломбировать Acc ('зуб', 11) ('труба', 3)  0.355
# параметризоваться Ins ('тип', 8) ('список', 2)  0.286
# перечертить Acc ('граница', 7) ('поле', 2)  0.269
# утруждаться Ins ('соблюдение', 18) ('раздумье', 2)  0.486
# покропить Ins ('вода', 18) ('кровь', 5)  0.621
# подмываться Ins ('вода', 12) ('рука', 3)  0.414
# залакировать Acc ('действительность', 24) ('телевидение', 3)  0.727
# срамить Ins ('истукан', 4) ('образ', 1)  0.444
# дубить Acc ('кожа', 17) ('шкура', 2)   0.68
# умащать Acc ('тело', 7) ('борода', 1)  0.304
# умащать Ins ('масло', 12) ('мёд', 3)    0.5
# залучить Acc ('звезда', 15) ('англичанин', 3)  0.333
# переметать Acc ('дорога', 10) ('сугроб', 2)  0.385
# зарыбить Ins ('карп', 9) ('форель', 2)  0.375
# подучивать Acc ('девчонка', 13) ('дружок', 3)  0.433
# продубить Ins ('ветер', 22) ('солнце', 6)  0.629
# ошпариться Ins ('кипяток', 24) ('чай', 4)  0.649
# девять Gen ('член', 9) ('миллион', 2)  0.474
# изъедать Acc ('душа', 8) ('мозг', 2)  0.308
# утишать Acc ('боль', 17) ('страдание', 2)  0.531
# обезлюдить Acc ('земля', 7) ('деревня', 2)  0.318
# хлорировать Acc ('вода', 13) ('колодец', 2)  0.565
# вплавить Acc ('кристалл', 4) ('светодиод', 1)  0.333
# дожечь Acc ('остаток', 15) ('ночь', 2)  0.577
# намутить Acc ('вода', 12) ('танк', 2)   0.48
# пленяться Ins ('красота', 12) ('жизнь', 2)  0.333
# подрыгать Ins ('нога', 24) ('ножка', 6)  0.571
# прижучить Acc ('брат', 8) ('парень', 2)  0.211
# долечить Ins ('миг', 4) ('птица', 1)  0.444
# висеться Ins ('голова', 25) ('грозд', 6)  0.568
# исклевать Ins ('птица', 8) ('осколок', 2)  0.308
# монополизироваться Ins ('партия', 4) ('власть', 1)  0.308
# приноравливать Acc ('шаг', 15) ('гортань', 2)  0.357
# соучаствовать Ins ('образ', 6) ('край', 1)  0.462
# стратифицировать Acc ('семя', 7) ('общество', 2)  0.368
# окатиться Ins ('вода', 31) ('порция', 3)  0.738
# дознаться Gen ('правда', 5) ('зло', 1)    0.5
# пролёживать Acc ('бок', 17) ('месяц', 2)   0.63
# затопотать Ins ('нога', 9) ('копыто', 2)  0.562
# обривать Acc ('голова', 22) ('ягодица', 2)  0.759
# умягчить Acc ('сердце', 18) ('суровость', 3)  0.581
# супить Acc ('бровь', 23) ('носик', 1)  0.767
# зашторивать Acc ('окно', 25) ('окошечко', 4)  0.714
# сообщиться Dat ('родитель', 8) ('покупатель', 1)    0.5
# вываживать Acc ('рыба', 15) ('конь', 4)  0.405
# доля Gen ('секунда', 19) ('процент', 2)  0.528
# сепарировать Acc ('молоко', 12) ('клетка', 3)  0.316
# прострелять Ins ('пуля', 9) ('авиация', 1)  0.643
# ссечь Acc ('голова', 21) ('всадник', 2)   0.75
# иммунизировать Acc ('молодёжь', 8) ('человек', 2)  0.333
# пассировать Acc ('лук', 17) ('мука', 4)  0.436
# насладить Acc ('творение', 7) ('душа', 2)  0.467
# отхаркиваться Ins ('кровь', 21) ('слизь', 3)  0.636
# протачивать Acc ('ход', 8) ('русло', 2)  0.296
# дошить Acc ('платье', 14) ('воздух', 4)  0.424
# присыпаться Ins ('земля', 8) ('зола', 2)  0.308
# прирабатывать Ins ('проституция', 7) ('шитьё', 2)  0.269
# передерживать Acc ('мяч', 21) ('дело', 4)  0.636
# несанкционированный Ins ('власть', 20) ('правительство', 3)  0.513
# одомашнивать Acc ('животное', 12) ('корова', 2)  0.353
# перемкнуть Acc ('провод', 8) ('контакт', 2)   0.32
# дооснащать Ins ('оборудование', 9) ('комплекс', 2)   0.45
# похмелиться Ins ('утро', 8) ('водочка', 2)  0.381
# огранивать Acc ('доступ', 13) ('слой', 3)  0.433
# побренчать Ins ('ключ', 12) ('мелочь', 3)    0.4
# испытующий Acc ('сердце', 16) ('любовь', 2)  0.615
# ломоть Gen ('хлеб', 19) ('сало', 2)  0.704
# недобитый Ins ('мафия', 11) ('войско', 3)  0.314
# напекать Acc ('голова', 12) ('макушка', 3)  0.545
# межевать Acc ('земля', 20) ('вотчина', 2)   0.69
# пропечь Ins ('солнце', 21) ('радиация', 1)  0.808
# скруглять Acc ('угол', 10) ('линия', 3)  0.357
# оттаптывать Acc ('нога', 10) ('колено', 2)  0.385
# раскупоривать Acc ('бутылка', 14) ('кубышка', 4)  0.452
# вымесить Acc ('тесто', 18) ('трасса', 5)  0.529
# таки Acc ('раз', 5) ('нарушение', 1)  0.455
# проклеить Ins ('скотч', 10) ('бумага', 2)  0.455
# ложа Acc ('рука', 14) ('голова', 4)  0.389
# тиснёный Ins ('золото', 22) ('буква', 2)   0.71
# втравливать Acc ('ребёнок', 12) ('мистер', 2)  0.429
# колобродить Acc ('ночь', 6) ('время', 1)  0.462
# вихляться Ins ('тело', 6) ('туловище', 1)  0.545
# наживлять Acc ('крючок', 9) ('червь', 2)  0.346
# припугивать Acc ('журналист', 5) ('читатель', 1)  0.357
# совлечь Acc ('одежда', 8) ('перчатка', 2)  0.364
# перерезывать Acc ('дорога', 7) ('связь', 2)  0.292
# обваривать Ins ('кипяток', 15) ('металлолом', 1)  0.714
# упекать Acc ('мать', 10) ('человек', 3)  0.417
# изнанка Gen ('жизнь', 17) ('ситуация', 3)   0.63
# выдача Gen ('кредит', 17) ('паспорт', 2)   0.63
# перегладить Acc ('бельё', 16) ('гора', 4)  0.485
# взъярить Acc ('гон', 8) ('море', 1)  0.615
# отрясти Acc ('прах', 21) ('пыль', 2)  0.778
# додавать Acc ('награда', 4) ('корова', 1)  0.444
# кровавить Acc ('степь', 4) ('морда', 1)  0.211
# бороновать Acc ('поле', 7) ('участок', 2)  0.269
# рекуперировать Acc ('энергия', 10) ('часть', 3)  0.323
# инцидентный Dat ('вершина', 23) ('ребро', 5)  0.676
# поотбивать Acc ('рука', 10) ('печёнка', 2)   0.37
# панировать Acc ('карп', 15) ('лапка', 1)  0.682
# бомбиться Ins ('авиация', 6) ('армия', 1)  0.462
# заморачивать Acc ('голова', 10) ('мозг', 2)  0.588
# подтоплять Acc ('деревня', 7) ('станция', 2)  0.259
# перестукиваться Ins ('клык', 4) ('зуб', 1)  0.364
# взбрызнуть Ins ('вода', 7) ('вещество', 2)  0.412
# заблагорассудиться Dat ('душа', 8) ('медик', 2)  0.308
# раскорячить Acc ('нога', 12) ('лапа', 3)  0.444
# намываться Ins ('прилив', 4) ('гель', 1)    0.4
# выскрёбывать Acc ('остаток', 7) ('слой', 2)  0.318
# приуготовить Acc ('путь', 4) ('роль', 1)  0.235
# огревать Ins ('дубинка', 19) ('палка', 2)  0.613
# растрёпывать Acc ('волос', 13) ('причёска', 3)  0.565
# высморкать Acc ('нос', 24) ('трубочка', 1)  0.828
# подушиться Ins ('дух', 18) ('вода', 3)  0.581
# купа Gen ('режиссёр', 14) ('фирма', 2)  0.667
# закавычить Acc ('слово', 10) ('вариант', 1)  0.667
# замкомандующего Ins ('корпус', 14) ('войско', 4)  0.483
# нес Acc ('вода', 12) ('золото', 1)  0.522
# нащипать Acc ('лучина', 7) ('пёрышко', 2)   0.35
# догулять Acc ('отпуск', 21) ('день', 2)  0.724
# сопля Ins ('пузырь', 7) ('веер', 2)  0.538
# крючить Acc ('палец', 4) ('морда', 1)  0.267
# рефлектировать Acc ('развитие', 4) ('опыт', 1)  0.235
# порадеть Dat ('человечек', 14) ('человек', 2)  0.636
# умышлять Acc ('зло', 12) ('злоба', 2)    0.6
# поматывать Ins ('голова', 17) ('грива', 4)  0.586
# намораживать Acc ('лёд', 8) ('переправа', 2)  0.364
# заспиртовать Acc ('голова', 6) ('рыба', 1)    0.4
# лизировать Acc ('клетка', 8) ('бактерия', 2)  0.348
# соборовать Acc ('житель', 4) ('покойник', 1)  0.235
# завеять Ins ('верёвочка', 4) ('ветер', 1)  0.308
# завеять Acc ('горе', 5) ('волос', 1)  0.455
# эквивалентный Dat ('сумма', 14) ('средство', 2)  0.519
# перезабыть Acc ('требование', 8) ('многий', 2)    0.5
# остеклять Acc ('квартира', 8) ('окно', 2)  0.444
# тушировать Acc ('соперник', 13) ('чемпион', 2)  0.542
# адоптировать Acc ('ребёнок', 4) ('система', 1)   0.25
# копнить Acc ('сено', 7) ('эпоха', 2)  0.389
# огосударствить Acc ('сектор', 5) ('отрасль', 1)  0.417
# проторять Acc ('путь', 14) ('дорога', 4)  0.609
# расхлебать Acc ('каша', 21) ('последствие', 2)   0.75
# навинчивать Acc ('глушитель', 10) ('наконечник', 2)  0.385
# обстирывать Acc ('семья', 5) ('жена', 1)  0.263
# окорачивать Acc ('свобода', 9) ('пират', 1)   0.45
# горбить Acc ('спина', 10) ('плечо', 3)    0.5
# отрясать Acc ('прах', 7) ('пыль', 2)  0.304
# оттолкать Acc ('машина', 11) ('автомобиль', 3)  0.478
# вздевать Acc ('рука', 10) ('шест', 1)  0.455
# воздымать Acc ('рука', 11) ('нога', 2)   0.55
# почмокивать Ins ('губа', 14) ('ротик', 1)    0.7
# заматываться Ins ('шарф', 4) ('утро', 1)    0.4
# пастеризовать Acc ('молоко', 7) ('сарделька', 2)  0.333
# разгораживать Acc ('ресторан', 8) ('шатёр', 2)  0.333
# побалтывать Ins ('ножка', 12) ('ласт', 2)    0.6
# повырубить Acc ('лес', 8) ('трезвенник', 2)  0.421
# понежить Acc ('тело', 10) ('царица', 3)    0.4
# возлить Acc ('елей', 8) ('миро', 2)  0.471
# пахтать Acc ('океан', 13) ('море', 2)   0.65
# обминать Acc ('тесто', 4) ('снег', 1)  0.222
# модернизовать Acc ('система', 4) ('парк', 1)  0.286
# замучивать Acc ('человек', 5) ('ребёнок', 1)  0.385
# обрезывать Acc ('плоть', 7) ('язычник', 2)  0.368
# вразлёт Acc ('бровь', 6) ('мозг', 1)  0.545
# ослушиваться Gen ('приказ', 10) ('предписание', 1)  0.526
# прилизывать Acc ('волос', 8) ('информация', 1)  0.421
# уваривать Acc ('пиво', 10) ('сок', 3)  0.417
# умилостивлять Ins ('жертва', 7) ('жертвоприношение', 1)    0.5
# довязывать Acc ('носок', 7) ('шарфик', 2)  0.333
# разыменовывать Acc ('указатель', 14) ('ссылка', 2)  0.667
# хлестаться Ins ('веник', 7) ('репейник', 2)  0.412
# изморить Ins ('голод', 7) ('терзание', 1)  0.389
# перевоплощать Acc ('характер', 5) ('вещь', 1)   0.25
# горбатить Acc ('спина', 7) ('фигура', 2)  0.467
# накликивать Acc ('беда', 9) ('график', 1)  0.529
# недопить Acc ('кофе', 4) ('четверть', 1)  0.444
# потрещать Ins ('язык', 5) ('стартер', 1)  0.455
# выкликивать Acc ('имя', 7) ('номер', 1)  0.538
# загромождаться Ins ('куча', 4) ('труп', 1)  0.333
# подмачивать Acc ('репутация', 7) ('имущество', 2)    0.5
# гибель Gen ('бог', 12) ('субъект', 1)  0.632
# блиндировать Ins ('мешок', 6) ('щит', 1)  0.462
# пришлёпывать Ins ('губа', 7) ('ладонь', 2)  0.467
# потоплять Acc ('корабль', 4) ('танец', 1)  0.308
# помавать Ins ('рука', 9) ('ручка', 2)  0.474
# опушаться Ins ('кайма', 7) ('пена', 1)    0.5
# футеровать Ins ('кирпич', 7) ('плитка', 2)  0.438
# щёлк Ins ('зуб', 7) ('бич', 2)  0.467
# поскрежетать Ins ('зуб', 12) ('стартер', 2)  0.571
# перепоясаться Ins ('ремень', 7) ('лента', 2)  0.412
# переметнуть Acc ('взгляд', 11) ('внимание', 2)   0.55
# дохлебать Acc ('остаток', 4) ('варево', 1)  0.333
# взмах Ins ('рука', 7) ('меч', 2)    0.5
# переохладить Acc ('вода', 4) ('оборудование', 1)  0.308
# понабивать Acc ('шишка', 4) ('подушка', 1)  0.444
# сквернить Acc ('тело', 10) ('дом', 1)  0.625
# разгул Gen ('бес', 8) ('зло', 1)  0.571
# обсидеть Ins ('муха', 4) ('правоохранитель', 1)  0.286
# помахаться Ins ('кулак', 7) ('коготь', 2)  0.538
# поглотать Acc ('воздух', 4) ('таблеточка', 1)    0.4
# откидать Acc ('снег', 9) ('право', 1)  0.529
# припалить Acc ('шерсть', 4) ('хвост', 1)    0.4
# неудовлетворяющий Dat ('требование', 11) ('правило', 1)  0.688
# заметный Ins ('глаз', 5) ('точка', 1)    0.5
# ушибать Acc ('нога', 4) ('ступня', 1)  0.333
# продырявливать Acc ('крыша', 4) ('противник', 1)  0.333
# накрашивать Acc ('губа', 10) ('ресница', 2)  0.625
# отплавать Acc ('матч', 5) ('первенство', 1)  0.455
# облепиться Ins ('сочувствие', 4) ('ларёк', 1)  0.364
# сдаивать Acc ('молоко', 7) ('струйка', 2)  0.438
# досушить Acc ('волос', 5) ('вещь', 1)  0.417
# долизывать Acc ('остаток', 4) ('капля', 1)  0.333
# скооперировать Acc ('усилие', 5) ('передача', 1)  0.417
# высудить Acc ('супруга', 6) ('награда', 1)  0.462
# обкосить Acc ('трава', 5) ('межа', 1)  0.417
# перешнуровывать Acc ('ботинок', 8) ('кроссовок', 2)  0.533
# доклеивать Acc ('марка', 5) ('подарок', 1)  0.455
# буферизовать Acc ('данные', 4) ('сигнал', 1)  0.444
# расклепать Acc ('цепь', 5) ('часть', 1)  0.455
# перхать Ins ('дым', 4) ('кровь', 1)    0.4
# обрыть Ins ('вал', 4) ('ров', 1)  0.444
# проклюнуть Acc ('скорлупа', 4) ('ухарь', 1)    0.4
# счёсывать Acc ('кожа', 5) ('плоть', 1)  0.417
# доклеить Acc ('обои', 4) ('уголок', 1)  0.308
# подматывать Acc ('леска', 5) ('блесна', 1)    0.5
# отёсывать Acc ('камень', 4) ('оглобля', 1)    0.4
# пережаривать Acc ('рыба', 5) ('стейка', 1)  0.417
# поизносить Acc ('слово', 5) ('имя', 1)    0.5
# выпрыснуть Acc ('содержимое', 5) ('капля', 1)  0.455
# крашеный Ins ('краска', 8) ('настойка', 2)  0.571
# тампонировать Acc ('рана', 4) ('трещина', 1)  0.364
# побесить Acc ('враг', 4) ('истеблишмент', 1)    0.4
# катя Acc ('работа', 5) ('воздух', 1)    0.5
# подмостить Acc ('рюкзак', 4) ('коврик', 1)  0.444
# перепустить Acc ('деревня', 4) ('движение', 1)    0.4
# обтряхивать Acc ('пыль', 4) ('лист', 1)    0.4

# %%
sorted(exceptions.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Ins образ', 760),
#  ('Acc раз', 453),
#  ('Acc время', 237),
#  ('Ins рука', 70),
#  ('Ins голос', 62),
#  ('Ins нога', 54),
#  ('Gen рубль', 50),
#  ('Gen человек', 49),
#  ('Ins голова', 42),
#  ('Acc голова', 42),
#  ('Acc глаз', 41),
#  ('Ins вода', 40),
#  ('Acc волос', 40),
#  ('Ins ночь', 38),
#  ('Acc рука', 36),
#  ('Gen год', 33),
#  ('Ins глаз', 32),
#  ('Dat человек', 30),
#  ('Ins взгляд', 28),
#  ('Gen раз', 27),
#  ('Ins зуб', 27),
#  ('Ins сила', 26),
#  ('Gen деньга', 25),
#  ('Acc год', 24),
#  ('Ins время', 23),
#  ('Acc слово', 22),
#  ('Ins лицо', 22),
#  ('Ins место', 22),
#  ('Ins палец', 22),
#  ('Ins кровь', 21),
#  ('Acc губа', 20),
#  ('Ins утро', 19),
#  ('Gen сила', 19),
#  ('Ins нос', 19),
#  ('Acc вода', 19),
#  ('Acc жизнь', 18),
#  ('Ins тело', 18),
#  ('Acc нога', 18),
#  ('Ins день', 18),
#  ('Ins слово', 17),
#  ('Ins ветер', 17),
#  ('Acc дверь', 17),
#  ('Gen тонна', 16),
#  ('Ins вечер', 16),
#  ('Ins нож', 16),
#  ('Ins солнце', 16),
#  ('Ins язык', 16),
#  ('Ins волна', 16),
#  ('Gen .', 15),
#  ('Acc внимание', 14),
#  ('Acc сердце', 14),
#  ('Acc лицо', 14),
#  ('Acc день', 14),
#  ('Acc тело', 13),
#  ('Gen вода', 13),
#  ('Dat власть', 12),
#  ('Dat народ', 12),
#  ('Ins губа', 12),
#  ('Ins лето', 11),
#  ('Acc пара', 11),
#  ('Gen дело', 10),
#  ('Gen слово', 10),
#  ('Acc деньга', 10),
#  ('Acc зуб', 10),
#  ('Ins краска', 10),
#  ('Acc ребёнок', 10),
#  ('Acc сигарета', 10),
#  ('Acc душа', 10),
#  ('Gen метр', 9),
#  ('Acc ночь', 9),
#  ('Acc дорога', 9),
#  ('Ins зима', 9),
#  ('Acc вопрос', 8),
#  ('Gen внимание', 8),
#  ('Gen глаз', 8),
#  ('Ins шаг', 8),
#  ('Gen цвет', 8),
#  ('Gen дрова', 8),
#  ('Ins миг', 8),
#  ('Acc палец', 8),
#  ('Acc срок', 8),
#  ('Acc рана', 8),
#  ('Acc стена', 8),
#  ('Acc человек', 8),
#  ('Ins жизнь', 7),
#  ('Acc дело', 7),
#  ('Ins суд', 7),
#  ('Dat ребёнок', 7),
#  ('Ins залп', 7),
#  ('Dat банк', 7),
#  ('Dat пол', 7),
#  ('Acc бровь', 7),
#  ('Gen живот', 7),
#  ('Ins смех', 7),
#  ('Acc мяч', 7),
#  ('Ins кулак', 7),
#  ('Acc имя', 7),
#  ('Ins год', 7),
#  ('Ins дух', 7),
#  ('Acc мозг', 7),
#  ('Ins полотенце', 7),
#  ('Ins кипяток', 7),
#  ('Acc взгляд', 6),
#  ('Ins жест', 6),
#  ('Gen километр', 6),
#  ('Dat страна', 6),
#  ('Gen род', 6),
#  ('Acc свет', 6),
#  ('Acc память', 6),
#  ('Gen страна', 6),
#  ('Dat шутка', 6),
#  ('Ins весна', 6),
#  ('Acc слеза', 6),
#  ('Acc машина', 6),
#  ('Ins человек', 6),
#  ('Acc воздух', 6),
#  ('Ins ключ', 6),
#  ('Gen полчасика', 6),
#  ('Acc бог', 6),
#  ('Acc спина', 6),
#  ('Ins осень', 6),
#  ('Acc кровь', 6),
#  ('Acc окно', 6),
#  ('Ins власть', 6),
#  ('Acc тесто', 6),
#  ('Ins закон', 5),
#  ('Ins темп', 5),
#  ('Ins плечо', 5),
#  ('Gen виски', 5),
#  ('Acc усилие', 5),
#  ('Acc граница', 5),
#  ('Dat пользователь', 5),
#  ('Dat женщина', 5),
#  ('Ins ракета', 5),
#  ('Dat чай', 5),
#  ('Gen воздух', 5),
#  ('Gen тип', 5),
#  ('Acc рот', 5),
#  ('Gen полмира', 5),
#  ('Ins огонь', 5),
#  ('Ins пуля', 5),
#  ('Gen ночь', 5),
#  ('Ins способ', 5),
#  ('Ins чудо', 5),
#  ('Acc вина', 5),
#  ('Ins свет', 5),
#  ('Acc порог', 5),
#  ('Acc обстановка', 5),
#  ('Ins галоп', 5),
#  ('Ins мысль', 5),
#  ('Ins спина', 5),
#  ('Acc нос', 5),
#  ('Ins масло', 5),
#  ('Ins снег', 5),
#  ('Acc путь', 5),
#  ('Ins хвост', 5),
#  ('Ins сон', 5),
#  ('Acc земля', 5),
#  ('Acc страница', 5),
#  ('Acc кожа', 5),
#  ('Ins локоть', 5),
#  ('Ins сердце', 5),
#  ('Acc молоко', 5),
#  ('Acc рыба', 5),
#  ('Acc ботинок', 5),
#  ('Ins ножницы', 5),
#  ('Gen член', 5),
#  ('Acc место', 4),
#  ('Acc история', 4),
#  ('Dat требование', 4),
#  ('Ins смерть', 4),
#  ('Gen вопрос', 4),
#  ('Ins корень', 4),
#  ('Gen время', 4),
#  ('Dat чек', 4),
#  ('Gen усилие', 4),
#  ('Ins рот', 4),
#  ('Acc дыхание', 4),
#  ('Ins указ', 4),
#  ('Gen отметка', 4),
#  ('Gen совет', 4),
#  ('Dat полицейский', 4),
#  ('Ins сторона', 4),
#  ('Acc деревня', 4),
#  ('Ins слеза', 4),
#  ('Ins взрыв', 4),
#  ('Ins грудь', 4),
#  ('Dat зритель', 4),
#  ('Acc опыт', 4),
#  ('Gen дерево', 4),
#  ('Ins поток', 4),
#  ('Acc телефон', 4),
#  ('Acc песня', 4),
#  ('Acc ситуация', 4),
#  ('Ins камень', 4),
#  ('Acc гость', 4),
#  ('Acc желание', 4),
#  ('Ins война', 4),
#  ('Acc план', 4),
#  ('Dat лицо', 4),
#  ('Ins энергия', 4),
#  ('Gen час', 4),
#  ('Acc право', 4),
#  ('Gen государство', 4),
#  ('Ins волчок', 4),
#  ('Dat дух', 4),
#  ('Gen снег', 4),
#  ('Acc цена', 4),
#  ('Ins гвоздь', 4),
#  ('Ins украдкой', 4),
#  ('Acc ремень', 4),
#  ('Ins рикошет', 4),
#  ('Gen кровь', 4),
#  ('Ins дерево', 4),
#  ('Ins дуга', 4),
#  ('Ins скотч', 4),
#  ('Acc поле', 4),
#  ('Acc щека', 4),
#  ('Ins душа', 4),
#  ('Acc кусок', 4),
#  ('Acc долг', 4),
#  ('Ins голод', 4),
#  ('Ins внимание', 4),
#  ('Acc бутылка', 4),
#  ('Ins стена', 4),
#  ('Acc лошадь', 4),
#  ('Ins ухо', 4),
#  ('Acc сила', 4),
#  ('Ins группа', 4),
#  ('Ins оружие', 4),
#  ('Ins деньга', 4),
#  ('Acc кое-что', 4),
#  ('Acc трава', 4),
#  ('Acc грех', 4),
#  ('Ins напильник', 4),
#  ('Acc семя', 4),
#  ('Acc остаток', 4),
#  ('Dat хиротония', 3),
#  ('Acc роль', 3),
#  ('Acc характер', 3),
#  ('Acc секретарь', 3),
#  ('Ins путь', 3),
#  ('Dat команда', 3),
#  ('Acc победа', 3),
#  ('Ins кандидат', 3),
#  ('Dat воздух', 3),
#  ('Acc интерес', 3),
#  ('Gen паспорт', 3),
#  ('Gen рука', 3),
#  ('Ins компания', 3),
#  ('Acc экзамен', 3),
#  ('Ins поцелуй', 3),
#  ('Acc многий', 3),
#  ('Ins улыбка', 3),
#  ('Ins бог', 3),
#  ('Gen финал', 3),
#  ('Gen жизнь', 3),
#  ('Dat делегация', 3),
#  ('Gen договор', 3),
#  ('Ins рывок', 3),
#  ('Gen ура', 3),
#  ('Ins вопрос', 3),
#  ('Gen костерок', 3),
#  ('Ins тираж', 3),
#  ('Acc оборона', 3),
#  ('Gen слеза', 3),
#  ('Acc решение', 3),
#  ('Acc яйцо', 3),
#  ('Gen суд', 3),
#  ('Dat девочка', 3),
#  ('Dat гражданин', 3),
#  ('Gen сапог', 3),
#  ('Ins узел', 3),
#  ('Acc информация', 3),
#  ('Dat государство', 3),
#  ('Acc счёт', 3),
#  ('Dat царь', 3),
#  ('Ins вихрь', 3),
#  ('Ins успех', 3),
#  ('Dat мысль', 3),
#  ('Acc стол', 3),
#  ('Acc мысль', 3),
#  ('Acc язык', 3),
#  ('Ins хор', 3),
#  ('Acc голос', 3),
#  ('Acc система', 3),
#  ('Ins кубарь', 3),
#  ('Gen искоса', 3),
#  ('Acc вид', 3),
#  ('Gen группа', 3),
#  ('Acc дрова', 3),
#  ('Acc нерв', 3),
#  ('Ins ток', 3),
#  ('Gen счастие', 3),
#  ('Gen хлеб', 3),
#  ('Acc танец', 3),
#  ('Acc тема', 3),
#  ('Ins государство', 3),
#  ('Dat страх', 3),
#  ('Ins эхо', 3),
#  ('Acc стул', 3),
#  ('Ins семья', 3),
#  ('Gen чёрт', 3),
#  ('Ins ребёнок', 3),
#  ('Ins судьба', 3),
#  ('Dat герой', 3),
#  ('Ins имя', 3),
#  ('Acc куча', 3),
#  ('Acc след', 3),
#  ('Ins ковёр', 3),
#  ('Ins почта', 3),
#  ('Acc час', 3),
#  ('Ins нитка', 3),
#  ('Ins кольцо', 3),
#  ('Acc запах', 3),
#  ('Acc молитва', 3),
#  ('Acc данные', 3),
#  ('Acc боль', 3),
#  ('Acc флаг', 3),
#  ('Ins слой', 3),
#  ('Acc век', 3),
#  ('Acc дурак', 3),
#  ('Ins клин', 3),
#  ('Ins час', 3),
#  ('Acc свеча', 3),
#  ('Ins обои', 3),
#  ('Ins усилие', 3),
#  ('Ins глотка', 3),
#  ('Acc мелодия', 3),
#  ('Ins скороговорка', 3),
#  ('Acc мать', 3),
#  ('Ins автор', 3),
#  ('Ins пятка', 3),
#  ('Ins пробка', 3),
#  ('Acc пол', 3),
#  ('Acc люк', 3),
#  ('Acc истина', 3),
#  ('Acc налог', 3),
#  ('Acc глупость', 3),
#  ('Acc ус', 3),
#  ('Acc дерево', 3),
#  ('Ins дым', 3),
#  ('Ins пузырь', 3),
#  ('Ins ремень', 3),
#  ('Ins вилка', 3),
#  ('Acc бок', 3),
#  ('Acc малость', 3),
#  ('Acc конь', 3),
#  ('Ins карандаш', 3),
#  ('Acc обои', 3),
#  ('Acc лёд', 3),
#  ('Gen житель', 2),
#  ('Dat обвинять', 2),
#  ('Dat инвестор', 2),
#  ('Ins цель', 2),
#  ('Acc мнение', 2),
#  ('Acc обвинение', 2),
#  ('Acc значение', 2),
#  ('Dat правда', 2),
#  ('Dat солдат', 2),
#  ('Gen медаль', 2),
#  ('Dat президент', 2),
#  ('Dat россиянин', 2),
#  ('Acc основа', 2),
#  ('Gen малёк', 2),
#  ('Gen работа', 2),
#  ('Acc цель', 2),
#  ('Gen пациент', 2),
#  ('Acc итог', 2),
#  ('Gen дом', 2),
#  ('Dat сотрудник', 2),
#  ('Ins судорога', 2),
#  ('Gen ожидание', 2),
#  ('Acc дива', 2),
#  ('Dat слух', 2),
#  ('Acc позиция', 2),
#  ('Dat рука', 2),
#  ('Gen власть', 2),
#  ('Dat многое', 2),
#  ('Ins опыт', 2),
#  ('Ins настоящее', 2),
#  ('Gen турист', 2),
#  ('Ins опрометью', 2),
#  ('Acc рекорд', 2),
#  ('Acc кнопка', 2),
#  ('Acc шайба', 2),
#  ('Acc изменение', 2),
#  ('Acc заверение', 2),
#  ('Ins коронавирус', 2),
#  ('Ins воздух', 2),
#  ('Gen слюни', 2),
#  ('Acc чаша', 2),
#  ('Gen мера', 2),
#  ('Acc средство', 2),
#  ('Acc ущерб', 2),
#  ('Gen ворота', 2),
#  ('Dat спасатель', 2),
#  ('Acc шея', 2),
#  ('Ins брак', 2),
#  ('Gen гримаса', 2),
#  ('Dat клуб', 2),
#  ('Acc отношение', 2),
#  ('Dat лев', 2),
#  ('Acc река', 2),
#  ('Gen здание', 2),
#  ('Acc лозунг', 2),
#  ('Dat ухо', 2),
#  ('Dat ответственность', 2),
#  ('Dat слово', 2),
#  ('Acc война', 2),
#  ('Gen персонаж', 2),
#  ('Ins град', 2),
#  ('Dat предприятие', 2),
#  ('Gen крендель', 2),
#  ('Ins вакцина', 2),
#  ('Ins зависть', 2),
#  ('Acc сумма', 2),
#  ('Dat бог', 2),
#  ('Acc кофе', 2),
#  ('Gen полдень', 2),
#  ('Ins дом', 2),
#  ('Dat мир', 2),
#  ('Gen ребёнок', 2),
#  ('Ins мозг', 2),
#  ('Acc урок', 2),
#  ('Gen мех', 2),
#  ('Acc должное', 2),
#  ('Gen сотня', 2),
#  ('Dat душа', 2),
#  ('Dat партнёр', 2),
#  ('Ins пара', 2),
#  ('Ins друг', 2),
#  ('Acc гражданин', 2),
#  ('Ins газ', 2),
#  ('Ins прокуратура', 2),
#  ('Acc удар', 2),
#  ('Gen мак', 2),
#  ('Acc вещь', 2),
#  ('Acc личность', 2),
#  ('Gen автомобиль', 2),
#  ('Dat кошка', 2),
#  ('Ins налог', 2),
#  ('Acc затвор', 2),
#  ('Gen воспоминание', 2),
#  ('Acc масло', 2),
#  ('Gen страх', 2),
#  ('Dat журналист', 2),
#  ('Dat мужчина', 2),
#  ('Acc женщина', 2),
#  ('Acc искра', 2),
#  ('Gen возможность', 2),
#  ('Gen очко', 2),
#  ('Ins лоб', 2),
#  ('Gen красота', 2),
#  ('Acc лапша', 2),
#  ('Acc гримаса', 2),
#  ('Dat гримаса', 2),
#  ('Acc лоб', 2),
#  ('Acc разговор', 2),
#  ('Ins злоба', 2),
#  ('Acc поклонник', 2),
#  ('Acc нужда', 2),
#  ('Acc текст', 2),
#  ('Ins дождь', 2),
#  ('Ins почерк', 2),
#  ('Acc бдительность', 2),
#  ('Acc пульс', 2),
#  ('Ins край', 2),
#  ('Ins условие', 2),
#  ('Acc горло', 2),
#  ('Ins фонарик', 2),
#  ('Ins колесо', 2),
#  ('Gen момент', 2),
#  ('Acc самолюбие', 2),
#  ('Acc слух', 2),
#  ('Acc пощёчина', 2),
#  ('Ins гнев', 2),
#  ('Acc рукав', 2),
#  ('Acc семья', 2),
#  ('Acc страна', 2),
#  ('Ins пар', 2),
#  ('Acc село', 2),
#  ('Ins доброволец', 2),
#  ('Gen туман', 2),
#  ('Dat туман', 2),
#  ('Ins позор', 2),
#  ('Gen га', 2),
#  ('Acc власть', 2),
#  ('Acc собака', 2),
#  ('Dat самолюбие', 2),
#  ('Acc содержимое', 2),
#  ('Ins ладонь', 2),
#  ('Acc число', 2),
#  ('Gen вино', 2),
#  ('Acc корова', 2),
#  ('Acc общество', 2),
#  ('Acc враг', 2),
#  ('Acc ярлык', 2),
#  ('Acc ухо', 2),
#  ('Acc сын', 2),
#  ('Acc очередь', 2),
#  ('Acc ёлка', 2),
#  ('Ins пинок', 2),
#  ('Acc колено', 2),
#  ('Ins волок', 2),
#  ('Gen фильм', 2),
#  ('Acc скважина', 2),
#  ('Acc курок', 2),
#  ('Acc палка', 2),
#  ('Gen секунда', 2),
#  ('Acc армия', 2),
#  ('Acc разница', 2),
#  ('Ins организм', 2),
#  ('Acc дыра', 2),
#  ('Ins веер', 2),
#  ('Gen бог', 2),
#  ('Acc соперник', 2),
#  ('Ins состав', 2),
#  ('Ins глина', 2),
#  ('Acc миф', 2),
#  ('Ins булавка', 2),
#  ('Acc пилюля', 2),
#  ('Gen вид', 2),
#  ('Acc закон', 2),
#  ('Acc ресурс', 2),
#  ('Acc бюджет', 2),
#  ('Acc хлеб', 2),
#  ('Ins железо', 2),
#  ('Acc дом', 2),
#  ('Acc краска', 2),
#  ('Acc работа', 2),
#  ('Acc энергия', 2),
#  ('Ins бинт', 2),
#  ('Acc постель', 2),
#  ('Gen приказ', 2),
#  ('Ins каток', 2),
#  ('Ins лёд', 2),
#  ('Ins толпа', 2),
#  ('Acc сахар', 2),
#  ('Ins лента', 2),
#  ('Acc гнездо', 2),
#  ('Acc беда', 2),
#  ('Acc прощение', 2),
#  ('Ins чай', 2),
#  ('Acc репутация', 2),
#  ('Ins зад', 2),
#  ('Gen дар', 2),
#  ('Acc песнь', 2),
#  ('Ins плеть', 2),
#  ('Acc наживка', 2),
#  ('Ins сумка', 2),
#  ('Acc стекло', 2),
#  ('Acc удочка', 2),
#  ('Acc одеяло', 2),
#  ('Acc почва', 2),
#  ('Ins уста', 2),
#  ('Dat друг', 2),
#  ('Acc лес', 2),
#  ('Ins фара', 2),
#  ('Acc шерсть', 2),
#  ('Ins сварка', 2),
#  ('Ins порядок', 2),
#  ('Acc картошка', 2),
#  ('Ins змея', 2),
#  ('Acc патрон', 2),
#  ('Acc сугроб', 2),
#  ('Ins революция', 2),
#  ('Acc кусочек', 2),
#  ('Ins стекло', 2),
#  ('Acc подробность', 2),
#  ('Acc капуста', 2),
#  ('Acc фотография', 2),
#  ('Ins желание', 2),
#  ('Acc иск', 2),
#  ('Ins лобзик', 2),
#  ('Acc меч', 2),
#  ('Ins веник', 2),
#  ('Ins ложка', 2),
#  ('Ins дело', 2),
#  ('Ins муха', 2),
#  ('Ins орган', 2),
#  ('Acc деньжата', 2),
#  ('Acc глушитель', 2),
#  ('Ins подарок', 2),
#  ('Ins топор', 2),
#  ('Acc будущее', 2),
#  ('Ins крем', 2),
#  ('Ins насос', 2),
#  ('Ins красота', 2),
#  ('Acc чёрт', 2),
#  ('Acc отверстие', 2),
#  ('Acc мясо', 2),
#  ('Ins земля', 2),
#  ('Ins утюг', 2),
#  ('Ins походка', 2),
#  ('Acc угол', 2),
#  ('Acc шаг', 2),
#  ('Acc икра', 2),
#  ('Ins шарф', 2),
#  ('Acc горе', 2),
#  ('Acc отпуск', 2),
#  ('Ins показание', 2),
#  ('Acc риск', 2),
#  ('Acc действительность', 2),
#  ('Acc камень', 2),
#  ('Acc билет', 2),
#  ('Acc прах', 2),
#  ('Ins штурм', 1),
#  ('Acc ответственность', 1),
#  ('Gen республиканец', 1),
#  ('Gen стан', 1),
#  ('Gen помощь', 1),
#  ('Acc впечатление', 1),
#  ('Acc обязанность', 1),
#  ('Dat яблоко', 1),
#  ('Dat буржуа', 1),
#  ('Ins комитет', 1),
#  ('Acc уважение', 1),
#  ('Dat секретарь', 1),
#  ('Ins орден', 1),
#  ('Dat владелец', 1),
#  ('Acc материал', 1),
#  ('Dat клетка', 1),
#  ('Dat мигрант', 1),
#  ('Ins последствие', 1),
#  ('Gen случай', 1),
#  ('Dat полок', 1),
#  ('Gen победа', 1),
#  ('Acc диссертация', 1),
#  ('Dat кзади', 1),
#  ('Dat версия', 1),
#  ('Dat критика', 1),
#  ('Acc гол', 1),
#  ('Gen голова', 1),
#  ('Gen акция', 1),
#  ('Dat пример', 1),
#  ('Acc пример', 1),
#  ('Acc вклад', 1),
#  ('Dat составитель', 1),
#  ('Ins экстерн', 1),
#  ('Gen боевик', 1),
#  ('Dat противник', 1),
#  ('Acc потеря', 1),
#  ('Acc смерть', 1),
#  ('Dat врач', 1),
#  ('Dat комиссия', 1),
#  ('Dat стена', 1),
#  ('Acc удовольствие', 1),
#  ('Dat г-жа', 1),
#  ('Gen устранение', 1),
#  ('Ins граната', 1),
#  ('Dat муж', 1),
#  ('Dat автобус', 1),
#  ('Gen сириец', 1),
#  ('Dat цель', 1),
#  ('Dat империя', 1),
#  ('Ins цвет', 1),
#  ('Dat воздействие', 1),
#  ('Gen фургон', 1),
#  ('Gen женщина', 1),
#  ('Ins пропадом', 1),
#  ('Dat прокурор', 1),
#  ('Dat заказчик', 1),
#  ('Gen обвинение', 1),
#  ('Ins рейс', 1),
#  ('Dat влияние', 1),
#  ('Dat население', 1),
#  ('Dat зал', 1),
#  ('Dat постановление', 1),
#  ('Gen с', 1),
#  ('Gen трактовка', 1),
#  ('Acc потребность', 1),
#  ('Ins войско', 1),
#  ('Gen держава', 1),
#  ('Acc бал', 1),
#  ('Gen смерть', 1),
#  ('Dat бедлам', 1),
#  ('Gen граница', 1),
#  ('Dat больной', 1),
#  ('Dat созидатель', 1),
#  ('Acc порядок', 1),
#  ('Dat общественность', 1),
#  ('Acc трубка', 1),
#  ('Ins китаец', 1),
#  ('Dat воин', 1),
#  ('Gen шеф', 1),
#  ('Gen трус', 1),
#  ('Dat некого', 1),
#  ('Dat ход', 1),
#  ('Gen гора', 1),
#  ('Acc ожидание', 1),
#  ('Acc форточка', 1),
#  ('Gen надежда', 1),
#  ('Gen народ', 1),
#  ('Gen регион', 1),
#  ('Acc президент', 1),
#  ('Acc достоинство', 1),
#  ('Acc чудо', 1),
#  ('Gen шишка', 1),
#  ('Ins самоубийство', 1),
#  ('Ins издательство', 1),
#  ('Gen четверть', 1),
#  ('Acc ниц', 1),
#  ('Acc невесть', 1),
#  ('Gen доверие', 1),
#  ('Dat футболист', 1),
#  ('Acc письмо', 1),
#  ('Dat с', 1),
#  ('Gen пояс', 1),
#  ('Acc арест', 1),
#  ('Dat тангента', 1),
#  ('Gen шайба', 1),
#  ('Gen изменение', 1),
#  ('Ins поддержка', 1),
#  ('Gen пересмотр', 1),
#  ('Acc столица', 1),
#  ('Gen штраф', 1),
#  ('Dat крем', 1),
#  ('Gen педаль', 1),
#  ('Gen палец', 1),
#  ('Gen оскар', 1),
#  ('Dat заключение', 1),
#  ('Dat водитель', 1),
#  ('Dat организация', 1),
#  ('Gen иллюзия', 1),
#  ('Gen отношение', 1),
#  ('Gen представительство', 1),
#  ('Ins сигарета', 1),
#  ('Dat флот', 1),
#  ('Ins хакер', 1),
#  ('Gen жертва', 1),
#  ('Dat характер', 1),
#  ('Ins бремя', 1),
#  ('Dat въезд', 1),
#  ('Dat девушка', 1),
#  ('Dat хоккеист', 1),
#  ('Dat выступление', 1),
#  ('Gen кусочек', 1),
#  ('Acc начало', 1),
#  ('Dat процесс', 1),
#  ('Dat профукать', 1),
#  ('Ins магнит', 1),
#  ('Gen правило', 1),
#  ('Dat серб', 1),
#  ('Dat чаша', 1),
#  ('Dat москвич', 1),
#  ('Acc дивизия', 1),
#  ('Dat боевик', 1),
#  ('Gen облом', 1),
#  ('Dat ни', 1),
#  ('Dat зверь', 1),
#  ('Gen осадок', 1),
#  ('Acc чувство', 1),
#  ('Acc десант', 1),
#  ('Acc необходимость', 1),
#  ('Gen народность', 1),
#  ('Dat парень', 1),
#  ('Gen пара', 1),
#  ('Gen бронь', 1),
#  ('Dat любовь', 1),
#  ('Gen туша', 1),
#  ('Gen правительство', 1),
#  ('Acc тонна', 1),
#  ('Acc полгода', 1),
#  ('Gen грань', 1),
#  ('Gen сми', 1),
#  ('Dat сми', 1),
#  ('Gen зло', 1),
#  ('Ins высказывание', 1),
#  ('Gen полицейский', 1),
#  ('Gen миссис', 1),
#  ('Dat белка', 1),
#  ('Ins дуэт', 1),
#  ('Acc тень', 1),
#  ('Ins покровитель', 1),
#  ('Gen грех', 1),
#  ('Gen политзаключённый', 1),
#  ('Dat тигрица', 1),
#  ('Ins баттерфляй', 1),
#  ('Ins делегация', 1),
#  ('Gen одеяло', 1),
#  ('Dat сапёр', 1),
#  ('Dat добро', 1),
#  ('Dat художник', 1),
#  ('Ins взрывчатка', 1),
#  ('Gen молитва', 1),
#  ('Dat отец', 1),
#  ('Acc затылок', 1),
#  ('Gen происхождение', 1),
#  ('Gen казнь', 1),
#  ('Acc сопротивление', 1),
#  ('Gen сопротивление', 1),
#  ('Gen петрушка', 1),
#  ('Dat игрок', 1),
#  ('Acc писатель', 1),
#  ('Gen очевидец', 1),
#  ('Dat бизнес', 1),
#  ('Gen направление', 1),
#  ('Gen мурашка', 1),
#  ('Ins техника', 1),
#  ('Acc пожар', 1),
#  ('Dat заявитель', 1),
#  ('Gen небо', 1),
#  ('Gen давность', 1),
#  ('Dat темнота', 1),
#  ('Gen чемпион', 1),
#  ('Acc любовь', 1),
#  ('Dat дездемона', 1),
#  ('Ins таксист', 1),
#  ('Acc попытка', 1),
#  ('Ins поклон', 1),
#  ('Acc полномочие', 1),
#  ('Gen таможня', 1),
#  ('Dat земля', 1),
#  ('Gen впечатление', 1),
#  ('Acc улыбка', 1),
#  ('Gen повар', 1),
#  ('Gen решимость', 1),
#  ('Dat молодёжь', 1),
#  ('Ins ум', 1),
#  ('Gen ухо', 1),
#  ('Gen земноводное', 1),
#  ('Gen объект', 1),
#  ('Dat государь', 1),
#  ('Acc танк', 1),
#  ('Gen танк', 1),
#  ('Dat тренер', 1),
#  ('Acc мама', 1),
#  ('Acc сюрприз', 1),
#  ('Gen начало', 1),
#  ('Dat фотография', 1),
#  ('Ins буква', 1),
#  ('Gen поцелуй', 1),
#  ('Gen половина', 1),
#  ('Gen допьяна', 1),
#  ('Gen мучение', 1),
#  ('Dat парк', 1),
#  ('Ins цена', 1),
#  ('Ins забор', 1),
#  ('Acc роман', 1),
#  ('Acc комната', 1),
#  ('Acc аккаунт', 1),
#  ('Dat корпус', 1),
#  ('Dat камлание', 1),
#  ('Gen вето', 1),
#  ('Dat церковь', 1),
#  ('Dat соперник', 1),
#  ('Gen структура', 1),
#  ('Dat цена', 1),
#  ('Ins служба', 1),
#  ('Gen славянин', 1),
#  ('Gen красавица', 1),
#  ('Ins мебель', 1),
#  ('Gen комиссия', 1),
#  ('Dat нуль', 1),
#  ('Ins камера', 1),
#  ('Dat господин', 1),
#  ('Gen свет', 1),
#  ('Acc пробел', 1),
#  ('Gen родитель', 1),
#  ('Dat таможенник', 1),
#  ('Acc шутка', 1),
#  ('Gen шутка', 1),
#  ('Ins свойство', 1),
#  ('Gen туча', 1),
#  ('Dat военнослужащий', 1),
#  ('Dat музыка', 1),
#  ('Dat шум', 1),
#  ('Acc яма', 1),
#  ('Gen билет', 1),
#  ('Gen нос', 1),
#  ('Ins бегство', 1),
#  ('Dat верёвочка', 1),
#  ('Ins категория', 1),
#  ('Acc официант', 1),
#  ('Acc воображение', 1),
#  ('Gen чуб', 1),
#  ('Acc успех', 1),
#  ('Dat аукционист', 1),
#  ('Acc процесс', 1),
#  ('Gen заместитель', 1),
#  ('Gen прокурор', 1),
#  ('Dat маршрут', 1),
#  ('Gen супостат', 1),
#  ('Dat глупость', 1),
#  ('Acc доля', 1),
#  ('Gen сумма', 1),
#  ('Gen чай', 1),
#  ('Acc подбородок', 1),
#  ('Dat опыт', 1),
#  ('Dat иностранец', 1),
#  ('Ins президент', 1),
#  ('Dat милость', 1),
#  ('Acc пыл', 1),
#  ('Acc должность', 1),
#  ('Dat доход', 1),
#  ('Gen масло', 1),
#  ('Ins подробность', 1),
#  ('Dat округ', 1),
#  ('Acc глоток', 1),
#  ('Acc уран', 1),
#  ('Dat песок', 1),
#  ('Dat товар', 1),
#  ('Ins лава', 1),
#  ('Gen модель', 1),
#  ('Dat пенсионер', 1),
#  ('Dat лес', 1),
#  ('Gen печаль', 1),
#  ('Acc пари', 1),
#  ('Dat критик', 1),
#  ('Ins обман', 1),
#  ('Dat тест', 1),
#  ('Dat покровитель', 1),
#  ('Ins мат', 1),
#  ('Dat оппозиция', 1),
#  ('Gen воз', 1),
#  ('Ins замечание', 1),
#  ('Dat самолёт', 1),
#  ('Dat дыхание', 1),
#  ('Dat технология', 1),
#  ('Acc станция', 1),
#  ('Dat фотограф', 1),
#  ('Acc клин', 1),
#  ('Gen извилина', 1),
#  ('Acc наркотик', 1),
#  ('Acc экспедиция', 1),
#  ('Gen колено', 1),
#  ('Dat движение', 1),
#  ('Acc огонь', 1),
#  ('Dat класс', 1),
#  ('Gen душа', 1),
#  ('Gen день', 1),
#  ('Acc ученик', 1),
#  ('Ins бутылка', 1),
#  ('Acc состояние', 1),
#  ('Gen видео', 1),
#  ('Ins режиссёр', 1),
#  ('Acc белок', 1),
#  ('Ins геном', 1),
#  ('Dat потребитель', 1),
#  ('Gen успех', 1),
#  ('Dat авиапассажир', 1),
#  ('Gen клетка', 1),
#  ('Dat представитель', 1),
#  ('Ins археолог', 1),
#  ('Gen полуфинал', 1),
#  ('Dat пассажир', 1),
#  ('Acc поклон', 1),
#  ('Gen пинок', 1),
#  ('Acc изотоп', 1),
#  ('Gen горе', 1),
#  ('Ins канцлер', 1),
#  ('Dat драйвер', 1),
#  ('Acc мир', 1),
#  ('Acc компенсация', 1),
#  ('Ins секретарь', 1),
#  ('Acc служба', 1),
#  ('Dat рана', 1),
#  ('Gen продукт', 1),
#  ('Dat регион', 1),
#  ('Dat жена', 1),
#  ('Gen фонд', 1),
#  ('Dat делец', 1),
#  ('Dat кровь', 1),
#  ('Acc чайник', 1),
#  ('Acc линия', 1),
#  ('Gen песнь', 1),
#  ('Gen лошадь', 1),
#  ('Dat хозяин', 1),
#  ('Ins оркестр', 1),
#  ('Gen гектар', 1),
#  ('Gen вечер', 1),
#  ('Ins долина', 1),
#  ('Gen крыло', 1),
#  ('Ins фен', 1),
#  ('Dat связь', 1),
#  ('Ins слюна', 1),
#  ('Gen доллар', 1),
#  ('Acc среда', 1),
#  ('Gen углерод', 1),
#  ('Ins гибкость', 1),
#  ('Acc волна', 1),
#  ('Gen абсурд', 1),
#  ('Gen предприятие', 1),
#  ('Gen возлюбить', 1),
#  ('Acc вариант', 1),
#  ('Ins гримаса', 1),
#  ('Gen истерика', 1),
#  ('Gen кошка', 1),
#  ('Acc самолёт', 1),
#  ('Acc колокол', 1),
#  ('Gen разработка', 1),
#  ('Ins маркировка', 1),
#  ('Gen дорога', 1),
#  ('Gen новолуние', 1),
#  ('Gen принцип', 1),
#  ('Dat аграрий', 1),
#  ('Gen кольцо', 1),
#  ('Gen граффити', 1),
#  ('Gen полбутылки', 1),
#  ...]

# %%
len(verb_comb)
# Out:
# 35223

# %%
verb = 'аккомпанировать'

total = 0
for prep, items1 in verb_comb[verb].items():
    for case, items2 in items1.items():
        total += sum([v for v in items2.values() if v > 2])

gov_list = {}
for prep, items1 in verb_comb[verb].items():
    for case, items2 in items1.items():
        print(prep, case, f"{sum([v for v in items2.values() if v > 2])/total:6.3}")
        gov_list[f"{prep} {case}"] = sum([v for v in items2.values() if v > 2])/total
# Out:
# _ Nom  0.211
# _ Dat  0.282
# _ Ins 0.00616
# _ Acc 0.0174
# _ Gen    0.0
# _ Loc    0.0
# НА Loc  0.361
# НА Acc 0.00168
# У Gen    0.0
# В Loc 0.0711
# В Acc 0.00616
# С Ins 0.00168
# С Gen    0.0
# ПО Dat    0.0
# ВО ВРЕМЯ Gen 0.0235
# ПРИ Loc 0.0123
# В КАЧЕСТВЕ Gen 0.00168
# БЕЗ Gen    0.0
# ЗА Ins 0.00336
# ВО Loc    0.0
# СРЕДИ Gen    0.0
# СО Gen    0.0
# СО Ins    0.0
# К Dat    0.0
# ИЗ Gen    0.0
# ДЛЯ Gen    0.0
# ПОД Acc    0.0
# ПОД Ins 0.00168
# ПОСЛЕ Gen    0.0
# ПО МЕРЕ Gen    0.0
# В ХОДЕ Gen    0.0
# ДО Gen    0.0
# ВМЕСТО Gen    0.0
# ПЕРЕД Ins    0.0
# В ТЕЧЕНИЕ Gen    0.0
# С ПОМОЩЬЮ Gen    0.0

# %%
gov_list = sorted(gov_list.items(), key=lambda x:x[1], reverse=True)
s = 0
out = verb
for prep, freq in gov_list:
    out += " + " + prep + f" {freq:6.3}"
    s += freq
    if s > 0.8:
        break
print(out)
# Out:
# аккомпанировать + НА Loc  0.361 + _ Dat  0.282 + _ Nom  0.211

# %%
verb_comb['агитировать']['В']
# Out:
# {'Loc': {'центр': 2,
#   'микроблог': 1,
#   'соцсеть': 7,
#   'стиль': 2,
#   'город': 5,
#   'автобус': 1,
#   'гонка': 1,
#   'рамка': 9,
#   'огонёк': 1,
#   'статья': 1,
#   'школа': 6,
#   'район': 4,
#   'сми': 4,
#   'кампания': 2,
#   'село': 1,
#   'присутствие': 1,
#   'среда': 2,
#   'часть': 2,
#   'интерес': 2,
#   'полок': 1,
#   'форма': 3,
#   'интервью': 1,
#   'год': 4,
#   'прошлое': 2,
#   'сентябрь': 2,
#   'преддверие': 7,
#   'интернет': 5,
#   'столица': 1,
#   'глубинка': 1,
#   'партия': 1,
#   'бундестаг': 3,
#   'магазин': 1,
#   'община': 2,
#   'страна': 1,
#   'губерния': 3,
#   'армия': 2,
#   'дело': 1,
#   'необходимость': 1,
#   'случай': 3,
#   'образ': 1,
#   'регион': 3,
#   'ситуация': 1,
#   'ролик': 10,
#   'учреждение': 1,
#   'кафе': 1,
#   'январь': 2,
#   'область': 5,
#   'смысл': 2,
#   'вид': 1,
#   'метро': 2,
#   'воззвание': 1,
#   'правительство': 1,
#   'блог': 3,
#   'сеть': 5,
#   'порядок': 3,
#   'теленовость': 1,
#   'уголок': 2,
#   'фельетон': 2,
#   'электричка': 2,
#   'число': 6,
#   'февраль': 17,
#   'квартал': 1,
#   'пресса': 2,
#   'передача': 2,
#   'путь': 1,
#   'округ': 1,
#   'штат': 3,
#   'театр': 2,
#   'темнота': 1,
#   'группа': 1,
#   'медиа': 1,
#   'видео': 1,
#   'начало': 3,
#   'ряса': 1,
#   'корпус': 1,
#   'трамвай': 1,
#   'посёлок': 1,
#   'пижама': 1,
#   'штаны': 1,
#   'вопрос': 1,
#   'эфир': 2,
#   'участие': 1,
#   'промежуток': 1,
#   'век': 1,
#   'станица': 1,
#   'деревня': 1,
#   'манера': 2,
#   'список': 1,
#   'доклад': 1,
#   'произведение': 2,
#   'борьба': 1,
#   'масса': 1,
#   'стена': 1,
#   'ряд': 1,
#   'выступление': 3,
#   'место': 1,
#   'противостояние': 1,
#   'семестр': 1,
#   'цель': 1,
#   'хутор': 1,
#   'газета': 1,
#   'март': 3,
#   'состав': 1,
#   'общежитие': 1,
#   'поездка': 4,
#   'критика': 1,
#   'продвижение': 1,
#   'октябрь': 2,
#   'ноябрь': 1,
#   'большинство': 1,
#   'парк': 1,
#   'книга': 1,
#   'серия': 1},
#  'Acc': {'разгар': 1,
#   'польза': 61,
#   'раз': 2,
#   'время': 17,
#   'год': 4,
#   'очередь': 2,
#   'спецназ': 1,
#   'поддержка': 19,
#   'суббота': 1,
#   'оппозиция': 1,
#   'период': 13,
#   'момент': 1,
#   'день': 14,
#   'край': 1,
#   'регион': 1,
#   'баня': 2,
#   'подписчик': 1,
#   'прайм-тайм': 1,
#   'воскресение': 1,
#   'четверг': 1,
#   'среда': 1,
#   'отряд': 1,
#   'класс': 1,
#   'колхоз': 2,
#   'школа': 1,
#   'мера': 1,
#   'партия': 1,
#   'ряд': 1,
#   'ресторан': 1,
#   'нарушение': 2,
#   'обход': 1,
#   'противовес': 1,
#   'рупор': 1,
#   'сезон': 1,
#   'отместка': 1,
#   'дом': 1}}

# %%
for verb, freq in verb_freq[100:200]:
    total = 0
    for prep, items1 in verb_comb[verb].items():
        for case, items2 in items1.items():
            thr_frq = np.log10(sum(items2.values())) - 0.2
#             thr_frq = 2
            total += sum([v for v in items2.values() if v > thr_frq])

    gov_list = {}
    for prep, items1 in verb_comb[verb].items():
        for case, items2 in items1.items():
            thr_frq = np.log10(sum(items2.values())) - 0.2
#             thr_frq = 2
            gov_list[f"{prep} {case}"] = sum([v for v in items2.values() if v > thr_frq])/total

    gov_list = sorted(gov_list.items(), key=lambda x:x[1], reverse=True)
    s = 0
    out = verb
    for prep, freq in gov_list:
        if prep != '_ Nom':
            out += " + " + prep + f" {freq:6.3}"
        s += freq
        if s > 0.8:
            break
    print(out)
# Out:
# организовать + _ Acc   0.38 + В Loc  0.105 + _ Ins 0.0952
# существовать + В Loc  0.153 + НА Loc 0.0477
# выполнять + _ Acc  0.704
# разработать + _ Acc   0.33 + _ Ins  0.105 + В Loc 0.0834
# рассмотреть + _ Acc  0.529 + В Loc 0.0849
# обладать + _ Ins  0.728
# поднять + _ Acc  0.589 + НА Acc 0.0598 + В Loc 0.0328
# использоваться + ДЛЯ Gen  0.211 + В Loc  0.166 + _ Ins 0.0466
# закрыть + _ Acc   0.45 + _ Ins 0.0675 + В Loc 0.0436
# пользоваться + _ Ins  0.614
# принести + _ Acc  0.497 + _ Dat  0.105
# внести + _ Acc  0.352 + В Acc  0.245
# рассматривать + _ Acc  0.642 + В Loc 0.0658
# снять + _ Acc  0.434 + С Gen  0.137 + В Loc 0.0465 + _ Ins 0.0394
# считаться + _ Ins  0.467
# предусматривать + _ Acc  0.635
# позволить + _ Dat  0.252
# связать + С Ins  0.657
# предлагать + _ Acc  0.314 + _ Dat  0.168 + В Loc 0.0533
# осуществлять + _ Acc    0.6 + В Loc 0.0832
# построить + _ Acc  0.226 + НА Loc  0.124 + В Loc  0.103 + ПО Dat 0.0593
# служить + _ Ins   0.38 + В Loc  0.172 + _ Dat 0.0574 + ДЛЯ Gen 0.0402
# вырасти + В Loc  0.131 + ПО Dat 0.0577 + ЗА Acc 0.0452 + ПО СРАВНЕНИЮ С Ins 0.0325
# покинуть + _ Acc  0.607 + В Loc 0.0634
# потерять + _ Acc  0.518 + В Loc 0.0869
# содержимый + _ Acc  0.652
# проводиться + В Loc  0.147 + НА Loc 0.0607 + ПО Dat 0.0603 + _ Ins 0.0392
# нести + _ Acc   0.58 + В Loc 0.0489
# продолжить + _ Acc  0.552 + В Loc 0.0562
# позволять + _ Dat  0.248
# искать + _ Acc  0.598 + _ Gen 0.0962
# поддержать + _ Acc  0.549 + В Loc 0.0588
# оказать + _ Acc   0.59 + _ Dat 0.0688
# состоять + ИЗ Gen  0.264 + В Loc  0.142
# происходить + В Loc  0.187 + НА Loc 0.0797 + ИЗ Gen 0.0381 + В Acc 0.0347 + ОТ Gen 0.0339
# подать + _ Acc  0.375 + В Acc  0.188 + В Loc 0.0491
# завершить + _ Acc  0.452 + В Loc 0.0782
# предоставлять + _ Acc  0.529 + _ Dat  0.179
# соответствовать + _ Dat  0.636
# выпустить + _ Acc  0.276 + В Loc 0.0999 + _ Ins 0.0684 + В Acc 0.0529 + НА Acc  0.038 + НА Loc 0.0363
# показывать + _ Acc  0.373 + В Loc 0.0456
# положить + _ Acc  0.414 + НА Acc  0.229 + В Acc  0.104 + _ Dat  0.102
# просить + _ Acc  0.429 + _ Gen  0.111 + В Loc 0.0494
# напоминать + _ Acc    0.4 + О Loc 0.0782
# нанести + _ Acc  0.409 + _ Dat  0.138 + _ Ins 0.0482
# жить + В Loc  0.337 + НА Loc 0.0719 + _ Ins 0.0553 + ПО Dat 0.0376 + С Ins 0.0338
# определить + _ Acc   0.41 + В Loc 0.0817 + _ Ins 0.0705
# выполнить + _ Acc   0.41 + В Loc 0.0955 + _ Ins 0.0414
# задержать + _ Acc  0.158 + В Loc  0.145 + ПО Dat  0.117 + _ Ins 0.0623 + НА Loc 0.0477
# смочь + В Loc 0.0956 + ПО Dat 0.0418 + _ Ins 0.0269
# изменить + _ Acc  0.603 + В Loc 0.0464
# смотреть + НА Acc  0.238 + _ Acc  0.195 + В Acc  0.128 + С Ins 0.0751
# подготовить + _ Acc  0.306 + _ Ins  0.111 + ПО Dat 0.0899 + К Dat 0.0598 + В Loc 0.0592
# выступить + С Ins  0.224 + НА Loc 0.0959 + В Loc 0.0848 + _ Ins 0.0795 + ПРОТИВ Gen 0.0427
# входить + В Acc  0.678
# включить + В Acc  0.444 + _ Acc  0.249
# отдать + _ Acc  0.453 + _ Dat  0.157 + В Acc 0.0754
# передавать + _ Acc  0.301 + СО Ins 0.0899 + _ Dat 0.0683
# помочь + _ Dat  0.351 + В Loc  0.139
# держать + _ Acc   0.46 + В Loc  0.244 + НА Loc 0.0659
# приводить + _ Acc  0.279 + К Dat  0.276
# иметься + В Loc   0.24 + НА Loc 0.0761
# хотеть + _ Gen 0.0915 + В Loc 0.0783 + _ Ins 0.0511 + _ Acc 0.0508
# добиться + _ Gen  0.718
# оценить + _ Acc  0.593
# сохранить + _ Acc  0.654 + В Loc 0.0848
# прекратить + _ Acc  0.555
# приобрести + _ Acc  0.462 + В Loc 0.0889 + _ Ins 0.0389
# объяснить + _ Acc  0.381 + _ Ins  0.161
# собрать + _ Acc  0.383 + В Loc 0.0771 + В Acc 0.0624 + _ Ins 0.0452 + НА Loc  0.035 + _ Gen 0.0343
# призвать + _ Acc  0.322 + К Dat  0.104 + В Loc 0.0663
# ожидать + _ Gen  0.395 + _ Acc 0.0993 + В Loc 0.0657
# выбрать + _ Acc  0.423 + _ Ins 0.0868 + ДЛЯ Gen 0.0698 + В Loc 0.0438
# означать + _ Acc  0.388
# брать + _ Acc  0.525 + В Acc 0.0695 + НА Acc 0.0468 + В Loc 0.0395
# пойти + НА Acc  0.237 + В Acc  0.155 + ПО Dat 0.0734 + К Dat 0.0556
# обратить + _ Acc  0.582 + НА Acc 0.0765
# увеличить + _ Acc  0.624
# называться + _ Ins  0.203
# выражать + _ Acc  0.671
# выглядеть + _ Ins  0.113 + В Loc   0.11
# возбудить + _ Acc   0.21 + ПО Dat   0.18
# относиться + К Dat  0.544
# лишить + _ Gen  0.639 + _ Acc  0.126
# подчеркнуть + _ Acc  0.255
# продолжаться + В Loc 0.0615 + _ Acc 0.0472 + ДО Gen 0.0456
# войти + В Acc  0.588
# начинать + _ Acc  0.214 + С Gen  0.198 + В Loc 0.0564
# основать + НА Loc  0.366 + _ Acc  0.123
# отличаться + _ Ins  0.323 + ОТ Gen  0.198
# устроить + _ Acc  0.493 + В Loc 0.0832 + НА Loc 0.0396
# утвердить + _ Acc    0.3 + _ Ins  0.129 + В Loc  0.104
# осуществляться + В Loc  0.118 + _ Ins 0.0803 + НА Loc 0.0633 + ПО Dat 0.0428
# утверждать + В Loc 0.0779
# сыграть + _ Acc  0.386 + В Loc  0.223 + НА Loc 0.0514
# выступать + В Loc  0.168 + ЗА Acc   0.14 + НА Loc  0.119 + _ Ins 0.0729 + ПРОТИВ Gen 0.0635 + С Ins 0.0571
# купить + _ Acc  0.551 + В Loc 0.0813 + ПО Dat 0.0301 + НА Loc  0.028 + НА Acc 0.0276
# приветствовать + _ Acc  0.658
# возникнуть + В Loc  0.151 + НА Loc 0.0653 + У Gen 0.0377 + В Acc 0.0289
# добавить + _ Acc   0.21 + В Acc  0.101 + В Loc 0.0797 + К Dat 0.0481

# %%
wordlist = ["абстрагироваться", "агитировать", "аккомпанировать", "актировать", "анализировать", "аннотировать", "апеллировать", "аргументировать", "арканить", "ассоциировать", "ассоциироваться", "асфальтировать", "багроветь", "базарить", "баламутить", "балансировать", "балластировать", "баловать", "бальзамировать", "бальзамировать", "банкротиться", "баррикадировать", "баррикадироваться", "басить", "баюкать", "бегать", "беднеть", "бедокурить", "бежать", "безобразить", "безобразничать", "белеть", "белить", "белить", "белить", "белиться", "бередить", "беременеть", "беречь", "беречься", "беседовать", "бесить", "беситься", "беспокоить", "беспокоить", "беспокоиться", "беспокоиться", "бессилеть", "бессилить", "бесславить", "бесчестить", "бетонировать", "бинтовать", "бить", "бить", "бить", "биться", "благодарить", "благодарить", "бледнеть", "блекнуть", "близиться", "блюсти", "богатеть", "бодать", "бодаться", "бодрить", "бодриться", "божиться", "болеть", "болеть", "болеть", "болтать", "болтать", "болтать", "бормотать", "бороздить", "боронить", "бороновать", "бороновать", "бороть", "бороться", "бояться", "бояться", "бояться", "бояться", "браковать", "бранить", "браниться", "браниться", "брататься", "брать", "браться", "брезгать", "брезговать", "бренчать", "брехать", "брить", "брить", "бриться", "бродить"]

# %%
my_gov = defaultdict(list)

for verb in wordlist:
    if verb not in verb_comb.keys():
        print(verb, "---")
        continue
    total = 0
    for prep, items1 in verb_comb[verb].items():
        for case, items2 in items1.items():
            thr_frq = np.log10(sum(items2.values())) - 0.2
#             thr_frq = 2
            total += sum([v for v in items2.values() if v > thr_frq])

    if total == 0:
        print(verb, "---")
        continue
    
    gov_list = {}
    for prep, items1 in verb_comb[verb].items():
        for case, items2 in items1.items():
            thr_frq = np.log10(sum(items2.values())) - 0.2
#             thr_frq = 2
            gov_list[f"{prep} {case}"] = sum([v for v in items2.values() if v > thr_frq])/total

    gov_list = sorted(gov_list.items(), key=lambda x:x[1], reverse=True)
    s = 0
    out = verb
    for prep, freq in gov_list:
        if prep != '_ Nom':
            out += f" + {prep} {freq:6.3}"
            my_gov[verb].append(prep)
        s += freq
        if s > 0.8:
            break
    print(out)
    
for verb in my_gov.keys():
    my_gov[verb] = list(set(my_gov[verb]))
# Out:
# абстрагироваться + ОТ Gen  0.829
# агитировать + ЗА Acc  0.298 + _ Acc   0.22 + ПРОТИВ Gen 0.0566 + В Loc 0.0412 + В Acc 0.0402
# аккомпанировать + НА Loc  0.342 + _ Dat  0.267
# актировать + ПО Dat  0.476 + _ Acc 0.0952 + ИЗ Gen 0.0952
# анализировать + _ Acc  0.622 + В Loc  0.178
# аннотировать + _ Acc  0.453 + _ Ins  0.205 + В Loc  0.103 + С ПОМОЩЬЮ Gen 0.0769
# апеллировать + К Dat  0.622
# аргументировать + _ Acc  0.535 + _ Ins  0.177
# арканить + _ Acc    0.6 + _ Gen    0.1 + _ Ins   0.05 + ПО Dat   0.05
# ассоциировать + С Ins  0.551 + _ Acc  0.161
# ассоциироваться + С Ins  0.443 + В Loc  0.069
# асфальтировать + _ Acc  0.196 + _ Ins 0.0363 + В Loc 0.0363
# багроветь + ОТ Gen   0.22 + НА Loc  0.149 + _ Ins  0.038
# базарить + ПО Dat  0.135 + В Loc  0.125 + О Loc  0.115 + _ Acc 0.0865 + С Ins 0.0577 + В Acc 0.0481 + ЗА Acc 0.0481 + _ Ins 0.0385
# баламутить + _ Acc  0.722 + НА Loc 0.0432
# балансировать + НА Loc  0.519 + МЕЖДУ Ins 0.0841 + _ Acc 0.0727
# балластировать + ДЛЯ Gen  0.333 + _ Ins  0.333 + _ Acc  0.333
# баловать + _ Acc  0.358 + _ Ins  0.318
# бальзамировать + _ Acc  0.636 + ЗА Acc 0.0593
# бальзамировать + _ Acc  0.636 + ЗА Acc 0.0593
# банкротиться + В Loc  0.075 + _ Ins   0.05
# баррикадировать + _ Acc  0.748 + _ Ins  0.122
# баррикадироваться + В Loc  0.386 + _ Ins 0.0682 + ОТ Gen 0.0682 + ЗА Ins 0.0682
# басить + В Acc  0.124 + _ Ins  0.106 + ОТ Gen 0.0796 + В Loc 0.0531 + _ Acc 0.0442 + С Gen 0.0354 + ИЗ Gen 0.0354
# баюкать + _ Acc   0.51 + НА Loc  0.149 + В Loc  0.124
# бегать + ПО Dat  0.332 + В Loc 0.0543 + _ Ins 0.0469 + _ Acc 0.0438 + В Acc 0.0421 + С Ins 0.0421
# беднеть + _ Acc 0.0495 + _ Ins 0.0462 + НА Loc 0.0363 + В Loc  0.033
# бедокурить + В Loc  0.409
# бежать + ПО Dat  0.115 + ИЗ Gen  0.102 + В Acc 0.0893 + В Loc 0.0561 + К Dat 0.0558 + ОТ Gen 0.0529 + НА Acc 0.0457 + _ Ins 0.0251 + ПОСЛЕ Gen 0.0237
# безобразить + _ Acc  0.417 + _ Ins  0.111 + В Loc 0.0833
# безобразничать + В Loc  0.191 + _ Acc  0.128 + НА Loc  0.117 + В Acc 0.0638 + ПО Dat 0.0532 + С Ins 0.0532
# белеть + В Loc  0.172 + НА Loc  0.146 + _ Ins  0.063
# белить + _ Acc  0.517 + _ Ins  0.148
# белить + _ Acc  0.517 + _ Ins  0.148
# белить + _ Acc  0.517 + _ Ins  0.148
# белиться + _ Ins  0.292 + С Ins 0.0417
# бередить + _ Acc  0.818
# беременеть + ОТ Gen  0.111 + В Loc 0.0775 + _ Ins 0.0554 + ПО Dat 0.0443 + _ Acc 0.0443 + ПОСЛЕ Gen 0.0369 + В Acc 0.0332
# беречь + _ Acc  0.701
# беречься + _ Gen   0.62
# беседовать + С Ins  0.395 + В Loc 0.0762 + О Loc 0.0612 + ПО Dat 0.0451 + НА Acc 0.0362 + СО Ins  0.033
# бесить + _ Acc  0.113 + _ Ins 0.0417
# беситься + ОТ Gen  0.195 + В Loc 0.0885 + НА Loc 0.0514 + _ Acc 0.0391 + В Acc 0.0309 + С Ins 0.0267 + _ Ins 0.0226 + ЗА Ins 0.0226 + ПРИ Loc 0.0185 + ПО Dat 0.0185
# беспокоить + _ Acc  0.304
# беспокоить + _ Acc  0.304
# беспокоиться + О Loc  0.375 + ЗА Acc  0.163 + С Gen 0.0296
# беспокоиться + О Loc  0.375 + ЗА Acc  0.163 + С Gen 0.0296
# бессилеть ---
# бессилить ---
# бесславить + _ Acc  0.778
# бесчестить + _ Acc   0.72 + _ Ins   0.12
# бетонировать + _ Acc   0.46 + _ Ins 0.0794 + _ Dat 0.0476 + В Loc 0.0476 + НА Loc 0.0476 + ПО Dat 0.0476
# бинтовать + _ Acc  0.787
# бить + _ Acc  0.202 + _ Ins  0.173 + ПО Dat  0.154 + В Acc  0.102
# бить + _ Acc  0.202 + _ Ins  0.173 + ПО Dat  0.154 + В Acc  0.102
# бить + _ Acc  0.202 + _ Ins  0.173 + ПО Dat  0.154 + В Acc  0.102
# биться + В Loc  0.156 + О Acc 0.0579 + _ Ins 0.0551 + ОБ Acc 0.0501 + ЗА Acc 0.0495 + С Ins  0.039
# благодарить + ЗА Acc  0.443 + _ Acc   0.34
# благодарить + ЗА Acc  0.443 + _ Acc   0.34
# бледнеть + НА Loc  0.133 + ОТ Gen  0.103 + В Loc 0.0585 + С Ins  0.033 + ПЕРЕД Ins 0.0319 + _ Ins 0.0287
# блекнуть ---
# близиться + К Dat   0.39
# блюсти + _ Acc  0.817
# богатеть + НА Loc  0.141 + _ Ins 0.0631 + _ Acc 0.0387 + В Loc 0.0258 + С Ins 0.0244 + ПО Dat  0.023 + ЗА СЧЕТ Gen 0.0201
# бодать + _ Ins   0.27 + _ Acc  0.252 + В Acc 0.0495
# бодаться + С Ins  0.215 + _ Ins  0.099 + _ Acc 0.0444 + НА Loc 0.0341 + В Acc 0.0307 + СО Ins 0.0307 + ПО Dat 0.0307
# бодрить + _ Acc  0.126 + _ Ins 0.0305
# бодриться + ИЗО Gen  0.177 + _ Ins  0.165 + НА Loc 0.0759 + _ Acc 0.0633 + В Loc 0.0633 + ПЕРЕД Ins 0.0506 + РАДИ Gen  0.038 + ИЗ Gen  0.038 + ПОСЛЕ Gen  0.038
# божиться + В Loc 0.0708 + НА Loc 0.0708 + _ Ins 0.0619 + ПОСЛЕ Gen 0.0442 + В Acc 0.0354 + НА Acc 0.0354 + _ Acc 0.0265
# болеть + _ Ins  0.105 + ЗА Acc 0.0641 + В Loc 0.0363
# болеть + _ Ins  0.105 + ЗА Acc 0.0641 + В Loc 0.0363
# болеть + _ Ins  0.105 + ЗА Acc 0.0641 + В Loc 0.0363
# болтать + _ Ins  0.158 + О Loc  0.147 + С Ins  0.128 + _ Acc  0.106 + ПО Dat  0.068 + В Loc 0.0662 + НА Loc 0.0323
# болтать + _ Ins  0.158 + О Loc  0.147 + С Ins  0.128 + _ Acc  0.106 + ПО Dat  0.068 + В Loc 0.0662 + НА Loc 0.0323
# болтать + _ Ins  0.158 + О Loc  0.147 + С Ins  0.128 + _ Acc  0.106 + ПО Dat  0.068 + В Loc 0.0662 + НА Loc 0.0323
# бормотать + ПОД Acc   0.32 + _ Acc  0.303 + В Acc 0.0342 + _ Ins 0.0318
# бороздить + _ Acc  0.649
# боронить + _ Acc  0.427 + _ Ins  0.122 + НА Loc 0.0976 + ПОД Acc 0.0244 + ОТ Gen 0.0244
# бороновать + _ Acc  0.475 + _ Ins  0.125 + НА Loc  0.125 + ДЛЯ Gen   0.05
# бороновать + _ Acc  0.475 + _ Ins  0.125 + НА Loc  0.125 + ДЛЯ Gen   0.05
# бороть ---
# бороться + С Ins  0.374 + ЗА Acc  0.257 + В Loc  0.041
# бояться + _ Gen  0.489
# бояться + _ Gen  0.489
# бояться + _ Gen  0.489
# бояться + _ Gen  0.489
# браковать + _ Acc  0.442 + ПО Dat 0.0814 + В Loc 0.0465 + _ Gen 0.0349 + В Acc 0.0349
# бранить + _ Acc  0.263 + ЗА Acc  0.156 + _ Ins  0.102 + В Loc 0.0349 + В Acc 0.0349
# браниться + _ Ins 0.0798 + В Loc 0.0798 + С Ins 0.0714 + _ Acc  0.063 + В Acc 0.0546 + НА Loc 0.0504 + ПО Dat 0.0378 + ЗА Acc 0.0294 + ВО Loc 0.0294 + ПРИ Loc 0.0168
# браниться + _ Ins 0.0798 + В Loc 0.0798 + С Ins 0.0714 + _ Acc  0.063 + В Acc 0.0546 + НА Loc 0.0504 + ПО Dat 0.0378 + ЗА Acc 0.0294 + ВО Loc 0.0294 + ПРИ Loc 0.0168
# брататься + С Ins  0.289 + В Acc   0.13 + В Loc 0.0422 + НА Loc 0.0357
# брать + _ Acc  0.525 + В Acc 0.0695 + НА Acc 0.0468 + В Loc 0.0395
# браться + ЗА Acc  0.368 + В Loc 0.0339 + В Acc 0.0302
# брезгать + _ Ins  0.583 + _ Acc 0.0833
# брезговать + _ Ins  0.323 + В Loc 0.0659 + В Acc 0.0539 + _ Acc 0.0479 + _ Gen 0.0299
# бренчать + НА Loc   0.44 + _ Ins  0.176 + В Loc 0.0768
# брехать + ПРО Acc 0.0463 + В Loc 0.0417 + НА Loc  0.037 + НА Acc  0.037 + _ Acc  0.037 + _ Dat  0.037 + _ Ins  0.037 + В Acc  0.037
# брить + _ Acc  0.639 + _ Ins 0.0352 + В Loc 0.0276 + В Acc 0.0235
# брить + _ Acc  0.639 + _ Ins 0.0352 + В Loc 0.0276 + В Acc 0.0235
# бриться + _ Ins  0.285 + _ Acc  0.138 + ПЕРЕД Ins 0.0632 + В Acc 0.0538 + В Loc 0.0524 + ПО Dat 0.0323
# бродить + ПО Dat   0.47 + В Loc  0.113 + _ Ins 0.0425

# %%
verb_comb['актировать']['_']
# Out:
# {'Acc': {'работа': 1,
#   'сумма': 1,
#   'инвалид': 1,
#   'состояние': 1,
#   'умерший': 2,
#   'человек': 1,
#   'утилизация': 1,
#   'тело': 1,
#   'нарушение': 1,
#   'перстень': 1,
#   'заклинание': 1,
#   'недостача': 1,
#   'багаж': 1,
#   'ущерб': 1,
#   'дело': 1,
#   'устройство': 1,
#   'день': 1},
#  'Nom': {'показатель': 2, 'фельдшер': 1, 'доходяга': 1},
#  'Ins': {'пачка': 1}}

# %%
len(verb_freq)
# Out:
# 32920

# %%
cntr = 0
cntr_n = 0
nom_verbs = []
for verb in tqdm(verb_comb.keys()):
    if verb not in verb_comb.keys():
#         print(verb, "---")
        continue
    total = 0
    for prep, items1 in verb_comb[verb].items():
        for case, items2 in items1.items():
            thr_frq = np.log10(sum(items2.values())) - 0.2
#             thr_frq = 2
            total += sum([v for v in items2.values() if v > thr_frq])

    if total == 0:
#         print(verb, "---")
        continue
    
    gov_list = {}
    for prep, items1 in verb_comb[verb].items():
        for case, items2 in items1.items():
            thr_frq = np.log10(sum(items2.values())) - 0.2
#             thr_frq = 2
            gov_list[f"{prep} {case}"] = sum([v for v in items2.values() if v > thr_frq])/total

    gov_list = sorted(gov_list.items(), key=lambda x:x[1], reverse=True)
    s = 0
    out = verb
    num_comb = 0
    for prep, freq in gov_list:
        if prep != '_ Nom':
            num_comb += 1
            out += " + " + prep + f" {freq:6.3}"
        s += freq
        if s > 0.8:
            break
    if num_comb > 0:
        cntr += 1
    else:
        cntr_n += 1
        nom_verbs.append(verb)
# Out:
#   0%|          | 0/35223 [00:00<?, ?it/s]

# %%
cntr #/ len(verb_comb.keys())
# Out:
# 33154

# %%
cntr_n, cntr
# Out:
# (2067, 33154)

# %%
nom_verbs[-20:]
# Out:
# ['обездушивать',
#  'щербиться',
#  'похороненный',
#  'эпоха',
#  'выштукатурить',
#  'имед',
#  'асет',
#  'они',
#  'резервный',
#  'расточитель',
#  'незатвердевший',
#  'простойный',
#  'предупредительный',
#  'лещ',
#  'сохраненный',
#  'подкорректированный',
#  'теть',
#  'перепрыгиваться',
#  'loved',
#  'построение']

# %%
for verb, freq in verb_freq[:1000]:
    if verb in nom_verbs:
        print(verb, freq)
# Out:
# полагать 94320
# озаглавить 39986
# настать 33214

# %%
for verb in nom_verbs[:20]:
    s = 0
    for prep, comb1 in verb_comb[verb].items():
        for cas, comb2 in comb1.items():
            for noun, freq in comb2.items():
                s += freq
    print(verb, s)
# Out:
# засориться 259
# обесточиваться 55
# настать 36351
# расцениваться 8289
# прозвенеть 3080
# налаживаться 3113
# газифицировать 799
# сбыться 7490
# подыскиваться 172
# благоустраиваться 244
# гласить 25710
# отзвенеть 110
# выдаться 14049
# отгреметь 917
# спориться 680
# развеяться 3237
# опустеть 8397
# погаснуть 11341
# притупляться 657
# отпадать 3820

# %%
verb_comb['полагать']
# Out:
# {'_': {'Nom': {'эксперт': 11910,
#    'власть': 761,
#    'врач': 199,
#    'юрист': 332,
#    'археолог': 144,
#    'исследователь': 2339,
#    'учёный': 3546,
#    'вопрос': 65,
#    'разработчик': 259,
#    'сайт': 8,
#    'управление': 45,
#    'издание': 436,
#    'специалист': 2166,
#    'глава': 1667,
#    'особенность': 6,
#    'океанолог': 3,
#    'собака': 1,
#    'собеседник': 346,
#    'гражданин': 41,
#    'политик': 215,
#    'вице-президент': 190,
#    'зоолог': 32,
#    'ветеринар': 12,
#    'дефект': 2,
#    'следствие': 3014,
#    'большинство': 1026,
#    'астроном': 197,
#    'наука': 30,
#    'лицо': 76,
#    'очевидец': 20,
#    'хищник': 6,
#    'адвокат': 514,
#    'правоохранитель': 81,
#    'генсек': 34,
#    'следователь': 1417,
#    'депутат': 566,
#    'президент': 798,
#    'парламентарий': 103,
#    'советник': 100,
#    'министр': 506,
#    'уровень': 16,
#    'хореограф': 2,
#    'эксперимент': 6,
#    'автор': 2341,
#    'журналист': 530,
#    'командование': 113,
#    'пневмония': 2,
#    'человек': 467,
#    'защитница': 1,
#    'руководство': 268,
#    'профсоюз': 9,
#    'аналитик': 5135,
#    'биолог': 88,
#    'директор': 1131,
#    'профессор': 488,
#    'медик': 91,
#    'экономист': 754,
#    'мера': 27,
#    'ведомство': 122,
#    'член': 482,
#    'историк': 719,
#    'разведчик': 23,
#    'академик': 37,
#    'доктор': 172,
#    'эпидемиолог': 13,
#    'миллиардер': 8,
#    'последствие': 4,
#    'инсайдер': 11,
#    'шанс': 10,
#    'сообщество': 35,
#    'правозащитник': 146,
#    'копия': 9,
#    'полиция': 446,
#    'дипломат': 143,
#    'предел': 20,
#    'производитель': 35,
#    'синоптик': 72,
#    'председатель': 517,
#    'источник': 755,
#    'заговорщик': 4,
#    'истец': 81,
#    'сторонник': 302,
#    'сенатор': 133,
#    'полицейский': 129,
#    'инструмент': 17,
#    'соединение': 2,
#    'представитель': 992,
#    'половина': 89,
#    'орган': 188,
#    'гендиректор': 317,
#    'метеоролог': 37,
#    'оон': 7,
#    'чиновник': 274,
#    'респондент': 72,
#    'соратник': 23,
#    'переход': 4,
#    'подписчик': 8,
#    'сооснователь': 9,
#    'миссия': 50,
#    'наблюдатель': 1397,
#    'церковь': 13,
#    'генерал': 106,
#    'прокурор': 86,
#    'епископ': 21,
#    'элита': 19,
#    'разведка': 75,
#    'социолог': 112,
#    'актёр': 25,
#    'участник': 462,
#    'комитет': 673,
#    'спецслужба': 131,
#    'оппозиционер': 64,
#    'пользователь': 44,
#    'прокуратура': 157,
#    'министерство': 67,
#    'посол': 48,
#    'родные': 47,
#    'общественник': 8,
#    'экипаж': 8,
#    'место': 47,
#    'банк': 55,
#    'продажа': 3,
#    'спикер': 58,
#    'инвестор': 84,
#    'лидер': 314,
#    'пресс-секретарь': 43,
#    'составитель': 34,
#    'боевик': 9,
#    'защита': 86,
#    'сотрудник': 354,
#    'задача': 41,
#    'страховщик': 17,
#    'законодатель': 36,
#    'клиент': 19,
#    'житель': 117,
#    'мастер': 7,
#    'пара': 10,
#    'мисс': 40,
#    'учитель': 17,
#    'импровизация': 1,
#    'продюсер': 29,
#    'друг': 67,
#    'мальчик': 8,
#    'женщина': 84,
#    'мама': 23,
#    'пёс': 2,
#    'родитель': 40,
#    'конфета': 1,
#    'висок': 1,
#    'победитель': 4,
#    'инструктор': 1,
#    'нарушение': 8,
#    'группа': 423,
#    'соседка': 1,
#    'фигура': 16,
#    'дядя': 5,
#    'удел': 7,
#    'владелец': 53,
#    'пауза': 3,
#    'план': 5,
#    'бабушка': 7,
#    'грабёж': 4,
#    'океан': 2,
#    'причина': 28,
#    'заместитель': 410,
#    'комментатор': 95,
#    'трейдер': 123,
#    'создатель': 123,
#    'ряд': 579,
#    'вице-премьер': 86,
#    'проект': 16,
#    'народ': 26,
#    'соотечественник': 7,
#    'банкир': 43,
#    'апологет': 5,
#    'часть': 346,
#    'служба': 45,
#    'руководитель': 641,
#    'ректор': 33,
#    'палата': 27,
#    'помощник': 23,
#    'господин': 1807,
#    'вариация': 1,
#    'вице-губернатор': 5,
#    'существо': 7,
#    'шаг': 65,
#    'тормоз': 2,
#    'компания': 164,
#    'регулятор': 40,
#    'библиотекарь': 1,
#    'развлечение': 5,
#    'заказчик': 6,
#    'приложение': 1,
#    'противник': 124,
#    'работник': 17,
#    'бонус': 1,
#    'психолог': 90,
#    'результат': 67,
#    'бизнесмен': 58,
#    'критик': 213,
#    'деньга': 11,
#    'славянин': 13,
#    'богиня': 3,
#    'начальник': 281,
#    'скептик': 53,
#    'партнёр': 203,
#    'фактор': 17,
#    'товарищ': 33,
#    'синоним': 5,
#    'контрагент': 1,
#    'немец': 41,
#    'индивид': 2,
#    'топ-менеджер': 36,
#    'провокация': 23,
#    'зампред': 73,
#    'способ': 102,
#    'труд': 3,
#    'премьер': 87,
#    'премьер-министр': 101,
#    'модель': 12,
#    'основатель': 59,
#    'консультант': 53,
#    'общество': 21,
#    'творец': 2,
#    'аграрий': 3,
#    'оптовик': 1,
#    'страна': 246,
#    'панацея': 7,
#    'недоразумение': 5,
#    'путь': 28,
#    'социалист': 10,
#    'пиарщик': 1,
#    'технократ': 2,
#    'треть': 70,
#    'четверть': 59,
#    'составлять': 2,
#    'сумасшествие': 2,
#    'предприниматель': 53,
#    'юстиция': 2,
#    'дело': 200,
#    'организация': 108,
#    'медицина': 3,
#    'москвич': 29,
#    'зритель': 15,
#    'проблема': 49,
#    'фишка': 1,
#    'отсутствие': 6,
#    'доброволец': 4,
#    'цена': 14,
#    'явление': 58,
#    'рэпер': 1,
#    'артист': 25,
#    'кормилец': 1,
#    'сочетание': 2,
#    'строитель': 7,
#    'главное': 42,
#    'ценность': 2,
#    'коммерсант': 15,
#    'начало': 37,
#    'гостев': 1,
#    'правда': 11,
#    'редактор': 119,
#    'искатель': 3,
#    'система': 16,
#    'диссертант': 2,
#    'механизм': 14,
#    'антипод': 2,
#    'психоаналитик': 8,
#    'агрессия': 3,
#    'характеристика': 2,
#    'формирование': 6,
#    'свобода': 4,
#    'активность': 2,
#    'исследование': 15,
#    'студент': 15,
#    'мать': 34,
#    'предпосылка': 3,
#    'представление': 3,
#    'способность': 3,
#    'оценивание': 1,
#    'наличие': 2,
#    'процесс': 39,
#    'отказ': 5,
#    'содержание': 2,
#    'изменение': 9,
#    'дислексия': 1,
#    'различие': 7,
#    'семья': 28,
#    'функция': 7,
#    'пред': 1,
#    'язык': 5,
#    'условие': 11,
#    'использование': 3,
#    'приращение': 1,
#    'вхождение': 1,
#    'помощь': 3,
#    'выявление': 2,
#    'угроза': 17,
#    'улучшение': 1,
#    'ослабление': 1,
#    'построение': 2,
#    'рассмотрение': 3,
#    'вклад': 3,
#    'изучение': 2,
#    'своеобразие': 2,
#    'ученик': 3,
#    'воздействие': 5,
#    'стратегия': 5,
#    'понятие': 9,
#    'основа': 7,
#    'век': 2,
#    'эмоция': 2,
#    'правило': 19,
#    'возможность': 15,
#    'мышление': 2,
#    'методист': 1,
#    'специфичность': 1,
#    'противоречие': 1,
#    'доминирование': 1,
#    'россиянин': 56,
#    'цель': 54,
#    'реализация': 2,
#    'тип': 5,
#    'инициативность': 1,
#    'традиция': 6,
#    'сотрудничество': 2,
#    'предмет': 7,
#    'восприятие': 2,
#    'континуум': 1,
#    'методика': 2,
#    'общение': 3,
#    'ответственность': 3,
#    'программа': 6,
#    'устойчивость': 1,
#    'инструкция': 1,
#    'сравнение': 2,
#    'самооценка': 1,
#    'приближение': 1,
#    'повышение': 5,
#    'ребёнок': 32,
#    'развитие': 7,
#    'подход': 13,
#    'феномен': 6,
#    'показатель': 11,
#    'требование': 4,
#    'анализ': 3,
#    'степень': 1,
#    'отношение': 4,
#    'девушка': 55,
#    'слепой': 1,
#    'воспроизведение': 2,
#    'действие': 5,
#    'произнесение': 1,
#    'компонент': 2,
#    'свойство': 8,
#    'психология': 2,
#    'привнесение': 1,
#    'факт': 17,
#    'внимание': 2,
#    'влияние': 1,
#    'философ': 72,
#    'выбор': 12,
#    'слабость': 3,
#    'усилие': 1,
#    'связь': 2,
#    'метод': 8,
#    'выполнение': 2,
#    'образец': 3,
#    'взаимоотношение': 2,
#    'возникновение': 3,
#    'направленность': 1,
#    'закономерность': 2,
#    'отличие': 1,
#    'наглядность': 1,
#    'узнавание': 1,
#    'мировоззрение': 7,
#    'автомобиль': 6,
#    'инженер': 59,
#    'ангар': 1,
#    'проверка': 5,
#    'фамилия': 3,
#    'статья': 3,
#    'обзор': 2,
#    'программист': 8,
#    'сеть': 3,
#    'пчела': 1,
#    'концепция': 8,
#    'вика': 1,
#    'игра': 13,
#    'ошибка': 30,
#    'предок': 11,
#    'лицензиат': 2,
#    'подарок': 9,
#    'химик': 9,
#    'заговор': 5,
#    'тема': 4,
#    'идея': 33,
#    'суть': 18,
#    'решение': 43,
#    'оптимист': 27,
#    'физик': 51,
#    'случай': 47,
#    'зло': 12,
#    'картинка': 1,
#    'форма': 21,
#    'боль': 2,
#    'секрет': 7,
#    'юзер': 4,
#    'поколение': 8,
#    'снег': 1,
#    'ступень': 2,
#    'обозреватель': 525,
#    'вконтакте': 1,
#    'история': 20,
#    'нейробиолог': 8,
#    'информация': 7,
#    'алгоритм': 2,
#    'гарант': 1,
#    'зона': 2,
#    'баг': 1,
#    'значение': 3,
#    'вариант': 32,
#    'взрослый': 1,
#    'замдиректора': 41,
#    'миф': 11,
#    'наса': 1,
#    'портал': 7,
#    'правительство': 532,
#    'движение': 21,
#    'писатель': 61,
#    'тэя': 1,
#    'время': 67,
#    'планировщик': 2,
#    'ребрендинг': 2,
#    'оператор': 7,
#    'схема': 3,
#    'активист': 74,
#    'напиток': 1,
#    'предположение': 3,
#    'намёк': 9,
#    'коллегия': 2,
#    'картина': 4,
#    'инспектор': 158,
#    'признак': 25,
#    'администратор': 11,
#    'размер': 6,
#    'число': 30,
#    'нелинейность': 1,
#    'теорема': 2,
#    'ао': 1,
#    'антимонопольщик': 5,
#    'барс': 1,
#    'наставник': 6,
#    'хозяйка': 9,
#    'волшебник': 2,
#    'трибун': 1,
#    'величество': 20,
#    'совет': 71,
#    'костюмер': 1,
#    'рыбак': 7,
#    'бесчинство': 1,
#    'завет': 1,
#    'оружие': 10,
#    'капитан': 29,
#    'батюшка': 2,
#    'вымысел': 8,
#    'посланник': 4,
#    'леди': 23,
#    'поиск': 9,
#    'косметика': 1,
#    'любовь': 10,
#    'организатор': 111,
#    'профессионал': 3,
#    'отшельник': 1,
#    'император': 24,
#    'альвара': 1,
#    'сэр': 46,
#    'жена': 28,
#    'еретик': 2,
#    'брат': 25,
#    'граф': 12,
#    'бдение': 1,
#    'пора': 130,
#    'матушка': 5,
#    'тюремщик': 2,
#    'сыщик': 31,
#    'отец': 69,
#    'шпион': 5,
#    'разговор': 4,
#    'концерт': 1,
#    'замена': 4,
#    'госпожа': 120,
#    'холод': 1,
#    'добыча': 3,
#    'светлость': 2,
#    'жрец': 5,
#    'юноша': 5,
#    'мсьё': 1,
#    'задавака': 1,
#    'решётка': 1,
#    'серин': 2,
#    'старейшина': 5,
#    'обязанность': 7,
#    'лорд': 22,
#    'молния': 2,
#    'маг': 6,
#    'звено': 14,
#    'трата': 11,
#    'слуга': 1,
#    'купец': 1,
#    'оскорбление': 3,
#    'набег': 1,
#    'иллюзия': 8,
#    'полуночник': 1,
#    'магия': 1,
#    'король': 27,
#    'гость': 20,
#    'описание': 4,
#    'дочурка': 1,
#    'стервятник': 1,
#    'царь': 14,
#    'глупец': 5,
#    'вояка': 4,
#    'превосходительство': 1,
#    'мороз': 2,
#    'владыка': 5,
#    'дед': 8,
#    'маршал': 15,
#    'конунг': 1,
#    'животное': 5,
#    'маркиза': 1,
#    'врачеватель': 3,
#    'эльф': 3,
#    'осведомитель': 2,
#    'грёза': 1,
#    'высочество': 2,
#    'сила': 30,
#    'скопление': 1,
#    'герцог': 3,
#    'сиятельство': 1,
#    'вид': 8,
#    'пехотинец': 3,
#    'сквайр': 1,
#    'колдунья': 4,
#    'гоблин': 3,
#    'талисман': 1,
#    'неведение': 2,
#    'глупость': 3,
#    'зерно': 2,
#    'девица': 2,
#    'щепочка': 1,
#    'матрос': 1,
#    'бесхребетность': 1,
#    'забота': 2,
#    'приятель': 8,
#    'догадка': 3,
#    'сон': 5,
#    'знак': 14,
#    'жезл': 1,
#    'миротворец': 2,
#    'книга': 3,
#    'попытка': 66,
#    'сударь': 4,
#    'чародей': 1,
#    'эдил': 1,
#    'сын': 23,
#    'гильдия': 1,
#    'агент': 19,
#    'магнит': 1,
#    'рапсодия': 2,
#    'воин': 1,
#    'последователь': 32,
#    'бог': 9,
#    'жест': 10,
#    'казначей': 5,
#    'мёд': 1,
#    'ревнитель': 2,
#    'сержант': 4,
#    'посланец': 1,
#    'экзарх': 1,
#    'пуля': 2,
#    'мистер': 111,
#    'обман': 9,
#    'миссис': 39,
#    'толпа': 3,
#    'участь': 3,
#    'фикция': 7,
#    'подружка': 4,
#    'болезнь': 10,
#    'журнал': 48,
#    'болван': 3,
#    'герр': 7,
#    'гений': 7,
#    'самоубийство': 14,
#    'обладатель': 5,
#    'парень': 15,
#    'кровь': 4,
#    'шериф': 6,
#    'револьвер': 2,
#    'девочка': 13,
#    'дочь': 34,
#    'победа': 3,
#    'джентльмен': 9,
#    'старина': 3,
#    'француз': 40,
#    'латиноамериканец': 2,
#    'имя': 30,
#    'шеф': 12,
#    'род': 4,
#    'самонадеянность': 2,
#    'основание': 14,
#    'конгресс': 3,
#    'пост': 3,
#    'некто': 6,
#    'начальство': 13,
#    'субъект': 10,
#    'сооружение': 3,
#    'коммунист': 72,
#    'офицер': 24,
#    'рана': 2,
#    'полковник': 29,
#    'сластолюбец': 2,
#    'переписка': 2,
#    'срыв': 4,
#    'операция': 8,
#    'ответ': 20,
#    'тренер': 27,
#    'выход': 10,
#    'убийца': 12,
#    'доля': 12,
#    'управляющий': 35,
#    'слабак': 3,
#    'том': 2,
#    'завтрак': 3,
#    'родственник': 55,
#    'ботинок': 4,
#    'личность': 10,
#    'дама': 7,
#    'свидетель': 13,
#    'подчинённый': 6,
#    'высокопревосходительство': 3,
#    'босс': 4,
#    'мадам': 18,
#    'пульверизатор': 2,
#    'капиталовложение': 2,
#    'лес': 2,
#    'торговец': 5,
#    'ночь': 2,
#    'ложь': 3,
#    'церемония': 2,
#    'объяснение': 3,
#    'мелочь': 5,
#    'невежда': 5,
#    'мэтр': 6,
#    'ребятки': 2,
#    'муж': 27,
#    'лемминг': 2,
#    'скотина': 2,
#    'дантист': 2,
#    'ангел-хранитель': 2,
#    'мэр': 57,
#    'коллега': 164,
#    'детектив': 17,
#    'старушка': 3,
#    'гангстер': 2,
#    'приговор': 2,
#    'грубиян': 4,
#    'жестокость': 2,
#    'архитектор': 30,
#    'чёрт': 2,
#    'блеф': 4,
#    'старик': 5,
#    'работа': 27,
#    'имитация': 5,
#    'возраст': 3,
#    'издатель': 22,
#    'коммандер': 4,
#    'шофер': 2,
#    'девка': 3,
#    'наказание': 5,
#    'тщеславие': 2,
#    'пушка': 2,
#    'кость': 3,
#    'сударыня': 2,
#    'удар': 9,
#    'водитель': 6,
#    'преступление': 13,
#    'школьник': 7,
#    'знакомый': 36,
#    'происки': 6,
#    'копа': 6,
#    'символ': 8,
#    'срок': 21,
#    'командир': 16,
#    'автогонки': 2,
#    'лекарство': 7,
#    'дом': 28,
#    'самоубийца': 2,
#    'трус': 2,
#    'доход': 4,
#    'самолёт': 3,
#    'чета': 2,
#    'значок': 4,
#    'штука': 3,
#    'майор': 12,
#    'ход': 15,
#    'команда': 25,
#    'фбр': 11,
#    'бандит': 4,
#    'охрана': 5,
#    'кандидатура': 9,
#    'газета': 997,
#    'евнух': 2,
#    'тело': 15,
#    'бедняк': 2,
#    'одноклассник': 2,
#    'точка': 7,
#    'румынка': 2,
#    'развалина': 4,
#    'лейтенант': 2,
#    'дорога': 6,
#    'плата': 7,
#    'машина': 7,
#    'дно': 2,
#    'чушь': 4,
#    'возвращение': 2,
#    'самаритянин': 2,
#    'пан': 5,
#    'донья': 3,
#    'террорист': 7,
#    'очередь': 4,
#    'шутка': 17,
#    'политолог': 1017,
#    'пастырь': 20,
#    'фонд': 36,
#    'доцент': 39,
#    'вывод': 5,
#    'фас': 20,
#    'суд': 73,
#    'вице-спикер': 49,
#    'мир': 19,
#    'совладелец': 9,
#    'израильтянин': 14,
#    'учение': 1,
#    'донос': 2,
#    'проректор': 20,
#    'ведущий': 17,
#    'телеканал': 5,
#    'арон': 1,
#    'надежда': 242,
#    'сми': 185,
#    'замглавы': 55,
#    'норма': 4,
#    'перезагрузка': 1,
#    'оперативник': 97,
#    'главред': 7,
#    'учредитель': 3,
#    'удовольствие': 5,
#    'психиатр': 29,
#    'ненавистник': 1,
#    'заболевание': 4,
#    'атака': 3,
#    'атаман': 2,
#    'загребной': 1,
#    'поддать': 3,
#    'паспорт': 1,
#    'статистика': 2,
#    'администрация': 67,
#    'легенда': 10,
#    'племянник': 3,
#    'голова': 4,
#    'центр': 33,
#    'поэтесса': 1,
#    'митрополит': 11,
#    'заведовать': 38,
#    'создание': 4,
#    'агентство': 209,
#    'элемент': 15,
#    'занятие': 18,
#    'несправедливость': 1,
#    'заявка': 3,
#    'богач': 1,
#    'канал': 9,
#    'конспиролог': 7,
#    'кандидат': 57,
#    'эколог': 36,
#    'европеец': 22,
#    'китаец': 18,
#    'режим': 4,
#    'максима': 1,
#    'псевдоним': 2,
#    'аппарат': 8,
#    'стратег': 88,
#    'маркетолог': 4,
#    'корреспондент': 79,
#    'сообщение': 2,
#    'долг': 12,
#    'лагерь': 3,
#    'иранист': 1,
#    'десяток': 2,
#    'омбудсмен': 21,
#    'поддержание': 2,
#    'cnn': 2,
#    'бастион': 1,
#    'публика': 4,
#    'утверждение': 4,
#    'востоковед': 14,
#    'декан': 13,
#    'букмекер': 33,
#    'защитник': 69,
#    'инициатор': 29,
#    'шишка': 1,
#    'ассамблея': 6,
#    'германец': 4,
#    'публицист': 41,
#    'губернатор': 43,
#    'катарец': 1,
#    'интернет-пользователь': 5,
#    'налог': 5,
#    'сигнал': 33,
#    'варяг': 1,
#    'классик': 4,
#    'инсценировка': 3,
#    'reuters': 2,
#    'натура': 2,
#    'верующий': 7,
#    'художник': 22,
#    'биограф': 36,
#    'американец': 115,
#    'клуб': 3,
#    'эзотерика': 1,
#    'финансист': 28,
#    'футболист': 7,
#    'принц': 18,
#    'плод': 20,
#    'генерал-лейтенант': 7,
#    'духовник': 4,
#    'цб': 10,
#    'прототип': 3,
#    'экс-глава': 24,
#    'фаворит': 1,
#    'разновидность': 4,
#    'шлюха': 1,
#    'декорация': 1,
#    'геворг': 1,
#    'bbc': 2,
#    'асв': 2,
#    'фифа': 1,
#    'репетитор': 1,
#    'бизнес': 5,
#    'носитель': 2,
#    'информатор': 2,
#    'демократ': 24,
#    'сервис': 2,
#    'пояс': 1,
#    'постпред': 18,
#    'полёт': 2,
#    'слава': 1,
#    'императорство': 1,
#    'князь': 15,
#    'игрок': 40,
#    'стечение': 1,
#    'англосакс': 1,
#    'араб': 5,
#    'потомок': 12,
#    'партия': 31,
#    'демограф': 4,
#    'олигархия': 1,
#    'компас': 1,
#    'святитель': 12,
#    'предательство': 2,
#    'старообрядец': 1,
#    'радикал': 4,
#    'протоиерей': 5,
#    'либерал': 16,
#    'зараза': 1,
#    'сноб': 1,
#    'прикрытие': 5,
#    'мистик': 5,
#    'нацист': 4,
#    'вождь': 5,
#    'знаток': 22,
#    'пианист': 2,
#    'спортсмен': 6,
#    'преувеличение': 2,
#    'состояние': 10,
#    'корень': 2,
#    'сторона': 152,
#    'преемник': 2,
#    'жизнь': 3,
#    'многоэтажка': 1,
#    'певец': 8,
#    'петербурженка': 1,
#    'общественность': 16,
#    'военный': 239,
#    'конкурент': 13,
#    'координатор': 43,
#    'проявление': 19,
#    'подлог': 1,
#    'государство': 81,
#    'опасность': 1,
#    'популист': 3,
#    'втягивание': 2,
#    'генерал-полковник': 5,
#    'событие': 21,
#    'поступок': 6,
#    'оптимум': 1,
#    'кадр': 2,
#    'экс-премьер': 15,
#    'адмирал': 31,
#    'архиепископ': 11,
#    'тележурналист': 1,
#    'потребитель': 3,
#    'теракт': 11,
#    'музыкант': 14,
#    'переводчик': 6,
#    'кинорежиссёр': 2,
#    'патриарх': 16,
#    'соответствие': 1,
#    'батальон': 2,
#    'замминистра': 52,
#    'пресса': 54,
#    'эльчибей': 1,
#    'ресурс': 13,
#    'термин': 7,
#    'блогер': 42,
#    'коалиция': 9,
#    'армия': 6,
#    'посетитель': 5,
#    'госсекретарь': 32,
#    'пилот': 9,
#    'множество': 10,
#    'враг': 20,
#    'прерогатива': 14,
#    'технолог': 3,
#    'военнослужащий': 3,
#    'реакция': 16,
#    'судно': 4,
#    'штурман': 1,
#    'стадо': 1,
#    'деятель': 26,
#    'ветеран': 9,
#    'признание': 3,
#    'итог': 2,
#    'месть': 17,
#    'альянс': 3,
#    'докладчик': 319,
#    'спецпредставитель': 10,
#    'блог': 3,
#    'патриот': 21,
#    'контрактник': 1,
#    'бортник': 1,
#    'макет': 2,
#    'конструктор': 25,
#    'репортёр': 18,
#    'вдова': 7,
#    'рбк': 5,
#    'минобороны': 1,
#    'вестник': 1,
#    'колумнист': 10,
#    'главком': 5,
#    'громада': 1,
#    'плевок': 2,
#    'секретарь': 139,
#    'вызов': 4,
#    'количество': 9,
#    'изобретение': 3,
#    'средство': 26,
#    'ополченец': 7,
#    'период': 3,
#    'генштаб': 4,
#    'командующий': 42,
#    'приоритет': 2,
#    'чех': 4,
#    'захоронение': 3,
#    'идеология': 5,
#    'пример': 11,
#    'боец': 4,
#    'зонтик': 1,
#    'энтузиаст': 9,
#    'бомбардировщик': 1,
#    'разведслужба': 21,
#    'блоггер': 4,
#    'территория': 4,
#    'уполномоченный': 20,
#    'чин': 3,
#    'примирение': 1,
#    'благо': 4,
#    'принцип': 3,
#    'реформатор': 3,
#    'грек': 13,
#    'предупреждение': 5,
#    'штаб': 14,
#    'хлор': 1,
#    'год': 2,
#    'попадание': 2,
#    'комплекс': 5,
#    'рисунок': 1,
#    'лишение': 1,
#    'феникс': 2,
#    ...},
#   'Acc': {'новость': 2,
#    'жалоба': 1,
#    'область': 1,
#    'риск': 6,
#    'расчёт': 2,
#    'цена': 15,
#    'ной': 1,
#    'осуждение': 1,
#    'пользователь': 2,
#    'случай': 1,
#    'навык': 1,
#    'услуга': 1,
#    'цикличность': 1,
#    'большинство': 1,
#    'цифра': 7,
#    'создание': 12,
#    'рынок': 2,
#    'половина': 2,
#    'задача': 3,
#    'вера': 4,
#    'структура': 5,
#    'увеличение': 6,
#    'устранение': 4,
#    'миссия': 2,
#    'исследование': 2,
#    'представитель': 2,
#    'организация': 2,
#    'логика': 2,
#    'форма': 5,
#    'взгляд': 6,
#    'образ': 3,
#    'время': 139,
#    'отсутствие': 13,
#    'любопытство': 1,
#    'потребность': 1,
#    'связь': 8,
#    'направление': 3,
#    'количество': 4,
#    'существование': 21,
#    'выделение': 2,
#    'внимание': 2,
#    'переход': 3,
#    'сознание': 3,
#    'взаимодействие': 1,
#    'система': 8,
#    'основание': 20,
#    'тема': 1,
#    'закономерность': 1,
#    'решение': 20,
#    'момент': 4,
#    'осуществление': 5,
#    'ребёнок': 1,
#    'ценность': 3,
#    'запущенность': 1,
#    'сложность': 5,
#    'сравнение': 2,
#    'роль': 8,
#    'проигрыш': 3,
#    'раунд': 1,
#    'норма': 4,
#    'раз': 9,
#    'развитие': 14,
#    'размер': 3,
#    'константа': 2,
#    'алгоритм': 2,
#    'вероятность': 6,
#    'отправка': 1,
#    'увлажнитель': 1,
#    'вектор': 2,
#    'старение': 1,
#    'свобода': 8,
#    'регулирование': 2,
#    'рецепт': 1,
#    'испытание': 2,
#    'обратный': 1,
#    'год': 18,
#    'враг': 1,
#    'выходка': 1,
#    'везение': 2,
#    'персона': 2,
#    'затея': 3,
#    'положение': 9,
#    'отношение': 5,
#    'право': 11,
#    'спешка': 1,
#    'команда': 1,
#    'город': 3,
#    'заверение': 5,
#    'пустяк': 1,
#    'вопрос': 12,
#    'брак': 4,
#    'деньга': 2,
#    'вырывание': 2,
#    'обстоятельство': 3,
#    'местечко': 2,
#    'неприятель': 2,
#    'драка': 2,
#    'психика': 2,
#    'скополамин': 2,
#    'разговор': 14,
#    'неделя': 6,
#    'мнение': 12,
#    'оборот': 2,
#    'мужчина': 2,
#    'удар': 3,
#    'подход': 4,
#    'смерть': 7,
#    'жизнь': 41,
#    'выбор': 3,
#    'понятие': 7,
#    'миссис': 2,
#    'истина': 3,
#    'мгновение': 3,
#    'возможность': 21,
#    'знакомый': 2,
#    'пандемия': 1,
#    'журналист': 1,
#    'обслуживание': 1,
#    'вариант': 5,
#    'сборная': 1,
#    'душа': 60,
#    'объединение': 5,
#    'носитель': 2,
#    'угроза': 3,
#    'плотность': 1,
#    'благо': 4,
#    'честность': 1,
#    'креатура': 1,
#    'территория': 6,
#    'факт': 8,
#    'религия': 3,
#    'ересь': 1,
#    'инфраструктура': 1,
#    'конец': 10,
#    'рост': 13,
#    'энергоноситель': 1,
#    'машина': 1,
#    'серебро': 1,
#    'надежда': 19,
#    'земля': 1,
#    'тактика': 1,
#    'обнуление': 1,
#    'неизбежность': 1,
#    'страх': 1,
#    'обязанность': 3,
#    'первооснова': 1,
#    'апейрон': 1,
#    'начало': 37,
#    'граница': 13,
#    'мера': 12,
#    'роспуск': 1,
#    'точка': 4,
#    'диалог': 3,
#    'плащаница': 1,
#    'голова': 2,
#    'радуга': 18,
#    'усиление': 3,
#    'наличие': 34,
#    'член': 2,
#    'заявление': 7,
#    'завышение': 1,
#    'падение': 2,
#    'версия': 4,
#    'способ': 4,
#    'оценка': 5,
#    'сражение': 1,
#    'улучшение': 1,
#    'строительство': 3,
#    'пояс': 1,
#    'авианосец': 1,
#    'пушка': 1,
#    'использование': 7,
#    'вхождение': 1,
#    'крейсер': 1,
#    'нанесение': 1,
#    'сохранение': 7,
#    'рука': 4,
#    'проблема': 7,
#    'войско': 4,
#    'модернизация': 2,
#    'требование': 7,
#    'размещение': 2,
#    'повышение': 3,
#    'опровержение': 1,
#    'число': 9,
#    'включение': 3,
#    'сюжет': 1,
#    'командир': 1,
#    'режим': 4,
#    'авиация': 1,
#    'визит': 2,
#    'мысль': 3,
#    'район': 2,
#    'манифест': 1,
#    'борьба': 5,
#    'гарантия': 3,
#    'отделение': 1,
#    'курд': 1,
#    'интервенция': 1,
#    'кадр': 1,
#    'анализ': 1,
#    'перспектива': 2,
#    'теракт': 2,
#    'соглашение': 1,
#    'заход': 1,
#    'страна': 1,
#    'потеря': 4,
#    'возникновение': 2,
#    'еврей': 2,
#    'метод': 3,
#    'донос': 1,
#    'президент': 2,
#    'идея': 9,
#    'учитель': 1,
#    'фашист': 1,
#    'достижение': 7,
#    'армия': 4,
#    'раб': 1,
#    'ликвидация': 2,
#    'свержение': 3,
#    'огораживание': 1,
#    'препятствие': 3,
#    'величие': 1,
#    'тезис': 2,
#    'народ': 3,
#    'восстановление': 1,
#    'сила': 13,
#    'изменение': 7,
#    'человек': 7,
#    'миролюбие': 1,
#    'сталинизм': 1,
#    'предшественник': 1,
#    'кое-что': 1,
#    'дебилизм': 1,
#    'немец': 1,
#    'инициатива': 2,
#    'обогащение': 1,
#    'привлечение': 3,
#    'патриарх': 1,
#    'неосведомлённость': 1,
#    'снижение': 8,
#    'сближение': 1,
#    'участие': 7,
#    'власть': 3,
#    'усилие': 1,
#    'разногласие': 5,
#    'выведение': 4,
#    'край': 1,
#    'кризис': 1,
#    'формулировка': 1,
#    'нападение': 2,
#    'союзник': 1,
#    'пропуск': 1,
#    'оклад': 1,
#    'оборона': 2,
#    'установление': 5,
#    'установка': 1,
#    'личность': 2,
#    'комиссарство': 1,
#    'разделение': 4,
#    'преобразование': 1,
#    'исток': 1,
#    'предоставление': 2,
#    'злопамятство': 1,
#    'самолёт': 7,
#    'обмен': 3,
#    'отказ': 4,
#    'знать': 1,
#    'штурм': 2,
#    'попытка': 10,
#    'служение': 1,
#    'история': 8,
#    'деятельность': 5,
#    'война': 1,
#    'причина': 14,
#    'прапорщик': 1,
#    'пропорция': 1,
#    'сей': 1,
#    'ведение': 1,
#    'империя': 3,
#    'различие': 5,
#    'критика': 7,
#    'одежда': 5,
#    'отравление': 2,
#    'состояние': 4,
#    'продвижение': 1,
#    'ходатайство': 2,
#    'мобилизация': 1,
#    'ошибка': 4,
#    'возвращение': 8,
#    'час': 1,
#    'ваххабизм': 1,
#    'реакция': 2,
#    'дорога': 2,
#    'эффект': 2,
#    'встреча': 2,
#    'срок': 4,
#    'клинок': 1,
#    'отвага': 1,
#    'доля': 2,
#    'измерение': 4,
#    'опасность': 6,
#    'присутствие': 8,
#    'маг': 1,
#    'сыщик': 2,
#    'родина': 1,
#    'апартамент': 2,
#    'десяток': 1,
#    'нововведение': 1,
#    'прямота': 1,
#    'интерес': 7,
#    'большевик': 1,
#    'клеймор': 2,
#    'намерение': 2,
#    'совет': 2,
#    'обитатель': 3,
#    'образина': 1,
#    'гаджет': 1,
#    'военачальник': 1,
#    'защита': 3,
#    'распределение': 3,
#    'король': 3,
#    'человечество': 5,
#    'дрын': 3,
#    'казнь': 4,
#    'разведка': 2,
#    'зона': 2,
#    'помешательство': 1,
#    'побережье': 1,
#    'пара': 2,
#    'флот': 1,
#    'себя': 3,
#    'позиция': 5,
#    'иллюзия': 1,
#    'цель': 11,
#    'жестокость': 1,
#    'ступенька': 1,
#    'варвар': 1,
#    'пришелец': 1,
#    'этап': 1,
#    'стиль': 2,
#    'формирование': 6,
#    'подозреваемый': 1,
#    'доблесть': 1,
#    'противник': 1,
#    'капитал': 1,
#    'выяснение': 1,
#    'неукоснительность': 1,
#    'план': 3,
#    'обучение': 2,
#    'купчишка': 1,
#    'музыка': 2,
#    'дело': 7,
#    'стремление': 2,
#    'убеждение': 2,
#    'игра': 3,
#    'дневник': 8,
#    'очередь': 1,
#    'замедление': 3,
#    'удовлетворение': 4,
#    'слово': 8,
#    'важность': 1,
#    'уход': 2,
#    'обсуждение': 5,
#    'вспышка': 1,
#    'утверждение': 12,
#    'возобновление': 3,
#    '.': 1,
#    'обвинение': 7,
#    'движение': 5,
#    'десятилетие': 1,
#    'отключение': 1,
#    'сторонник': 1,
#    'проведение': 14,
#    'нарушение': 1,
#    'введение': 3,
#    'реализация': 2,
#    'корректив': 1,
#    'характер': 6,
#    'конфликт': 2,
#    'сумма': 4,
#    'век': 1,
#    'коррекция': 1,
#    'взыскание': 1,
#    'отскок': 1,
#    'вмешательство': 7,
#    'серьёзность': 2,
#    'экс-глава': 1,
#    'потрясение': 1,
#    'владелец': 1,
#    'информация': 5,
#    'настрой': 2,
#    'прогноз': 1,
#    'эйфория': 1,
#    'выход': 3,
#    'скачок': 1,
#    'месяц': 4,
#    'условие': 6,
#    'дешевизна': 1,
#    'ухудшение': 1,
#    'акция': 1,
#    'уверенность': 1,
#    'отмена': 1,
#    'повторение': 1,
#    'постановка': 1,
#    'понижение': 1,
#    'тон': 1,
#    'мат': 1,
#    'сходство': 1,
#    'вид': 3,
#    'недостаток': 6,
#    'предложение': 2,
#    'покушение': 1,
#    'энтузиазм': 1,
#    'независимость': 1,
#    'бросок': 1,
#    'дом': 2,
#    'минута': 1,
#    'свойство': 5,
#    'общение': 1,
#    'свадьба': 3,
#    'отцовство': 1,
#    'школа': 1,
#    'учение': 2,
#    'наряд': 1,
#    'день': 3,
#    'подвиг': 1,
#    'одиночество': 1,
#    'нестандартность': 1,
#    'знакомство': 1,
#    'ужин': 1,
#    'чаевой': 1,
#    'возраст': 2,
#    'сентиментальность': 1,
#    'ремарка': 1,
#    'отчёт': 1,
#    'полчаса': 1,
#    'секунда': 1,
#    'эпопея': 1,
#    'мир': 8,
#    'функция': 1,
#    'поражение': 2,
#    'документ': 1,
#    'данные': 2,
#    'трудность': 4,
#    'достоинство': 3,
#    'активность': 4,
#    'институт': 1,
#    'безопасность': 1,
#    'устойчивость': 1,
#    'пересмотр': 2,
#    'скрещивание': 1,
#    'планета': 3,
#    'сплав': 1,
#    'законодательство': 4,
#    'явление': 3,
#    'состав': 2,
#    'тело': 6,
#    'размах': 1,
#    'тягота': 1,
#    'черта': 2,
#    'выступление': 2,
#    'ответ': 5,
#    'страсть': 1,
#    'объяснение': 2,
#    'гибель': 1,
#    'рыцарь': 1,
#    'интервал': 1,
#    'защищенность': 1,
#    'предположение': 2,
#    'ситуация': 3,
#    'коэффициент': 2,
#    'стоимость': 1,
#    'граф': 1,
#    'курс': 3,
#    'всплеск': 2,
#    'счастие': 6,
#    'танец': 1,
#    'крушение': 4,
#    'действие': 10,
#    'передача': 5,
#    'давление': 6,
#    'необходимость': 10,
#    'стручок': 3,
#    'разработка': 6,
#    'поведение': 3,
#    'чтение': 3,
#    'воздействие': 6,
#    'мотив': 2,
#    'недовольство': 4,
#    'рекрут': 2,
#    'динамика': 1,
#    'политика': 1,
#    'аватар': 2,
#    'купе': 1,
#    'подписание': 2,
#    'упрочение': 2,
#    'приоритет': 3,
#    'поддержка': 1,
#    'оказание': 3,
#    'неясность': 2,
#    'успех': 5,
#    'решимость': 1,
#    'орлан': 1,
#    'сезон': 1,
#    'освобождение': 2,
#    'оснащение': 1,
#    'принятие': 7,
#    'зарплата': 2,
#    'издание': 2,
#    'клонирование': 2,
#    'корабль': 1,
#    'снос': 2,
#    'декрет': 1,
#    'просьба': 2,
#    'доказательство': 2,
#    'лидер': 1,
#    'энергия': 4,
#    'преимущество': 1,
#    'тайна': 1,
#    'новинка': 1,
#    'непрактичность': 1,
#    'столетие': 1,
#    'звезда': 2,
#    'путь': 3,
#    'затрата': 1,
#    'преодоление': 2,
#    'природа': 2,
#    'ложь': 1,
#    'сотня': 1,
#    'эпоха': 2,
#    'вес': 1,
#    'печать': 7,
#    'венец': 15,
#    'название': 3,
#    'результат': 6,
#    'житель': 1,
#    'забота': 3,
#    'проблематика': 1,
#    'термин': 2,
#    'познание': 3,
#    'государство': 2,
#    'нахождение': 1,
#    'воспитание': 3,
#    'яйцо': 1,
#    'склонность': 1,
#    'скатерть': 1,
#    'осень': 1,
#    'камень': 2,
#    'содержимое': 1,
#    'кумир': 1,
#    'определение': 1,
#    'выжимка': 1,
#    'панлогизм': 1,
#    'собственность': 2,
#    'эволюция': 3,
#    'сон': 1,
#    'способность': 4,
#    'преграда': 2,
#    'вооружение': 1,
#    'культ': 1,
#    'сторона': 1,
#    'нищета': 1,
#    'диктатура': 2,
#    'прошлое': 2,
#    'будущее': 2,
#    'контраст': 3,
#    'цент': 1,
#    'синтез': 1,
#    'причинность': 1,
#    'смысл': 4,
#    'любовь': 2,
#    'развлечение': 2,
#    'появление': 3,
#    'экономка': 2,
#    'знамение': 3,
#    'накопление': 1,
#    'образование': 1,
#    'деяние': 1,
#    'процесс': 3,
#    'владение': 1,
#    'легализация': 1,
#    'лесть': 1,
#    'агитация': 1,
#    'разрыв': 1,
#    'замена': 1,
#    'наука': 4,
#    'баланс': 1,
#    'элемент': 2,
#    'температура': 3,
#    'разрушение': 2,
#    'фраза': 1,
#    'вселенная': 1,
#    'предок': 2,
#    'часть': 4,
#    'пассив': 2,
#    'материя': 2,
#    'кавалерия': 1,
#    'пришествие': 1,
#    'концепция': 3,
#    'род': 1,
#    'воздаяние': 2,
#    'мечта': 1,
#    'отождествление': 3,
#    'утро': 1,
#    'рубль': 1,
#    'основа': 10,
#    'тысяча': 1,
#    'крепость': 1,
#    'исполнение': 2,
#    'провидение': 1,
#    'автобус': 1,
#    'реформирование': 2,
#    'косточка': 1,
#    'отсечение': 1,
#    'инвестиция': 1,
#    'разгром': 1,
#    'переговоры': 1,
#    'влияние': 3,
#    'суть': 1,
#    'выставление': 1,
#    'грабёж': 1,
#    'возврат': 1,
#    'ответственность': 2,
#    'соревнование': 1,
#    'порок': 1,
#    'производитель': 1,
#    'обстановка': 1,
#    'изъятие': 1,
#    'деление': 3,
#    'население': 2,
#    'отрыв': 1,
#    'лицо': 1,
#    'бунт': 1,
#    'отступление': 2,
#    'посягательство': 1,
#    'рабовладение': 1,
#    'желание': 2,
#    'сокрушение': 1,
#    'исчезновение': 1,
#    'укрепление': 1,
#    'россиянин': 2,
#    'охрана': 1,
#    'благополучие': 1,
#    'значение': 4,
#    'собрание': 1,
#    'допустимость': 1,
#    'потенциал': 1,
#    'акт': 4,
#    'времяпрепровождение': 1,
#    'пища': 1,
#    'степень': 3,
#    'слава': 2,
#    'деревня': 1,
#    'контракция': 1,
#    'честь': 2,
#    'пришелица': 1,
#    'погода': 1,
#    'философия': 1,
#    'голос': 2,
#    'настройка': 1,
#    'работа': 6,
#    'упражнение': 3,
#    'удочка': 1,
#    'предел': 7,
#    'литература': 2,
#    'поле': 2,
#    'умысел': 1,
#    'поговорка': 1,
#    'пребывание': 3,
#    'взаимность': 1,
#    'стрела': 1,
#    'постройка': 4,
#    'финансирование': 2,
#    'откровенность': 1,
#    'жемчуг': 1,
#    'зерно': 1,
#    'бизнес': 1,
#    'происхождение': 6,
#    'аллопатия': 1,
#    'воин': 1,
#    'оружие': 2,
#    'разница': 2,
#    'разум': 3,
#    'книжка': 1,
#    'речь': 2,
#    'труд': 2,
#    'прибор': 2,
#    'вандал': 1,
#    'порядок': 1,
#    'зависимость': 1,
#    'перст': 1,
#    'предикат': 1,
#    'долг': 4,
#    'внук': 1,
#    'лепта': 1,
#    'интернет': 1,
#    'группа': 3,
#    'согласованность': 1,
#    'принцип': 8,
#    'хвастовство': 2,
#    'чувство': 1,
#    'перегрузка': 1,
#    'вина': 2,
#    'стан': 2,
#    'справедливость': 1,
#    'убийство': 1,
#    'революция': 2,
#    'ограниченность': 2,
#    'неизменность': 1,
#    'отдельность': 1,
#    'единство': 2,
#    'скорость': 2,
#    'ограничение': 3,
#    'множественность': 1,
#    'ветвь': 1,
#    'вечность': 2,
#    'общество': 3,
#    'христианство': 2,
#    'тип': 3,
#    'индивидуальность': 1,
#    'продолжение': 5,
#    'несовершенство': 1,
#    'десерт': 1,
#    'сын': 1,
#    'церковь': 1,
#    'пентхаус': 1,
#    'событие': 2,
#    'следствие': 1,
#    'царство': 2,
#    'высказывание': 1,
#    'рассуждение': 2,
#    'признак': 3,
#    'целостность': 1,
#    'методология': 1,
#    'обращение': 1,
#    'уста': 2,
#    'заимствование': 2,
#    'воля': 3,
#    'значимость': 1,
#    'преемственность': 1,
#    'альтернатива': 1,
#    'грань': 1,
#    'сущность': 5,
#    'заслуга': 1,
#    'ковчег': 1,
#    'посещение': 1,
#    'предмет': 4,
#    'преступление': 1,
#    'составлять': 1,
#    'карьера': 2,
#    'уничтожение': 3,
#    'фланг': 1,
#    'сведение': 1,
#    'князь': 2,
#    'смычка': 1,
#    'гвардия': 1,
#    'последствие': 1,
#    'радость': 1,
#    'масштаб': 2,
#    'тотальность': 1,
#    'стратегия': 1,
#    'асимметрия': 1,
#    'посылка': 1,
#    'покой': 1,
#    'мышление': 1,
#    'корень': 2,
#    'знак': 1,
#    'проникновение': 3,
#    'совершенствование': 1,
#    'промежуток': 1,
#    'израильтянин': 1,
#    'имя': 2,
#    'милостыня': 1,
#    'занятие': 2,
#    'крест': 1,
#    'сердце': 1,
#    'подчинённый': 1,
#    'упование': 1,
#    'экономия': 3,
#    'императив': 1,
#    'неравенство': 2,
#    'спасение': 2,
#    'отличие': 1,
#    'яд': 1,
#    'добро': 1,
#    'камушек': 1,
#    'плод': 1,
#    'ладонь': 1,
#    'менеджмент': 1,
#    'устройство': 2,
#    'продукт': 1,
#    'самосознание': 2,
#    'механизм': 1,
#    'перевес': 2,
#    'денотат': 1,
#    'длина': 1,
#    'круг': 1,
#    'оппонент': 1,
#    'тьма': 1,
#    'состоятельность': 2,
#    'покорение': 1,
#    'одобрение': 1,
#    'глава': 1,
#    'захват': 1,
#    'правительство': 1,
#    'исправление': 1,
#    'операция': 1,
#    'вывод': 3,
#    'аргумент': 2,
#    'место': 1,
#    'готовность': 2,
#    'запрет': 2,
#    'усложнение': 1,
#    'распространение': 1,
#    'предупреждение': 1,
#    'упоминание': 1,
#    'выполнение': 1,
#    'столкновение': 1,
#    'инквизиция': 1,
#    'экзотичность': 1,
#    'конфигурация': 1,
#    'картина': 2,
#    'отставка': 1,
#    'тенденция': 1,
#    'индекс': 1,
#    'целесообразность': 1,
#    'комбинация': 1,
#    'упрёк': 1,
#    'пакет': 1,
#    'приписывание': 1,
#    'зампред': 1,
#    'срочность': 1,
#    'замечание': 2,
#    'подключение': 1,
#    'гора': 1,
#    'расширение': 1,
#    'сокращение': 1,
#    'старт': 1,
#    'проявление': 1,
#    'планирование': 2,
#    'дискуссия': 1,
#    'унификация': 1,
#    'обзор': 1,
#    'причинение': 2,
#    'ссылка': 1,
#    'чуточку': 1,
#    'сомнение': 1,
#    'помощь': 2,
#    'вымывание': 1,
#    'закрепление': 1,
#    'признание': 2,
#    'оформление': 1,
#    'привлекательность': 1,
#    'вовлечение': 1,
#    'комета': 1,
#    'потомство': 2,
#    'знание': 4,
#    'претензия': 2,
#    'обоснование': 1,
#    'невозмутимость': 1,
#    'вода': 1,
#    'дуализм': 1,
#    'изучение': 3,
#    'отрешённость': 1,
#    'дыхание': 2,
#    'метафизика': 1,
#    'закон': 1,
#    'неотделимость': 1,
#    'трактовка': 2,
#    'море': 1,
#    'местоблюститель': 1,
#    'отрицание': 1,
#    'пример': 1,
#    'антураж': 1,
#    'сутки': 1,
#    'апостол': 1,
#    'икона': 6,
#    'язык': 3,
#    'тяжесть': 1,
#    'семя': 1,
#    'книга': 3,
#    'переустройство': 2,
#    'сделка': 1,
#    'арианство': 1,
#    'архимандрит': 1,
#    'отбор': 1,
#    'отвод': 1,
#    'река': 2,
#    'интерпретация': 1,
#    'глубина': 1,
#    'пространство': 2,
#    'родство': 3,
#    'храм': 1,
#    'рапсод': 1,
#    'победа': 1,
#    'этика': 1,
#    'выражение': 2,
#    'текст': 2,
#    'пропаганда': 1,
#    'мотивация': 1,
#    'превышение': 1,
#    'первоначало': 1,
#    'индивидуум': 1,
#    'калорийность': 1,
#    'поэма': 1,
#    'наследственность': 1,
#    'пар': 1,
#    'разумение': 1,
#    'покойник': 1,
#    'трагедия': 1,
#    'вещество': 1,
#    'стихия': 1,
#    'нерегулярность': 1,
#    'экзорцизм': 1,
#    'завершение': 1,
#    'христианин': 2,
#    'прикосновение': 1,
#    'сласть': 1,
#    'разность': 1,
#    'несогласие': 1,
#    'течение': 1,
#    'сопровождение': 2,
#    'бюджет': 1,
#    'уровень': 2,
#    'творение': 1,
#    'мишарь': 1,
#    'приспособление': 1,
#    'вышина': 1,
#    'лечение': 1,
#    'открытие': 2,
#    'реальность': 1,
#    'принадлежность': 1,
#    'архиепископство': 2,
#    'применение': 3,
#    'схема': 2,
#    'ракоскорпион': 1,
#    'гипотеза': 1,
#    'копьё': 1,
#    'провал': 1,
#    'цензура': 1,
#    'восстание': 1,
#    'общность': 1,
#    'училище': 1,
#    'эмиграция': 1,
#    'надобность': 1,
#    'счётчик': 1,
#    'ордината': 1,
#    'ярус': 1,
#    'баллада': 1,
#    'коктейль': 1,
#    'патриархия': 1,
#    'воззрение': 1,
#    'сообщение': 1,
#    'перевод': 1,
#    'антисемитизм': 2,
#    'почитание': 2,
#    'отклонение': 1,
#    'очищение': 1,
#    'уничижение': 1,
#    'зломыслие': 1,
#    'травма': 1,
#    'исключительность': 1,
#    'регрессия': 1,
#    'техника': 1,
#    'авторство': 2,
#    'линия': 1,
#    'примат': 3,
#    'манера': 1,
#    'произведение': 1,
#    'характеристика': 1,
#    'период': 1,
#    'свет': 1,
#    'светило': 1,
#    'шарообразность': 1,
#    'представление': 3,
#    'филология': 1,
#    'переворот': 1,
#    'омовение': 1,
#    'голосование': 1,
#    'сериал': 1,
#    'конфуцианство': 1,
#    'ранг': 1,
#    'заучивание': 1,
#    'язычество': 1,
#    'закручивание': 1,
#    'огонь': 1,
#    'генератор': 1,
#    'мщение': 1,
#    'эмиссия': 1,
#    'буква': 1,
#    'описание': 1,
#    'поэзия': 1,
#    'обеспечение': 1,
#    'регион': 1,
#    'тетрахорд': 1,
#    'раса': 1,
#    'вычурность': 1,
#    'вызов': 1,
#    'сопротивление': 1,
#    ...},
#   'Ins': {'образ': 151,
#    'вмешательство': 1,
#    'гигант': 1,
#    'лето': 3,
#    'цель': 107,
#    'слово': 34,
#    'мотив': 12,
#    'фактор': 15,
#    'идея': 8,
#    'пакет': 1,
#    'канал': 1,
#    'время': 48,
#    'студент': 1,
#    'особенность': 5,
#    'вопрос': 7,
#    'сила': 10,
#    'творец': 3,
#    'инструмент': 9,
#    'враг': 12,
#    'судья': 3,
#    'направление': 3,
#    'часть': 50,
#    'суверен': 1,
#    'слуга': 1,
#    'стукач': 1,
#    'залог': 1,
#    'спасение': 2,
#    'мера': 20,
#    'импульс': 1,
#    'тренд': 2,
#    'сценарий': 1,
#    'попытка': 13,
#    'активность': 2,
#    'составлять': 4,
#    'причина': 97,
#    'условие': 10,
#    'единица': 3,
#    'субъект': 3,
#    'форма': 13,
#    'этап': 4,
#    'объект': 9,
#    'показатель': 4,
#    'свойство': 2,
#    'механизм': 3,
#    'метод': 4,
#    'существо': 9,
#    'результат': 22,
#    'выработка': 1,
#    'заблуждение': 1,
#    'основа': 17,
#    'игра': 3,
#    'длительность': 1,
#    'сторонник': 9,
#    'предыстория': 1,
#    'фундамент': 4,
#    'вероятность': 1,
#    'приобретение': 3,
#    'необходимость': 3,
#    'проблема': 8,
#    'мошенник': 2,
#    'удача': 4,
#    'цена': 2,
#    'спаситель': 3,
#    'ворот': 1,
#    'рогоносец': 1,
#    'мишень': 3,
#    'основание': 10,
#    'миф': 2,
#    'знаток': 5,
#    'говор': 1,
#    'претензия': 1,
#    'средоточие': 1,
#    'народ': 6,
#    'ценитель': 1,
#    'счастливец': 1,
#    'учёный': 3,
#    'пуп': 2,
#    'долг': 25,
#    'тон': 3,
#    'задача': 41,
#    'замена': 1,
#    'бесчестие': 2,
#    'глупость': 3,
#    'собеседник': 1,
#    'предатель': 3,
#    'хранилище': 1,
#    'верх': 3,
#    'человек': 43,
#    'жертва': 9,
#    'средство': 28,
#    'вина': 49,
#    'голод': 2,
#    'дом': 3,
#    'потеря': 7,
#    'кладезь': 2,
#    'дурь': 2,
#    'предмет': 5,
#    'препарат': 2,
#    'правило': 3,
#    'издержка': 2,
#    'невесть': 2,
#    'красавец': 2,
#    'орудие': 3,
#    'партия': 3,
#    'прогресс': 2,
#    'член': 12,
#    'мерзавка': 2,
#    'профессионал': 2,
#    'борец': 2,
#    'мастерица': 2,
#    'персона': 2,
#    'специалист': 6,
#    'исполнитель': 18,
#    'кузен': 2,
#    'лжец': 2,
#    'друг': 9,
#    'шовинист': 2,
#    'унижение': 2,
#    'моралист': 2,
#    'шантажист': 4,
#    'момент': 8,
#    'отец': 11,
#    'стерва': 2,
#    'призвание': 3,
#    'находка': 2,
#    'женщина': 11,
#    'достоинство': 4,
#    'глава': 8,
#    'ночь': 4,
#    'дело': 40,
#    'вдова': 2,
#    'похвальба': 3,
#    'потрясение': 3,
#    'британец': 2,
#    'атавизм': 1,
#    'победитель': 9,
#    'меньшинство': 1,
#    'разновидность': 3,
#    'губернатор': 1,
#    'метеорит': 1,
#    'занятие': 6,
#    'будущее': 1,
#    'президент': 7,
#    'стихия': 1,
#    'критик': 1,
#    'валюта': 1,
#    'система': 4,
#    'продолжение': 3,
#    'стимул': 4,
#    'территория': 11,
#    'овчарка': 1,
#    'нация': 3,
#    'оружие': 4,
#    'сфера': 3,
#    'пантеист': 1,
#    'центр': 9,
#    'беспилотник': 1,
#    'столкновение': 2,
#    'глупец': 2,
#    'кандидат': 5,
#    'лидер': 8,
#    'шар': 2,
#    'ориентир': 1,
#    'источник': 28,
#    'решение': 21,
#    'акт': 15,
#    'явление': 13,
#    'вариант': 20,
#    'жизнь': 4,
#    'наследник': 7,
#    'надежда': 2,
#    'совпадение': 2,
#    'игрок': 2,
#    'мнение': 3,
#    'провокация': 5,
#    'элемент': 9,
#    'процесс': 6,
#    'ошибка': 32,
#    'прелюдия': 1,
#    'выход': 18,
#    'стелс': 1,
#    'деятель': 3,
#    'самолёт': 2,
#    'операция': 6,
#    'ветвь': 4,
#    'блеф': 1,
#    'крыло': 3,
#    'подход': 2,
#    'защита': 5,
#    'еда': 1,
#    'матерь': 14,
#    'следствие': 13,
#    'блажь': 2,
#    'шаг': 37,
#    'авантюра': 1,
#    'образец': 7,
#    'срок': 1,
#    'вклад': 3,
#    'имитация': 1,
#    'государство': 5,
#    'альтернатива': 4,
#    'фигура': 14,
#    'база': 3,
#    'руководитель': 4,
#    'адресат': 5,
#    'капитуляция': 1,
#    'марионетка': 1,
#    'конституция': 1,
#    'идиот': 3,
#    'союзник': 6,
#    'тяжеловес': 1,
#    'организатор': 16,
#    'опора': 2,
#    'дезинформация': 1,
#    'первопричина': 2,
#    'преимущество': 6,
#    'картель': 1,
#    'банда': 1,
#    'завеса': 1,
#    'угроза': 6,
#    'писатель': 3,
#    'вершитель': 1,
#    'интерес': 2,
#    'хозяин': 9,
#    'представитель': 10,
#    'пункт': 6,
#    'отступление': 2,
#    'мечта': 2,
#    'ценность': 7,
#    'вершина': 4,
#    'мозг': 1,
#    'обязанность': 4,
#    'главнокомандующий': 2,
#    'проект': 2,
#    'комплимент': 1,
#    'право': 3,
#    'ответ': 8,
#    'приоритет': 2,
#    'доблесть': 2,
#    'продукт': 3,
#    'поле': 2,
#    'сепаратист': 1,
#    'тема': 5,
#    'прикрытие': 5,
#    'порождение': 2,
#    'гарантия': 6,
#    'камень': 4,
#    'способ': 14,
#    'диктатура': 1,
#    'сумасшествие': 1,
#    'машина': 1,
#    'держава': 1,
#    'предстоятель': 2,
#    'вера': 1,
#    'объединение': 1,
#    'партнёр': 5,
#    'десятилетие': 3,
#    'предок': 19,
#    'выбор': 3,
#    'мститель': 1,
#    'мужчина': 4,
#    'самозванец': 2,
#    'инициатор': 11,
#    'галл': 1,
#    'язык': 6,
#    'слой': 1,
#    'отклонение': 1,
#    'защитник': 1,
#    'горняк': 1,
#    'эпизод': 2,
#    'инициатива': 3,
#    'общество': 2,
#    'неизбежность': 1,
#    'грех': 1,
#    'изобретатель': 2,
#    'негр': 1,
#    'взрыв': 2,
#    'противник': 7,
#    'честь': 2,
#    'пространство': 1,
#    'доказательство': 4,
#    'больной': 2,
#    'погон': 1,
#    'эполет': 1,
#    'крестьянин': 3,
#    'поселянин': 2,
#    'изъян': 1,
#    'норма': 2,
#    'весна': 5,
#    'исход': 2,
#    'князь': 9,
#    'участник': 9,
#    'министр': 3,
#    'начало': 16,
#    'повод': 13,
#    'новость': 2,
#    'террорист': 4,
#    'нападение': 1,
#    'осень': 4,
#    'сигнал': 5,
#    'преувеличение': 3,
#    'лицо': 4,
#    'группа': 1,
#    'исключение': 1,
#    'зима': 2,
#    'виновница': 2,
#    'смертник': 2,
#    'ислам': 1,
#    'ход': 2,
#    'выходец': 4,
#    'связник': 2,
#    'собственность': 4,
#    'место': 21,
#    'завсектором': 2,
#    'акция': 3,
#    'испытание': 3,
#    'преемник': 2,
#    'лицемерие': 2,
#    'случай': 3,
#    'прототип': 9,
#    'реакция': 2,
#    'столетие': 1,
#    'апогей': 3,
#    'неблагодарность': 2,
#    'успех': 3,
#    'случайность': 4,
#    'обмен': 1,
#    'качество': 1,
#    'тайна': 1,
#    'деяние': 2,
#    'татарин': 1,
#    'препятствие': 4,
#    'день': 2,
#    'сюрприз': 4,
#    'коммунист': 7,
#    'врач': 2,
#    'город': 3,
#    'уродство': 1,
#    'профан': 2,
#    'пень': 2,
#    'воробей': 2,
#    'сердце': 1,
#    'чудо': 2,
#    'создатель': 5,
#    'зло': 4,
#    'удел': 1,
#    'молодёжь': 2,
#    'знамение': 6,
#    'полковник': 1,
#    'стратег': 1,
#    'авантюрист': 1,
#    'личность': 3,
#    'вознаграждение': 3,
#    'обманщик': 2,
#    'надругательство': 1,
#    'избранник': 1,
#    'аргумент': 7,
#    'маг': 1,
#    'монстр': 1,
#    'величина': 4,
#    'эстет': 2,
#    'уроженец': 3,
#    'капля': 3,
#    'придаток': 2,
#    'болт': 2,
#    'профи': 2,
#    'добыча': 3,
#    'виновник': 11,
#    'жулик': 4,
#    'монета': 1,
#    'художник': 1,
#    'факт': 3,
#    'пунктик': 1,
#    'вотчина': 1,
#    'недостаток': 2,
#    'служба': 1,
#    'изображение': 2,
#    'офицер': 2,
#    'боец': 2,
#    'признак': 6,
#    'потомок': 11,
#    'привилегия': 4,
#    'развлечение': 1,
#    'зверьё': 1,
#    'дружинник': 1,
#    'ученик': 3,
#    'рыцарь': 1,
#    'любительница': 1,
#    'колдунья': 1,
#    'парень': 1,
#    'ловкач': 1,
#    'сучка': 1,
#    'пассажир': 1,
#    'муж': 2,
#    'нарушение': 3,
#    'дно': 1,
#    'свидетельство': 5,
#    'поэт': 7,
#    'разбойник': 2,
#    'изменение': 1,
#    'элита': 1,
#    'наивность': 5,
#    'автор': 19,
#    'подельник': 3,
#    'эксперт': 2,
#    'мальчишка': 1,
#    'формальность': 6,
#    'ужас': 3,
#    'конкурент': 3,
#    'правитель': 3,
#    'правительница': 6,
#    'охотник': 2,
#    'добро': 3,
#    'сын': 15,
#    'событие': 9,
#    'преступление': 2,
#    'родственник': 5,
#    'наказание': 3,
#    'держатель': 1,
#    'теракт': 1,
#    'инвестор': 1,
#    'всплеск': 1,
#    'проповедь': 1,
#    'водитель': 1,
#    'провал': 2,
#    'госсекретарь': 2,
#    'советник': 1,
#    'свершение': 1,
#    'сложность': 1,
#    'заявка': 1,
#    'изготовитель': 1,
#    'характеристика': 1,
#    'хулиган': 1,
#    'организация': 2,
#    'диверсия': 1,
#    'оратор': 1,
#    'шантаж': 1,
#    'терапия': 1,
#    'победа': 1,
#    'житель': 3,
#    'дилетант': 2,
#    'год': 3,
#    'драйвер': 1,
#    'покупатель': 2,
#    'король': 3,
#    'бедняк': 1,
#    'жена': 5,
#    'самореклама': 1,
#    'вирус': 1,
#    'снайпер': 1,
#    'получатель': 2,
#    'мигрант': 1,
#    'соперник': 3,
#    'история': 5,
#    'галактика': 2,
#    'хищник': 3,
#    'мастер': 3,
#    'вздор': 1,
#    'пловец': 1,
#    'земля': 1,
#    'ребёнок': 4,
#    'видимость': 1,
#    'путь': 4,
#    'знак': 3,
#    'поступок': 3,
#    'слабость': 1,
#    'копия': 2,
#    'торговля': 1,
#    'ерунда': 1,
#    'плод': 5,
#    'лечение': 2,
#    'совершенство': 1,
#    'директор': 1,
#    'любовник': 4,
#    'ирландец': 1,
#    'девчонка': 1,
#    'тело': 3,
#    'пилот': 1,
#    'королева': 3,
#    'дева': 1,
#    'хитрец': 3,
#    'самоубийство': 4,
#    'звезда': 2,
#    'махина': 1,
#    'принц': 1,
#    'признание': 2,
#    'уста': 1,
#    'дед': 1,
#    'умерший': 1,
#    'освобождение': 1,
#    'брюнет': 1,
#    'кумир': 1,
#    'девственница': 1,
#    'помеха': 4,
#    'рейс': 1,
#    'приверженец': 2,
#    'празднование': 1,
#    'утро': 3,
#    'вечер': 2,
#    'секрет': 1,
#    'сказка': 3,
#    'мусор': 1,
#    'праздник': 1,
#    'вербовщик': 1,
#    'протеже': 1,
#    'мероприятие': 9,
#    'отложение': 1,
#    'гимн': 1,
#    'падальщик': 1,
#    'раб': 1,
#    'консерватор': 1,
#    'чиновник': 1,
#    'плот': 1,
#    'ключ': 3,
#    'хранитель': 1,
#    'экстраверт': 1,
#    'значение': 3,
#    'артефакт': 2,
#    'пример': 3,
#    'компонент': 2,
#    'знакомый': 1,
#    'юноша': 1,
#    'компенсация': 3,
#    'фрагмент': 1,
#    'святилище': 1,
#    'счастливчик': 3,
#    'волшебник': 1,
#    'тупица': 1,
#    'формулировка': 1,
#    'константа': 2,
#    'ограничение': 1,
#    'неудачник': 1,
#    'развитие': 4,
#    'пик': 5,
#    'импровизация': 4,
#    'плюс': 2,
#    'метаморфоза': 3,
#    'желание': 2,
#    'отметка': 3,
#    'приговор': 2,
#    'столица': 9,
#    'товар': 3,
#    'пережиток': 1,
#    'бренд': 1,
#    'жестокость': 1,
#    'допинг': 1,
#    'сливка': 1,
#    'актив': 1,
#    'хлеб': 1,
#    'кусок': 1,
#    'предлог': 2,
#    'награда': 1,
#    'шхуна': 1,
#    'покушение': 3,
#    'свидетель': 4,
#    'шарлатан': 1,
#    'птица': 2,
#    'политика': 2,
#    'нарушитель': 1,
#    'ячейка': 2,
#    'погром': 1,
#    'минус': 3,
#    'взятка': 1,
#    'довод': 1,
#    'репетиция': 1,
#    'жильё': 1,
#    'супруга': 4,
#    'проверка': 2,
#    'тестирование': 1,
#    'заказчик': 2,
#    'волонтёр': 1,
#    'поручитель': 1,
#    'ад': 1,
#    'антифеминист': 1,
#    'открытие': 1,
#    'материал': 1,
#    'манёвр': 2,
#    'дополнение': 1,
#    'основоположник': 1,
#    'верхушка': 1,
#    'род': 9,
#    'критерий': 5,
#    'приближение': 1,
#    'позвоночный': 1,
#    'вещество': 1,
#    'трюк': 1,
#    'соль': 1,
#    'психолог': 1,
#    'сущность': 2,
#    'пора': 1,
#    'сопротивление': 1,
#    'жрец': 2,
#    'халдей': 1,
#    'бунтовщица': 1,
#    'главное': 2,
#    'добродетель': 1,
#    'бандит': 1,
#    'владыка': 25,
#    'предприятие': 2,
#    'имя': 13,
#    'война': 3,
#    'малыш': 1,
#    'кара': 3,
#    'учение': 1,
#    'роскошь': 2,
#    'черёд': 2,
#    'наследие': 2,
#    'учительница': 1,
#    'буква': 1,
#    'замысел': 3,
#    'тапёр': 1,
#    'колесо': 1,
#    'индивидуалист': 1,
#    'пастух': 3,
#    'животное': 3,
#    'истина': 2,
#    'сочинитель': 1,
#    'миллионер': 1,
#    'население': 3,
#    'профилактик': 2,
#    'работа': 5,
#    'пессимизм': 1,
#    'умишко': 1,
#    'маньяк': 1,
#    'грань': 1,
#    'славянин': 7,
#    'хазар': 2,
#    'европеец': 1,
#    'угощение': 1,
#    'звено': 4,
#    'благодетель': 3,
#    'блюститель': 1,
#    'гарант': 19,
#    'хранительница': 1,
#    'господин': 1,
#    'ловкость': 1,
#    'сообщество': 2,
#    'проводник': 2,
#    'особа': 1,
#    'прослойка': 1,
#    'святыня': 1,
#    'воспитание': 1,
#    'обучение': 1,
#    'образование': 2,
#    'разумение': 2,
#    'распорядитель': 3,
#    'владычица': 2,
#    'республика': 1,
#    'чужак': 1,
#    'благо': 5,
#    'демократ': 3,
#    'финал': 1,
#    'состояние': 1,
#    'конструктор': 1,
#    'любитель': 1,
#    'грешник': 1,
#    'носитель': 4,
#    'тысячелетие': 1,
#    'агент': 3,
#    'каста': 1,
#    'венец': 1,
#    'умный': 4,
#    'безумец': 1,
#    'метода': 1,
#    'духовность': 1,
#    'лотос': 1,
#    'слеза': 1,
#    'провокатор': 2,
#    'трата': 2,
#    'чтиво': 1,
#    'дорога': 1,
#    'явь': 1,
#    'падение': 1,
#    'подмога': 1,
#    'феномен': 1,
#    'звёздочка': 1,
# ...
#    'верх': 1,
#    'порог': 1,
#    'начало': 1,
#    'утверждение': 1,
#    'карта': 1,
#    'мерин': 1,
#    'счастие': 1,
#    'этаж': 1,
#    'фотография': 1,
#    'плёнка': 1,
#    'нары': 1,
#    'фронт': 1,
#    'заря': 1,
#    'поверхность': 1,
#    'практика': 2,
#    'сегмент': 1,
#    'гробница': 3,
#    'корабль': 1,
#    'трапеза': 1,
#    'жертвенник': 1,
#    'подход': 1,
#    'излёт': 1,
#    'след': 1,
#    'пашня': 1}},
#  'ВНЕ': {'Gen': {'спор': 3,
#    'конкуренция': 1,
#    'религия': 1,
#    'сомнение': 3,
#    'подозрение': 4,
#    'зависимость': 8,
#    'профессия': 1,
#    'опасность': 6,
#    'обсуждение': 3,
#    'предел': 2,
#    'логика': 1,
#    'компетенция': 1,
#    'страна': 1,
#    'отношение': 1}},
#  'ПО': {'Dat': {'сообщение': 65,
#    'сведение': 24,
#    'слово': 221,
#    'сила': 38,
#    'дикость': 1,
#    'неуклюжесть': 1,
#    'мнение': 40,
#    'данные': 175,
#    'образ': 2,
#    'условие': 3,
#    'признание': 4,
#    'наивность': 37,
#    'душа': 4,
#    'глупость': 4,
#    'недоумие': 2,
#    'правило': 3,
#    'ошибка': 3,
#    'крайность': 4,
#    'видимость': 38,
#    'дело': 7,
#    'вероятность': 3,
#    'соображение': 5,
#    'карман': 7,
#    'причина': 84,
#    'повод': 2,
#    'умолчание': 5,
#    'результат': 10,
#    'ряд': 2,
#    'информация': 52,
#    'суть': 6,
#    'инерция': 2,
#    'расчёт': 3,
#    'стечение': 1,
#    'привычка': 2,
#    'состояние': 1,
#    'утверждение': 3,
#    'недомыслие': 2,
#    'плечо': 3,
#    'молодость': 4,
#    'признак': 6,
#    'итог': 3,
#    'прикидка': 1,
#    'опрос': 2,
#    'оценка': 2,
#    'традиция': 3,
#    'ощущение': 2,
#    'простота': 4,
#    'вкус': 1,
#    'дурость': 2,
#    'кабак': 1,
#    'путь': 3,
#    'след': 1,
#    'старомодность': 1,
#    'беспечность': 1,
#    'неопытность': 2,
#    'магазин': 1,
#    'подсчёт': 1,
#    'аналогия': 4,
#    'барабан': 2,
#    'недоразумение': 1,
#    'критерий': 1,
#    'чин': 4,
#    'середина': 1,
#    'убеждение': 1,
#    'зуб': 1,
#    'стиль': 1,
#    'версия': 2,
#    'грамотность': 1,
#    'адрес': 1,
#    'рисунок': 1,
#    'смысл': 1,
#    'название': 1,
#    'детскость': 1,
#    'темнота': 2,
#    'линия': 1,
#    'должность': 1,
#    'поговорка': 1,
#    'натура': 1,
#    'серость': 1,
#    'гордыня': 1,
#    'случай': 2,
#    'свидетельство': 4,
#    'борьба': 1,
#    'недалёкость': 1,
#    'часть': 1,
#    'штат': 1,
#    'рассуждение': 1,
#    'заявление': 3,
#    'право': 2,
#    'вопрос': 4,
#    'существо': 3,
#    'проблема': 1,
#    'необходимость': 2,
#    'определение': 7,
#    'щепетильность': 1,
#    'изображение': 2,
#    'расположение': 1,
#    'отрывок': 1,
#    'пример': 1,
#    'вина': 1,
#    'останки': 1,
#    'правда': 1,
#    'воспоминание': 1,
#    'предположение': 1,
#    'тупость': 2,
#    'человек': 1,
#    'замысел': 1,
#    'прибытие': 1,
#    'оклад': 1,
#    'износ': 1},
#   'Acc': {'день': 3, 'горло': 1, 'колено': 1, 'десятка': 1, 'душа': 1},
#   'Loc': {'вступление': 1, 'истребление': 1, 'прошествие': 1}},
#  'В СВЯЗИ С': {'Ins': {'ухудшение': 1,
#    'воззрение': 1,
#    'факт': 2,
#    'снижение': 2,
#    'афера': 1,
#    'проблема': 3,
#    'некомпетентность': 1,
#    'событие': 2,
#    'кампания': 1,
#    'запас': 1,
#    'угроза': 1,
#    'назначение': 1,
#    'намерение': 1,
#    'ситуация': 1,
#    'порядок': 2,
#    'утверждение': 2,
#    'вопрос': 4,
#    'практика': 1,
#    'предложение': 3,
#    'заявление': 1,
#    'нанесение': 1,
#    'решение': 2,
#    'подпункт': 1,
#    'задача': 1,
#    'проект': 4,
#    'обсуждение': 2,
#    'нарушение': 1,
#    'масштаб': 1,
#    'суд': 1,
#    'выбор': 1,
#    'рост': 2,
#    'вывод': 1,
#    'применимость': 1,
#    'осуществление': 1,
#    'развитие': 2,
#    'характер': 1,
#    'необходимость': 1,
#    'темп': 1,
#    'дело': 1,
#    'поступление': 1,
#    'малочисленность': 1,
#    'дискуссия': 1,
#    'борьба': 1,
#    'процесс': 1}},
#  'ВО': {'Loc': {'интерес': 2,
#    'случай': 85,
#    'класс': 1,
#    'вселенная': 2,
#    'уважение': 2,
#    'ведомство': 5,
#    'фракция': 2,
#    'политика': 1,
#    'флот': 1,
#    'владычица': 1,
#    'мир': 3,
#    'прогноз': 1,
#    'империя': 1,
#    'мид': 1,
#    'банк': 6,
#    'страна': 1,
#    'ассоциация': 1,
#    'владение': 1,
#    'организация': 2,
#    'фактор': 1,
#    'язык': 1,
#    'власть': 1,
#    'многое': 2,
#    'регион': 1,
#    'время': 1,
#    'фронт': 1,
#    'избежание': 1,
#    'текст': 1,
#    'церковь': 3,
#    'часть': 1},
#   'Acc': {'имя': 1,
#    'время': 8,
#    'глава': 1,
#    'гроб': 2,
#    'фланг': 1,
#    'внимание': 1,
#    'слава': 1,
#    'благо': 2,
#    'жизнь': 1,
#    'прах': 1}},
#  'МИМО': {'Gen': {'тазик': 1}},
#  'ДЛЯ': {'Gen': {'ухо': 1,
#    'исследование': 1,
#    'изучение': 1,
#    'реализация': 3,
#    'преодоление': 2,
#    'простота': 3,
#    'утверждение': 1,
#    'расчёт': 1,
#    'индексация': 1,
#    'управляемость': 1,
#    'установление': 1,
#    'равновесие': 2,
#    'борьба': 1,
#    'получение': 4,
#    'польза': 1,
#    'обстрел': 1,
#    'дело': 1,
#    'всадник': 1,
#    'человек': 3,
#    'извлечение': 2,
#    'обеспечение': 3,
#    'выход': 1,
#    'принятие': 1,
#    'убедительность': 2,
#    'угонщик': 1,
#    'отвод': 2,
#    'дурак': 1,
#    'перевоплощение': 1,
#    'полёт': 1,
#    'большинство': 1,
#    'придание': 1,
#    'кластер': 1,
#    'краткость': 1,
#    'шкала': 1,
#    'определённость': 2,
#    'начало': 1,
#    'сюрреалист': 2,
#    'сбережение': 1,
#    'манёвр': 1,
#    'поездка': 1,
#    'реклама': 1,
#    'раздача': 1,
#    'воскрешение': 1,
#    'счастие': 1,
#    'счёт': 1,
#    'читатель': 1,
#    'разработка': 1,
#    'перехват': 1,
#    'охрана': 1,
#    'приращение': 1,
#    'выполнение': 1,
#    'обитель': 1,
#    'сотворение': 1,
#    'смена': 1,
#    'сравнение': 2,
#    'деятельность': 1,
#    'рассмотрение': 2,
#    'совершенствование': 1,
#    'цель': 1,
#    'окружность': 1,
#    'последовательность': 1,
#    'лобызание': 1,
#    'кура': 1,
#    'взрослый': 1,
#    'определение': 1,
#    'поручение': 1,
#    'время': 1,
#    'означение': 1,
#    'группа': 1,
#    'снятие': 1,
#    'слово': 1,
#    'мирянин': 1,
#    'вещество': 1,
#    'литература': 1}},
#  'ПОД': {'Ins': {'контроль': 10,
#    'рука': 3,
#    'начало': 2,
#    'сущность': 1,
#    'вопрос': 3,
#    'корабль': 1,
#    'действие': 2,
#    'воздействие': 1,
#    'угроза': 7,
#    'завеса': 1,
#    'руководство': 1,
#    'знамя': 1,
#    'давление': 1,
#    'каблук': 1,
#    'поверхность': 1,
#    'буква': 2,
#    'добродетель': 1,
#    'любовь': 1,
#    'вода': 1,
#    'птица': 2,
#    'одежда': 1,
#    'сознание': 2,
#    'выражение': 1,
#    'защита': 1,
#    'осенение': 1},
#   'Acc': {'сила': 14, 'пророчество': 1, 'дых': 1}},
#  'ВОПРЕКИ': {'Dat': {'ожидание': 1,
#    'законодательство': 1,
#    'смысл': 1,
#    'мнение': 8,
#    'подозрение': 2,
#    'теория': 2,
#    'реальность': 1,
#    'отсутствие': 1,
#    'позиция': 1,
#    'воззрение': 1}},
#  'ВМЕСТО': {'Gen': {'курс': 1,
#    'волос': 2,
#    'убеждение': 1,
#    'постулат': 1,
#    'заимствование': 1}},
#  'ПОСЛЕ': {'Gen': {'победа': 4,
#    'прохождение': 1,
#    'дело': 2,
#    'размышление': 3,
#    'потоп': 1,
#    'изыскание': 1,
#    'приход': 1,
#    'взятие': 1,
#    'достижение': 1,
#    'развал': 2,
#    'война': 1,
#    'оккупация': 1,
#    'окончание': 1,
#    'саммит': 1,
#    'акт': 1,
#    'крушение': 1,
#    'показатель': 1,
#    'высказывание': 2,
#    'кризис': 1,
#    'переговоры': 1,
#    'событие': 2,
#    'крах': 2,
#    'анализ': 2,
#    'уход': 1,
#    'создание': 1,
#    'шаг': 1,
#    'обнародование': 1,
#    'трагедия': 1,
#    'смерть': 1,
#    'ночь': 2,
#    'переход': 1,
#    'визит': 1,
#    'падение': 1,
#    'рассказ': 1,
#    'триумф': 1,
#    'успех': 1,
#    'разочарование': 1,
#    'скандал': 1,
#    'количество': 1,
#    'появление': 2,
#    'изучение': 2,
#    'посещение': 1,
#    'подготовка': 1,
#    'консультация': 1,
#    'рассмотрение': 1,
#    'подвиг': 1,
#    'вступление': 1,
#    'революция': 2,
#    'просмотр': 1,
#    'письмо': 1,
#    'поражение': 7,
#    'день': 1,
#    'беседа': 2,
#    'смена': 1,
#    'заседание': 1,
#    'обсуждение': 1,
#    'выступление': 1,
#    'проведение': 1,
#    'пролонгация': 1,
#    'призыв': 1,
#    'работа': 2,
#    'возвращение': 1,
#    'арест': 1,
#    'наступление': 1,
#    'строительство': 1,
#    'открытие': 1,
#    'потеря': 1,
#    'конференция': 1,
#    'сражение': 1,
#    'захват': 2,
#    'утаивание': 1,
#    'выпуск': 1,
#    'подписание': 1,
#    'завершение': 1,
#    'эксгумация': 1}},
#  'БЕЗ': {'Gen': {'основание': 215,
#    'учёт': 2,
#    'участие': 1,
#    'мысль': 1,
#    'тень': 3,
#    'надежда': 1,
#    'скромность': 1,
#    'сомнение': 7,
#    'санкция': 1,
#    'помощь': 4,
#    'прецедент': 1,
#    'обращение': 1,
#    'повод': 1,
#    'ум': 5,
#    'причина': 2,
#    'недостаток': 1,
#    'шутка': 1,
#    'потеря': 1,
#    'юмор': 1,
#    'цинизм': 1,
#    'изменение': 1,
#    'смирение': 1,
#    'вмешательство': 2,
#    'зазрение': 1,
#    'надобность': 1,
#    'ущерб': 3,
#    'доказывание': 1,
#    'ангажированность': 1,
#    'подкрепление': 1,
#    'трещина': 1}},
#  'В КАЧЕСТВЕ': {'Gen': {'итог': 1,
#    'условие': 1,
#    'отличие': 1,
#    'наследник': 2,
#    'кандидат': 1,
#    'мера': 9,
#    'содержимый': 1,
#    'бунт': 1,
#    'плац': 1,
#    'фи': 1,
#    'становление': 1,
#    'прообраз': 1,
#    'связь': 1,
#    'предмет': 1,
#    'следствие': 2,
#    'носитель': 1,
#    'основа': 1,
#    'пример': 1,
#    'задача': 1,
#    'пояснение': 1,
#    'страна': 1,
#    'сопредседатель': 1,
#    'замечание': 1,
#    'время': 1,
#    'мерило': 1,
#    'группа': 1,
#    'корень': 1,
#    'место': 1}},
#  'К': {'Dat': {'фонд': 1,
#    'курс': 1,
#    'сожаление': 15,
#    'середина': 1,
#    'лицо': 2,
#    'земля': 1,
#    'счастие': 6,
#    'боль': 2,
#    'пример': 91,
#    'слово': 19,
#    'война': 1,
#    'день': 2,
#    'время': 4,
#    'организация': 1,
#    'сентябрь': 1,
#    'изумление': 1,
#    'босс': 1,
#    'сведение': 1,
#    'несчастие': 1,
#    'конец': 1,
#    'праздник': 1,
#    'декада': 1,
#    'место': 1,
#    'радость': 1,
#    'нога': 7,
#    'начало': 3,
#    'момент': 1,
#    'беда': 1,
#    'величие': 1,
#    'вест': 1}},
#  'ОТ': {'Gen': {'познание': 1,
#    'нежелание': 1,
#    'рождение': 2,
#    'разочарование': 2,
#    'месье': 2,
#    'название': 1,
#    'слово': 1,
#    'осведомлённость': 1,
#    'информация': 1,
#    'непрофессионализм': 1,
#    'готовность': 1,
#    'безвыходность': 1,
#    'опасность': 2,
#    'неустроенность': 1,
#    'полковник': 1,
#    'эмблема': 1,
#    'хлорка': 1,
#    'человек': 1,
#    'тётушка': 1,
#    'недоедание': 1,
#    'деятельность': 3,
#    'смех': 1,
#    'местоположение': 1,
#    'костёр': 1,
#    'царь': 1,
#    'нелепость': 1,
#    'сын': 1,
#    'собрат': 1,
#    'жара': 1,
#    'швед': 1,
#    'поле': 1,
#    'медведь': 1,
#    'яд': 1,
#    'ошибка': 1,
#    'ангел': 1}},
#  'ПОСРЕДСТВОМ': {'Gen': {'деятельность': 1}},
#  'ПРИ': {'Loc': {'заболевание': 1,
#    'работа': 1,
#    'восприятие': 1,
#    'определение': 1,
#    'применение': 1,
#    'поражение': 1,
#    'расчёт': 2,
#    'условие': 8,
#    'уважение': 8,
#    'журнал': 2,
#    'проектирование': 1,
#    'наличие': 7,
#    'создание': 3,
#    'абсурдность': 1,
#    'отсутствие': 7,
#    'отношение': 1,
#    'рассмотрение': 9,
#    'правитель': 1,
#    'душа': 1,
#    'обстоятельство': 8,
#    'арест': 1,
#    'выполнение': 1,
#    'сценарий': 3,
#    'симпатия': 1,
#    'подписание': 1,
#    'сложность': 2,
#    'риск': 1,
#    'кросс-курс': 1,
#    'конъюнктура': 1,
#    'подход': 2,
#    'сохранение': 3,
#    'взаимопонимание': 1,
#    'слово': 4,
#    'обмен': 1,
#    'жизнь': 3,
#    'обращение': 1,
#    'двор': 1,
#    'случай': 1,
#    'формирование': 1,
#    'расследование': 1,
#    'доля': 1,
#    'понимание': 2,
#    'открытие': 1,
#    'состояние': 2,
#    'разработка': 1,
#    'составление': 2,
#    'формулировка': 2,
#    'запись': 1,
#    'содержание': 1,
#    'совпадение': 1,
#    'ровность': 1,
#    'пение': 1,
#    'районирование': 1,
#    'погребение': 1,
#    'чтение': 1,
#    'участие': 1,
#    'дорога': 1}},
#  'МЕЖДУ': {'Ins': {'объём': 1, 'свинка': 1, 'творец': 2}},
#  'ПО МЕРЕ': {'Gen': {'обучение': 1, 'подготовка': 1, 'развитие': 1}},
#  'ПРО': {'Acc': {'юнит-тест': 1, 'бытие': 1, 'деталь': 1}},
#  'О': {'Loc': {'наличие': 9,
#    'человек': 2,
#    'стадо': 1,
#    'теория': 1,
#    'символика': 1,
#    'война': 1,
#    'понижение': 1,
#    'провокация': 1,
#    'возможность': 3,
#    'характер': 1,
#    'поцелуй': 1,
#    'дедушка': 1,
#    'оборот': 1,
#    'приверженность': 1,
#    'правомерность': 1,
#    'причастность': 2,
#    'благополучие': 1,
#    'перевозка': 1,
#    'душа': 1,
#    'главное': 2,
#    'системность': 1,
#    'признание': 1,
#    'цивилизованность': 1,
#    'персона': 1,
#    'эксперимент': 1,
#    'фальсификация': 1,
#    'точность': 1,
#    'странник': 1,
#    'будущее': 1,
#    'суждение': 1,
#    'конец': 1,
#    'папоротник': 1,
#    'осведомлённость': 1,
#    'связь': 1,
#    'мальчик': 1,
#    'существование': 2,
#    'возобновление': 1,
#    'мотив': 1,
#    'постройка': 1,
#    'происхождение': 1,
#    'победа': 1}},
#  'ПО СРАВНЕНИЮ С': {'Ins': {'период': 1}},
#  'ПЕРЕД': {'Ins': {'начало': 4,
#    'лицо': 2,
#    'встреча': 2,
#    'престол': 7,
#    'глаз': 1,
#    'война': 1,
#    'шествие': 1,
#    'публикация': 1,
#    'бог': 1}},
#  'В СООТВЕТСТВИИ С': {'Ins': {'положение': 3,
#    'опрос': 2,
#    'результат': 1,
#    'дух': 1,
#    'соображение': 1,
#    'случай': 1,
#    'этимология': 1,
#    'понимание': 1,
#    'позиция': 2,
#    'норма': 1,
#    'принцип': 1,
#    'указание': 2,
#    'учение': 1,
#    'исследование': 1,
#    'взгляд': 1}},
#  'БЛАГОДАРЯ': {'Dat': {'отвага': 1,
#    'данные': 1,
#    'вмешательство': 1,
#    'ферма': 1,
#    'энтузиаст': 1,
#    'структура': 1,
#    'стиль': 1,
#    'довод': 1,
#    'знание': 1,
#    'характер': 1,
#    'отчуждение': 1,
#    'новизна': 1}},
#  'ЧЕРЕЗ': {'Acc': {'гид': 2,
#    'окно': 2,
#    'четверть': 2,
#    'год': 2,
#    'полуостров': 1,
#    'не-я': 1,
#    'предел': 1}},
#  'ПО ПОВОДУ': {'Gen': {'сценарий': 2,
#    'возможность': 1,
#    'захват': 1,
#    'миграция': 1,
#    'текст': 1,
#    'запись': 1,
#    'арест': 1}},
#  'КО': {'Dat': {'время': 2}},
#  'ВОКРУГ': {'Gen': {'грех': 1}},
#  'ВО ВРЕМЯ': {'Gen': {'кампания': 1,
#    'принятие': 1,
#    'форум': 1,
#    'зарождение': 1,
#    'беседа': 2,
#    'поездка': 1,
#    'антракт': 1,
#    'интервью': 1,
#    'разработка': 2,
#    'знамение': 1,
#    'игра': 1,
#    'война': 1}},
#  'СО': {'Gen': {'сторона': 86, 'слово': 2, 'время': 2, 'точка': 1},
#   'Ins': {'ссылка': 5,
#    'тонкость': 1,
#    'очевидность': 2,
#    'основание': 1,
#    'уверенность': 2,
#    'максимализм': 1,
#    'легкомыслие': 1,
#    'серьёзность': 1,
#    'клюв': 1,
#    'определённость': 1,
#    'условие': 1}},
#  'ОКОЛО': {'Gen': {'треть': 15, 'четверть': 6, 'половина': 13, 'час': 1}},
#  'ВПЕРЕДИ': {'Gen': {'конкурент': 1, 'планета': 1}},
#  'ПРОТИВ': {'Gen': {'орудие': 1,
#    'вступление': 1,
#    'изменение': 1,
#    'реформа': 1,
#    'визит': 1,
#    'реклама': 1,
#    'приход': 1,
#    'церемония': 1,
#    'правило': 1,
#    'продолжение': 6,
#    'операция': 1,
#    'пиар': 1,
#    'культура': 1,
#    'благотворительность': 1,
#    'отступление': 1,
#    'шумиха': 1,
#    'принятие': 1,
#    'единство': 1,
#    'присоединение': 1,
#    'совесть': 1}},
#  'В ТЕЧЕНИЕ': {'Gen': {'квартал': 1,
#    'полугодие': 1,
#    'время': 3,
#    'десяток': 1,
#    'период': 2,
#    'половина': 1,
#    'часть': 1}},
#  'В ХОДЕ': {'Gen': {'бой': 1, 'подсчёт': 1}},
#  'НАКАНУНЕ': {'Gen': {'революция': 2, 'визит': 1, 'мнение': 1}},
#  'ВСЛЕДСТВИЕ': {'Gen': {'террор': 1,
#    'увеличение': 1,
#    'недоразумение': 1,
#    'безумие': 1,
#    'раскопка': 1,
#    'взгляд': 1}},
#  'С ПОМОЩЬЮ': {'Gen': {'решимость': 1, 'сочинение': 3}},
#  'ОТНОСИТЕЛЬНО': {'Gen': {'цена': 1,
#    'критика': 1,
#    'вопрос': 2,
#    'требование': 1,
#    'рост': 1,
#    'инцидент': 1,
#    'продолжительность': 1,
#    'последствие': 1,
#    'оговорка': 4,
#    'существование': 1,
#    'акт': 1,
#    'стать': 1,
#    'проблема': 1,
#    'предложение': 1,
#    'критерий': 1,
#    'реформа': 1,
#    'построение': 1,
#    'свобода': 1,
#    'земля': 1}},
#  'РАДИ': {'Gen': {'бутафория': 1,
#    'выгода': 1,
#    'простота': 1,
#    'служение': 3,
#    'прекращение': 1,
#    'энергия': 1,
#    'предположение': 1,
#    'победа': 1}},
#  'СПУСТЯ': {'Acc': {'год': 1, 'десятилетие': 1, 'период': 1}},
#  'ВВИДУ': {'Gen': {'распространённость': 1,
#    'размер': 1,
#    'соображение': 1,
#    'подтверждение': 1,
#    'реорганизация': 1,
#    'отсутствие': 6,
#    'наличие': 1,
#    'существование': 1,
#    'доля': 1,
#    'нарушение': 1,
#    'неоднородность': 1,
#    'вклад': 1,
#    'нестабильность': 2,
#    'ужас': 1,
#    'результат': 2,
#    'констатация': 1,
#    'вопрос': 1,
#    'факт': 1,
#    'уход': 1,
#    'всемогущество': 1,
#    'успех': 1}},
#  'ОБ': {'Loc': {'происхождение': 1, 'размер': 1, 'природа': 1}},
#  'ПОВЕРХ': {'Gen': {'престол': 1}},
#  'ЗА СЧЕТ': {'Gen': {'правительство': 1, 'мероприятие': 1}},
#  'ПРИ ПОМОЩИ': {'Gen': {'войско': 1}},
#  'ПРЕД': {'Ins': {'икона': 1, 'престол': 1, 'ковчег': 1}},
#  'БЕЗО': {'Gen': {'основание': 1}},
#  'ИЗО': {'Gen': {'лёд': 1}}}

# %%
verbs_noms = ['светать', 'холодать', 'смеркаться', 'вьюжить']


# for verb, comb0 in tqdm(verb_comb.items()):
for verb in verbs_noms:
    comb0 = verb_comb[verb]
    s_n = 0
    s = 0
    for prep, comb1 in verb_comb[verb].items():
        for cas, comb2 in comb1.items():
            for noun, freq in comb2.items():
                s += freq
#     if s < 100:
#         continue
        
    if '_' not in comb0.keys() or 'Nom' not in comb0['_']:
        print('!!!', verb)
        continue
    for noun, freq in comb0['_']['Nom'].items():
        s_n += freq
#     if s_n / s < 0.01:
    print(verb, s_n, s)
# Out:
# светать 31 269
# холодать 24 177
# смеркаться 25 232
# вьюжить 17 47

# %%
verb_comb['холодать']['_']['Nom']
# Out:
# {'ребята': 1,
#  'правда': 1,
#  'погода': 2,
#  'отношение': 5,
#  'явление': 1,
#  'мисс': 1,
#  'ночь': 3,
#  'шея': 1,
#  'май': 1,
#  'осень': 1,
#  'неохота': 1,
#  'климат': 3,
#  'воздух': 1,
#  'правило': 1,
#  'комната': 1}

# %% [markdown]
# В статье надо написать, что надо чистить от таких сочетаний.
#
# Сейчас можно пройтись и проверить, где они есть, совпадают ли с моим \_pos. Может и выкинуть.

# %%
cooccur = []
cooccur2 = []

for verb, comb1 in verb_comb.items():
    for prep, comb2 in comb1.items():
        for cas, comb3 in comb2.items():
            if len(comb3) <= 2:
                continue
            s_combs = sorted(comb3.items(), key=lambda x:x[1], reverse=True)
            if s_combs[0][1] > 3 * s_combs[1][1]:
                cooccur.append(f'{verb}:{prep}:{cas}:{s_combs[0][0]}:{s_combs[0][1]}:{s_combs[1][1]}')
                cooccur2.append(f'{verb} {prep} {cas}')

# %%
cooccur
# Out:
# ['случиться:_:Gen:год:110:19',
#  'случиться:ВОЗЛЕ:Gen:дом:21:5',
#  'случиться:ИЗ:Gen:ряд:25:5',
#  'случиться:ДО:Gen:конец:62:20',
#  'случиться:ПРОТИВ:Gen:воля:6:1',
#  'просиять:В:Loc:земля:244:8',
#  'просиять:В:Acc:ответ:30:7',
#  'просиять:_:Nom:лицо:429:61',
#  'просиять:_:Ins:улыбка:206:24',
#  'просиять:ПРИ:Loc:вид:42:7',
#  'просиять:НА:Acc:мгновение:9:2',
#  'просиять:СРЕДИ:Gen:лицо:6:1',
#  'приступить:_:Loc:.:22:2',
#  'приступить:В:Acc:время:1053:289',
#  'приступить:НА:Acc:день:196:34',
#  'приступить:С:Ins:цель:594:168',
#  'приступить:ДО:Gen:конец:82:24',
#  'приступить:ВО:Acc:вторник:202:7',
#  'приступить:ПРИ:Loc:поддержка:305:88',
#  'приступить:КО:Dat:этап:159:35',
#  'приступить:ПОД:Ins:руководство:111:25',
#  'приступить:В ХОДЕ:Gen:сессия:41:11',
#  'приступить:ОТ:Gen:имя:7:2',
#  'приступить:ВВИДУ:Gen:роль:10:2',
#  'приступить:РАДИ:Gen:спасение:6:1',
#  'рассказать:О:Acc:хищение:7:2',
#  'рассказать:ПО:Acc:ужас:5:1',
#  'рассказать:СО:Ins:ссылка:458:59',
#  'рассказать:ДЛЯ:Gen:начало:193:20',
#  'рассказать:С:Gen:начало:334:74',
#  'рассказать:С:Ins:удовольствие:309:82',
#  'рассказать:С:Acc:десяток:7:1',
#  'рассказать:МЕЖДУ:Ins:дело:41:2',
#  'рассказать:В СВЯЗИ С:Ins:сообщение:15:4',
#  'рассказать:ПРИ:Loc:встреча:229:44',
#  'рассказать:ОТ:Gen:лицо:115:34',
#  'рассказать:В КАЧЕСТВЕ:Gen:пример:135:10',
#  'рассказать:ВО:Acc:вторник:367:39',
#  'рассказать:БЕЗ:Gen:утайка:198:19',
#  'рассказать:ДО:Gen:конец:178:25',
#  'рассказать:ВОПРЕКИ:Dat:договорённость:4:1',
#  'стоять:_:Acc:время:3666:681',
#  'стоять:_:Loc:посередине:314:21',
#  'стоять:ВО:Loc:двор:1682:157',
#  'стоять:ЗА:Ins:спина:5193:1484',
#  'стоять:С:Gen:сторона:989:229',
#  'стоять:С:Acc:минута:319:41',
#  'стоять:О:Acc:бок:302:2',
#  'стоять:СО:Gen:время:118:31',
#  'стоять:ВДОЛЬ:Gen:стена:1082:357',
#  'стоять:РАДИ:Gen:справедливость:919:32',
#  'стоять:МЕЖДУ:Gen:нога:45:10',
#  'стоять:ПОСРЕДИ:Gen:комната:1361:274',
#  'стоять:ПОСРЕДИНЕ:Gen:комната:74:19',
#  'стоять:ВОКРУГ:Gen:стол:187:37',
#  'стоять:ОБ:Loc:управляемость:10:3',
#  'стоять:ОБ:Acc:рука:5:1',
#  'стоять:ВВИДУ:Gen:эмиграция:14:3',
#  'стоять:В ХОДЕ:Gen:торг:27:7',
#  'получать:_:Ins:образ:2811:392',
#  'получать:_:Loc:год:263:31',
#  'получать:ВО:Loc:сон:221:70',
#  'получать:СО:Gen:спутник:217:52',
#  'получать:В ХОДЕ:Gen:гонка:594:40',
#  'получать:ВНЕ:Gen:зависимость:179:23',
#  'получать:ПЕРЕД:Ins:выбор:264:29',
#  'получать:ПОСРЕДСТВОМ:Gen:связь:34:8',
#  'быть:_:Loc:.:188:37',
#  'быть:НА:Acc:момент:5710:1161',
#  'быть:В:Acc:время:8501:2364',
#  'быть:ПО:Acc:сторона:180:32',
#  'быть:ВО:Acc:время:656:150',
#  'быть:С:Gen:сторона:2459:650',
#  'быть:С:Ins:учёт:398:54',
#  'быть:БЕЗ:Gen:сомнение:186:40',
#  'быть:ВО ВРЕМЯ:Gen:война:280:49',
#  'быть:МЕЖДУ:Gen:нога:12:2',
#  'быть:ОТ:Gen:брак:944:100',
#  'быть:СО:Ins:время:104:22',
#  'быть:НАД:Ins:голова:50:16',
#  'быть:ИЗО:Gen:день:10:2',
#  'быть:КО:Dat:время:76:7',
#  'быть:ПРИ ПОМОЩИ:Gen:общество:5:1',
#  'быть:ПОЗАДИ:Gen:дом:7:2',
#  'быть:ВПЕРЕДИ:Gen:планета:7:2',
#  'родиться:В:Loc:семья:69964:21691',
#  'родиться:_:Loc:.:664:92',
#  'родиться:НА:Acc:свет:699:68',
#  'родиться:ПО:Acc:сторона:21:1',
#  'родиться:ОТ:Gen:брак:1171:162',
#  'родиться:ВО:Acc:время:140:25',
#  'родиться:ВНЕ:Gen:брак:209:8',
#  'родиться:ЧЕРЕЗ:Acc:год:506:50',
#  'родиться:ПЕРЕД:Ins:война:35:5',
#  'родиться:СО:Ins:время:21:5',
#  'родиться:СПУСТЯ:Acc:год:113:37',
#  'родиться:СРЕДИ:Gen:человек:13:4',
#  'родиться:С ПОМОЩЬЮ:Gen:сечение:21:3',
#  'родиться:НАКАНУНЕ:Gen:война:7:2',
#  'родиться:ПО СРАВНЕНИЮ С:Ins:половина:9:2',
#  'переехать:_:Nom:семья:7581:877',
#  'переехать:_:Loc:.:192:7',
#  'переехать:ПО:Loc:окончание:156:23',
#  'переехать:ОКОЛО:Gen:год:22:5',
#  'переехать:ВО:Loc:половина:37:4',
#  'переехать:ВО ВРЕМЯ:Gen:война:110:8',
#  'переехать:КО:Dat:двор:14:1',
#  'переехать:ОТ:Gen:родитель:31:10',
#  'получить:_:Loc:.:770:69',
#  'получить:В:Loc:результат:42403:9372',
#  'получить:ПО:Loc:окончание:1300:354',
#  'получить:СО:Ins:время:451:65',
#  'получить:ДО:Gen:конец:1555:327',
#  'получить:ПО МЕРЕ:Gen:освобождение:144:13',
#  'получить:ВОПРЕКИ:Dat:ожидание:29:8',
#  'получить:МЕЖДУ:Gen:глаз:11:2',
#  'получить:ОБ:Acc:известие:5:1',
#  'учиться:ПО:Loc:окончание:177:29',
#  'учиться:ПО:Acc:день:7:2',
#  'учиться:_:Loc:.:204:25',
#  'учиться:ЗА:Acc:граница:247:56',
#  'учиться:ЗА:Ins:граница:317:19',
#  'учиться:В ТЕЧЕНИЕ:Gen:год:69:18',
#  'учиться:ПОД:Ins:руководство:528:24',
#  'учиться:ВО:Acc:смена:86:17',
#  'учиться:ПОСЛЕ:Gen:окончание:723:176',
#  'учиться:ПРО:Acc:запас:4:1',
#  'рукоположить:В:Acc:сан:3539:916',
#  'рукоположить:ЗА:Ins:литургия:12:1',
#  'рукоположить:_:Gen:год:34:9',
#  'рукоположить:ПО:Loc:окончание:82:12',
#  'рукоположить:К:Dat:церковь:133:43',
#  'рукоположить:ДЛЯ:Gen:служение:68:15',
#  'продолжать:ПО:Acc:день:286:13',
#  'продолжать:К:Dat:сожаление:425:63',
#  'продолжать:ПОД:Ins:руководство:171:45',
#  'продолжать:В ТЕЧЕНИЕ:Gen:период:1234:290',
#  'продолжать:ВНЕ:Gen:зависимость:54:6',
#  'продолжать:ПРИ:Loc:поддержка:435:134',
#  'продолжать:ОТ:Gen:имя:38:6',
#  'продолжать:ЗА СЧЕТ:Gen:средство:13:3',
#  'продолжать:ИЗО:Gen:сила:27:8',
#  'продолжать:ВВИДУ:Gen:отсутствие:13:3',
#  'продолжать:ВОЗЛЕ:Gen:дом:5:1',
#  'продолжать:ВСЛЕДСТВИЕ:Gen:активность:19:6',
#  'приглашать:_:Ins:жест:474:137',
#  'приглашать:ДЛЯ:Gen:участие:384:92',
#  'приглашать:СО:Ins:слово:8:1',
#  'приглашать:ПОСЛЕ:Gen:окончание:30:8',
#  'приглашать:ИЗ:Gen:страна:48:14',
#  'приглашать:ПОД:Acc:кат:34:4',
#  'приглашать:ПОД:Ins:предлог:38:9',
#  'приглашать:КО:Dat:двор:26:4',
#  'приглашать:ВО:Acc:дворец:38:8',
#  'приглашать:ОТ:Gen:имя:38:10',
#  'приглашать:СПУСТЯ:Acc:время:10:3',
#  'приглашать:ВНЕ:Gen:зависимость:5:1',
#  'жить:_:Ins:жизнь:12129:614',
#  'жить:_:Loc:.:105:28',
#  'жить:_:Par:народ:13:2',
#  'жить:СО:Gen:время:180:53',
#  'жить:ОТ:Gen:зарплата:141:36',
#  'жить:ВО:Acc:время:1045:87',
#  'жить:ЗА:Acc:счёт:444:82',
#  'жить:О:Acc:бок:1273:2',
#  'жить:СРЕДИ:Gen:человек:513:82',
#  'жить:ВО ВРЕМЯ:Gen:война:298:63',
#  'жить:ПЕРЕД:Ins:война:82:14',
#  'жить:ДЛЯ:Gen:человек:470:69',
#  'жить:ПОСРЕДСТВОМ:Gen:накопление:12:2',
#  'жить:ИЗО:Gen:день:47:10',
#  'жить:НАКАНУНЕ:Gen:война:16:4',
#  'жить:КО:Dat:время:17:2',
#  'жить:ПРЕД:Ins:лице:4:1',
#  'провести:_:Loc:.:245:61',
#  'провести:БЕЗ:Gen:сон:481:149',
#  'провести:С:Ins:цель:5535:1367',
#  'провести:ЗА:Ins:решётка:1402:379',
#  'провести:ВО:Loc:половина:746:208',
#  'провести:ВО:Acc:вторник:1248:71',
#  'провести:СО:Gen:время:296:78',
#  'провести:У:Gen:здание:449:105',
#  'провести:ЗА СЧЁТ:Gen:средство:13:2',
#  'провести:ВНЕ:Gen:дом:129:36',
#  'провести:В ХОДЕ:Gen:сессия:1560:412',
#  'провести:ПРИ ПОМОЩИ:Gen:телескоп:40:11',
#  'провести:О:Acc:бок:115:2',
#  'провести:ПЕРЕД:Ins:начало:400:124',
#  'провести:НАКАНУНЕ:Gen:поездка:314:80',
#  'провести:РАДИ:Gen:присоединение:13:4',
#  'провести:МЕЖДУ:Gen:нога:28:7',
#  'провести:ОТ:Gen:имя:139:28',
#  'провести:ВОЗЛЕ:Gen:здание:68:20',
#  'провести:ВОПРЕКИ:Dat:запрет:44:13',
#  'провести:ПОПЕРЕК:Gen:горло:9:2',
#  'провести:ВНУТРЬ:Gen:дом:13:4',
#  'провести:ВБЛИЗИ:Gen:граница:37:8',
#  'провести:НАПРОТИВ:Gen:здание:13:4',
#  'приходить:К:Dat:вывод:8118:1048',
#  'приходить:В:Acc:голова:5351:1488',
#  'приходить:С:Gen:работа:735:154',
#  'приходить:СО:Ins:время:142:39',
#  'приходить:СО:Gen:мир:127:41',
#  'приходить:У:Gen:человек:15:3',
#  'приходить:ВО:Loc:сон:577:53',
#  'приходить:СРЕДИ:Gen:ночь:18:5',
#  'приходить:ДО:Gen:пора:47:13',
#  'приходить:ВО ВРЕМЯ:Gen:еда:212:17',
#  'приходить:СО СТОРОНЫ:Gen:залив:61:5',
#  'приходить:СПУСТЯ:Acc:время:68:22',
#  'приходить:ВСЛЕДСТВИЕ:Gen:война:9:2',
#  'приходить:ВОПРЕКИ:Dat:ожидание:5:1',
#  'принять:_:Nom:решение:113100:18313',
#  'принять:_:Gen:человек:1786:373',
#  'принять:_:Loc:.:353:104',
#  'принять:СО:Ins:время:181:59',
#  'принять:НА:Acc:вооружение:17850:4024',
#  'принять:ПО:Loc:окончание:1412:411',
#  'принять:К:Dat:сведение:32833:2503',
#  'принять:ВНЕ:Gen:зависимость:92:21',
#  'принять:О:Acc:решение:15:2',
#  'принять:БЕЗ:Gen:голосование:5203:324',
#  'принять:ОТ:Gen:имя:400:117',
#  'принять:ВО:Loc:чтение:3069:751',
#  'принять:ВО:Acc:внимание:12524:1421',
#  'принять:ИЗ:Gen:рука:1342:239',
#  'принять:ДО:Gen:конец:1886:240',
#  'принять:ОКОЛО:Gen:человек:488:105',
#  'принять:ВОКРУГ:Gen:здание:4:1',
#  'состояться:_:Loc:.:117:32',
#  'состояться:НА:Acc:день:1106:97',
#  'состояться:С:Gen:космодром:384:46',
#  'состояться:У:Gen:здание:300:82',
#  'состояться:ВО:Acc:вторник:1931:74',
#  'состояться:СРЕДИ:Gen:участник:7:2',
#  'состояться:ДО:Gen:конец:1017:117',
#  'состояться:В СООТВЕТСТВИИ С:Ins:понимание:213:65',
#  'состояться:ЗА:Acc:день:524:142',
#  'состояться:О:Loc:роман:5:1',
#  'состояться:В СВЯЗИ С:Ins:рассмотрение:370:25',
#  'состояться:ВНЕ:Gen:зависимость:44:14',
#  'состояться:ОТ:Gen:имя:12:2',
#  'состояться:С ПОМОЩЬЮ:Gen:пианист:10:3',
#  'идти:_:Nom:речь:235546:11305',
#  'идти:_:Par:противу:8:2',
#  'идти:ПО:Loc:окончание:39:8',
#  'идти:О:Loc:боец:6764:2040',
#  'идти:О:Acc:бок:281:8',
#  'идти:ДО:Gen:конец:2121:351',
#  'идти:КО:Dat:дно:555:46',
#  'идти:ОБ:Acc:рука:48:2',
#  'идти:МИМО:Gen:дом:175:37',
#  'идти:ПОД:Ins:флаг:1430:308',
#  'идти:ИЗО:Gen:рот:248:18',
#  'идти:С ПОМОЩЬЮ:Gen:наклейка:70:6',
#  'понравиться:В:Loc:целое:215:52',
#  'понравиться:С:Gen:взгляд:362:44',
#  'понравиться:ПО:Dat:слово:211:43',
#  'понравиться:ДО:Gen:степень:21:5',
#  'понравиться:СО:Ins:время:18:1',
#  'понравиться:В КАЧЕСТВЕ:Gen:клиент:4:1',
#  'понравиться:ВО:Loc:случай:25:8',
#  'понравиться:БЕЗ:Gen:сомнение:20:4',
#  'понравиться:СОГЛАСНО:Dat:опрос:5:1',
#  'понравиться:ИЗО:Gen:сила:6:1',
#  'строить:ПО:Loc:окончание:9:2',
#  'строить:НА:Loc:основа:1483:482',
#  'строить:С:Gen:нуль:365:80',
#  'строить:С:Ins:учёт:257:66',
#  'строить:ПОД:Acc:ключ:22:4',
#  'строить:ВО:Acc:время:54:5',
#  'строить:ПРИ:Loc:поддержка:158:13',
#  'строить:ОТНОСИТЕЛЬНО:Gen:будущее:13:2',
#  'строить:В СВЯЗИ С:Ins:сокращение:10:2',
#  'строить:ВО ВРЕМЯ:Gen:война:34:4',
#  'организовать:С:Ins:цель:2609:392',
#  'организовать:_:Loc:.:185:12',
#  'организовать:ПО:Acc:сторона:217:3',
#  'организовать:ЗА СЧЕТ:Gen:средство:61:20',
#  'организовать:В СВЯЗИ С:Ins:проведение:107:28',
#  'организовать:В ХОДЕ:Gen:сессия:315:51',
#  'организовать:ОТ:Gen:имя:127:31',
#  'организовать:У:Gen:здание:113:17',
#  'организовать:ПО СРАВНЕНИЮ С:Ins:прошлое:4:1',
#  'публиковать:ПОД:Ins:псевдоним:251:78',
#  'публиковать:ВО:Acc:вторник:38:3',
#  'публиковать:ОТ:Gen:имя:44:6',
#  'публиковать:СО:Ins:ссылка:166:2',
#  'публиковать:ОБ:Loc:оппозиционер:9:1',
#  'публиковать:ПО МЕРЕ:Gen:поступление:8:2',
#  'публиковать:ПРО:Acc:пытка:4:1',
#  'уменьшиться:_:Ins:образ:471:20',
#  'уменьшиться:_:Loc:.:27:3',
#  'уменьшиться:ЗА:Ins:предел:13:2',
#  'уменьшиться:ВО:Acc:вторник:17:2',
#  'уменьшиться:СО:Ins:время:87:3',
#  'уменьшиться:СО:Gen:время:30:3',
#  'уменьшиться:С:Gen:начало:227:46',
#  'уменьшиться:ДЛЯ:Gen:сравнение:12:3',
#  'уменьшиться:В СООТВЕТСТВИИ С:Ins:условие:97:7',
#  'уменьшиться:КО:Dat:время:5:1',
#  'уменьшиться:ВВИДУ:Gen:сокращение:5:1',
#  'стать:_:Loc:.:595:55',
#  'стать:СО:Ins:время:6636:83',
#  'стать:ПО СРАВНЕНИЮ С:Ins:год:106:33',
#  'стать:БЕЗ:Gen:сомнение:278:91',
#  'стать:ИЗО:Gen:сила:83:4',
#  'стать:МЕЖДУ:Gen:нога:27:5',
#  'иметь:_:Par:вид:50:4',
#  'иметь:ПО:Acc:день:100:23',
#  'иметь:ПОД:Ins:рука:913:279',
#  'иметь:ПО МЕРЕ:Gen:необходимость:26:8',
#  'иметь:СО:Ins:ссылка:366:53',
#  'иметь:СО:Gen:время:265:85',
#  'иметь:В СВЯЗИ С:Ins:рассмотрение:584:31',
#  'иметь:ВО ВРЕМЯ:Gen:война:253:64',
#  'иметь:О:Acc:представление:12:1',
#  'иметь:СРЕДИ:Gen:награда:264:64',
#  'иметь:ВО:Acc:время:359:20',
#  'иметь:ПРО:Acc:запас:34:1',
#  'иметь:ОТНОСИТЕЛЬНО:Gen:время:21:5',
#  'иметь:НАКАНУНЕ:Gen:война:29:8',
#  'укрываться:_:Nom:боевик:334:77',
#  'укрываться:_:Ins:одеяло:125:33',
#  'укрываться:_:Acc:время:52:9',
#  'укрываться:ПО:Dat:данные:125:15',
#  'укрываться:С:Ins:голова:32:4',
#  'укрываться:НА:Loc:территория:164:20',
#  'укрываться:В ТЕЧЕНИЕ:Gen:день:4:1',
#  'укрываться:ПЕРЕД:Ins:арест:4:1',
#  'характеризоваться:В:Loc:целое:307:81',
#  'характеризоваться:К:Dat:сожаление:22:6',
#  'характеризоваться:В СООТВЕТСТВИИ С:Ins:информация:48:6',
#  'характеризоваться:В ТЕЧЕНИЕ:Gen:период:28:8',
#  'характеризоваться:СО:Gen:время:14:2',
#  'характеризоваться:В КАЧЕСТВЕ:Gen:преступление:8:2',
#  'проводить:_:Ins:взгляд:5843:1765',
#  'проводить:_:Gen:время:354:111',
#  'проводить:_:Loc:.:36:8',
#  'проводить:С:Ins:цель:3131:617',
#  'проводить:В ХОДЕ:Gen:сессия:190:43',
#  'проводить:СРЕДИ:Gen:население:161:42',
#  'проводить:ВБЛИЗИ:Gen:граница:25:7',
#  'проводить:ОТ:Gen:имя:200:19',
#  'проводить:ПО МЕРЕ:Gen:необходимость:262:24',
#  'проводить:ВОЗЛЕ:Gen:здание:29:9',
#  'проводить:О:Acc:бок:23:3',
#  'проводить:КО:Dat:вход:8:2',
#  'проводить:БЕЗО:Gen:ремикс:4:1',
#  'объясняться:ВО:Loc:многое:1287:12',
#  'объясняться:НА:Acc:взгляд:123:18',
#  'объясняться:В ТЕЧЕНИЕ:Gen:период:11:3',
#  'объясняться:БЕЗ:Gen:сомнение:11:2',
#  'объясняться:ИЗ:Gen:язык:8:1',
#  'напоминать:_:Par:вид:4:1',
#  'напоминать:ВО:Loc:многое:921:42',
#  'напоминать:В:Loc:связь:1550:440',
#  'напоминать:ПО:Acc:день:20:1',
#  'напоминать:СО:Gen:сторона:28:9',
#  'напоминать:СО:Ins:ссылка:47:4',
#  'напоминать:ДО:Gen:боль:328:42',
#  'напоминать:БЕЗ:Gen:конец:43:11',
#  'напоминать:ПОД:Ins:микроскоп:13:4',
#  'напоминать:ПОД:Acc:поп:54:4',
#  'напоминать:СРЕДИ:Gen:подозреваемый:8:2',
#  'напоминать:РАДИ:Gen:справедливость:4:1',
#  'напоминать:В СООТВЕТСТВИИ С:Ins:предложение:10:2',
#  'определить:ВО:Loc:многое:970:38',
#  'определить:ПО:Acc:сторона:5:1',
#  'определить:ПО:Loc:окончание:142:33',
#  'определить:СОГЛАСНО:Dat:положение:70:18',
#  'определить:ИЗ:Gen:расчёт:76:18',
#  'определить:ДО:Gen:конец:257:55',
#  'определить:БЕЗ:Gen:труд:140:35',
#  'определить:ВМЕСТО:Gen:свобода:14:3',
#  'определить:ВНЕ:Gen:зависимость:14:3',
#  'определить:НАД:Ins:поле:13:3',
#  'определить:ВВИДУ:Gen:отсутствие:10:2',
#  'определить:ОКОЛО:Gen:год:7:1',
#  'определить:НАКАНУНЕ:Gen:проведение:9:2',
#  'выбирать:МЕЖДУ:Gen:коалиция:4:1',
#  'выбирать:ПО:Loc:окончание:30:4',
#  'выбирать:С:Ins:учёт:285:49',
#  'выбирать:БЕЗ:Gen:вмешательство:47:14',
#  'выбирать:ОКОЛО:Gen:треть:7:2',
#  'выбирать:ПУТЕМ:Gen:голосование:94:24',
#  'выбирать:ВНЕ:Gen:зависимость:24:2',
#  'выбирать:ПО СРАВНЕНИЮ С:Ins:немец:25:2',
#  'выбирать:ПЕРЕД:Ins:начало:31:6',
#  'выбирать:В ХОДЕ:Gen:выбор:89:26',
#  'выбирать:В ТЕЧЕНИЕ:Gen:год:13:4',
#  'обсуждаться:В:Acc:время:591:184',
#  'обсуждаться:_:Nom:вопрос:19349:3222',
#  'обсуждаться:ВО:Acc:вторник:135:10',
#  'обсуждаться:К:Dat:пример:34:9',
#  'обсуждаться:ПО:Dat:слово:2418:570',
#  'обсуждаться:ПО:Acc:день:8:1',
#  'обсуждаться:СО:Gen:время:29:4',
#  'обсуждаться:БЕЗ:Gen:участие:876:6',
#  'вызывать:ВО:Loc:мир:195:59',
#  'вызывать:ВО:Acc:время:42:12',
#  'вызывать:ПО:Acc:день:60:7',
#  'вызывать:С:Ins:учёт:285:46',
#  'вызывать:В КАЧЕСТВЕ:Gen:свидетель:110:5',
#  'вызывать:ВНЕ:Gen:зависимость:27:6',
#  'вызывать:СО:Ins:время:31:5',
#  'вызывать:ЗА:Ins:предел:38:7',
#  'вызывать:ПЕРЕД:Ins:матч:17:5',
#  'вызывать:ЗА СЧЕТ:Gen:импорт:4:1',
#  'попросить:_:Nom:президент:20281:1182',
#  'попросить:_:Gen:помощь:21187:2353',
#  'попросить:_:Dat:власть:35:9',
#  'попросить:_:Par:чай:47:5',
#  'попросить:ОТ:Gen:имя:149:20',
#  'попросить:ЧЕРЕЗ:Acc:время:82:25',
#  'попросить:ПОД:Acc:конец:24:5',
#  'попросить:ПОД:Ins:предлог:50:15',
#  'попросить:О:Loc:помощь:1925:513',
#  'попросить:ОБ:Acc:убежище:7:1',
#  'попросить:СО:Gen:сторона:35:7',
#  'попросить:ПЕРЕД:Ins:смерть:149:40',
#  'попросить:К:Dat:телефон:259:29',
#  'попросить:ВМЕСТО:Gen:ответ:18:4',
#  'попросить:ИЗ:Gen:бюджет:35:11',
#  'попросить:СКВОЗЬ:Acc:слеза:8:2',
#  'попросить:ВОПРЕКИ:Dat:ожидание:4:1',
#  'отметить:_:Loc:.:38:6',
#  'отметить:НА:Acc:вопрос:329:83',
#  'отметить:С:Ins:удовлетворение:9106:777',
#  'отметить:В СВЯЗИ С:Ins:вопрос:203:18',
#  'отметить:БЕЗ:Gen:удовольствие:122:36',
#  'отметить:СО:Gen:сторона:657:33',
#  'отметить:СО:Ins:ссылка:163:15',
#  'отметить:ВО:Acc:вторник:159:20',
#  'отметить:ПОД:Ins:название:68:21',
#  'отметить:РАДИ:Gen:справедливость:360:20',
#  'отметить:ОТ:Gen:имя:38:3',
#  'отметить:МЕЖДУ:Ins:дело:16:3',
#  'отметить:ПУТЕМ:Gen:проведение:14:4',
#  'измениться:_:Nom:ситуация:10453:3382',
#  'измениться:_:Acc:раз:88:29',
#  'измениться:_:Ins:образ:1942:66',
#  'измениться:С:Gen:момент:2962:312',
#  'измениться:СО:Gen:время:645:60',
#  'измениться:СО:Ins:время:496:35',
#  'измениться:ДО:Gen:неузнаваемость:1043:38',
#  'находиться:НА:Acc:момент:9242:1219',
#  'находиться:МЕЖДУ:Gen:нога:30:8',
#  'находиться:_:Ins:образ:1688:273',
#  'находиться:_:Acc:время:8856:1173',
#  'находиться:_:Par:зад:12:2',
#  'находиться:У:Gen:власть:6017:632',
#  'находиться:ПОД:Acc:залог:47:12',
#  'находиться:С:Ins:визит:5669:600',
#  'находиться:СО:Gen:время:461:98',
#  'находиться:НАД:Ins:территория:351:106',
#  'находиться:ЧЕРЕЗ:Acc:дорога:235:29',
#  'находиться:ВО ВРЕМЯ:Gen:война:1345:210',
#  'находиться:ВО:Acc:время:508:136',
#  'находиться:В ХОДЕ:Gen:война:163:32',
#  'находиться:В СВЯЗИ С:Ins:участие:288:77',
#  'находиться:ИЗ:Gen:число:115:20',
#  'находиться:ВЫШЕ:Gen:отметка:51:13',
#  'находиться:ПО СРАВНЕНИЮ С:Ins:страна:24:7',
#  'находиться:ВОПРЕКИ:Dat:договорённость:62:10',
#  'находиться:КО:Dat:время:70:6',
#  'находиться:ВСЛЕДСТВИЕ:Gen:катастрофа:25:6',
#  'находиться:О:Acc:бок:25:1',
#  'находиться:ПРОТИВ:Gen:воля:17:5',
#  'находиться:ПОСРЕДСТВОМ:Gen:восприятие:7:2',
#  'оставаться:_:Gen:время:1175:244',
#  'оставаться:_:Acc:время:5258:1083',
#  'оставаться:В:Acc:время:2990:763',
#  'оставаться:ВО:Acc:время:153:40',
#  'оставаться:ПО:Acc:день:1812:58',
#  'оставаться:У:Gen:власть:1030:250',
#  'оставаться:С:Ins:учёт:481:139',
#  'оставаться:СО:Gen:время:264:38',
#  'оставаться:СРЕДИ:Gen:стать:309:31',
#  'оставаться:ВО ВРЕМЯ:Gen:война:145:28',
#  'оставаться:В СВЯЗИ С:Ins:отсутствие:28:7',
#  'оставаться:ВВИДУ:Gen:отсутствие:39:8',
#  'оставаться:СПУСТЯ:Acc:год:60:17',
#  'оставаться:КО:Dat:время:22:3',
#  'оставаться:ИЗО:Gen:день:9:1',
#  'оставаться:ПО ОТНОШЕНИЮ К:Dat:скорость:16:2',
#  'оставаться:ОБ:Loc:организатор:30:1',
#  'оставаться:ПРО:Acc:запас:8:1',
#  'отмечать:_:Loc:.:31:4',
#  'отмечать:НА:Acc:день:92:25',
#  'отмечать:ВО:Loc:мир:118:36',
#  'отмечать:С:Ins:удовлетворение:19642:3416',
#  'отмечать:С:Gen:сторона:225:49',
#  'отмечать:СО:Gen:сторона:149:21',
#  'отмечать:СО:Ins:ссылка:1812:8',
#  'отмечать:ВОПРЕКИ:Dat:мнение:5:1',
#  'отмечать:ОТ:Gen:имя:14:2',
#  'отмечать:В СВЯЗИ С:Ins:вопрос:82:25',
#  'отмечать:РАДИ:Gen:справедливость:9:1',
#  'отмечать:ПОСРЕДСТВОМ:Gen:разработка:15:3',
#  'посвящать:_:Nom:газета:638:68',
#  'посвящать:БЕЗ:Gen:остаток:15:2',
#  'посвящать:В ТЕЧЕНИЕ:Gen:год:7:2',
#  'обстоять:_:Nom:дело:18901:733',
#  'обстоять:_:Gen:дело:301:2',
#  'обстоять:_:Ins:образ:1319:10',
#  'обстоять:С:Gen:точка:55:15',
#  'обстоять:НА:Loc:дело:853:107',
#  'обстоять:ПРИ:Loc:замер:83:4',
#  'обстоять:ИЗ:Gen:страна:136:29',
#  'обстоять:К:Dat:сожаление:75:13',
#  'обстоять:ВО:Acc:время:6:1',
#  'касаться:ПО:Dat:слово:1078:259',
#  'касаться:С:Gen:точка:171:50',
#  'касаться:НА:Acc:раз:138:30',
#  'касаться:ВНЕ:Gen:зависимость:57:2',
#  'касаться:ЗА:Ins:предел:26:8',
#  'касаться:ЗА:Acc:период:50:10',
#  'касаться:ВО ВРЕМЯ:Gen:удар:129:9',
#  'касаться:В ТЕЧЕНИЕ:Gen:период:43:6',
#  'ждать:С:Ins:нетерпение:12127:433',
#  'ждать:ПО:Dat:слово:1185:392',
#  'ждать:ПО:Acc:сторона:96:21',
#  'ждать:ВО:Loc:двор:252:66',
#  'ждать:ВО:Acc:вторник:76:9',
#  'ждать:БЛАГОДАРЯ:Dat:методика:16:4',
#  'ждать:СО:Gen:день:267:25',
#  'ждать:СО:Ins:страх:206:11',
#  'ждать:В ХОДЕ:Gen:формирование:36:10',
#  'ждать:НАД:Ins:залив:4:1',
#  'протекать:_:Nom:река:7893:1342',
#  'протекать:_:Acc:деревня:445:112',
#  'протекать:ПОД:Acc:дудка:10:3',
#  'протекать:ПО:Dat:территория:7276:1885',
#  'протекать:ПО:Acc:сторона:12:2',
#  'протекать:ПО:Loc:область:10:3',
#  'протекать:МИМО:Gen:деревня:52:9',
#  'протекать:ПРИ:Loc:температура:89:25',
#  'протекать:ОТ:Gen:исток:19:5',
#  'протекать:ВО ВРЕМЯ:Gen:дождь:15:2',
#  'протекать:СКВОЗЬ:Acc:палец:11:3',
#  'протекать:ВДОЛЬ:Gen:граница:123:32',
#  'бороться:С:Acc:минута:10:1',
#  'бороться:ДО:Gen:конец:1235:91',
#  'бороться:ПО:Dat:слово:359:99',
#  'бороться:ПО:Loc:завершение:8:1',
#  'бороться:ИЗ:Gen:сила:123:7',
#  'бороться:ВО ВРЕМЯ:Gen:война:72:17',
#  'бороться:ПРИ:Loc:поддержка:61:10',
#  'бороться:ПО МЕРЕ:Gen:сила:40:5',
#  'бороться:МЕЖДУ:Ins:желание:4:1',
#  'бороться:ВНЕ:Gen:зависимость:28:1',
#  'бороться:СПУСТЯ:Acc:год:11:2',
#  'бороться:ПО ПОВОДУ:Gen:цена:6:1',
#  'приходиться:НА:Acc:доля:15209:1477',
#  'приходиться:К:Dat:сожаление:599:150',
#  'приходиться:ВО:Acc:время:284:39',
#  'приходиться:С:Acc:десяток:7:1',
#  'приходиться:ЗА:Ins:неимение:61:11',
#  'приходиться:СО:Ins:время:24:4',
#  'приходиться:ВМЕСТО:Gen:снег:41:6',
#  'приходиться:ВВИДУ:Gen:отсутствие:16:3',
#  'приходиться:ПРОТИВ:Gen:воля:6:1',
#  'приходиться:КО:Dat:двор:36:6',
#  'приходиться:ЗА СЧЕТ:Gen:средство:9:2',
#  'приходиться:ВНЕ:Gen:зависимость:12:3',
#  'видеть:_:Nom:человек:4545:1394',
#  'видеть:_:Ins:глаз:5023:975',
#  'видеть:В:Acc:раз:5214:1329',
#  'видеть:ВОЗЛЕ:Gen:дом:74:10',
#  'видеть:ИЗ:Gen:окно:932:41',
#  'видеть:ВО:Loc:сон:13736:200',
#  'видеть:СО:Gen:сторона:630:174',
#  'видеть:НАД:Ins:голова:78:8',
#  'видеть:ВДОЛЬ:Gen:дорога:23:5',
#  'видеть:ПО МЕРЕ:Gen:приближение:11:3',
#  'видеть:ИЗО:Gen:день:49:1',
#  'произойти:_:Loc:.:101:26',
#  'произойти:_:Par:толк:7:2',
#  'произойти:ПО:Loc:окончание:141:40',
#  'произойти:ЗА:Ins:предел:154:39',
#  'произойти:ВО:Acc:вторник:2044:238',
#  'произойти:СО:Gen:время:905:72',
#  'произойти:НАПРОТИВ:Gen:дом:66:20',
#  'произойти:ДО:Gen:конец:395:125',
#  'произойти:В КАЧЕСТВЕ:Gen:свидетельство:4:1',
#  'произойти:В ВИДЕ:Gen:голосование:4:1',
#  'произойти:КО:Dat:время:14:2',
#  'произойти:ПРОТИВ:Gen:воля:19:5',
#  'вывести:_:Acc:войско:6281:1596',
#  'вывести:_:Loc:.:31:5',
#  'вывести:С:Gen:территория:1686:223',
#  'вывести:СОГЛАСНО:Dat:документ:169:45',
#  'вывести:ДО:Gen:конец:435:30',
#  'вывести:ПОД:Ins:имя:187:62',
#  'вывести:ПОД:Acc:рука:90:16',
#  'вывести:ВОПРЕКИ:Dat:пожелание:7:2',
#  'вывести:ВО:Acc:двор:289:65',
#  'вывести:ПРОТИВ:Gen:воля:10:3',
#  'вывести:В КАЧЕСТВЕ:Gen:капитан:56:15',
#  'вывести:ВНЕ:Gen:зависимость:12:2',
#  'вывести:МИМО:Gen:орбита:12:1',
#  'вывести:БЕЗО:Gen:условие:4:1',
#  'вывести:ВОКРУГ:Gen:точка:5:1',
#  'вывести:ИЗО:Gen:лёд:11:1',
#  'вскрыться:НАКАНУНЕ:Gen:саммит:8:1',
#  'вскрыться:СПУСТЯ:Acc:год:4:1',
#  'комментировать:_:Ins:образ:188:44',
#  'комментировать:В:Loc:интервью:486:160',
#  'комментировать:ПОД:Ins:заголовок:15:3',
#  'комментировать:ПО:Dat:просьба:176:28',
#  'комментировать:С:Gen:точка:32:8',
#  'комментировать:ВО:Acc:вторник:30:1',
#  'комментировать:ПОСЛЕ:Gen:выбор:38:10',
#  'комментировать:ЗА:Ins:кадр:17:3',
#  'комментировать:ЗА:Acc:время:4:1',
#  'комментировать:ПОСРЕДСТВОМ:Gen:работа:8:1',
#  'комментировать:ПО МЕРЕ:Gen:необходимость:12:2',
#  'брать:_:Dat:человек:50:8',
#  'брать:В:Acc:рука:5841:1079',
#  'брать:ВО:Acc:внимание:331:40',
#  'брать:ПОД:Ins:председательство:158:18',
#  'брать:ОТ:Gen:жизнь:376:81',
#  'брать:ВОЗЛЕ:Gen:село:28:9',
#  'брать:ВМЕСТО:Gen:масло:28:6',
#  'брать:ИЗО:Gen:рот:6:1',
#  'брать:В СООТВЕТСТВИИ С:Ins:план:47:14',
#  'брать:ПРО:Acc:запас:12:1',
#  'злоупотреблять:_:Gen:человек:8:2',
#  'злоупотреблять:В:Loc:цель:65:17',
#  'злоупотреблять:НА:Loc:протяжение:22:5',
#  'злоупотреблять:ПРИ:Loc:заключение:27:4',
#  'злоупотреблять:С:Ins:цель:38:1',
#  'злоупотреблять:ВО ВРЕМЯ:Gen:владение:11:3',
#  'злоупотреблять:ВО:Loc:мир:4:1',
#  'остаться:ПО:Loc:окончание:306:73',
#  'остаться:ИЗ:Gen:состав:269:70',
#  'остаться:С:Gen:время:749:212',
#  'остаться:С:Acc:десяток:24:4',
#  'остаться:ПОД:Acc:конец:37:10',
#  'остаться:ПРИ:Loc:мнение:656:140',
#  'остаться:СО:Gen:время:1313:66',
#  'остаться:СОГЛАСНО:Dat:ведомость:337:91',
#  'остаться:О:Acc:чудо:4:1',
#  'остаться:ПРО:Acc:запас:16:3',
#  'остаться:ВОПРЕКИ:Dat:требование:36:9',
#  'остаться:ВБЛИЗИ:Gen:уровень:20:6',
#  'остаться:ВВИДУ:Gen:отсутствие:12:3',
#  'расследовать:_:Acc:дело:6115:2025',
#  'расследовать:_:Ins:образ:285:53',
#  'расследовать:ДО:Gen:конец:62:5',
#  'расследовать:В ТЕЧЕНИЕ:Gen:период:13:4',
#  'расследовать:БЕЗ:Gen:нарушение:37:6',
#  'расследовать:ВНЕ:Gen:зависимость:7:1',
#  'расследовать:СО:Ins:тщательность:4:1',
#  'совершить:_:Loc:.:143:27',
#  'совершить:_:Dat:хиротония:523:33',
#  'совершить:ИЗ:Gen:побуждение:776:126',
#  'совершить:НА:Loc:территория:9376:1150',
#  'совершить:НА:Acc:день:439:95',
#  'совершить:ВО:Acc:вторник:514:170',
#  'совершить:ВО ВРЕМЯ:Gen:война:547:174',
#  'совершить:ОТ:Gen:имя:135:10',
#  'совершить:К:Dat:время:687:211',
#  'совершить:СО:Gen:время:83:20',
#  'совершить:ВОЗЛЕ:Gen:дом:97:22',
#  'совершить:ВСЛЕДСТВИЕ:Gen:исполнение:67:6',
#  'совершить:ПОСРЕДИ:Gen:день:5:1',
#  'совершить:КО:Dat:время:7:2',
#  'совершить:СРЕДИ:Gen:день:16:5',
#  'переходить:СО:Ins:время:79:10',
#  'переходить:ИЗ:Gen:рука:2120:187',
#  'переходить:ПРИ:Loc:температура:171:47',
#  'переходить:ПОСЛЕ:Gen:смерть:279:35',
#  'переходить:ВО:Acc:владение:258:34',
#  'переходить:ПОД:Acc:контроль:653:175',
#  'переходить:ЗА СЧЕТ:Gen:наплыв:11:2',
#  'переходить:ВО ВРЕМЯ:Gen:война:184:9',
#  'связать:СО:Gen:время:40:8',
#  'связать:ПО:Acc:день:29:4',
#  'связать:ВО:Loc:многое:2273:76',
#  'связать:ВО:Acc:время:37:9',
#  'связать:ЗА:Ins:спина:967:16',
#  'связать:ДО:Gen:конец:93:28',
#  'связать:ПО СРАВНЕНИЮ С:Ins:период:15:4',
#  'связать:В ТЕЧЕНИЕ:Gen:период:88:11',
#  'связать:ВМЕСТО:Gen:набор:4:1',
#  'связать:НАД:Ins:голова:6:1',
#  'уходить:_:Ins:корень:3022:350',
#  'уходить:_:Gen:время:161:39',
#  'уходить:С:Ins:голова:290:71',
#  'уходить:ЗА:Acc:горизонт:592:158',
#  'уходить:ВО ВРЕМЯ:Gen:наводнение:95:18',
#  'уходить:ДЛЯ:Gen:защита:35:7',
#  'уходить:СКВОЗЬ:Acc:палец:42:4',
#  'уходить:НАД:Ins:голова:7:2',
#  'уходить:О:Loc:причина:5:1',
#  'справляться:В:Acc:время:93:26',
#  'справляться:ПО:Acc:день:9:2',
#  'справляться:СОГЛАСНО:Dat:исследование:7:2',
#  'справляться:О:Loc:здоровье:152:36',
#  'справляться:ВО:Acc:время:5:1',
#  'справляться:ПОД:Ins:руководство:13:2',
#  'слышать:_:Gen:раз:151:41',
#  'слышать:ИЗ:Gen:уста:600:60',
#  'слышать:ЗА:Ins:спина:460:60',
#  'слышать:ВО:Loc:сон:863:67',
#  'слышать:СКВОЗЬ:Acc:сон:290:67',
#  'слышать:СО:Gen:сторона:177:18',
#  'слышать:БЕЗ:Gen:сомнение:32:10',
#  'слышать:ПОД:Acc:утро:10:2',
#  'слышать:ЗА СЧЕТ:Gen:применение:6:1',
#  'доверять:_:Dat:человек:1222:312',
#  'доверять:В:Acc:время:88:19',
#  'доверять:ДО:Gen:конец:106:23',
#  'доверять:СО:Ins:время:11:2',
#  'доверять:ПРИ:Loc:решение:40:6',
#  'доверять:ВО:Acc:время:6:1',
#  'доверять:ДЛЯ:Gen:сравнение:8:1',
#  'доверять:ВО ВРЕМЯ:Gen:болезнь:6:1',
#  'доверять:ПОД:Acc:слово:4:1',
#  'решить:_:Loc:.:39:8',
#  'решить:ЗА:Acc:время:269:63',
#  'решить:ПУТЕМ:Gen:переговоры:231:75',
#  'решить:ДО:Gen:конец:569:94',
#  'решить:СО:Ins:время:166:12',
#  'решить:ВОЗЛЕ:Gen:дом:5:1',
#  'решить:МЕЖДУ:Ins:дело:13:4',
#  'решить:ВВИДУ:Gen:отсутствие:40:12',
#  'решить:ИЗО:Gen:сила:6:1',
#  'обладать:ПО:Acc:день:12:2',
#  'обладать:ВО:Acc:время:28:1',
#  'обладать:С:Ins:учёт:95:21',
#  'обладать:БЕЗ:Gen:различие:129:35',
#  'обладать:ПЕРЕД:Ins:начало:9:2',
#  'обладать:ПОД:Acc:стать:7:1',
#  'пользоваться:_:Gen:человек:298:40',
#  'пользоваться:БЛАГОДАРЯ:Dat:качество:116:34',
#  'пользоваться:ВО:Loc:мир:409:60',
#  'пользоваться:ВО:Acc:время:142:19',
#  'пользоваться:ВНЕ:Gen:зависимость:41:11',
#  'пользоваться:СО:Gen:время:74:10',
#  'пользоваться:ИЗО:Gen:день:8:2',
#  'пользоваться:ПО МЕРЕ:Gen:необходимость:22:6',
#  'пользоваться:ВВИДУ:Gen:отсутствие:8:2',
#  'пользоваться:В ВИДЕ:Gen:исключение:5:1',
#  'отправиться:_:Acc:раз:201:34',
#  'отправиться:_:Loc:.:89:4',
#  'отправиться:ПО:Loc:окончание:339:85',
#  'отправиться:ДО:Gen:конец:110:19',
#  'отправиться:СО:Gen:станция:100:10',
#  'отправиться:ПЕРЕД:Ins:начало:37:8',
#  'отправиться:ПРИ:Loc:поддержка:63:20',
#  'отправиться:ВО:Loc:половина:114:15',
#  'отправиться:ВО ВРЕМЯ:Gen:война:60:17',
#  'отправиться:ВОКРУГ:Gen:свет:16:3',
#  'отправиться:КО:Dat:двор:89:14',
#  'отправиться:ПРИ ПОМОЩИ:Gen:родитель:5:1',
#  'отправиться:МИМО:Gen:дом:8:1',
#  'отправиться:ВВИДУ:Gen:отсутствие:7:1',
#  'отправиться:НАД:Ins:голова:5:1',
#  'встречаться:ДЛЯ:Gen:обсуждение:453:55',
#  'встречаться:ПОД:Ins:название:126:31',
#  'встречаться:ОКОЛО:Gen:год:104:17',
#  'встречаться:МЕЖДУ:Ins:заявление:50:12',
#  'заехать:В:Loc:половина:154:44',
#  'заехать:_:Acc:раз:72:18',
#  'заехать:ВО:Acc:двор:277:12',
#  'заехать:ВО:Loc:половина:16:3',
#  'заехать:ОТ:Gen:душа:15:2',
#  'заехать:СО:Gen:сила:22:7',
#  'заехать:МЕЖДУ:Gen:нога:13:3',
#  'заехать:БЕЗ:Gen:предупреждение:13:3',
#  'узнать:_:Gen:дело:109:30',
#  'узнать:НА:Loc:сайт:728:193',
#  'узнать:НА:Acc:день:379:61',
#  'узнать:БЕЗ:Gen:труд:368:49',
#  'узнать:СО:Gen:слово:98:25',
#  'узнать:СО:Ins:время:147:6',
#  'узнать:ДО:Gen:конец:95:12',
#  'узнать:МЕЖДУ:Ins:дело:6:1',
#  'предложить:_:Loc:.:126:8',
#  'предложить:ПОД:Acc:конец:57:9',
#  'предложить:ВО:Acc:вторник:191:18',
#  'предложить:ПО:Loc:окончание:132:43',
#  'предложить:СО:Gen:сторона:243:12',
#  'предложить:У:Gen:скала:76:7',
#  'предложить:КО:Dat:чтение:94:3',
#  'предложить:ПЕРЕД:Ins:начало:61:20',
#  'предложить:В ВИДЕ:Gen:опция:38:5',
#  'предложить:ОТ:Gen:имя:385:37',
#  'предложить:ВНЕ:Gen:зависимость:13:2',
#  'предложить:МЕЖДУ:Ins:дело:11:1',
#  'предложить:ПУТЕМ:Gen:создание:14:3',
#  'ехать:ПО:Loc:окончание:13:2',
#  'ехать:_:Gen:фургон:132:24',
#  'ехать:_:Loc:комфорт:13:4',
#  'ехать:БЕЗ:Gen:остановка:121:29',
#  'ехать:ЗА:Ins:руль:314:86',
#  'ехать:СО:Ins:скорость:710:27',
#  'ехать:В КАЧЕСТВЕ:Gen:пассажир:72:9',
#  'ехать:ВО:Loc:сон:151:46',
#  'ехать:У:Gen:человек:13:4',
#  'ехать:МЕЖДУ:Gen:сосна:5:1',
#  'ехать:ОКОЛО:Gen:час:86:23',
#  'ехать:ВПЕРЕДИ:Gen:колонна:35:10',
#  'ехать:В СВЯЗИ С:Ins:ситуация:4:1',
#  'продолжить:_:Loc:.:39:8',
#  'продолжить:ПО:Dat:слово:1340:435',
#  'продолжить:НА:Loc:сессия:3024:690',
#  'продолжить:НА:Acc:день:186:34',
#  'продолжить:ПОД:Ins:руководство:277:28',
#  'продолжить:ВО:Acc:вторник:241:16',
#  'продолжить:В ХОДЕ:Gen:сессия:314:43',
#  'продолжить:ВНЕ:Gen:зависимость:59:7',
#  'продолжить:СО:Gen:сторона:66:6',
#  'продолжить:ПО ОТНОШЕНИЮ К:Dat:евро:10:2',
#  'писать:_:Nom:газета:59815:16882',
#  'писать:_:Loc:.:134:14',
#  'писать:О:Loc:влияние:4091:482',
#  'писать:О:Acc:статья:9:2',
#  'писать:ВО:Acc:вторник:1090:97',
#  'писать:ПО:Dat:повод:1095:291',
#  'писать:ПО:Acc:день:14:3',
#  'писать:НА:Loc:язык:2554:798',
#  'писать:СО:Gen:слово:101:23',
#  'писать:СО:Ins:ссылка:23048:14',
#  'писать:ПОД:Ins:псевдоним:1052:127',
#  'писать:ПОД:Acc:диктовка:190:31',
#  'писать:ПРОТИВ:Gen:ветер:13:4',
#  'писать:К:Dat:пример:289:32',
#  'писать:ВМЕСТО:Gen:слово:15:4',
#  'писать:РАДИ:Gen:деньга:16:5',
#  'писать:С ПОМОЩЬЮ:Gen:программа:14:4',
#  'писать:СПУСТЯ:Acc:год:39:12',
#  'писать:БЛАГОДАРЯ:Dat:снимок:43:12',
#  'писать:ИЗО:Gen:день:9:2',
#  'писать:МЕЖДУ:Gen:строка:14:1',
#  'задавать:_:Acc:вопрос:32834:2449',
#  'задавать:_:Gen:вопрос:225:50',
#  'задавать:ЗА:Acc:вопрос:30:6',
#  'задавать:ЗА:Ins:вопрос:14:3',
#  'задавать:ДО:Gen:пора:19:5',
#  'задавать:В КАЧЕСТВЕ:Gen:свидетель:10:2',
#  'задавать:В ВИДЕ:Gen:текст:4:1',
#  'задавать:БЕЗ:Gen:конец:43:3',
#  'задавать:ВМЕСТО:Gen:слово:11:3',
#  'задавать:ПО МЕРЕ:Gen:полёт:4:1',
#  'задавать:О:Loc:защитник:12:3',
#  'составлять:_:Ins:образ:2925:606',
#  'составлять:_:Loc:.:372:14',
#  'составлять:ДЛЯ:Gen:сравнение:1861:185',
#  'составлять:В:Loc:среднее:6036:1974',
#  'составлять:С:Ins:учёт:1710:83',
#  'составлять:С:Acc:десяток:4:1',
#  'составлять:ПО:Acc:день:22:2',
#  'составлять:БЕЗ:Gen:учёт:476:11',
#  'составлять:ВО ВРЕМЯ:Gen:война:65:9',
#  'составлять:КО:Dat:время:33:5',
#  'составлять:ПРОТИВ:Gen:доллар:53:16',
#  'составлять:В ХОДЕ:Gen:торг:59:11',
#  'составлять:ВНЕ:Gen:зависимость:67:5',
#  'составлять:НАКАНУНЕ:Gen:война:28:6',
#  'составлять:ОТНОСИТЕЛЬНО:Gen:отметка:50:5',
#  'составлять:НАД:Ins:уровень:14:3',
#  'назвать:_:Dat:водитель:198:64',
#  'назвать:_:Loc:.:92:5',
#  'назвать:В:Acc:честь:42067:3123',
#  'назвать:ПО:Dat:имя:5130:734',
#  'назвать:ПО:Loc:окончание:83:20',
#  'назвать:С:Ins:натяжка:436:112',
#  'назвать:С:Acc:десяток:33:8',
#  'назвать:СО:Gen:сторона:294:25',
#  'назвать:СО:Ins:ссылка:99:27',
#  'назвать:МЕЖДУ:Ins:эст:5:1',
#  'назвать:О:Loc:действие:10:3',
#  'назвать:ВО:Acc:вторник:207:39',
#  'назвать:ДО:Gen:конец:127:22',
#  'назвать:ВОКРУГ:Gen:свет:4:1',
#  'делиться:_:Dat:впечатление:13:4',
#  'делиться:БЕЗ:Gen:остаток:62:7',
#  'делиться:С:Gen:точка:55:9',
#  'делиться:В:Acc:очередь:992:156',
#  'делиться:ВО ВРЕМЯ:Gen:экскурсия:18:5',
#  'делиться:ВО:Acc:время:18:5',
#  'делиться:СОГЛАСНО:Dat:классификация:32:9',
#  'делиться:СПУСТЯ:Acc:год:11:2',
#  'крыться:_:Nom:причина:3747:709',
#  'крыться:ЗА:Ins:слово:173:42',
#  'крыться:НА:Acc:взгляд:66:9',
#  'крыться:НА:Loc:дело:93:12',
#  'использовать:_:Ins:образ:3480:353',
#  'использовать:ПО:Acc:день:105:6',
#  'использовать:В:Loc:цель:14655:4075',
#  'использовать:С:Ins:цель:2520:456',
#  'использовать:ВНЕ:Gen:зависимость:83:13',
#  'использовать:В СВЯЗИ С:Ins:лечение:592:14',
#  'использовать:ВОПРЕКИ:Dat:интерес:101:18',
#  'использовать:НАКАНУНЕ:Gen:выбор:13:4',
#  'использовать:КО:Dat:время:6:1',
#  'покупать:_:Dat:ребёнок:233:68',
#  'покупать:К:Dat:пример:53:13',
#  'покупать:НА:Acc:деньга:577:106',
#  'покупать:НА:Loc:рынок:873:135',
#  'покупать:В:Loc:магазин:1224:352',
#  'покупать:ЗА:Ins:граница:229:26',
#  'покупать:ПО:Dat:цена:1599:205',
#  'покупать:СО:Ins:скидка:67:3',
#  'покупать:ВМЕСТО:Gen:упаковка:37:6',
#  'покупать:ВО:Loc:сон:289:15',
#  'покупать:ВО:Acc:время:57:3',
#  'покупать:В КАЧЕСТВЕ:Gen:подарок:58:7',
#  'покупать:ПО МЕРЕ:Gen:необходимость:9:2',
#  'покупать:ОКОЛО:Gen:половина:11:3',
#  'покупать:ОТ:Gen:имя:20:5',
#  'покупать:ВОПРЕКИ:Dat:санкция:7:2',
#  'покупать:ВБЛИЗИ:Gen:уровень:4:1',
#  'иметься:_:Ins:образ:613:80',
#  'иметься:В:Loc:распоряжение:15437:4491',
#  'иметься:С:Gen:сторона:549:104',
#  'иметься:ВО:Acc:время:28:3',
#  'иметься:ПОД:Ins:рука:213:69',
#  'иметься:НАКАНУНЕ:Gen:война:12:2',
#  'иметься:КО:Dat:время:14:4',
#  'иметься:ВОКРУГ:Gen:глаз:44:6',
#  'иметься:ПРО:Acc:запас:10:1',
#  'иметься:ПОЗАДИ:Gen:глаз:210:14',
#  'иметься:В ТЕЧЕНИЕ:Gen:период:25:8',
#  'считать:_:Nom:эксперт:35295:11713',
#  'считать:_:Loc:.:29:3',
#  'считать:ПО:Acc:день:95:6',
#  'считать:ЗА:Acc:честь:304:68',
#  'считать:С:Ins:учёт:1262:73',
#  'считать:С:Acc:сделка:13:3',
#  'считать:ПОД:Acc:сила:61:11',
#  'считать:ВО:Loc:случай:538:51',
#  'считать:ВО:Acc:время:48:9',
#  'считать:ВО ВРЕМЯ:Gen:война:26:7',
#  'считать:СО:Gen:сторона:351:75',
#  'считать:СО:Ins:ссылка:24:6',
#  'считать:ПОСРЕДСТВОМ:Gen:возражение:7:1',
#  'считать:ВНЕ:Gen:зависимость:88:14',
#  'считать:ВВИДУ:Gen:отсутствие:43:10',
#  'считать:ВОПРЕКИ:Dat:мнение:30:8',
#  'считать:ЗА СЧЕТ:Gen:человечество:43:2',
#  'считать:КО:Dat:время:6:1',
#  'наблюдаться:ЗА:Ins:предел:28:8',
#  'наблюдаться:НА:Loc:рынок:3099:748',
#  'наблюдаться:СОГЛАСНО:Dat:данные:145:36',
#  'наблюдаться:МЕЖДУ:Ins:страна:70:18',
#  'наблюдаться:ВНЕ:Gen:зависимость:23:2',
#  'наблюдаться:СО СТОРОНЫ:Gen:инвестор:14:4',
#  'наблюдаться:С ПОМОЩЬЮ:Gen:телескоп:11:3',
#  'поступать:_:Ins:образ:1596:496',
#  'поступать:ПО:Loc:окончание:104:13',
#  'поступать:ПО:Acc:день:9:1',
#  'поступать:ПОСЛЕ:Gen:окончание:310:87',
#  'поступать:ПОД:Acc:командование:47:14',
#  'поступать:СОГЛАСНО:Dat:соглашение:410:20',
#  'поступать:СО СТОРОНЫ:Gen:сепаратист:62:8',
#  'поступать:БЕЗ:Gen:экзамен:35:11',
#  'поступать:ВО ВРЕМЯ:Gen:война:33:10',
#  'поступать:ВМЕСТО:Gen:картинка:12:3',
#  'давать:_:Acc:возможность:41834:11601',
#  'давать:_:Gen:деньга:425:96',
#  'давать:НА:Loc:рынок:828:270',
#  'давать:ПО:Loc:окончание:32:9',
#  'давать:ДЛЯ:Gen:начало:443:134',
#  'давать:В КАЧЕСТВЕ:Gen:свидетель:85:22',
#  'давать:С ПОМОЩЬЮ:Gen:средство:16:4',
#  'давать:ПОД:Acc:процент:134:41',
#  'давать:ВНЕ:Gen:зависимость:47:5',
#  'давать:О:Loc:дело:100:19',
#  'давать:РАДИ:Gen:бог:32:4',
#  'давать:ИЗО:Gen:сила:14:2',
#  'давать:ВВИДУ:Gen:округление:15:1',
#  'стараться:_:Ins:сила:1212:328',
#  'стараться:_:Gen:сила:21:6',
#  'стараться:В:Acc:время:668:174',
#  'стараться:ИЗО:Gen:сила:5281:8',
#  'стараться:ПО:Acc:день:5:1',
#  'стараться:ОТ:Gen:душа:28:5',
#  'стараться:ПОД:Ins:предлог:47:8',
#  'стараться:ВО:Loc:случай:130:24',
#  'стараться:ВО:Acc:время:40:11',
#  'стараться:РАДИ:Gen:благо:22:7',
#  'стараться:ЗА:Acc:время:31:10',
#  'стараться:ИЗ:Gen:сила:284:6',
#  'стараться:СО:Gen:сторона:55:10',
#  'стараться:С ПОМОЩЬЮ:Gen:мера:66:5',
#  'стараться:ПРОТИВ:Gen:лидер:7:1',
#  'стараться:В СВЯЗИ С:Ins:спад:18:2',
#  'приниматься:ОТ:Gen:кандидат:73:24',
#  'приниматься:ВО:Acc:внимание:3074:15',
#  'приниматься:В ВИДЕ:Gen:копия:198:10',
#  'приниматься:ПОСРЕДСТВОМ:Gen:голосование:13:2',
#  'приниматься:СО:Gen:время:7:2',
#  'приниматься:БЕЗО:Gen:участие:4:1',
#  'повысить:_:Ins:образ:711:49',
#  'повысить:_:Loc:.:60:3',
#  ...]

# %%
cnt = 0
for diff in diff_pos:
    if diff in cooccur2:
        print(diff)
        cnt += 1
# Out:
# агитировать ПРОТИВ Gen
# анализировать В Loc
# ассоциироваться В Loc
# басить _ Ins
# пробасить _ Ins
# пробасить В Acc
# баюкать НА Loc
# бегать В Loc
# обеднеть ЗА Acc
# бежать ИЗ Gen
# побежать В Acc
# обезобразить _ Ins
# выбелить _ Ins
# забеременеть С ПОМОЩЬЮ Gen
# забеременеть _ Acc
# беречься _ Gen
# беседовать ПО Dat
# беседовать НА Acc
# обессилить ОТ Gen
# пробить В Acc
# биться ОБ Acc
# побиться ОБ Acc
# бледнеть В Loc
# богатеть _ Ins
# разбогатеть БЛАГОДАРЯ Dat
# разбогатеть НА Loc
# болеть В Loc
# заболеть ПО Dat
# поболтать НА Acc
# бормотать ПОД Acc
# пробормотать _ Ins
# пробормотать В Acc
# пробормотать ПОД Acc
# побояться _ Acc
# брататься В Acc
# браться В Loc
# браться В Acc
# бриться ПЕРЕД Ins
# побриться _ Acc
# бросаться В Acc
# обрюзгнуть В Acc
# брюзжать ПО Dat
# брюзжать НА Loc
# бубнить ПОД Acc
# пробубнить В Acc
# пробубнить ПОД Acc
# будоражиться _ Ins
# пробуравить _ Ins
# буреть С Ins
# бурчать В Loc
# бурчать ПОД Acc
# пробурчать В Acc
# бухнуть НА Acc
# бывать _ Acc
# побывать В ХОДЕ Gen
# свалить В Acc
# валиться ОТ Gen
# валиться С Gen
# валиться ИЗ Gen
# повезти НА Acc
# обвенчать ВО ВРЕМЯ Gen
# повенчать НА Acc
# венчаться В Loc
# обвенчаться В Loc
# увенчаться _ Ins
# верещать _ Ins
# проверещать _ Ins
# поверить НА Acc
# вериться С Ins
# верстать _ Ins
# поверстать В Loc
# поверстать В Acc
# сверстать ИЗ Gen
# вертеть _ Ins
# веселеть НА Loc
# веселиться ДО Gen
# повеселиться В Loc
# повеселиться НА Acc
# повеселиться С Ins
# ветвиться В Loc
# ветвиться ОТ Gen
# вечереть НА Loc
# вечереть ЗА Ins
# вешаться НА Acc
# повеситься В Loc
# вещать _ Ins
# провещать _ Ins
# вздыхать С Ins
# вздохнуть С Ins
# взрослеть НА Loc
# повзрослеть НА Acc
# повидать В Loc
# повидать НА Loc
# видеться В Loc
# видеться В Acc
# привидеться ВО Loc
# завизировать _ Acc
# висеть В Loc
# повиснуть В Loc
# повлечь ПО Dat
# влюбляться С Gen
# влюбиться ПО Acc
# влюбиться С Gen
# отводить В Acc
# воевать В Loc
# вернуть НА Acc
# возвращаться С Gen
# волноваться ПО Dat
# волноваться ПЕРЕД Ins
# взволноваться НА Acc
# вопить _ Ins
# завопить _ Ins
# завопить В Acc
# своровать ПО Dat
# врать _ Acc
# наврать В Acc
# соврать НА Loc
# соврать _ Acc
# вставать _ Ins
# вставать ПЕРЕД Ins
# встать НА Loc
# входить В Acc
# войти В Acc
# выгонять С Gen
# выгонять НА Acc
# выгнать С Gen
# выгнать НА Acc
# выжидать _ Gen
# выкупать ПО Dat
# выпивать _ Ins
# выпить _ Ins
# выпустить НА Loc
# выступить В Loc
# выступить С Ins
# выть НА Acc
# завыть В Acc
# вытягиваться В Acc
# вытянуться ВО Acc
# погадать ПО Dat
# гадить НА Acc
# нагадить ВО Loc
# нагадить НА Acc
# загасить В Loc
# угасить _ Ins
# угаснуть ПОСЛЕ Gen
# гибнуть В Loc
# погибнуть В Loc
# погибнуть ПО Dat
# загипсовать ДО Gen
# глохнуть В Acc
# гнаться ПО Dat
# гнить С Gen
# гноить В Loc
# погнуть В Loc
# гнуться В Acc
# согнуться ОТ Gen
# согнуться ПОД Ins
# согнуться В Loc
# гнушаться _ Acc
# говорить НА Loc
# поговорить НА Acc
# сказать В Loc
# годиться НА Acc
# голосовать НА Loc
# подготовить ПО Dat
# приготовить ДЛЯ Gen
# гранить _ Acc
# грезиться В Loc
# грезиться ВО Loc
# пригрезиться _ Ins
# грести К Dat
# сгрести _ Ins
# сгрести В Acc
# нагреть _ Ins
# нагреть ДО Gen
# нагреть ЗА Acc
# греться В Loc
# нагреться ДО Gen
# нагреться ЗА Acc
# согреться В Acc
# грешить ПРОТИВ Gen
# погрешить ПРОТИВ Gen
# согрешить _ Acc
# угробить В Loc
# пригрозить В Loc
# грозиться В Loc
# загрубеть ОТ Gen
# огрубеть ОТ Gen
# грубить В Acc
# нагрубить В Acc
# сгрудиться В Acc
# сгруппировать ПО Dat
# группироваться ВОКРУГ Gen
# грустить В Loc
# грустить ПО Dat
# загрустить ПРИ Loc
# разгрызть С Ins
# загрязнить В Loc
# загубить НА Loc
# удавить _ Ins
# удавиться ЗА Acc
# двигаться В Loc
# двигаться В Acc
# двигаться С Ins
# двинуться _ Ins
# действовать _ Ins
# действовать НА Loc
# продекламировать _ Ins
# делаться ПО Dat
# разделиться НА Acc
# удержаться С Ins
# дерзить _ Acc
# дерзить В Loc
# дешеветь НА Loc
# подешеветь ПО Dat
# продешевить ПРИ Loc
# подивиться В Acc
# дичать НА Loc
# одичать ОТ Gen
# одичать ЗА Acc
# добираться НА Acc
# добраться В Loc
# раздобреть НА Loc
# договариваться ОБ Loc
# доказывать В Loc
# доказать В Loc
# задолжать _ Acc
# задолжать _ Gen
# досадовать В Loc
# дохнуть В Acc
# подохнуть С Gen
# выдраить ДО Gen
# надраить ДО Gen
# разодрать В Acc
# дублировать ПО Dat
# думать _ Ins
# думать _ Acc
# думать ОБ Loc
# думаться ПО Dat
# думаться НА Acc
# сдуреть НА Loc
# дурить _ Acc
# дурить _ Dat
# задурить _ Acc
# дуть С Gen
# дуть НА Acc
# выдуть ИЗ Gen
# задушить В Loc
# удушить _ Ins
# ездить НА Acc
# уехать ЗА Acc
# ехидничать НАД Ins
# жадничать В Loc
# жарить В Loc
# зажарить ДО Gen
# сжать В Acc
# жаться В Loc
# пожелтеть ОТ Gen
# жениться В Acc
# жертвовать _ Ins
# пожертвовать _ Ins
# обжечься _ Acc
# обжечься НА Loc
# ожиреть НА Loc
# сожрать С Ins
# забивать В Loc
# забить НА Loc
# забыть В Loc
# забыть НА Acc
# завершиться _ Ins
# завести ПО Dat
# заворачивать ЗА Acc
# завернуть ЗА Acc
# заглядывать ЧЕРЕЗ Acc
# заимствовать ИЗ Gen
# заимствоваться БЕЗ Gen
# заключить С Ins
# замереть В Loc
# замереть НА Loc
# записать НА Acc
# записаться ДЛЯ Gen
# запретить _ Ins
# зарекаться _ Acc
# заречься _ Acc
# засыхать НА Loc
# засохнуть ПОСЛЕ Gen
# заходить ПО Dat
# заявить В Loc
# звенеть В Loc
# звереть НА Loc
# звучать В Loc
# прозвучать В Loc
# здороваться СО Ins
# здороваться ЗА Acc
# здороваться ПРИ Loc
# поздороваться ЗА Acc
# перезимовать _ Acc
# перезимовать НА Loc
# знобить ОТ Gen
# зондировать НА Acc
# созреть В Loc
# зазубрить ПО Dat
# идти О Loc
# избирать ИЗ Gen
# изменяться В Loc
# изменяться _ Ins
# наименовать В Acc
# импровизировать НА Acc
# импровизировать ПО Dat
# импровизировать НА Loc
# инструктировать ПО Dat
# инструктировать _ Ins
# проинструктировать _ Ins
# искупить _ Ins
# истощить _ Ins
# казаться В Loc
# искалечить _ Ins
# покалечиться НА Loc
# каменеть _ Ins
# накапать В Acc
# покатить _ Ins
# покатить В Acc
# каяться НА Loc
# кивать _ Ins
# кивнуть _ Ins
# скиснуть В Loc
# кланяться ДО Gen
# преклониться ПРЕД Ins
# сложить НА Loc
# склеить ИЗ Gen
# клепать С ПОМОЩЬЮ Gen
# клепать БЕЗ Gen
# склониться В Loc
# подковать В Loc
# колебаться НА Loc
# колотить В Acc
# колошматить _ Ins
# колошматить В Acc
# скомбинировать _ Ins
# комкать В Loc
# компилировать В Acc
# скомпилировать В Loc
# компоновать С Ins
# скомпоновать ПО Dat
# скомпоновать _ Ins
# скомпрометировать В Loc
# конденсировать ИЗ Gen
# проконопатить _ Ins
# законсервировать ПОСЛЕ Gen
# сконструировать _ Ins
# консультировать ПО Dat
# проконсультировать ПО Dat
# консультироваться ПО Dat
# проконсультироваться ПО Dat
# проконсультироваться СО Ins
# контрактовать В Acc
# кончать _ Ins
# кончить _ Ins
# скооперировать _ Acc
# закопаться В Acc
# копировать В Loc
# накопить В ХОДЕ Gen
# скопить _ Gen
# копиться _ Ins
# скопиться НА Loc
# копнить _ Acc
# закоптить ОТ Gen
# кормиться С Gen
# обкорнать _ Ins
# коробиться ПРИ Loc
# откорректировать ПО Dat
# откорректировать В Acc
# скорректировать В Acc
# скорректировать С Ins
# выкорчевать В Loc
# выкорчевать С Ins
# скорчиться НА Loc
# косить В Acc
# коситься В Acc
# скоситься В Acc
# закоснеть В Loc
# закостенеть В Loc
# накостылять ПО Dat
# закоченеть ОТ Gen
# выкрасить _ Ins
# выкрасить В Acc
# накрасить _ Ins
# окрасить В Acc
# выкраситься В Acc
# краснеть _ Acc
# краснеть ПОД Ins
# накрахмалить ДО Gen
# накренить В Acc
# крениться В Acc
# крепнуть _ Acc
# крестить В Loc
# креститься ПО Dat
# креститься ПОД Ins
# креститься НА Acc
# перекреститься _ Acc
# кривить _ Ins
# покривить _ Ins
# кристаллизоваться В Loc
# кристаллизоваться ИЗ Gen
# кристаллизоваться ПРИ Loc
# кричать _ Ins
# закричать _ Ins
# крикнуть _ Ins
# крикнуть В Acc
# прокричать _ Ins
# выкроить В Loc
# кропать В Loc
# кропить _ Ins
# накрошить _ Gen
# раскрошиться В Acc
# крутиться В Loc
# крутиться ВОКРУГ Gen
# закрутиться В Loc
# закрутиться НА Loc
# скрючиться ОТ Gen
# скукожиться В Loc
# купаться НА Loc
# выкупаться ПО Dat
# покуражиться В Loc
# покурить В Acc
# куролесить _ Acc
# куролесить _ Ins
# кушать НА Loc
# покушать _ Gen
# лгать _ Acc
# солгать В Acc
# солгать _ Acc
# полеветь _ Acc
# легчать НА Loc
# полегчать НА Acc
# полегчать НА Loc
# лежать В Loc
# лечь В Acc
# лезть ИЗ Gen
# полезть В Acc
# взлелеять НА Loc
# лепетать НА Loc
# налепить _ Gen
# лететь _ Ins
# лететь В Acc
# полететь К Dat
# лечиться _ Acc
# вылечиться В Loc
# вылечиться ЗА Acc
# лиловеть В Loc
# линять _ Acc
# отлить В Loc
# отлить ОТ Gen
# отлить НА Loc
# лихорадить _ Acc
# лихорадить В Acc
# залихорадить В Loc
# облобызать В Acc
# ловить НА Loc
# поймать НА Loc
# ложиться В Acc
# сломаться В Acc
# сломаться НА Loc
# лопотать НА Loc
# лукавить НА Loc
# слукавить НА Loc
# облупить _ Ins
# слупить _ Gen
# облупиться _ Ins
# облысеть В Loc
# польстить _ Ins
# наляпать _ Ins
# наляпать НА Acc
# сляпать НА Acc
# промазать С Gen
# мазаться _ Ins
# измазаться ПО Acc
# измазаться _ Ins
# намазаться _ Ins
# малевать НА Loc
# намалевать _ Ins
# намалевать НА Loc
# маневрировать С Ins
# вымараться В Loc
# маршировать ПО Dat
# маскироваться В Loc
# махать _ Ins
# махнуть _ Ins
# махнуть В Acc
# меблировать В Loc
# мелеть _ Ins
# измельчать В Acc
# измельчить В Loc
# измельчить В Acc
# размельчить В Loc
# размельчить В Acc
# сменить НА Loc
# меняться В Loc
# меняться В Acc
# перемениться В Loc
# мерить _ Ins
# смерить _ Ins
# меркнуть В Loc
# меркнуть НА Loc
# померкнуть В Loc
# мерять _ Ins
# месить _ Ins
# наметать В Loc
# сметать НА Loc
# метить НА Acc
# мечтать _ Acc
# мечтать В Loc
# мешаться ПОД Ins
# смешаться В Loc
# помиловать _ Ins
# примирить С Ins
# помириться В Loc
# млеть В Loc
# вымокнуть ДО Gen
# промокнуть ДО Gen
# молодеть _ Ins
# молодеть НА Loc
# помолодеть В Acc
# молоть _ Ins
# смолоть В Acc
# молчать _ Acc
# помолчать С Acc
# смонтировать В Loc
# морить _ Ins
# выморить _ Ins
# заморить _ Ins
# поморить _ Ins
# уморить _ Ins
# наморщить _ Acc
# мотать _ Ins
# мотать ИЗ Gen
# замотать _ Ins
# помотать _ Ins
# умотать ПО Dat
# мочить В Loc
# вымочить ДО Gen
# намочить В Loc
# намочить _ Ins
# мочь В Loc
# смочь _ Ins
# мошенничать _ Ins
# мрачнеть НА Loc
# мудрить О Loc
# намудрить _ Acc
# мужать НА Loc
# возмужать В Acc
# мурлыкать ПОД Acc
# промурлыкать _ Ins
# промурлыкать НА Acc
# мусолить В Loc
# замусолить _ Ins
# мусорить НА Loc
# замутиться В Loc
# мутнеть В Loc
# помутнеть В Loc
# мухлевать В Acc
# замучить _ Ins
# намылиться _ Acc
# намылиться ЗА Acc
# намылиться ДО Gen
# вымыться _ Ins
# вымыться ПОД Ins
# помыться С Gen
# помыться _ Ins
# помыться ПОД Ins
# мычать В Acc
# промычать В Acc
# промычать С Ins
# помягчеть В Loc
# промямлить _ Acc
# промямлить В Acc
# мять В Loc
# мяться НА Loc
# наблюдать С Ins
# наглеть ОТ Gen
# наглеть НА Loc
# наглеть С Ins
# обнаглеть ОТ Gen
# обнаглеть ДО Gen
# назначать В Loc
# направляться В Acc
# направиться В Acc
# наследовать _ Dat
# наступить В Loc
# нездоровиться С Gen
# понести В Loc
# нестись С Ins
# нестись В Acc
# нестись НА Loc
# никнуть К Dat
# поникнуть _ Ins
# сникнуть ПОД Ins
# обнищать В Loc
# переночевать _ Acc
# пронумеровать В Loc
# понюхать _ Dat
# обещать В Loc
# оборачиваться В Acc
# обращаться В Acc
# обращаться ЗА Ins
# обратиться В Acc
# обходиться В Loc
# обойтись В Acc
# общаться ПО Dat
# объясниться В Loc
# объясниться ПО ПОВОДУ Gen
# оглядываться В Loc
# оглядываться ПО Dat
# оглянуться В Loc
# оглянуться ПО Dat
# оглянуться ЧЕРЕЗ Acc
# одолжить _ Gen
# одолжить НА Acc
# оказываться _ Ins
# освобождаться В Loc
# оскорбить В Loc
# оскорбиться ДО Gen
# оставаться _ Acc
# остановить _ Ins
# острить ПО Dat
# сострить В Acc
# отбирать ДЛЯ Gen
# отобрать ДЛЯ Gen
# отвыкать С Ins
# отличиться _ Ins
# отмечать С Ins
# отнестись С Ins
# отпускать ПО Dat
# отпускать В Acc
# отпустить НА Acc
# отречься В Acc
# отрываться С Ins
# отстегнуть ОТ Gen
# отходить В Loc
# отходить В Acc
# отходить НА Acc
# отойти В Acc
# отойти К Dat
# пакостить ПО Dat
# спалить _ Acc
# попарить В Loc
# париться В Loc
# париться _ Ins
# париться НА Loc
# спасовать _ Ins
# запатентовать _ Ins
# спеленать ПО Dat
# запеленговать _ Acc
# пенять НА Acc
# испепелить _ Ins
# переворачивать С Gen
# переворачиваться С Gen
# передавать СО Ins
# перестать В Loc
# перетягивать НА Acc
# перетянуть НА Acc
# перейти ПОД Acc
# перчить ПО Dat
# поперчить _ Ins
# воспеть _ Ins
# спеть _ Ins
# печалиться ПО Dat
# пикировать НА Acc
# спикировать К Dat
# писаться НА Loc
# выплавить ИЗ Gen
# сплавить ПО Dat
# плавиться ПРИ Loc
# поплакать В Loc
# поплакать НА Loc
# спланировать _ Ins
# уплатить В Loc
# уплатить _ Ins
# поплатиться _ Ins
# плевать В Acc
# плюнуть _ Acc
# плюнуть _ Ins
# плюнуть В Acc
# заплести В Acc
# расплодиться В Loc
# расплодиться В Acc
# оплошать В Loc
# плутовать В Loc
# плыть ПЕРЕД Ins
# плыть К Dat
# проплыть ПОД Ins
# расплющить _ Ins
# расплющить В Acc
# сплющить С Gen
# сплющить В Acc
# плясать В Loc
# поворачивать В Acc
# повернуть _ Ins
# повернуть В Acc
# поворачиваться В Acc
# повернуться В Acc
# погибать В Loc
# подавать В Acc
# поддавать _ Ins
# поддать _ Ins
# поддать _ Dat
# поддать ПОД Acc
# поднимать В Acc
# подняться В Acc
# пожимать _ Ins
# пожать _ Ins
# позориться ПЕРЕД Ins
# опозориться ПО Dat
# купить НА Acc
# отполировать ДО Gen
# полнеть ПО Dat
# пополнеть ПОСЛЕ Gen
# полоскать В Loc
# всполошиться НА Acc
# получить В Loc
# получаться _ Ins
# понять В Acc
# поразиться В Acc
# опороситься В Loc
# опорочить В Loc
# запорошить _ Ins
# поступить ОТ Gen
# послать К Dat
# потягиваться _ Ins
# праветь _ Ins
# править В Loc
# представить НА Loc
# прибегать В Loc
# прибивать _ Ins
# прибивать НА Loc
# прибить _ Ins
# прибывать ИЗ Gen
# прибывать С Ins
# прибыть ДЛЯ Gen
# прибыть НА Acc
# прибыть С Ins
# пригласить ДЛЯ Gen
# приехать НА Acc
# принимать К Dat
# приниматься ВО Acc
# присылать НА Acc
# прислать В Acc
# приходить В Acc
# приходить К Dat
# прийти В Acc
# прийти К Dat
# приходиться НА Acc
# пробовать НА Acc
# попробовать В Loc
# попробовать НА Acc
# проводить _ Ins
# запрограммировать _ Ins
# продавать ПО Dat
# проживать ПО Dat
# проживать НА Loc
# прожить _ Acc
# прожить В Loc
# произвести В Acc
# произвести НА Acc
# проказить _ Gen
# пропадать _ Ins
# пропадать НА Loc
# пропасть БЕЗ Gen
# просвещать В Loc
# просвещать ПО Dat
# просветить НА Acc
# просить _ Acc
# просыпаться В Loc
# проснуться _ Ins
# опротестовать _ Acc
# опротестовать В Loc
# протянуть _ Dat
# проявить В Loc
# пружинить ПОД Ins
# напружинить _ Acc
# прыгать В Loc
# прыгать В Acc
# прыгать С Ins
# прыгнуть В Acc
# прыгнуть С Ins
# прыскать ОТ Gen
# прясть _ Ins
# спрятать В Acc
# пугаться _ Acc
# испугаться НА Acc
# напугаться ДО Gen
# пускать В Acc
# пустить В Acc
# путаться ПОД Ins
# перепутаться В Loc
# путешествовать В Loc
# пыжиться ОТ Gen
# напыжиться ОТ Gen
# пылить ПО Dat
# пропыхтеть НА Loc
# пялиться _ Ins
# пятиться _ Ins
# пятиться В Acc
# пятнать _ Ins
# запятнать _ Ins
# работать С Ins
# сравнять НА Loc
# равняться ПО Dat
# порадеть _ Dat
# разговаривать ПО Dat
# разговаривать НА Loc
# разить ЗА Acc
# заразиться В Loc
# заразиться С Gen
# размышлять _ Acc
# размышлять НА Acc
# разоблачить В Loc
# рапортовать ОБ Loc
# рассказывать В Loc
# расстаться _ Ins
# расти _ Ins
# растянуть В Loc
# растянуть ВО Loc
# разорвать В Acc
# рваться В Acc
# разорваться НА Loc
# регистрировать В Loc
# зарегистрировать _ Ins
# зарегистрировать ПО Dat
# регистрироваться _ Ins
# регистрироваться В Acc
# регистрироваться НА Loc
# зарегистрироваться НА Loc
# отрегулировать НА Acc
# отредактировать _ Ins
# зарезать _ Ins
# резаться _ Ins
# резаться В Acc
# прорезаться В Loc
# зарезервировать В Loc
# рекомендовать _ Ins
# репетовать _ Acc
# ретироваться НА Acc
# отрецензировать В Loc
# прорецензировать _ Ins
# проржаветь _ Ins
# робеть В Loc
# робеть ПРИ Loc
# оробеть НА Acc
# оробеть ПРИ Loc
# породниться _ Ins
# родить В Loc
# рождаться С Ins
# родиться В Loc
# розоветь НА Loc
# ронять В Acc
# выругать _ Ins
# ругаться НА Loc
# выругаться В Loc
# выругаться СКВОЗЬ Acc
# выругаться ПОД Acc
# ручаться _ Ins
# рушиться НА Loc
# обрушиться В Loc
# обрушиться С Ins
# порыжеть ОТ Gen
# рядить ПОД Acc
# садить ЗА Acc
# саднить В Loc
# садиться В Acc
# осалить _ Ins
# сбить _ Ins
# просверлить _ Ins
# светить В Loc
# светлеть _ Ins
# посветлеть _ Ins
# просветлеть _ Ins
# освидетельствовать НА Acc
# свирепеть НА Loc
# рассвирепеть НА Acc
# свистеть В Loc
# свистеть НАД Ins
# просвистеть НАД Ins
# просвистеть В Loc
# связываться ПО Dat
# связаться ПО Dat
# освятить В Acc
# сговориться О Loc
# сговориться ЗА Ins
# сереть ЗА Ins
# серчать НА Acc
# высечь ИЗ Gen
# посеять ПОД Ins
# посеять НА Loc
# сигнализировать ОБ Loc
# просигнализировать _ Acc
# сигналить В Acc
# сидеть ЗА Ins
# посинеть ОТ Gen
# осиротеть ПОСЛЕ Gen
# скалиться В Loc
# оскалиться В Loc
# скальпировать _ Ins
# поскандалить _ Acc
# поскандалить В Acc
# осклабиться В Loc
# скрести НА Loc
# скрыться С Gen
# скрыться НА Loc
# поскучнеть _ Ins
# ослабнуть В Loc
# прославить НА Acc
# наследить В Loc
# следовать ПО Dat
# последовать _ Dat
# случаться В Loc
# случаться _ Acc
# слушаться В Loc
# послушаться _ Gen
# слышаться В Loc
# послышаться В Loc
# осмелеть ПОСЛЕ Gen
# посметь _ Acc
# смеяться _ Ins
# смеяться ОТ Gen
# засмеяться _ Ins
# засмеяться В Acc
# посмеяться ОТ Gen
# сморкаться В Acc
# высморкаться В Acc
# посмотреть В Acc
# смотреться НА Loc
# присниться _ Ins
# собрать _ Ins
# собраться НА Loc
# собраться У Gen
# совершить НА Loc
# солить В Loc
# засолить В Loc
# посолить _ Ins
# сообщать СО Ins
# сообщить В Loc
# сотрудничать СО Ins
# спадать _ Ins
# поспать _ Acc
# спешить ПО Dat
# сплетничать ЗА Ins
# спорить _ Acc
# спохватываться В Loc
# спохватиться В Acc
# спрашивать _ Gen
# спускать НА Acc
# спустить НА Acc
# сталкивать _ Ins
# столкнуть _ Ins
# стараться _ Ins
# стараться ИЗО Gen
# постараться НА Acc
# стареть НА Loc
# постареть НА Loc
# стариться НА Loc
# застеклить _ Ins
# постелить В Loc
# стенографировать _ Ins
# стеснить В Loc
# постесняться _ Dat
# стереть В Acc
# настлать НА Acc
# стопориться В Loc
# стоять ЗА Ins
# постоять С Acc
# пострадать В Loc
# пострадать ПО Dat
# застраховать В Loc
# страховаться _ Ins
# стрелять НА Acc
# стрельнуть В Acc
# постричь В Loc
# постричь В Acc
# постричь С Ins
# стричься В Loc
# стричься _ Acc
# постричься В Loc
# постричься ПОД Ins
# постричься С Ins
# строить НА Loc
# построить ПО Dat
# выстроиться У Gen
# строчить НА Loc
# прострочить НА Loc
# состряпать НА Acc
# постучать _ Ins
# стыковать В Loc
# состыковать СО Ins
# стыковаться СО Ins
# стыковаться _ Ins
# стынуть В Loc
# стыть В Loc
# сулиться _ Dat
# ссутулиться В Loc
# засучить _ Ins
# схватывать НА Loc
# сойти В Loc
# сходиться ВО Loc
# сойтись ВО Loc
# сойтись НА Loc
# посчитать _ Ins
# таить _ Gen
# таращиться _ Acc
# таращиться _ Ins
# таскать ИЗ Gen
# тащить ЗА Acc
# притащить В Acc
# утащить НА Acc
# таять ВО Loc
# таять НА Loc
# твердеть ОТ Gen
# сотворить ПО Dat
# темнеть В Loc
# потемнеть В Loc
# стемнеть НА Loc
# стемнеть ЗА Ins
# стемнеть К Dat
# потеплеть _ Ins
# потеплеть НА Loc
# теребить В Loc
# растерзать _ Ins
# растерзать В Acc
# потерять В Loc
# утерять В Loc
# потеряться НА Loc
# теснить НА Loc
# потеснить НА Loc
# тесниться В Loc
# тесниться К Dat
# потесниться НА Loc
# стесниться В Loc
# ткать НА Loc
# растолочь В Acc
# толстеть ПО Dat
# толстеть НА Loc
# потолстеть ЗА Acc
# растолстеть ЗА Acc
# истомиться В Loc
# утонуть ПРИ Loc
# вытопить ИЗ Gen
# топнуть _ Ins
# топорщиться В Acc
# топтать _ Ins
# сторговать ЗА Acc
# сторговаться В Loc
# сторговаться ПО Dat
# сторговаться О Loc
# сторговаться НА Loc
# затормозить ПЕРЕД Ins
# тормозиться _ Ins
# торопиться С Ins
# тошнить ПО Dat
# транскрибировать НА Acc
# тревожиться ПО Dat
# встревожиться НА Acc
# трезветь НА Loc
# протрезветь _ Ins
# трезвонить _ Acc
# трезвонить В Acc
# натренировать НА Acc
# тренироваться В Acc
# тренироваться ПОД Ins
# оттрепать ЗА Acc
# растрепать _ Ins
# трепаться ПО Dat
# истрепаться ЗА Acc
# потрепаться ЗА Acc
# трудиться НА Acc
# струсить В Acc
# трясти _ Ins
# трясти ЗА Acc
# тупеть НА Loc
# тупить В Loc
# вытурить С Gen
# потускнеть ОТ Gen
# стушеваться ПОД Ins
# стушеваться ПРИ Loc
# тушить В Loc
# затушить В Loc
# потягаться В Loc
# потягаться _ Ins
# потянуть _ Ins
# убеждаться _ Acc
# убеждаться В Acc
# убедиться _ Acc
# убить В Loc
# убить ПО Dat
# удаваться _ Ins
# удаваться С Ins
# удаться _ Ins
# удерживаться С Ins
# уезжать ПО Dat
# уезжать ЗА Acc
# ужинать В Loc
# поужинать В Loc
# поужинать В Acc
# улыбаться _ Ins
# улыбаться В Acc
# улыбаться ВО Acc
# улыбнуться _ Ins
# улыбнуться В Acc
# суметь _ Ins
# умереть _ Ins
# умереть НА Loc
# умнеть НА Loc
# умолять НА Loc
# употреблять В Acc
# упразднить ПОСЛЕ Gen
# проурчать _ Ins
# усмехнуться В Acc
# успевать ЗА Acc
# успеть ЗА Acc
# успокоиться В Loc
# уставать НА Loc
# устать ЗА Acc
# установить _ Ins
# уходить _ Ins
# фальшивить НА Loc
# сформировать _ Ins
# формироваться _ Ins
# формироваться НА Loc
# сформироваться В Loc
# отформовать _ Ins
# сформулировать _ Ins
# фотографировать ДЛЯ Gen
# сфотографировать НА Loc
# фотографироваться В Loc
# фотографироваться НА Loc
# сфотографироваться НА Acc
# сфотографироваться НА Loc
# халтурить ПО Dat
# схалтурить НА Loc
# схалтурить ПРИ Loc
# нахамить В Loc
# нахамить ПО Dat
# нахамить В Acc
# хватать _ Ins
# хиреть НА Loc
# хитрить _ Acc
# хлопотать НА Loc
# похлопотать ПО Dat
# похлопотать НА Loc
# захмелеть С Gen
# хмуриться _ Acc
# холодать НА Loc
# похолодать _ Ins
# похолодать НА Loc
# похолодать К Dat
# хорониться НА Loc
# хорошеть НА Loc
# похорошеть В Acc
# хотеть В Loc
# хотеть _ Ins
# захотеться ДО Gen
# сохраниться НА Loc
# прохрипеть _ Ins
# охрипнуть ОТ Gen
# хромировать _ Acc
# худеть ПОСЛЕ Gen
# худеть НА Loc
# худеть С Ins
# похудеть В Acc
# поцапаться С Ins
# поцеловаться НА Acc
# чадить _ Ins
# очаровать _ Ins
# чахнуть НАД Ins
# чахнуть НА Loc
# зачахнуть НА Loc
# чеканить ПО Dat
# отчеканить В Acc
# отчеканить НА Loc
# чернеть НА Loc
# почернеть ОТ Gen
# очернить В Loc
# зачерстветь В Loc
# вычесать ИЗ Gen
# почесаться В Loc
# чистить _ Ins
# вычистить ДО Gen
# чихать ОТ Gen
# чихать В Acc
# чихать _ Acc
# членить НА Acc
# расчленить _ Ins
# учудить НА Acc
# чуяться В Loc
# пошарить _ Ins
# швартовать У Gen
# пришвартовать В Loc
# швартоваться В Loc
# пришвартоваться В Loc
# шевелить _ Ins
# пошевелиться ВО Loc
# пошевелиться В Acc
# шельмовать С Ins
# шептать В Acc
# нашинковать _ Ins
# сшить НА Acc
# нашкодить В Loc
# вышколить _ Ins
# отшлифовать ДО Gen
# проштамповать _ Ins
# заштриховать _ Ins
# заштриховать НА Loc
# шутить _ Acc
# шутить НА Acc
# пошутить ПО Dat
# пошутить В Acc
# пошутить НА Acc
# щериться В Loc
# ощериться В Loc
# общипать _ Ins
# щупать _ Ins
# пощупать _ Ins
# щуриться НА Loc
# проэкзаменовать В Loc
# сэкономить В Loc
# явить _ Dat
# язвить ПО Dat
# съязвить В Acc
# прояснеть В Loc
# охладеть ПОСЛЕ Gen
# повредить В Loc
# запылить С Gen
# запылить ПО Dat
# запылить В Acc
# покончить _ Acc
# покончить _ Ins

# %%
cnt, len(cooccur2)
# Out:
# (1235, 48209)

# %%
for verb, comb1 in verb_comb.items():
    for prep, comb2 in comb1.items():
        for cas, comb3 in comb2.items():
            if len(comb3) <= 2:
                continue
            s_combs = sorted(comb3.items(), key=lambda x:x[1], reverse=True)
            if s_combs[0][1] > 6 * s_combs[1][1] and s_combs[0][1] > 1000b:
                print(f'{verb}:{prep}:{cas}:{s_combs[0][0]}:{s_combs[0][1]}:{s_combs[1][1]}')
# Out:
# стоять:ВО:Loc:двор:1682:157
# получать:_:Ins:образ:2811:392
# родиться:ОТ:Gen:брак:1171:162
# переехать:_:Nom:семья:7581:877
# жить:_:Ins:жизнь:12129:614
# жить:ВО:Acc:время:1045:87
# жить:О:Acc:бок:1273:2
# провести:ВО:Acc:вторник:1248:71
# приходить:К:Dat:вывод:8118:1048
# принять:_:Nom:решение:113100:18313
# принять:К:Dat:сведение:32833:2503
# принять:БЕЗ:Gen:голосование:5203:324
# принять:ВО:Acc:внимание:12524:1421
# принять:ДО:Gen:конец:1886:240
# состояться:НА:Acc:день:1106:97
# состояться:ВО:Acc:вторник:1931:74
# состояться:ДО:Gen:конец:1017:117
# идти:_:Nom:речь:235546:11305
# идти:ДО:Gen:конец:2121:351
# организовать:С:Ins:цель:2609:392
# стать:СО:Ins:время:6636:83
# объясняться:ВО:Loc:многое:1287:12
# обсуждаться:_:Nom:вопрос:19349:3222
# попросить:_:Nom:президент:20281:1182
# попросить:_:Gen:помощь:21187:2353
# отметить:С:Ins:удовлетворение:9106:777
# измениться:_:Ins:образ:1942:66
# измениться:С:Gen:момент:2962:312
# измениться:ДО:Gen:неузнаваемость:1043:38
# находиться:НА:Acc:момент:9242:1219
# находиться:_:Ins:образ:1688:273
# находиться:_:Acc:время:8856:1173
# находиться:У:Gen:власть:6017:632
# находиться:С:Ins:визит:5669:600
# находиться:ВО ВРЕМЯ:Gen:война:1345:210
# оставаться:ПО:Acc:день:1812:58
# отмечать:СО:Ins:ссылка:1812:8
# обстоять:_:Nom:дело:18901:733
# обстоять:_:Ins:образ:1319:10
# ждать:С:Ins:нетерпение:12127:433
# бороться:ДО:Gen:конец:1235:91
# приходиться:НА:Acc:доля:15209:1477
# видеть:ВО:Loc:сон:13736:200
# произойти:ВО:Acc:вторник:2044:238
# вывести:С:Gen:территория:1686:223
# остаться:СО:Gen:время:1313:66
# совершить:НА:Loc:территория:9376:1150
# переходить:ИЗ:Gen:рука:2120:187
# связать:ВО:Loc:многое:2273:76
# уходить:_:Ins:корень:3022:350
# писать:О:Loc:влияние:4091:482
# писать:ВО:Acc:вторник:1090:97
# писать:СО:Ins:ссылка:23048:14
# писать:ПОД:Ins:псевдоним:1052:127
# задавать:_:Acc:вопрос:32834:2449
# составлять:ДЛЯ:Gen:сравнение:1861:185
# составлять:С:Ins:учёт:1710:83
# назвать:В:Acc:честь:42067:3123
# назвать:ПО:Dat:имя:5130:734
# использовать:_:Ins:образ:3480:353
# покупать:ПО:Dat:цена:1599:205
# считать:С:Ins:учёт:1262:73
# стараться:ИЗО:Gen:сила:5281:8
# приниматься:ВО:Acc:внимание:3074:15
# направить:_:Gen:рубль:2352:356
# направить:НА:Loc:фон:9788:612
# направить:ПОСЛЕ:Gen:окончание:1291:170
# вести:_:Ins:образ:3231:295
# составить:_:Ins:образ:5710:885
# составить:_:Loc:.:1062:52
# составить:С:Ins:учёт:3344:194
# посеять:ПОД:Ins:номер:1624:1
# внести:НА:Acc:рассмотрение:15530:449
# внести:СОГЛАСНО:Dat:постановление:1450:26
# внести:ОТ:Gen:имя:1351:8
# собрать:В ХОДЕ:Gen:перепись:2073:162
# занять:_:Acc:место:147821:24324
# сказать:К:Dat:слово:1849:213
# сказать:ВО:Acc:вторник:1342:89
# начать:ПРИ:Loc:поддержка:1168:165
# поднять:ПО:Dat:тревога:3261:378
# поднять:ДО:Gen:уровень:1049:162
# поднять:НАД:Ins:голова:1994:220
# работать:_:Gen:житель:5622:883
# работать:ПО:Loc:окончание:1713:272
# работать:ПОСЛЕ:Gen:окончание:7758:1178
# приводить:_:Acc:слово:32532:4770
# приводить:В КАЧЕСТВЕ:Gen:пример:2254:349
# приводить:СО:Ins:ссылка:1308:123
# заниматься:ПОД:Ins:руководство:1914:69
# уйти:В:Acc:отставка:30251:2633
# уйти:С:Ins:голова:1745:240
# употреблять:В:Acc:пища:2981:130
# привести:В КАЧЕСТВЕ:Gen:пример:5353:277
# лежать:В:Loc:основа:33771:4380
# изъять:В ХОДЕ:Gen:обыск:1663:236
# изъять:С:Gen:место:1039:128
# мочь:_:Ins:образ:21857:3579
# мочь:В:Loc:случай:49802:8218
# мочь:СО:Ins:время:1799:61
# пойти:КО:Dat:дно:1314:49
# попытаться:_:Acc:раз:1167:44
# повредить:В:Loc:результат:3581:245
# поступить:ОТ:Gen:предприниматель:5649:387
# поступить:ПО:Loc:окончание:1865:147
# стучаться:В:Acc:дверь:1136:181
# сообщить:СО:Ins:ссылка:24831:23
# сообщить:ВО:Acc:вторник:8595:44
# пытаться:ИЗО:Gen:сила:2239:14
# говорить:НА:Loc:язык:13430:1175
# говорить:НА:Acc:тема:2515:283
# увидеть:ВО:Loc:сон:7790:361
# обнаружить:С:Ins:удивление:2822:367
# обнаружить:БЕЗ:Gen:сознание:1263:197
# оказать:НА:Loc:место:1798:166
# пострадать:В:Loc:результат:31508:2334
# поставить:ВО:Acc:глава:1182:86
# выпить:_:Ins:залп:2171:185
# выпить:_:Par:чай:1865:11
# признать:_:Nom:суд:29471:2360
# привлечь:_:Acc:внимание:52430:1512
# привлечь:НА:Acc:сторона:2601:235
# прибыть:НА:Acc:место:24549:1418
# прибыть:К:Dat:место:3264:387
# обратить:_:Acc:внимание:120059:1784
# доставить:В:Acc:больница:26078:3352
# возбудить:ПО:Dat:факт:31383:2934
# возбудить:_:Nom:дело:80727:6526
# возбудить:_:Acc:дело:48304:506
# возбудить:НА:Loc:основание:1145:122
# похитить:_:Gen:рубль:1724:134
# призывать:В:Loc:связь:3551:406
# предпринять:С:Ins:цель:2659:205
# сходить:С:Gen:ум:10115:886
# взять:ИЗ:Gen:рука:3489:512
# задержать:С:Ins:поличное:1961:123
# сдать:НА:Acc:хранение:2502:298
# вернуться:ДЛЯ:Gen:участие:1440:169
# вернуться:ЗА:Acc:стол:1635:249
# вернуться:ПО:Loc:окончание:1153:172
# написать:СО:Ins:ссылка:1147:19
# предоставить:В:Acc:распоряжение:4089:627
# изменить:_:Ins:образ:7510:153
# выявить:С:Gen:начало:1850:108
# выявить:ЗА:Acc:сутки:3606:309
# уволиться:ПО:Dat:желание:1105:103
# двигаться:В:Acc:сторона:5402:713
# двигаться:В:Loc:направление:7272:372
# двигаться:С:Ins:скорость:2019:269
# двигаться:СО:Ins:скорость:3398:19
# встретиться:_:Acc:раз:1478:123
# встретиться:ДЛЯ:Gen:обсуждение:1179:125
# запретить:НА:Loc:территория:3485:383
# сложиться:_:Ins:образ:1171:93
# рекомендовать:_:Nom:комитет:27552:3698
# рекомендовать:_:Ins:комитет:3629:336
# бывать:_:Acc:раз:2876:429
# вернуть:ПОД:Acc:контроль:1668:146
# позвонить:_:Acc:раз:1022:96
# вынести:_:Ins:суд:3341:283
# прийти:В:Acc:голова:24766:3335
# проживать:_:Gen:человек:2933:320
# проживать:ПО:Dat:данные:21074:1876
# проживать:НА:Loc:территория:12022:1122
# проживать:СОГЛАСНО:Dat:перепись:3228:481
# сделать:ОТ:Gen:имя:5022:207
# уехать:ЗА:Acc:граница:2462:354
# дуть:_:Nom:ветер:7108:947
# перекинуться:_:Ins:пара:1197:153
# провалиться:СКВОЗЬ:Acc:земля:2400:92
# звать:НА:Acc:помощь:2467:70
# разойтись:_:Ins:тираж:2667:345
# разойтись:В:Acc:сторона:1236:109
# предъявить:_:Nom:обвинение:38235:1933
# предъявить:_:Acc:обвинение:21778:3445
# повлечь:ПО:Dat:неосторожность:8158:198
# завершить:ДО:Gen:конец:2341:180
# проникнуть:НА:Acc:территория:3850:294
# погибнуть:В:Loc:результат:120808:8339
# погибнуть:ПО:Dat:данные:24621:2163
# гибнуть:_:Nom:человек:2381:318
# отмечаться:НА:Loc:сайт:2648:272
# играть:_:Acc:роль:122210:1822
# позвать:НА:Acc:помощь:2268:124
# покончить:_:Acc:жизнь:5995:890
# покончить:_:Ins:самоубийство:5428:164
# пропасть:БЕЗ:Gen:весть:30738:81
# звонить:ПО:Dat:телефон:2016:317
# обратиться:ЗА:Ins:помощь:18652:1837
# увеличиться:_:Ins:образ:1759:102
# увеличиться:С:Gen:начало:1262:203
# способствовать:_:Ins:образ:2318:257
# способствовать:ВО:Loc:многое:2051:34
# разводить:_:Ins:рука:2556:100
# обращать:_:Acc:внимание:49356:498
# обращать:_:Gen:внимание:1025:6
# закурить:_:Acc:сигарета:2615:341
# скрыться:С:Gen:место:8433:330
# начаться:ВО:Loc:половина:1364:178
# ударить:С:Ins:сила:1405:51
# угрожать:_:Nom:опасность:4100:336
# угрожать:В:Loc:случай:1710:142
# грозить:В:Loc:случай:3591:175
# продавать:НА:Loc:рынок:2353:336
# продавать:ПО:Dat:цена:3193:221
# осуществляться:В ТЕЧЕНИЕ:Gen:период:1204:95
# применить:ДЛЯ:Gen:разгон:1505:193
# применить:НА:Loc:практика:1052:173
# отпустить:_:Acc:рука:3209:521
# причинить:В:Loc:результат:3682:110
# удовлетворить:_:Nom:суд:12383:1007
# явиться:С:Ins:повинная:1033:143
# действовать:ОТ:Gen:имя:3419:243
# уполномочить:_:Acc:секретарь:1089:134
# становиться:СО:Ins:время:1496:20
# нарушаться:_:Nom:право:2467:399
# просить:О:Loc:помощь:2744:426
# просить:НА:Loc:сессия:2802:252
# сбить:С:Gen:нога:5413:485
# обходить:_:Ins:сторона:3294:268
# убить:В:Loc:результат:11870:1421
# пожаловать:_:Nom:добро:4899:438
# построить:_:Gen:метр:1250:101
# числиться:СОГЛАСНО:Dat:список:1435:145
# существовать:_:Ins:образ:1127:131
# перепутать:_:Acc:война:1456:145
# забыть:В:Loc:борьба:2653:253
# толкнуть:_:Acc:дверь:3775:157
# побить:_:Acc:рекорд:7913:245
# побить:_:Nom:рекорд:1563:95
# оккупировать:_:Ins:войско:7306:977
# оккупировать:В:Acc:год:4336:131
# образоваться:В:Loc:результат:10416:742
# увезти:В:Acc:больница:2359:231
# увезти:В:Loc:направление:1872:218
# унести:_:Acc:жизнь:12270:1111
# отойти:В:Acc:сторона:6495:1065
# описать:_:Nom:вид:5031:662
# схватиться:_:Ins:рука:1442:56
# ответить:НА:Acc:вопрос:53846:1958
# уточняться:В:Loc:сообщение:2729:441
# представить:ОТ:Gen:имя:2413:27
# окончить:_:Loc:.:1902:15
# путаться:_:Nom:мысль:1559:68
# заблокировать:ПЕРЕД:Ins:окончание:1017:19
# свидетельствовать:В:Acc:польза:2504:372
# услышать:ИЗ:Gen:уста:1065:66
# услышать:ЗА:Ins:спина:1839:289
# выжить:_:Ins:чудо:1093:167
# выжить:ИЗ:Gen:ум:1073:82
# исполнять:ПО:Dat:результат:2873:157
# планироваться:ДО:Gen:конец:1987:63
# произвести:_:Acc:впечатление:21482:2307
# произвести:НА:Acc:свет:1635:184
# выставить:ЗА:Acc:дверь:1052:121
# показать:С:Gen:сторона:1523:202
# возникнуть:В СВЯЗИ С:Ins:наращивание:2489:91
# превратиться:СО:Ins:время:1258:4
# понять:В:Acc:момент:2199:333
# выходить:ВО:Acc:двор:1465:163
# лидировать:С:Ins:отрыв:1186:152
# оформить:_:Ins:образ:1097:118
# вносить:НА:Acc:рассмотрение:1787:204
# зависеть:_:Ins:образ:1415:102
# зависеть:ВО:Loc:многое:6841:77
# начинать:_:Gen:.:1014:43
# объявить:В:Acc:розыск:21787:2242
# объявить:ВНЕ:Gen:закон:1657:16
# держать:В:Loc:рука:38783:2366
# держать:ЗА:Acc:рука:6212:561
# предстать:ПЕРЕД:Ins:суд:10723:862
# предстать:ПО:Dat:обвинение:1224:147
# выделяться:НА:Loc:фон:3972:525
# подвести:_:Acc:итог:15986:1581
# подвести:_:Nom:итог:3839:350
# выступить:ОТ:Gen:имя:4029:133
# попадаться:НА:Loc:путь:1014:99
# предпринимать:С:Ins:цель:1702:103
# смочь:_:Ins:образ:4688:303
# сообщать:СО:Ins:ссылка:149671:5
# сообщать:ВО:Acc:вторник:1523:9
# подготовить:НА:Loc:основа:5099:555
# подготовить:ПО:Dat:материал:18635:1465
# подготовить:ПОД:Ins:руководство:1388:222
# относиться:_:Ins:образ:1223:68
# относиться:ПО:Dat:данные:23451:1431
# обязать:_:Nom:суд:5828:775
# госпитализировать:В:Acc:больница:5843:809
# принимать:ВО:Acc:внимание:28996:150
# принимать:К:Dat:сведение:31145:383
# смотреть:ПОД:Acc:нога:1386:9
# смотреть:ВО:Acc:глаз:1805:139
# освободить:ПРИ:Loc:поддержка:1129:135
# содержаться:ПОД:Ins:стража:9999:681
# перейти:_:Ins:лето:4690:666
# перейти:НА:Loc:право:3830:184
# перейти:ВО:Acc:владение:1481:107
# расти:_:Ins:темп:5141:603
# приговорить:_:Nom:суд:23798:667
# приговорить:_:Ins:суд:4173:464
# заключить:ПОД:Acc:стража:5865:490
# выписать:ИЗ:Gen:больница:4179:267
# остановить:ДЛЯ:Gen:проверка:1388:189
# выпасть:НА:Acc:доля:4381:309
# утверждать:СО:Ins:ссылка:1211:53
# учитывать:_:Ins:образ:2273:20
# протянуть:_:Acc:рука:40011:1064
# умереть:ПОСЛЕ:Gen:болезнь:1670:209
# заявить:ВО:Acc:вторник:6696:641
# заявить:СО:Gen:сторона:1679:163
# хотеть:_:Ins:образ:3469:335
# хотеть:НА:Loc:дело:2193:287
# поменять:_:Ins:место:1118:174
# пнуть:_:Ins:нога:1680:146
# свернуть:ЗА:Acc:угол:1130:52
# выбросить:ЗА:Acc:борт:1067:127
# съехать:В:Acc:кювет:1290:119
# входить:В:Acc:состав:205921:33260
# входить:ПОСЛЕ:Gen:реформа:1182:100
# прозвучать:ИЗ:Gen:уста:1398:66
# отвечать:НА:Acc:вопрос:54396:1991
# встать:НА:Loc:путь:3612:201
# побежать:_:Nom:мурашка:2908:363
# вздохнуть:С:Ins:облегчение:8193:354
# отреагировать:_:Ins:образ:2565:330
# собраться:НА:Loc:площадь:4757:512
# развести:_:Ins:рука:9117:140
# развести:В:Acc:сторона:1610:86
# убирать:СО:Gen:стол:1148:118
# попить:_:Par:чай:1180:5
# отказать:ВО:Loc:въезд:1740:187
# следовать:ПОСЛЕ:Gen:ознакомление:1151:127
# уделяться:_:Nom:внимание:32995:314
# оценить:ПО:Dat:достоинство:4830:360
# подавить:С:Ins:труд:1455:85
# кинуть:_:Acc:взгляд:3137:292
# разгореться:С:Ins:сила:1373:5
# перерасти:В:Acc:беспорядок:20904:2046
# вступить:В:Acc:сила:58818:7601
# завести:_:Nom:дело:6185:568
# подать:_:Ins:рука:2614:341
# отложить:В:Acc:сторона:4416:335
# заходить:_:Nom:речь:4482:599
# появиться:НА:Acc:свет:16246:1435
# появляться:НА:Acc:свет:1729:154
# таить:_:Gen:грех:1638:11
# получаться:_:Ins:образ:1302:85
# исключать:_:Acc:возможность:4715:415
# уделять:_:Acc:внимание:50405:1282
# исполняться:В:Loc:год:1127:76
# пригласить:С:Gen:согласие:2113:56
# запереть:_:Acc:дверь:5683:257
# запереть:_:Nom:дверь:2024:179
# думать:ОБ:Loc:угроза:2449:171
# думать:НА:Loc:дело:1083:113
# распределиться:_:Ins:образ:4850:3
# отдать:ПОД:Acc:суд:1728:276
# подхватить:НА:Acc:рука:5457:56
# передавать:_:Ins:путь:2397:331
# передавать:СО:Ins:ссылка:21617:221
# доказать:В:Loc:суд:1974:236
# пообещать:НА:Loc:встреча:1974:178
# защищать:НА:Loc:игра:1829:245
# стартовать:С:Gen:космодром:2704:436
# пробовать:НА:Acc:вкус:1270:162
# переступить:_:Acc:порог:4859:642
# захватить:В:Acc:плен:7164:755
# научиться:_:Dat:многое:2210:207
# позволять:_:Ins:образ:1184:108
# присвоить:В:Acc:честь:1482:212
# присвоить:С:Ins:вручение:2817:52
# подписать:ДО:Gen:конец:1450:52
# подписать:ОТ:Gen:имя:1030:70
# занимать:НА:Acc:момент:2280:346
# уступить:_:Acc:место:10572:1448
# выразить:ОТ:Gen:имя:1975:142
# накрывать:_:Acc:стол:1125:84
# накрывать:НА:Acc:стол:1510:6
# проделать:_:Nom:работа:1860:157
# окунуться:С:Ins:голова:1094:52
# устроиться:НА:Acc:работа:7323:541
# устроиться:В:Loc:кресло:2315:190
# выбрать:НА:Loc:драфт:3515:382
# выбрать:ПОД:Ins:номер:1956:54
# учить:В:Loc:школа:1631:208
# повлиять:_:Ins:образ:1756:46
# бросить:_:Acc:взгляд:34529:5477
# бросить:ПОД:Acc:нога:1119:52
# бросить:ЧЕРЕЗ:Acc:плечо:2431:96
# представлять:С:Gen:точка:1975:282
# достаться:В:Acc:наследство:2399:175
# полюбить:_:Nom:друг:1222:146
# оправдать:_:Nom:суд:2738:232
# продаваться:ПО:Dat:цена:2807:247
# называться:СОГЛАСНО:Dat:карта:1144:26
# ознакомиться:ПО:Dat:адрес:1105:173
# служить:ВО ВРЕМЯ:Gen:война:2314:34
# ставить:ВО:Acc:глава:1285:19
# вырасти:С:Gen:начало:3533:472
# вспомнить:В:Loc:связь:1608:130
# успеть:ЗА:Acc:время:5480:708
# перечислить:НА:Acc:счёт:2886:93
# убедиться:_:Acc:раз:1663:14
# отразить:_:Ins:образ:1211:183
# удостоить:С:Ins:вручение:3686:61
# окружить:СО:Gen:сторона:3126:4
# любить:С:Gen:детство:1177:91
# основать:_:Loc:.:1088:34
# основать:ПОД:Ins:название:1321:151
# учредить:С:Ins:цель:1553:223
# прилагать:_:Acc:усилие:18994:488
# распространить:В КАЧЕСТВЕ:Gen:документ:2159:35
# выполнять:_:Ins:образ:1727:208
# решать:В СООТВЕТСТВИИ С:Ins:право:1268:23
# сказаться:_:Ins:образ:2147:147
# сохранить:НА:Loc:уровень:3458:293
# отслужить:В:Loc:армия:1231:160
# отличиться:НА:Loc:минута:1404:90
# называть:ПО:Dat:имя:2843:350
# побывать:В ХОДЕ:Gen:визит:5357:33
# слушать:В:Loc:программа:2277:236
# выступать:ОТ:Gen:имя:11997:319
# почтить:_:Acc:память:7477:33
# записаться:ДЛЯ:Gen:выступление:1371:83
# учитываться:_:Ins:образ:1059:151
# запустить:НА:Acc:орбита:1100:179
# разделиться:_:Nom:мнение:3231:412
# обойтись:В:Acc:сумма:2232:325
# обойтись:К:Dat:счастие:1112:121
# подбирать:_:Acc:слово:4314:370
# воспитываться:_:Nom:ребёнок:2134:124
# открываться:ИЗ:Gen:окно:1504:30
# поговорить:НА:Acc:тема:1241:91
# сдавать:В:Acc:аренда:3578:124
# изучать:ПОД:Ins:руководство:1080:101
# преследовать:_:Acc:цель:15606:1618
# возглавить:НА:Loc:выбор:1279:102
# мечтать:С:Gen:детство:1397:168
# сменить:НА:Loc:пост:12340:1436
# спрятать:В:Acc:карман:1933:263
# разработать:ПОД:Ins:руководство:2345:341
# прозвенеть:_:Nom:звонок:1296:164
# подводить:_:Acc:итог:12589:474
# пропустить:МИМО:Gen:ухо:2730:31
# защитить:_:Acc:диссертация:22081:2604
# защитить:ПОД:Ins:руководство:1919:5
# сыграть:_:Acc:роль:75031:4421
# передаваться:_:Ins:путь:1722:273
# расчесать:_:Acc:волос:1090:39
# повернуть:_:Acc:голова:17393:2236
# повернуть:В:Acc:сторона:5066:219
# выглядеть:_:Ins:образ:9104:651
# выглядеть:НА:Loc:фон:5882:886
# подняться:С:Ins:труд:1788:177
# взыскать:_:Nom:суд:1238:195
# взыскать:_:Gen:рубль:2842:264
# взыскать:В:Acc:польза:2096:255
# ввести:С:Ins:цель:1124:128
# назреть:_:Nom:необходимость:1788:292
# послать:К:Dat:чёрт:1082:123
# задать:_:Acc:вопрос:35590:918
# задать:_:Nom:вопрос:3874:366
# въехать:НА:Acc:территория:1902:235
# въехать:ВО:Acc:двор:1025:43
# зарегистрироваться:НА:Loc:сайт:13389:177
# переместить:_:Gen:страна:5316:18
# уделить:_:Nom:внимание:11539:246
# уделить:_:Acc:внимание:19181:814
# рисковать:_:Ins:жизнь:5695:510
# подходить:НА:Acc:роль:1467:167
# определяться:С:Ins:учёт:1149:184
# заручиться:_:Ins:поддержка:11318:994
# казаться:НА:Loc:фон:1790:256
# казаться:НА:Acc:взгляд:3869:223
# победить:НА:Loc:выбор:14251:1365
# победить:ВО:Loc:тур:1311:187
# победить:ВО:Acc:раз:1141:48
# запомнить:НА:Acc:жизнь:1778:166
# удаваться:С:Ins:труд:1405:86
# теряться:В:Loc:догадка:1942:173
# надеяться:_:Ins:образ:1249:125
# надеяться:ПО:Dat:слово:1100:113
# перевести:ПОД:Acc:арест:1311:145
# набирать:В:Loc:среднее:2107:214
# опуститься:В:Acc:кресло:3259:296
# откладывать:_:Nom:самка:1738:240
# отстаивать:В:Loc:суд:1078:136
# обозначить:НА:Loc:карта:6738:320
# тронуть:_:Nom:улыбка:1541:228
# воплотить:В:Acc:жизнь:4862:640
# повесить:_:Acc:трубка:7033:560
# учесть:_:Ins:образ:1126:95
# скачать:С:Gen:сайт:1036:62
# уточнять:СО:Ins:ссылка:1407:1
# переполнить:_:Acc:чаша:1210:91
# вписать:В:Acc:история:1132:176
# планировать:В:Acc:время:2932:428
# планировать:ДО:Gen:конец:1558:61
# одержать:_:Acc:победа:56575:2980
# владеть:ПО:Dat:данные:1494:221
# держаться:ЗА:Acc:рука:3773:551
# прокомментировать:_:Ins:образ:1908:299
# претерпеть:_:Acc:изменение:6298:444
# повыситься:ПО:Dat:итог:3198:331
# исполниться:В:Loc:год:1762:220
# означать:В:Loc:перевод:7799:1281
# даваться:С:Ins:труд:2526:65
# рассчитать:НА:Loc:основа:1862:200
# определять:ВО:Loc:многое:1233:21
# определять:_:Ins:образ:1200:178
# складываться:_:Ins:образ:1305:171
# наполнить:ДО:Gen:край:1053:153
# развеваться:НА:Loc:ветер:1156:50
# удостоиться:БЛАГОДАРЯ:Dat:череда:1699:23
# постучаться:В:Acc:дверь:1321:152
# оказываться:_:Acc:раз:1539:242
# качать:_:Ins:голова:6697:87
# содействовать:_:Ins:образ:1230:60
# производить:_:Acc:впечатление:12684:1766
# заявлять:_:Acc:раз:3290:429
# прогнозировать:НА:Loc:уровень:1291:102
# окружать:СО:Gen:сторона:1182:4
# сводить:С:Ins:конец:1967:171
# сводить:С:Gen:ум:6541:32
# насчитываться:НА:Loc:территория:2160:128
# насчитываться:ПРИ:Loc:плотность:1531:32
# понимать:ДО:Gen:конец:1088:25
# распределить:_:Ins:образ:1209:13
# подышать:_:Ins:воздух:2967:65
# претворить:В:Acc:жизнь:2701:121
# зажить:_:Ins:жизнь:1066:36
# лишиться:В:Loc:результат:2740:398
# транслироваться:В:Loc:эфир:1813:216
# чувствовать:ПО:Dat:слово:1080:99
# освятить:В:Acc:честь:2083:105
# освятить:ВО:Acc:имя:1211:8
# меняться:В:Loc:зависимость:3180:367
# меняться:СО:Ins:время:1084:63
# забросить:_:Acc:шайба:3793:323
# функционировать:ПО:Dat:данные:1216:159
# привлекать:_:Acc:внимание:17205:1717
# пересмотреть:В:Acc:сторона:2090:208
# разместить:_:Acc:материал:12521:1416
# спасаться:_:Ins:бегство:2620:86
# доводиться:ДО:Gen:сведение:2395:49
# совпасть:ПО:Dat:время:2393:77
# воплощать:В:Acc:жизнь:1640:176
# забить:НА:Loc:минута:6299:305
# расставить:ПО:Dat:место:1900:214
# зарабатывать:НА:Acc:жизнь:6324:645
# прокатиться:_:Nom:волна:3769:131
# отлучить:ОТ:Gen:церковь:1215:84
# обусловить:ВО:Loc:многое:1555:7
# воздавать:_:Acc:должное:1388:159
# санкционировать:_:Nom:суд:2054:232
# допускаться:В:Loc:случай:1343:104
# крутиться:В:Loc:голова:2511:146
# водить:ЗА:Acc:нос:1690:111
# разговаривать:ПО:Dat:телефон:4546:173
# разговаривать:НА:Loc:язык:2150:149
# слушаться:_:Nom:дело:1491:212
# жать:_:Acc:рука:1359:206
# отставать:_:Nom:компания:1999:281
# унаследовать:ПОСЛЕ:Gen:смерть:2657:135
# окутать:_:Nom:туман:1741:272
# окутать:_:Acc:столица:1519:185
# глядеть:_:Nom:глаз:3089:453
# дополнять:_:Nom:друг:3543:179
# раскинуть:_:Acc:рука:3371:350
# прилагаться:_:Nom:усилие:2564:307
# озаботить:_:Nom:комитет:1965:251
# бросаться:В:Acc:глаз:7837:313
# оспаривать:В:Loc:суд:1522:125
# взлететь:НА:Acc:воздух:1656:254
# разрушить:В:Loc:результат:5073:278
# разрушить:ДО:Gen:основание:1113:37
# говориться:НА:Loc:сайт:7842:690
# пожать:_:Ins:плечо:46744:151
# пожать:_:Acc:рука:13117:318
# влиять:_:Ins:образ:1986:77
# присоединить:_:Dat:с:1013:26
# пустить:В:Acc:ход:3750:609
# упразднить:ПОСЛЕ:Gen:установление:1205:112
# упразднить:ПО:Dat:постановление:1113:40
# форсировать:_:Acc:река:3224:335
# улыбнуться:_:Ins:улыбка:3806:548
# улыбнуться:В:Acc:ответ:6546:292
# подрабатывать:_:Ins:таксист:1532:116
# подрабатывать:_:Nom:президент:1464:39
# подрабатывать:В:Loc:начало:1471:89
# подрабатывать:ПО:Dat:слово:1478:76
# опубликовать:ВО:Acc:вторник:1612:8
# научить:_:Dat:многое:1496:213
# захватывать:_:Nom:дух:1446:126
# слышаться:В:Loc:голос:4124:272
# выручить:ОТ:Gen:продажа:2728:138
# лететь:СО:Ins:скорость:1501:42
# сойтись:ВО:Loc:мнение:2506:27
# придаваться:_:Nom:значение:3049:93
# смотреться:НА:Loc:фон:1828:127
# почистить:_:Acc:зуб:1323:106
# свести:С:Gen:ум:2867:197
# перевернуть:С:Gen:нога:1232:41
# сказываться:_:Ins:образ:1497:12
# удовлетворять:_:Acc:потребность:5625:607
# нажимать:_:Acc:кнопка:2218:274
# сравнять:_:Acc:счёт:8700:73
# сравнять:НА:Loc:минута:1075:21
# тряхнуть:_:Ins:голова:6478:525
# влюбиться:С:Gen:взгляд:1466:29
# стрелять:ПО:Dat:бандит:3286:462
# стрелять:НА:Acc:поражение:7659:161
# тренироваться:ПОД:Ins:руководство:1348:38
# ловить:НА:Loc:мысль:1891:310
# удостоверять:_:Acc:личность:3033:260
# прогнозироваться:НА:Loc:уровень:1247:69
# спустить:НА:Acc:вода:10765:589
# распределяться:_:Ins:образ:1758:16
# похоронить:НА:Loc:кладбище:30769:479
# запасть:В:Acc:душа:1122:151
# оскорблять:_:Acc:чувство:2717:420
# покрываться:_:Nom:расход:2252:248
# слепить:_:Acc:глаз:1368:140
# заразиться:_:Ins:коронавирус:7464:1101
# заразиться:С:Gen:начало:6641:11
# заразиться:ВО:Loc:мир:1276:13
# сослужить:_:Acc:служба:1882:34
# махнуть:В:Acc:сторона:3413:318
# махнуть:_:Ins:рука:27871:359
# наполниться:_:Ins:слеза:2634:306
# поведать:_:Acc:история:1937:221
# нажать:_:Acc:кнопка:9336:732
# вынуть:ИЗ:Gen:карман:4380:480
# разорвать:В:Acc:клок:1312:173
# возвести:ПО:Dat:проект:1335:175
# воздержаться:ПРИ:Loc:голосование:1676:24
# выкинуть:ИЗ:Gen:голова:2188:192
# вводить:В:Acc:заблуждение:5127:790
# консультировать:ПО:Dat:вопрос:2087:53
# добавить:_:Dat:инвестор:1182:96
# рассуждать:НА:Acc:тема:1038:13
# продлить:ДО:Gen:конец:1888:205
# истекать:_:Ins:кровь:3387:281
# лить:_:Nom:дождь:1880:152
# пожинать:_:Acc:плод:1367:90
# разложить:НА:Loc:стол:1767:289
# постучать:В:Acc:дверь:9209:490
# сдерживать:С:Ins:труд:3158:35
# заносить:В:Acc:отчёт:5053:199
# сжечь:ВО ВРЕМЯ:Gen:война:1016:24
# склонить:_:Acc:голова:11278:407
# реагировать:_:Ins:образ:1412:44
# поймать:НА:Loc:мысль:3460:552
# отклонить:_:Nom:суд:9699:1225
# анализировать:В:Loc:интервью:9575:171
# поверить:В:Loc:дело:1372:79
# поверить:НА:Acc:слово:1779:104
# въезжать:НА:Acc:территория:1182:64
# лезть:_:Nom:мысль:1007:160
# лезть:ИЗ:Gen:кожа:1597:60
# зачесть:_:Acc:доля:1887:212
# зачесть:_:Gen:сумма:1094:10
# зачесть:В:Acc:счёт:2119:127
# скорректировать:С:Ins:учёт:1673:102
# сообщаться:НА:Loc:сайт:61958:2010
# сообщаться:В:Loc:пресс-релиз:14010:2228
# сообщаться:СО:Ins:ссылка:1272:8
# вспыхнуть:С:Ins:сила:1363:17
# вспыхнуть:ПОСЛЕ:Gen:повышение:19678:346
# задаваться:_:Ins:вопрос:11891:140
# акцентировать:_:Acc:внимание:4434:81
# изъявить:_:Acc:желание:5005:802
# трястись:_:Nom:рука:2041:203
# колотиться:_:Nom:сердце:5060:58
# прогреться:_:Nom:воздух:3934:170
# сменять:_:Nom:друг:4394:64
# унижать:_:Acc:достоинство:16582:253
# приземлиться:_:Nom:самолёт:4754:648
# приземлиться:В:Loc:аэропорт:3555:314
# оштрафовать:_:Nom:суд:2260:293
# оштрафовать:НА:Acc:сумма:1259:26
# попасться:ПОД:Acc:рука:2096:147
# различаться:В:Loc:зависимость:1641:271
# обеспокоить:_:Nom:комитет:7178:697
# сбрасывать:СО:Gen:счёт:1059:68
# оглядываться:ПО:Dat:сторона:3885:13
# убедить:В:Loc:необходимость:3870:573
# проследить:ЗА:Ins:взгляд:1868:210
# претерпевать:_:Acc:изменение:1931:95
# сформулировать:_:Ins:образ:2188:258
# удариться:_:Ins:голова:3463:365
# истечь:_:Nom:срок:8585:881
# увенчать:_:Nom:щит:2092:77
# издаваться:НА:Loc:язык:1030:92
# прижимать:К:Dat:грудь:4037:408
# прибрать:К:Dat:рука:2394:6
# расследоваться:_:Nom:дело:2559:242
# транслировать:В:Loc:эфир:1112:136
# символизировать:_:Nom:цвет:2349:368
# отвлекать:_:Acc:внимание:2280:269
# затруднить:_:Nom:движение:2311:351
# равняться:ПО:Dat:данные:1816:105
# подешеветь:ПО:Dat:итог:1435:173
# встряхнуть:_:Ins:голова:1601:211
# отступить:В:Acc:сторона:1951:194
# отступить:НА:Acc:шаг:3447:397
# подсчитывать:_:Acc:ущерб:2990:411
# приводиться:НА:Loc:сайт:1746:189
# выстроиться:_:Nom:очередь:1912:174
# обстрелять:ЗА:Acc:сутки:1056:122
# повернуться:В:Acc:сторона:3494:319
# загадать:_:Acc:желание:1434:118
# затаить:_:Acc:дыхание:9713:668
# кружиться:_:Nom:голова:6265:331
# взглянуть:_:Acc:раз:2800:128
# понести:В:Loc:результат:3144:498
# прогреметь:_:Nom:взрыв:13422:667
# пожимать:_:Ins:плечо:3580:32
# пожимать:_:Acc:рука:3596:102
# рожать:_:Acc:ребёнок:2866:189
# читаться:НА:Loc:лицо:1656:81
# замести:_:Acc:след:1444:47
# тронуться:С:Gen:место:2784:10
# тронуться:В:Acc:путь:1760:147
# преподать:_:Acc:урок:1977:30
# расчёсывать:_:Acc:волос:1523:73
# отставить:В:Acc:сторона:1550:52
# махать:_:Ins:рука:6833:592
# растянуться:В:Loc:улыбка:1036:101
# напасть:С:Ins:нож:1979:216
# присягнуть:НА:Acc:верность:1623:16
# обвить:_:Ins:рука:4087:475
# вериться:С:Ins:труд:2215:11
# дерзить:_:Acc:пари:1761:218
# ломать:_:Acc:голова:5018:532
# закатать:_:Acc:рукав:1114:86
# выучить:_:Acc:язык:2647:326
# сломя:_:Acc:голова:2379:5
# пригрозить:В:Loc:случай:1679:106
# устраиваться:НА:Acc:работа:1907:310
# выслать:ИЗ:Gen:страна:3221:130
# кивать:_:Ins:голова:3753:69
# допросить:ПО:Dat:дело:1644:176
# обвинить:ВО ВРЕМЯ:Gen:пресс-конференция:1514:143
# раскрасить:В:Acc:цвет:1158:44
# заметать:_:Acc:след:1256:58
# рассыпаться:_:Nom:волос:1483:242
# рассыпаться:ПО:Dat:плечо:1872:307
# реформировать:_:Acc:система:1529:236
# пробить:В:Acc:угол:1149:121
# оспорить:В:Loc:суд:4286:317
# понизиться:ПО:Dat:итог:2498:99
# вооружить:ДО:Gen:зуб:1927:5
# сулить:_:Nom:сон:1357:143
# увенчаться:_:Ins:успех:4570:109
# предвещать:_:Nom:сон:4102:118
# затащить:В:Acc:постель:1680:249
# биться:_:Nom:сердце:8024:528
# возбуждать:_:Acc:дело:4415:387
# свалить:_:Acc:вина:1111:183
# баллотироваться:НА:Loc:выбор:2114:29
# покрывать:_:Ins:поцелуй:2820:462
# сходиться:ВО:Loc:мнение:3913:42
# трещать:ПО:Dat:шов:1467:24
# вдохнуть:_:Ins:грудь:1112:37
# сжать:В:Acc:кулак:2702:179
# кружить:_:Acc:голова:1510:135
# перебросить:В:Acc:район:1361:175
# разблокировать:_:Acc:аккаунт:1042:131
# разблокировать:_:Nom:twitter:1017:92
# отбросить:В:Acc:сторона:4237:120
# претворять:В:Acc:жизнь:2120:30
# отсидеть:В:Loc:тюрьма:1797:127
# выхватить:У:Gen:демократ:1030:28
# запирать:_:Acc:дверь:1128:101
# покатиться:_:Nom:слеза:1387:182
# рвануть:С:Gen:место:1491:24
# отвергать:_:Acc:обвинение:6684:836
# закружиться:_:Nom:голова:6435:129
# отодвинуть:В:Acc:сторона:2246:61
# двинуться:В:Loc:направление:1300:148
# вскружить:_:Acc:голова:1877:5
# вторгнуться:НА:Acc:территория:2257:187
# отходить:В:Acc:сторона:1034:82
# вмешиваться:ВО:Acc:дело:1033:104
# конкурировать:НА:Loc:рынок:1595:115
# приписываться:_:Nom:авторство:1165:170
# нагнетать:С:Ins:цель:1394:2
# завернуть:ЗА:Acc:угол:1496:169
# рассказываться:_:Nom:история:1066:22
# тыкать:_:Ins:палец:2817:303
# отречься:ОТ:Gen:престол:2280:230
# натолкнуть:НА:Acc:мысль:1139:187
# потрясти:_:Ins:голова:1983:182
# потрясти:ДО:Gen:глубина:1095:164
# потемнеть:В:Loc:глаз:2168:47
# валиться:С:Gen:нога:1105:60
# вменять:В:Acc:вина:1360:174
# устоять:НА:Loc:нога:1235:102
# разливаться:ПО:Dat:тело:1333:92
# скандировать:_:Acc:лозунг:2030:233
# заострить:_:Acc:внимание:1652:60
# приписать:_:Acc:деревня:1027:134
# бытовать:_:Nom:мнение:1898:152
# покрасить:В:Acc:цвет:1697:36
# подорвать:_:Nom:законопроект:3688:514
# подорвать:НА:Loc:фон:3697:119
# придерживать:_:Ins:рука:1220:125
# отвлечь:_:Acc:внимание:5905:334
# разлиться:ПО:Dat:тело:1515:181
# приподняться:НА:Loc:локоть:2471:211
# отвиснуть:_:Nom:челюсть:1231:70
# окрасить:В:Acc:цвет:5536:823
# процедить:СКВОЗЬ:Acc:зуб:3907:31
# залегать:НА:Loc:глубина:1272:102
# наклонить:_:Acc:голова:8032:92
# протягивать:_:Acc:рука:6619:241
# тикать:_:Nom:час:1503:87
# узаконить:_:Acc:отношение:1168:149
# сдаться:В:Acc:плен:2475:126
# отдёрнуть:_:Acc:рука:3004:353
# захлопнуться:_:Nom:дверь:4078:417
# сконструировать:_:Ins:образ:1024:81
# захлестнуть:_:Nom:волна:2565:293
# блестеть:_:Nom:глаз:4627:626
# мерить:_:Ins:шаг:1829:161
# присниться:_:Nom:сон:3055:313
# улыбаться:_:Ins:улыбка:1644:269
# улыбаться:В:Acc:ответ:1263:155
# вилять:_:Ins:хвост:2411:247
# брызнуть:ИЗ:Gen:глаз:1090:173
# скрестить:НА:Loc:грудь:6379:83
# помахать:_:Ins:рука:7728:566
# уцелеть:_:Ins:чудо:1453:58
# приспустить:_:Nom:флаг:1135:17
# обнять:_:Ins:рука:1578:172
# напоминаться:_:Dat:делегация:1286:19
# дислоцировать:НА:Loc:территория:1632:238
# проноситься:В:Loc:голова:1003:92
# нокаутировать:В:Loc:раунд:1259:139
# постричь:В:Acc:монашество:1885:279
# подслушать:_:Acc:разговор:1585:256
# свергнуть:В:Loc:результат:1509:92
# подливать:_:Acc:масло:1221:155
# подливать:В:Acc:огонь:1274:93
# разрываться:_:Nom:сердце:2041:309
# пересохнуть:В:Loc:горло:1962:33
# стереть:С:Gen:лицо:3784:343
# стереть:ИЗ:Gen:память:1007:46
# пристегнуть:_:Acc:ремень:1108:75
# отлететь:В:Acc:сторона:1468:131
# лаять:_:Nom:собака:1127:116
# осаждать:_:Nom:мигрант:1658:162
# переключить:_:Acc:внимание:2809:225
# сдуть:_:Ins:ветер:1067:35
# осмотреться:ПО:Dat:сторона:1139:6
# вытереть:СО:Gen:лоб:1096:79
# выкатиться:ЗА:Acc:предел:1380:49
# покачать:_:Ins:голова:55097:93
# зачитывать:ДЛЯ:Gen:пенсия:1962:37
# оглянуться:ПО:Dat:сторона:1582:18
# оглянуться:ЧЕРЕЗ:Acc:плечо:1121:9
# отпереть:_:Acc:дверь:2065:312
# поплыть:ПЕРЕД:Ins:глаз:1599:31
# выкрасить:В:Acc:цвет:3233:88
# выкрасить:_:Ins:краска:1015:42
# раскалываться:_:Nom:голова:1617:33
# балансировать:НА:Loc:грань:1763:264
# усыновлять:_:Acc:ребёнок:1053:123
# мотать:_:Ins:голова:1973:33
# охладить:_:Acc:пыл:1162:146
# восторжествовать:_:Nom:справедливость:1066:167
# потирать:_:Acc:рука:2909:364
# обставить:_:Ins:мебель:1258:90
# создаться:_:Nom:впечатление:2454:391
# отбрасывать:_:Acc:тень:1971:264
# топтаться:НА:Loc:место:1287:92
# поднести:КО:Dat:рот:1578:143
# скоротать:_:Acc:время:1129:106
# воздать:_:Acc:должное:1907:217
# отскочить:В:Acc:сторона:1666:72
# сузиться:_:Nom:глаз:2756:197
# окраситься:В:Acc:цвет:1015:168
# пронестись:В:Loc:голова:4439:396
# влачить:_:Acc:существование:1136:65
# попытать:_:Gen:счастие:1672:52
# созывать:_:Ins:делегация:4027:107
# передёрнуть:_:Ins:плечо:2514:81
# передёрнуть:_:Acc:затвор:1077:40
# растягивать:_:Acc:слово:1840:259
# загладить:_:Acc:вина:1517:127
# хлопнуть:В:Acc:ладоши:1576:77
# замотать:_:Ins:голова:2901:128
# щёлкнуть:_:Nom:замок:1388:193
# засунуть:_:Acc:рука:4055:568
# скрипеть:_:Ins:зуб:1368:91
# округлить:_:Acc:глаз:1700:29
# кивнуть:_:Ins:голова:9154:58
# забиться:_:Nom:сердце:9511:212
# забиться:В:Acc:угол:1541:213
# побледнеть:_:Nom:лицо:1275:187
# обусловливать:_:Acc:необходимость:1723:134
# возбуждаться:_:Nom:дело:1153:142
# подлить:_:Acc:масло:1904:79
# подлить:В:Acc:огонь:2105:72
# обозревать:_:Gen:ru:2226:1
# затрясти:_:Ins:голова:1065:62
# качнуть:_:Ins:голова:2573:76
# переправиться:ЧЕРЕЗ:Acc:река:1609:124
# переправиться:НА:Acc:берег:1510:148
# засучить:_:Acc:рукав:1167:17
# валять:_:Acc:дурак:1283:62
# ассигновать:_:Acc:сумма:2111:159
# закатить:_:Acc:глаз:4258:459
# скосить:_:Acc:глаз:2443:372
# препроводить:_:Ins:настоящее:1008:48
# вертеться:В:Loc:голова:1602:105
# глянуть:НА:Acc:час:1425:165
# вскочить:НА:Acc:нога:7972:581
# морочить:_:Acc:голова:1638:21
# обвести:ВОКРУГ:Gen:палец:1873:14
# пожурить:_:Acc:ученик:1459:16
# пожурить:_:Nom:директор:1456:23
# откинуться:В:Loc:кресло:2298:133
# улучить:_:Acc:момент:1675:197
# переставлять:_:Acc:нога:1441:53
# вздрогнуть:ОТ:Gen:неожиданность:2604:382
# метнуть:_:Acc:взгляд:2294:309
# оглядеться:ПО:Dat:сторона:4226:5
# метнуться:В:Acc:сторона:1060:137
# повертеть:В:Loc:рука:1626:180
# ткнуть:_:Ins:палец:7290:411
# пробормотать:ПОД:Acc:нос:1439:1
# переминаться:С:Gen:нога:2524:44
# переминаться:НА:Acc:нога:2505:44
# закивать:_:Ins:голова:1659:41
# зазвонить:_:Nom:телефон:8179:289
# шепнуть:НА:Acc:ухо:1949:301
# распахнуться:_:Nom:дверь:9723:928
# подвернуться:ПОД:Acc:рука:1083:78
# стукнуть:_:Ins:кулак:1758:271
# бормотать:ПОД:Acc:нос:2045:1
# вертеть:В:Loc:рука:2130:289
# вертеть:_:Ins:голова:1853:135
# хлопать:В:Acc:ладоши:1638:91
# всплеснуть:_:Ins:рука:3896:47
# окинуть:_:Ins:взгляд:16376:919
# прошептать:НА:Acc:ухо:3215:297
# замахать:_:Ins:рука:3687:132
# отвориться:_:Nom:дверь:4215:136
# сверкнуть:_:Ins:глаз:3024:444
# помотать:_:Ins:голова:4121:13
# упереть:_:Acc:рука:1651:160
# заломить:_:Acc:рука:1110:180
# расплыться:В:Loc:улыбка:4672:144
# вытаращить:_:Acc:глаз:2506:28
# прислонить:К:Dat:стена:1171:159
# шмыгнуть:_:Ins:нос:1846:20
# подпрыгнуть:_:Nom:сердце:1028:86
# прислониться:_:Ins:спина:3184:408
# захлопать:В:Acc:ладоши:1560:76
# взъерошить:_:Acc:волос:1832:69
# окидывать:_:Ins:взгляд:1783:124
# озираться:ПО:Dat:сторона:2668:5
# мотнуть:_:Ins:голова:4154:35
# подкашиваться:_:Nom:нога:1182:129
# скрипнуть:_:Nom:дверь:1619:206
# скрипнуть:_:Ins:зуб:1876:115
# запрокинуть:_:Acc:голова:4142:114
# загибать:_:Acc:палец:1028:32
# заламывать:_:Acc:рука:1032:90
# побрать:_:Nom:чёрт:15822:171
# пригладить:_:Acc:волос:2313:111
# забыться:_:Ins:сон:1004:15
# совать:_:Acc:нос:2112:170
# наворачиваться:НА:Acc:глаз:1070:3
# наворачиваться:_:Nom:слеза:1361:14
# взбрести:В:Acc:голова:2026:24
# видать:_:Acc:вид:2610:56
# воспрянуть:_:Ins:дух:1226:7
# разболеться:_:Nom:голова:1467:126
# смерить:_:Ins:взгляд:4107:51
# нахмурить:_:Acc:бровь:2558:352
# топать:_:Ins:нога:1008:146
# отворить:_:Acc:дверь:2189:163
# закусить:_:Acc:губа:6074:314
# округлиться:_:Nom:глаз:2378:83
# заколотиться:_:Nom:сердце:2658:15
# начистить:ДО:Gen:блеск:1097:7
# выговаривать:_:Acc:слово:1603:98
# выпучить:_:Acc:глаз:1750:26
# простыть:_:Nom:след:1532:8
# навернуться:_:Nom:слеза:3379:10
# навернуться:НА:Acc:глаз:3125:3
# подкоситься:_:Nom:нога:1944:278
# ёкнуть:_:Nom:сердце:1934:39
# застилать:_:Acc:глаз:1476:180
# защемить:_:Nom:сердце:1683:13
# отлечь:ОТ:Gen:сердце:1017:60
# прищурить:_:Acc:глаз:2836:87
# облизнуть:_:Acc:губа:3130:64
# навострить:_:Acc:ухо:1021:147
# обрамлять:_:Acc:лицо:1441:159
# вздыматься:_:Nom:грудь:1648:126
# преисполнить:_:Gen:решимость:3271:106
# превозмогать:_:Acc:боль:1174:85
# зажмурить:_:Acc:глаз:1942:17
# исказиться:_:Nom:лицо:1884:140
# подрать:_:Nom:чёрт:2239:13
# испрашивать:_:Acc:компенсация:1377:184
